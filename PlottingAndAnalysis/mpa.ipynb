# %%
import rs
import os
# !pwd
# Out:
# /Users/frank/Dropbox/My Mac (PN115993.campus.nist.gov)/Documents/programming/molgroups/PlottingAndAnalysis

# %% [markdown]
# ## Define result directory and set up fit source
# The results directory is the save directory for the refl1d/bumps/garefl fit, which is typically one directory level up from the fit setup. If a garefl fit does not use MCMC, give the setup directory.
# The runfile is either the Python or C++ setup file. The refl1d Python runfile for a garefl fit is expected to be run.py.

# %%
# Bumps Test
# setupdir = '/Users/frank/Documents/programming/molgroups/PlottingAndAnalysis'
# mcmcstor = setupdir + '/T1'
# runfile = 'run-ff'
# fitsource = 'bumps'

# Refl1D Test
setupdir = '/Users/frank/Desktop/ssBLMtest'
mcmcstor = setupdir + '/Output'
runfile = 'ssblm_tiox_both'
fitsource = 'refl1d'


# Garefl test
# setupdir = '/Users/frank/Desktop/garefltest'
# mcmcstor = setupdir + '/MCMC_64000_500'
# runfile = 'setup.cc'
# fitsource = 'garefl'

# Clean up previous results files
# TODO: Come up with a scheme on how to handle result files (keep or delete)
os.chdir(setupdir)
if os.path.isfile(mcmcstor + '/sErr.dat'):
    os.remove(mcmcstor + '/sErr.dat')
if os.path.isfile(mcmcstor + '/isErr.dat'):
    os.remove(mcmcstor + '/isErr.dat')
if os.path.isfile(mcmcstor + '/StatDataPython.dat'):
    os.remove(mcmcstor + '/StatDataPython.dat')

fit = rs.CMolStat(fitsource=fitsource, spath=setupdir, mcmcpath=mcmcstor, runfile=runfile)

# %% [markdown]
# ## Load MCMC information bumps / refl1d files

# %%
#fit.fnLoadStatData(sparse=0)
#fit.fnLoadParameters()
sparse = 0.02
fit.fnAnalyzeStatFile(fConfidence=-1, sparse=sparse)
# Out:
# Analysis of current MC simulation ...
# Number of iterations: 66
#           background ch061  [ |  -  |   ]  [    -1e-07,     1e-05]  [ 1.282e-06(0.000),  3.607e-06(0.010),   7.35e-06(0.002)] (- 2.325e-06, + 3.743e-06)
#            intensity ch061  [ |   -  |  ]  [       0.9,      1.05]  [    0.9218(0.001),      0.973(0.004),      1.024(0.001)] (-   0.05123, +   0.05101)
#             siox interface  [  |  -  |  ]  [         2,         9]  [     3.408(0.000),      5.828(0.001),      7.789(0.002)] (-      2.42, +     1.962)
#                   siox rho  [ |  -   |  ]  [       3.1,       5.1]  [     3.356(0.000),      3.972(0.004),      4.711(0.003)] (-    0.6157, +    0.7388)
#             siox thickness  [ |  -  |   ]  [         5,        40]  [     9.314(0.004),      18.29(0.009),      29.59(0.007)] (-     8.976, +      11.3)
#                   tiox rho  [  | - |    ]  [     1.163,     3.163]  [     1.582(0.001),      1.996(0.005),      2.451(0.004)] (-    0.4139, +    0.4549)
#                    d2o rho  [   |  - |  ]  [       5.3,       6.5]  [     5.618(0.001),      5.976(0.012),      6.262(0.004)] (-    0.3577, +    0.2863)
#        substrate roughness  [ |  -    | ]  [         2,         9]  [     2.885(0.004),       5.03(0.015),      8.129(0.002)] (-     2.146, +     3.098)
# inner acyl chain thickness  [ | -    |  ]  [         8,        16]  [     9.044(0.008),      10.76(0.025),      14.38(0.001)] (-     1.713, +     3.626)
# outer acyl chain thickness  [ |   -  |  ]  [         8,        16]  [     8.897(0.006),      11.91(0.003),      14.24(0.010)] (-     3.011, +     2.333)
#      submembrane thickness  [ |   -  |  ]  [         0,        50]  [     5.773(0.011),       27.3(0.016),      40.59(0.000)] (-     21.52, +      13.3)
#          bilayer roughness  [ |   -   | ]  [         2,         9]  [     2.818(0.003),      5.515(0.023),      8.037(0.002)] (-     2.697, +     2.522)
#    volume fraction bilayer  [  |  -  |  ]  [         0,         1]  [    0.1824(0.024),     0.4967(0.006),     0.7986(0.007)] (-    0.3143, +    0.3019)
#           background ch060  [  | -   |  ]  [    -1e-07,     1e-05]  [ 2.214e-06(0.001),  4.234e-06(0.006),  8.374e-06(0.001)] (-  2.02e-06, + 4.141e-06)
#                    h2o rho  [ |  -   |  ]  [      -0.6,       0.6]  [   -0.4511(0.001),   -0.06307(0.012),     0.3046(0.005)] (-    0.3881, +    0.3677)
#       total tiox thickness  [    | -  | ]  [        50,       150]  [     90.94(0.001),      114.5(0.004),      135.8(0.000)] (-     23.59, +     21.24)
# Maximum deviation from average over last 5 iterations: 0.0384
# Confidence level: 0.6827

# %%
fit.fnPullMolgroup(['lipid1'], sparse=sparse)
# Out:
# Failure to load StatDataPython.dat.
# Recreate statistical data from sErr.dat.
# Processing parameter set 0.
#
# 248.44848382095915
# 121.37245253091443
# Processing parameter set 1.
#
# 440.1594706543934
# 384.659226947364
# Processing parameter set 2.
#
# 279.4469658043717
# 68.6346292039432
# Processing parameter set 3.
#
# 408.2893582374347
# 376.49480417552
# Processing parameter set 4.
#
# 597.0672269631159
# 140.3509967413692
# Processing parameter set 5.
#
# 346.99457569080505
# 696.3392785666066
# Processing parameter set 6.
#
# 187.79327792154558
# 42.32625970447002
# Processing parameter set 7.
#
# 127.56853628954703
# 104.93891974370426
# Processing parameter set 8.
#
# 271.43897002583816
# 137.08474008465228
# Processing parameter set 9.
#
# 461.69461204720454
# 58.88124238474945
# Processing parameter set 10.
#
# 355.4943874848151
# 648.0934400088486
# Processing parameter set 11.
#
# 283.90422517340704
# 170.89068719625473
# Processing parameter set 12.
#
# 224.56280040100287
# 27.08207720117074
# Processing parameter set 13.
#
# 393.99878521607025
# 560.2226559883228
# Processing parameter set 14.
#
# 469.4372366312376
# 499.1806855001095
# Processing parameter set 15.
#
# 340.1709822660303
# 7.3910550169097995
# Processing parameter set 16.
#
# 248.13686509439017
# 123.59804771835593
# Processing parameter set 17.
#
# 387.39415495656556
# 247.59173034925595
# Processing parameter set 18.
#
# 163.0553990964638
# 251.20792891825616
# Processing parameter set 19.
#
# 373.31242736707696
# 701.5274910867518
# Processing parameter set 20.
#
# 155.13568125920398
# 165.30716524958365
# Processing parameter set 21.
#
# 202.98235313341516
# 89.05559049012626
# Processing parameter set 22.
#
# 271.8847476815076
# 27.152775856016028
# Processing parameter set 23.
#
# 378.2776204510186
# 145.16858863311367
# Processing parameter set 24.
#
# 165.73100516270082
# 13.303719244877081
# Processing parameter set 25.
#
# 249.8149796146711
# 98.12353494380007
# Processing parameter set 26.
#
# 292.6703485211057
# 31.561601703407256
# Processing parameter set 27.
#
# 152.72763957574804
# 67.4424932965647
# Processing parameter set 28.
#
# 187.14120359079288
# 45.74323491417835
# Processing parameter set 29.
#
# 281.57854601226904
# 520.5491252907415
# Processing parameter set 30.
#
# 448.44918655183255
# 199.4641133760793
# Processing parameter set 31.
#
# 152.6827783054206
# 106.45539643526959
# Processing parameter set 32.
#
# 193.18283427880704
# 48.62507800638314
# Processing parameter set 33.
#
# 462.9419938340372
# 172.63311781371516
# Processing parameter set 34.
#
# 187.60674144084606
# 97.27301048660458
# Processing parameter set 35.
#
# 311.02456503752944
# 32.94559361155751
# Processing parameter set 36.
#
# 206.34348119729793
# 80.14357675462387
# Processing parameter set 37.
#
# 194.64419358364424
# 34.63925387200225
# Processing parameter set 38.
#
# 114.75405696186587
# 35.06248545146036
# Processing parameter set 39.
#
# 259.51524421833136
# 21.61626226643861
# Processing parameter set 40.
#
# 196.22692548959233
# 70.8668436838593
# Processing parameter set 41.
#
# 180.28513987092296
# 54.593759790371415
# Processing parameter set 42.
#
# 194.64419358364424
# 34.63925387200225
# Processing parameter set 43.
#
# 91.89593735394125
# 61.97347157468698
# Processing parameter set 44.
#
# 125.46314077101908
# 95.97242653353801
# Processing parameter set 45.
#
# 221.58031908623434
# 35.106711564447366
# Processing parameter set 46.
#
# 165.73100516270082
# 13.303719244877081
# Processing parameter set 47.
#
# 225.123454528031
# 58.629353933237866
# Processing parameter set 48.
#
# 246.00160488859268
# 119.44493397266287
# Processing parameter set 49.
#
# 134.28042957241573
# 44.935567060610225
# Processing parameter set 50.
#
# 266.99333554437186
# 17.240415763330148
# Processing parameter set 51.
#
# 134.40017306006706
# 61.75395925652221
# Processing parameter set 52.
#
# 257.18226666070257
# 31.866573905782
# Processing parameter set 53.
#
# 282.6162829346888
# 84.40060647903441
# Processing parameter set 54.
#
# 176.03550421064367
# 96.77834592137002
# Processing parameter set 55.
#
# 129.44162360675662
# 24.681283016921697
# Processing parameter set 56.
#
# 159.46219314999018
# 40.06401886335347
# Processing parameter set 57.
#
# 199.54272356438196
# 59.025256933981325
# Processing parameter set 58.
#
# 66.82880179532985
# 46.06656399928444
# Processing parameter set 59.
#
# 313.3208082031938
# 72.6796156633956
# Processing parameter set 60.
#
# 202.36724610008653
# 59.87614074680427
# Processing parameter set 61.
#
# 213.54692063627962
# 62.67066441906477
# Processing parameter set 62.
#
# 109.28690275659541
# 19.32645301937113

# %%
fit.fnCreateBilayerPlotData()
# Out:
# Initializing ...
# Pulling all molgroups ...
#   substrate ...
# Loaded statistical data from StatDataPython.dat
#   siox ...
# Loaded statistical data from StatDataPython.dat
#   tether ...
# Loaded statistical data from StatDataPython.dat
# Molecular group bME does not exist.
# Molecular group tetherg does not exist.
# Molecular group tether does not exist.
#   innerhg ...
# Loaded statistical data from StatDataPython.dat
#   innerhc ...
# Loaded statistical data from StatDataPython.dat
#   outerhc ...
# Loaded statistical data from StatDataPython.dat
#   outerhg ...
# Loaded statistical data from StatDataPython.dat
#   protein ...
# Loaded statistical data from StatDataPython.dat
# Molecular group protein does not exist.
# Applying corrections ...
#
# Calculating statistics ...
#
# Saving data to bilayerplotdata.dat ...

# %%
fit.fnCalculateMolgroupProperty(fConfidence=-1)
# Out:
# Loaded statistical data from StatDataPython.dat
# Did not find any fractional envelopes ...
# WaterFracHeadgroup1  [     0.546,      0.546,      0.546] (-         0, +         0)
# WaterFracHeadgroup2  [    0.5053,     0.5053,     0.5053] (-         0, +         0)
# WaterFracHydrocarbon  [   0.03223,    0.03223,    0.03223] (-         0, +         0)
# WaterFracLipid1  [   0.03767,    0.03767,    0.03767] (-         0, +         0)
# WaterFracLipid2  [   0.02658,    0.02658,    0.02658] (-         0, +         0)
# WaterFracSubMembrane  [    0.9964,     0.9964,     0.9964] (-         0, +         0)
# defect_hc_AVG  [         0,          0,          0] (-         0, +         0)
# defect_hc_COM  [     1e+05,      1e+05,      1e+05] (-         0, +         0)
# defect_hc_INT  [         0,          0,          0] (-         0, +         0)
# defect_hg_AVG  [         0,          0,          0] (-         0, +         0)
# defect_hg_COM  [     1e+05,      1e+05,      1e+05] (-         0, +         0)
# defect_hg_INT  [         0,          0,          0] (-         0, +         0)
# fAreaPerLipid2  [     75.11,      75.11,      75.11] (-         0, +         0)
# fTotalLipid1Length  [     12.32,      12.32,      12.32] (-         0, +         0)
# fTotalLipid2Length  [     12.32,      12.32,      12.32] (-         0, +         0)
# headgroup1_2_AVG  [         0,          0,          0] (-         0, +         0)
# headgroup1_2_COM  [     1e+05,      1e+05,      1e+05] (-         0, +         0)
# headgroup1_2_INT  [         0,          0,          0] (-         0, +         0)
# headgroup1_3_AVG  [         0,          0,          0] (-         0, +         0)
# headgroup1_3_COM  [     1e+05,      1e+05,      1e+05] (-         0, +         0)
# headgroup1_3_INT  [         0,          0,          0] (-         0, +         0)
# headgroup1_AVG  [      2.14,       2.14,       2.14] (-         0, +         0)
# headgroup1_COM  [     55.37,      55.37,      55.37] (-         0, +         0)
# headgroup1_INT  [     4.274,      4.274,      4.274] (-         0, +         0)
# headgroup2_2_AVG  [         0,          0,          0] (-         0, +         0)
# headgroup2_2_COM  [     1e+05,      1e+05,      1e+05] (-         0, +         0)
# headgroup2_2_INT  [         0,          0,          0] (-         0, +         0)
# headgroup2_3_AVG  [         0,          0,          0] (-         0, +         0)
# headgroup2_3_COM  [     1e+05,      1e+05,      1e+05] (-         0, +         0)
# headgroup2_3_INT  [         0,          0,          0] (-         0, +         0)
# headgroup2_AVG  [      2.14,       2.14,       2.14] (-         0, +         0)
# headgroup2_COM  [     88.26,      88.26,      88.26] (-         0, +         0)
# headgroup2_INT  [     4.274,      4.274,      4.274] (-         0, +         0)
# lipid1_AVG  [     5.508,      5.508,      5.508] (-         0, +         0)
# lipid1_COM  [     65.55,      65.55,      65.55] (-         0, +         0)
# lipid1_INT  [        11,         11,         11] (-         0, +         0)
# lipid2_AVG  [     5.508,      5.508,      5.508] (-         0, +         0)
# lipid2_COM  [     78.09,      78.09,      78.09] (-         0, +         0)
# lipid2_INT  [        11,         11,         11] (-         0, +         0)
# methyl1_AVG  [    0.6587,     0.6587,     0.6587] (-         0, +         0)
# methyl1_COM  [     71.16,      71.16,      71.16] (-         0, +         0)
# methyl1_INT  [     1.315,      1.315,      1.315] (-         0, +         0)
# methyl2_AVG  [    0.6587,     0.6587,     0.6587] (- -1.11e-16, +  1.11e-16)
# methyl2_COM  [     72.47,      72.47,      72.47] (-         0, +         0)
# methyl2_INT  [     1.315,      1.315,      1.315] (-         0, +         0)
# normarea_AVG  [     75.11,      75.11,      75.11] (-         0, +         0)
# normarea_COM  [     74.75,      74.75,      74.75] (-         0, +         0)
# normarea_INT  [       150,        150,        150] (-         0, +         0)
# siox_AVG  [    0.5007,     0.5007,     0.5007] (-         0, +         0)
# siox_COM  [      20.5,       20.5,       20.5] (-         0, +         0)
# siox_INT  [         1,          1,          1] (-         0, +         0)
# substrate_AVG  [     10.14,      10.14,      10.14] (-         0, +         0)
# substrate_COM  [     9.974,      9.974,      9.974] (-         0, +         0)
# substrate_INT  [     20.25,      20.25,      20.25] (-         0, +         0)
