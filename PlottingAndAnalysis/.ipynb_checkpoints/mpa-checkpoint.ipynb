# %%
import rs
# !pwd
# Out:
# /Users/frank/Dropbox/My Mac (PN115993.campus.nist.gov)/Documents/programming/molgroups/PlottingAndAnalysis

# %% [markdown]
# ## Define result directory and set up fit source
# The results directory is the save directory for the refl1d/bumps/garefl fit, which is typically one directory level up from the fit setup. If a garefl fit does not use MCMC, give the setup directory.
# The runfile is either the Python or C++ setup file. The refl1d Python runfile for a garefl fit is expected to be run.py.

# %%
results_dir = 'T1'
runfile = 'run-ff'

#fitsource = 'refl1d'
fitsource = 'bumps'
#fitsource = 'garefl'

fit = rs.CMolStat(fitsource=fitsource, resultspath=results_dir, runfile=runfile)

# %% [markdown]
# ## Load MCMC information bumps / refl1d files

# %%
#fit.fnLoadStatData(sparse=0)
#fit.fnLoadParameters()
sparse = 0.0
fit.fnAnalyzeStatFile(fConfidence=-1, sparse=sparse)
# Out:
# Analysis of current MC simulation ...
# Number of iterations: 12238
#   bulknsld  [     |+    ]  [     9e-06,     1e-05]  [ 9.533e-06(0.000),  9.554e-06(0.000),  9.573e-06(0.000)] (- 2.117e-08, +  1.92e-08)
#         dq  [          +#  [     -0.01,      0.01]  [  0.009834(0.000),   0.009946(0.000),   0.009988(0.000)] (- 0.0001118, + 4.266e-05)
#    l_lipid  [       +   ]  [         9,        13]  [     11.93(0.000),      11.94(0.000),      11.95(0.000)] (-   0.01392, +   0.01232)
#  prefactor  [+          ]  [   1.5e+04,     4e+04]  [ 1.565e+04(0.000),  1.576e+04(0.000),  1.603e+04(0.000)] (-     111.4, +     274.7)
#      sigma  #+          ]  [         1,         4]  [     1.005(0.000),       1.02(0.000),      1.052(0.000)] (-   0.01559, +   0.03181)
# vf_bilayer  [     |  - |]  [      0.95,         1]  [    0.9756(0.000),      0.992(0.000),     0.9985(0.000)] (-   0.01639, +  0.006558)
# Maximum deviation from average over last 5 iterations: 0.0001
# Confidence level: 0.6827

# %%
fit.fnPullMolgroup(['protein'], sparse=sparse)
# Out:
# Failure to load StatDataPython.dat.
# Recreate statistical data from sErr.dat.
# Processing parameter set 0.
#
# 1.6217524542294377
# Processing parameter set 1.
#
# 1.6718970702497247
# Processing parameter set 2.
#
# 1.630069256632842
# Processing parameter set 3.
#
# 1.6384467847972548
# Processing parameter set 4.
#
# 1.6486618489718803
# Processing parameter set 5.
#
# 1.6218321772622744
# Processing parameter set 6.
#
# 1.6455400876260131
# Processing parameter set 7.
#
# 1.6433298650984907
# Processing parameter set 8.
#
# 1.6448848802184395
# Processing parameter set 9.
#
# 1.6725983813857803
# Processing parameter set 10.
#
# 1.6501233195845355
# Processing parameter set 11.
#
# 1.643095548233789
# Processing parameter set 12.
#
# 1.65039341230275
# Processing parameter set 13.
#
# 1.6520282365432533
# Processing parameter set 14.
#
# 1.7431923764882005
# Processing parameter set 15.
#
# 1.8822573340455873
# Processing parameter set 16.
#
# 1.648551264337904
# Processing parameter set 17.
#
# 1.6590308690296864
# Processing parameter set 18.
#
# 1.646735160565497
# Processing parameter set 19.
#
# 1.6375332762205987
# Processing parameter set 20.
#
# 1.6395591194676924
# Processing parameter set 21.
#
# 1.648058152570898
# Processing parameter set 22.
#
# 1.6629106430040106
# Processing parameter set 23.
#
# 1.7215635212112346
# Processing parameter set 24.
#
# 1.645633771457097
# Processing parameter set 25.
#
# 1.689772586367903
# Processing parameter set 26.
#
# 1.7130190866710315
# Processing parameter set 27.
#
# 1.6684219634466209
# Processing parameter set 28.
#
# 1.6593492258506783
# Processing parameter set 29.
#
# 1.6943599938007101
# Processing parameter set 30.
#
# 1.6915509950020484
# Processing parameter set 31.
#
# 1.6245897594628773
# Processing parameter set 32.
#
# 1.632962525086878
# Processing parameter set 33.
#
# 1.6454817015369154
# Processing parameter set 34.
#
# 1.6263185926049726
# Processing parameter set 35.
#
# 1.655684263746622
# Processing parameter set 36.
#
# 1.6406919571502958
# Processing parameter set 37.
#
# 1.6705504520909715
# Processing parameter set 38.
#
# 1.6422011750184262
# Processing parameter set 39.
#
# 1.6379793050826033
# Processing parameter set 40.
#
# 1.6668216903225532
# Processing parameter set 41.
#
# 1.6430499780703218
# Processing parameter set 42.
#
# 1.7072583619595558
# Processing parameter set 43.
#
# 1.674951254838318
# Processing parameter set 44.
#
# 1.6890017036427947
# Processing parameter set 45.
#
# 1.667482310973404
# Processing parameter set 46.
#
# 1.706258858819237
# Processing parameter set 47.
#
# 1.8267552121470434
# Processing parameter set 48.
#
# 1.661080996502301
# Processing parameter set 49.
#
# 1.6966088395756975
# Processing parameter set 50.
#
# 1.62319748172041
# Processing parameter set 51.
#
# 1.6174965366595342
# Processing parameter set 52.
#
# 1.639214025266662
# Processing parameter set 53.
#
# 1.6783953892864034
# Processing parameter set 54.
#
# 1.6380483873124088
# Processing parameter set 55.
#
# 1.628852544755853
# Processing parameter set 56.
#
# 1.6292636734543584
# Processing parameter set 57.
#
# 1.6555158374250194
# Processing parameter set 58.
#
# 1.6217524542294377
# Processing parameter set 59.
#
# 1.6725706161016511
# Processing parameter set 60.
#
# 1.630069256632842
# Processing parameter set 61.
#
# 1.6384467847972548
# Processing parameter set 62.
#
# 1.6486618489718803
# Processing parameter set 63.
#
# 1.6218321772622744
# Processing parameter set 64.
#
# 1.6455400876260131
# Processing parameter set 65.
#
# 1.6433298650984907
# Processing parameter set 66.
#
# 1.6448848802184395
# Processing parameter set 67.
#
# 1.6725983813857803
# Processing parameter set 68.
#
# 1.6501233195845355
# Processing parameter set 69.
#
# 1.6437062635665358
# Processing parameter set 70.
#
# 1.6503589505357001
# Processing parameter set 71.
#
# 1.6520282365432533
# Processing parameter set 72.
#
# 1.7431923764882005
# Processing parameter set 73.
#
# 1.8822573340455873
# Processing parameter set 74.
#
# 1.6472962195681717
# Processing parameter set 75.
#
# 1.6590308690296864
# Processing parameter set 76.
#
# 1.646735160565497
# Processing parameter set 77.
#
# 1.6375332762205987
# Processing parameter set 78.
#
# 1.6402844681555624
# Processing parameter set 79.
#
# 1.648058152570898
# Processing parameter set 80.
#
# 1.6503167585071878
# Processing parameter set 81.
#
# 1.7215635212112346
# Processing parameter set 82.
#
# 1.645633771457097
# Processing parameter set 83.
#
# 1.689772586367903
# Processing parameter set 84.
#
# 1.7130190866710315
# Processing parameter set 85.
#
# 1.6684219634466209
# Processing parameter set 86.
#
# 1.6620693929036954
# Processing parameter set 87.
#
# 1.6943599938007101
# Processing parameter set 88.
#
# 1.6915509950020484
# Processing parameter set 89.
#
# 1.6245897594628773
# Processing parameter set 90.
#
# 1.632962525086878
# Processing parameter set 91.
#
# 1.6454817015369154
# Processing parameter set 92.
#
# 1.6263185926049726
# Processing parameter set 93.
#
# 1.655684263746622
# Processing parameter set 94.
#
# 1.6406919571502958
# Processing parameter set 95.
#
# 1.6705504520909715
# Processing parameter set 96.
#
# 1.6422011750184262
# Processing parameter set 97.
#
# 1.6379793050826033
# Processing parameter set 98.
#
# 1.6668216903225532
# Processing parameter set 99.
#
# 1.6430499780703218
# Processing parameter set 100.
#
# 1.7072583619595558
# Processing parameter set 101.
#
# 1.674951254838318
# Processing parameter set 102.
#
# 1.6890017036427947
# Processing parameter set 103.
#
# 1.667482310973404
# Processing parameter set 104.
#
# 1.706258858819237
# Processing parameter set 105.
#
# 1.8267552121470434
# Processing parameter set 106.
#
# 1.661080996502301
# Processing parameter set 107.
#
# 1.6966088395756975
# Processing parameter set 108.
#
# 1.62319748172041
# Processing parameter set 109.
#
# 1.6174965366595342
# Processing parameter set 110.
#
# 1.639214025266662
# Processing parameter set 111.
#
# 1.6782213979229985
# Processing parameter set 112.
#
# 1.6380483873124088
# Processing parameter set 113.
#
# 1.628852544755853
# Processing parameter set 114.
#
# 1.6292636734543584
# Processing parameter set 115.
#
# 1.6515804875954145
# Processing parameter set 116.
#
# 1.6217524542294377
# Processing parameter set 117.
#
# 1.6725706161016511
# Processing parameter set 118.
#
# 1.630069256632842
# Processing parameter set 119.
#
# 1.6384467847972548
# Processing parameter set 120.
#
# 1.6486618489718803
# Processing parameter set 121.
#
# 1.6218321772622744
# Processing parameter set 122.
#
# 1.6455400876260131
# Processing parameter set 123.
#
# 1.6433298650984907
# Processing parameter set 124.
#
# 1.6448848802184395
# Processing parameter set 125.
#
# 1.6725983813857803
# Processing parameter set 126.
#
# 1.630989943362832
# Processing parameter set 127.
#
# 1.6437062635665358
# Processing parameter set 128.
#
# 1.6503589505357001
# Processing parameter set 129.
#
# 1.6520282365432533
# Processing parameter set 130.
#
# 1.7269418589020147
# Processing parameter set 131.
#
# 1.8822573340455873
# Processing parameter set 132.
#
# 1.6472962195681717
# Processing parameter set 133.
#
# 1.6590308690296864
# Processing parameter set 134.
#
# 1.646735160565497
# Processing parameter set 135.
#
# 1.6375332762205987
# Processing parameter set 136.
#
# 1.6402844681555624
# Processing parameter set 137.
#
# 1.648058152570898
# Processing parameter set 138.
#
# 1.6503167585071878
# Processing parameter set 139.
#
# 1.7215635212112346
# Processing parameter set 140.
#
# 1.645633771457097
# Processing parameter set 141.
#
# 1.677317448844797
# Processing parameter set 142.
#
# 1.7123856879457888
# Processing parameter set 143.
#
# 1.6684219634466209
# Processing parameter set 144.
#
# 1.6620693929036954
# Processing parameter set 145.
#
# 1.6943599938007101
# Processing parameter set 146.
#
# 1.6915509950020484
# Processing parameter set 147.
#
# 1.6245897594628773
# Processing parameter set 148.
#
# 1.632962525086878
# Processing parameter set 149.
#
# 1.6454817015369154
# Processing parameter set 150.
#
# 1.6255973349577515
# Processing parameter set 151.
#
# 1.655684263746622
# Processing parameter set 152.
#
# 1.6406919571502958
# Processing parameter set 153.
#
# 1.6705504520909715
# Processing parameter set 154.
#
# 1.6422011750184262
# Processing parameter set 155.
#
# 1.6379793050826033
# Processing parameter set 156.
#
# 1.6668216903225532
# Processing parameter set 157.
#
# 1.6430499780703218
# Processing parameter set 158.
#
# 1.709498271589269
# Processing parameter set 159.
#
# 1.674951254838318
# Processing parameter set 160.
#
# 1.6890017036427947
# Processing parameter set 161.
#
# 1.667482310973404
# Processing parameter set 162.
#
# 1.706258858819237
# Processing parameter set 163.
#
# 1.8267552121470434
# Processing parameter set 164.
#
# 1.6647983041486845
# Processing parameter set 165.
# 1.6966088395756975
# Processing parameter set 166.
#
# 1.62319748172041
# Processing parameter set 167.
#
# 1.6174965366595342
# Processing parameter set 168.
#
# 1.639214025266662
# Processing parameter set 169.
#
# 1.6782213979229985
# Processing parameter set 170.
#
# 1.6380483873124088
# Processing parameter set 171.
#
# 1.628852544755853
# Processing parameter set 172.
#
# 1.6292636734543584
# Processing parameter set 173.
#
# 1.6515804875954145
# Processing parameter set 174.
#
# 1.6217524542294377
# Processing parameter set 175.
#
# 1.6725706161016511
# Processing parameter set 176.
#
# 1.630069256632842
# Processing parameter set 177.
#
# 1.6384467847972548
# Processing parameter set 178.
#
# 1.6486618489718803
# Processing parameter set 179.
#
# 1.6218321772622744
# Processing parameter set 180.
#
# 1.6467113455613878
# Processing parameter set 181.
#
# 1.6433298650984907
# Processing parameter set 182.
#
# 1.6448848802184395
# Processing parameter set 183.
#
# 1.6725983813857803
# Processing parameter set 184.
#
# 1.630989943362832
# Processing parameter set 185.
#
# 1.6437062635665358
# Processing parameter set 186.
#
# 1.65039521742134
# Processing parameter set 187.
#
# 1.6407170616211986
# Processing parameter set 188.
#
# 1.7269418589020147
# Processing parameter set 189.
#
# 1.8822573340455873
# Processing parameter set 190.
#
# 1.6472962195681717
# Processing parameter set 191.
#
# 1.6485002994568472
# Processing parameter set 192.
#
# 1.646735160565497
# Processing parameter set 193.
#
# 1.6375332762205987
# Processing parameter set 194.
#
# 1.6402844681555624
# Processing parameter set 195.
#
# 1.648058152570898
# Processing parameter set 196.
#
# 1.6503167585071878
# Processing parameter set 197.
#
# 1.7215635212112346
# Processing parameter set 198.
#
# 1.645633771457097
# Processing parameter set 199.
#
# 1.677317448844797
# Processing parameter set 200.
#
# 1.7123856879457888
# Processing parameter set 201.
#
# 1.6622036299933816
# Processing parameter set 202.
#
# 1.6620693929036954
# Processing parameter set 203.
#
# 1.6943599938007101
# Processing parameter set 204.
#
# 1.6915509950020484
# Processing parameter set 205.
#
# 1.6245897594628773
# Processing parameter set 206.
#
# 1.632962525086878
# Processing parameter set 207.
#
# 1.6454817015369154
# Processing parameter set 208.
#
# 1.6255973349577515
# Processing parameter set 209.
#
# 1.655684263746622
# Processing parameter set 210.
#
# 1.6406919571502958
# Processing parameter set 211.
#
# 1.6534234032134278
# Processing parameter set 212.
#
# 1.6422011750184262
# Processing parameter set 213.
#
# 1.6379793050826033
# Processing parameter set 214.
#
# 1.6668216903225532
# Processing parameter set 215.
#
# 1.6430499780703218
# Processing parameter set 216.
#
# 1.709498271589269
# Processing parameter set 217.
#
# 1.674951254838318
# Processing parameter set 218.
#
# 1.6890017036427947
# Processing parameter set 219.
#
# 1.667482310973404
# Processing parameter set 220.
#
# 1.706258858819237
# Processing parameter set 221.
#
# 1.8267552121470434
# Processing parameter set 222.
#
# 1.6647983041486845
# Processing parameter set 223.
#
# 1.6966088395756975
# Processing parameter set 224.
#
# 1.62319748172041
# Processing parameter set 225.
#
# 1.6174965366595342
# Processing parameter set 226.
#
# 1.639214025266662
# Processing parameter set 227.
#
# 1.6782213979229985
# Processing parameter set 228.
#
# 1.6380483873124088
# Processing parameter set 229.
#
# 1.628852544755853
# Processing parameter set 230.
#
# 1.6292636734543584
# Processing parameter set 231.
#
# 1.6522145495725422
# Processing parameter set 232.
#
# 1.6217524542294377
# Processing parameter set 233.
#
# 1.672083188225842
# Processing parameter set 234.
#
# 1.630069256632842
# Processing parameter set 235.
#
# 1.6384467847972548
# Processing parameter set 236.
#
# 1.6486618489718803
# Processing parameter set 237.
#
# 1.6218321772622744
# Processing parameter set 238.
#
# 1.6467113455613878
# Processing parameter set 239.
#
# 1.6433298650984907
# Processing parameter set 240.
#
# 1.6448848802184395
# Processing parameter set 241.
#
# 1.6725983813857803
# Processing parameter set 242.
#
# 1.630989943362832
# Processing parameter set 243.
#
# 1.6437062635665358
# Processing parameter set 244.
#
# 1.6379093906378308
# Processing parameter set 245.
#
# 1.6407170616211986
# Processing parameter set 246.
#
# 1.7269418589020147
# Processing parameter set 247.
#
# 1.8822573340455873
# Processing parameter set 248.
#
# 1.6472962195681717
# Processing parameter set 249.
#
# 1.6485002994568472
# Processing parameter set 250.
#
# 1.646735160565497
# Processing parameter set 251.
#
# 1.6375332762205987
# Processing parameter set 252.
#
# 1.6402844681555624
# Processing parameter set 253.
#
# 1.6443477527401384
# Processing parameter set 254.
#
# 1.6503167585071878
# Processing parameter set 255.
#
# 1.7215635212112346
# Processing parameter set 256.
#
# 1.645633771457097
# Processing parameter set 257.
#
# 1.677317448844797
# Processing parameter set 258.
#
# 1.7123856879457888
# Processing parameter set 259.
#
# 1.6622036299933816
# Processing parameter set 260.
#
# 1.6620693929036954
# Processing parameter set 261.
#
# 1.6943599938007101
# Processing parameter set 262.
#
# 1.6915509950020484
# Processing parameter set 263.
#
# 1.6245897594628773
# Processing parameter set 264.
#
# 1.632962525086878
# Processing parameter set 265.
#
# 1.6454817015369154
# Processing parameter set 266.
#
# 1.6255973349577515
# Processing parameter set 267.
#
# 1.655684263746622
# Processing parameter set 268.
#
# 1.6406919571502958
# Processing parameter set 269.
#
# 1.6498376073059144
# Processing parameter set 270.
#
# 1.6422011750184262
# Processing parameter set 271.
#
# 1.6379793050826033
# Processing parameter set 272.
#
# 1.6668216903225532
# Processing parameter set 273.
#
# 1.6430499780703218
# Processing parameter set 274.
#
# 1.709498271589269
# Processing parameter set 275.
#
# 1.674951254838318
# Processing parameter set 276.
#
# 1.6890017036427947
# Processing parameter set 277.
#
# 1.6659705217979788
# Processing parameter set 278.
#
# 1.706258858819237
# Processing parameter set 279.
#
# 1.8267552121470434
# Processing parameter set 280.
#
# 1.6647983041486845
# Processing parameter set 281.
#
# 1.6966088395756975
# Processing parameter set 282.
#
# 1.62319748172041
# Processing parameter set 283.
#
# 1.6174965366595342
# Processing parameter set 284.
#
# 1.639214025266662
# Processing parameter set 285.
#
# 1.6792984645555658
# Processing parameter set 286.
#
# 1.6380483873124088
# Processing parameter set 287.
#
# 1.628852544755853
# Processing parameter set 288.
#
# 1.6292636734543584
# Processing parameter set 289.
#
# 1.6522145495725422
# Processing parameter set 290.
#
# 1.6217524542294377
# Processing parameter set 291.
#
# 1.6576912752463877
# Processing parameter set 292.
#
# 1.630069256632842
# Processing parameter set 293.
#
# 1.6384467847972548
# Processing parameter set 294.
#
# 1.6486618489718803
# Processing parameter set 295.
#
# 1.6218321772622744
# Processing parameter set 296.
#
# 1.6467113455613878
# Processing parameter set 297.
#
# 1.6433298650984907
# Processing parameter set 298.
#
# 1.6448848802184395
# Processing parameter set 299.
#
# 1.6725983813857803
# Processing parameter set 300.
#
# 1.630989943362832
# Processing parameter set 301.
#
# 1.6437062635665358
# Processing parameter set 302.
#
# 1.6379093906378308
# Processing parameter set 303.
#
# 1.6407170616211986
# Processing parameter set 304.
#
# 1.7269418589020147
# Processing parameter set 305.
#
# 1.8822573340455873
# Processing parameter set 306.
#
# 1.6472962195681717
# Processing parameter set 307.
#
# 1.6485002994568472
# Processing parameter set 308.
#
# 1.646735160565497
# Processing parameter set 309.
#
# 1.6332201858874853
# Processing parameter set 310.
#
# 1.6402844681555624
# Processing parameter set 311.
#
# 1.6443477527401384
# Processing parameter set 312.
#
# 1.6503167585071878
# Processing parameter set 313.
#
# 1.7215635212112346
# Processing parameter set 314.
#
# 1.645633771457097
# Processing parameter set 315.
#
# 1.677317448844797
# Processing parameter set 316.
#
# 1.7123856879457888
# Processing parameter set 317.
#
# 1.6622036299933816
# Processing parameter set 318.
#
# 1.6620693929036954
# Processing parameter set 319.
#
# 1.6943599938007101
# Processing parameter set 320.
#
# 1.6915509950020484
# Processing parameter set 321.
#
# 1.6245897594628773
# Processing parameter set 322.
#
# 1.632962525086878
# Processing parameter set 323.
#
# 1.6454817015369154
# Processing parameter set 324.
#
# 1.6255973349577515
# Processing parameter set 325.
#
# 1.655684263746622
# Processing parameter set 326.
#
# 1.6406919571502958
# Processing parameter set 327.
#
# 1.6498376073059144
# Processing parameter set 328.
#
# 1.6422011750184262
# Processing parameter set 329.
#
# 1.6379793050826033
# Processing parameter set 330.
# 1.6317197579986722
# Processing parameter set 331.
#
# 1.6430499780703218
# Processing parameter set 332.
#
# 1.709498271589269
# Processing parameter set 333.
#
# 1.674951254838318
# Processing parameter set 334.
#
# 1.6888048617891074
# Processing parameter set 335.
#
# 1.6659705217979788
# Processing parameter set 336.
#
# 1.706258858819237
# Processing parameter set 337.
#
# 1.8267552121470434
# Processing parameter set 338.
#
# 1.6534169268053818
# Processing parameter set 339.
#
# 1.6966088395756975
# Processing parameter set 340.
#
# 1.62319748172041
# Processing parameter set 341.
#
# 1.6174965366595342
# Processing parameter set 342.
#
# 1.639214025266662
# Processing parameter set 343.
#
# 1.6582407362988378
# Processing parameter set 344.
#
# 1.6380483873124088
# Processing parameter set 345.
#
# 1.628852544755853
# Processing parameter set 346.
#
# 1.6292636734543584
# Processing parameter set 347.
#
# 1.6522145495725422
# Processing parameter set 348.
#
# 1.6217524542294377
# Processing parameter set 349.
#
# 1.6576912752463877
# Processing parameter set 350.
#
# 1.630069256632842
# Processing parameter set 351.
#
# 1.6384467847972548
# Processing parameter set 352.
#
# 1.6486618489718803
# Processing parameter set 353.
#
# 1.6218321772622744
# Processing parameter set 354.
#
# 1.6467113455613878
# Processing parameter set 355.
#
# 1.6433298650984907
# Processing parameter set 356.
#
# 1.6448848802184395
# Processing parameter set 357.
#
# 1.6725983813857803
# Processing parameter set 358.
#
# 1.630989943362832
# Processing parameter set 359.
#
# 1.6437062635665358
# Processing parameter set 360.
#
# 1.642941613454353
# Processing parameter set 361.
#
# 1.6407170616211986
# Processing parameter set 362.
#
# 1.7269418589020147
# Processing parameter set 363.
#
# 1.8822573340455873
# Processing parameter set 364.
#
# 1.6472962195681717
# Processing parameter set 365.
#
# 1.6485002994568472
# Processing parameter set 366.
#
# 1.646735160565497
# Processing parameter set 367.
#
# 1.6332201858874853
# Processing parameter set 368.
#
# 1.6402844681555624
# Processing parameter set 369.
#
# 1.6443477527401384
# Processing parameter set 370.
#
# 1.6503167585071878
# Processing parameter set 371.
#
# 1.7215635212112346
# Processing parameter set 372.
#
# 1.645633771457097
# Processing parameter set 373.
#
# 1.677317448844797
# Processing parameter set 374.
#
# 1.714205035386981
# Processing parameter set 375.
#
# 1.6622036299933816
# Processing parameter set 376.
#
# 1.6620693929036954
# Processing parameter set 377.
#
# 1.6943599938007101
# Processing parameter set 378.
#
# 1.6915509950020484
# Processing parameter set 379.
#
# 1.621607347378438
# Processing parameter set 380.
#
# 1.632962525086878
# Processing parameter set 381.
#
# 1.6454817015369154
# Processing parameter set 382.
#
# 1.6254635486916265
# Processing parameter set 383.
#
# 1.655684263746622
# Processing parameter set 384.
#
# 1.6406919571502958
# Processing parameter set 385.
#
# 1.6498376073059144
# Processing parameter set 386.
#
# 1.6422011750184262
# Processing parameter set 387.
#
# 1.6379793050826033
# Processing parameter set 388.
#
# 1.6317197579986722
# Processing parameter set 389.
#
# 1.6430499780703218
# Processing parameter set 390.
#
# 1.709498271589269
# Processing parameter set 391.
#
# 1.6639651762749077
# Processing parameter set 392.
#
# 1.6888048617891074
# Processing parameter set 393.
#
# 1.6659705217979788
# Processing parameter set 394.
#
# 1.706258858819237
# Processing parameter set 395.
#
# 1.8267552121470434
# Processing parameter set 396.
#
# 1.6534169268053818
# Processing parameter set 397.
#
# 1.6966088395756975
# Processing parameter set 398.
#
# 1.62319748172041
# Processing parameter set 399.
#
# 1.6174965366595342
# Processing parameter set 400.
#
# 1.639214025266662
# Processing parameter set 401.
#
# 1.6458493387723552
# Processing parameter set 402.
#
# 1.6380483873124088
# Processing parameter set 403.
#
# 1.628852544755853
# Processing parameter set 404.
#
# 1.6292636734543584
# Processing parameter set 405.
#
# 1.6522145495725422
# Processing parameter set 406.
#
# 1.6217524542294377
# Processing parameter set 407.
#
# 1.6576912752463877
# Processing parameter set 408.
#
# 1.630069256632842
# Processing parameter set 409.
#
# 1.6384467847972548
# Processing parameter set 410.
#
# 1.6486618489718803
# Processing parameter set 411.
#
# 1.6218321772622744
# Processing parameter set 412.
#
# 1.6467113455613878
# Processing parameter set 413.
#
# 1.6433298650984907
# Processing parameter set 414.
#
# 1.6448848802184395
# Processing parameter set 415.
#
# 1.668127668294035
# Processing parameter set 416.
#
# 1.630989943362832
# Processing parameter set 417.
#
# 1.6437062635665358
# Processing parameter set 418.
#
# 1.642941613454353
# Processing parameter set 419.
#
# 1.6407170616211986
# Processing parameter set 420.
#
# 1.7269418589020147
# Processing parameter set 421.
#
# 1.8822573340455873
# Processing parameter set 422.
#
# 1.6472962195681717
# Processing parameter set 423.
#
# 1.6485002994568472
# Processing parameter set 424.
#
# 1.63103259977548
# Processing parameter set 425.
#
# 1.6332201858874853
# Processing parameter set 426.
#
# 1.6402844681555624
# Processing parameter set 427.
#
# 1.6443477527401384
# Processing parameter set 428.
#
# 1.6503167585071878
# Processing parameter set 429.
#
# 1.7215635212112346
# Processing parameter set 430.
#
# 1.645633771457097
# Processing parameter set 431.
#
# 1.677317448844797
# Processing parameter set 432.
#
# 1.714205035386981
# Processing parameter set 433.
#
# 1.6622036299933816
# Processing parameter set 434.
#
# 1.6620693929036954
# Processing parameter set 435.
#
# 1.6943599938007101
# Processing parameter set 436.
#
# 1.6915509950020484
# Processing parameter set 437.
#
# 1.621607347378438
# Processing parameter set 438.
#
# 1.632962525086878
# Processing parameter set 439.
#
# 1.6454817015369154
# Processing parameter set 440.
#
# 1.6242687566388043
# Processing parameter set 441.
#
# 1.655684263746622
# Processing parameter set 442.
#
# 1.6406919571502958
# Processing parameter set 443.
#
# 1.6453577896588651
# Processing parameter set 444.
#
# 1.6352117801344666
# Processing parameter set 445.
#
# 1.6379793050826033
# Processing parameter set 446.
#
# 1.6317197579986722
# Processing parameter set 447.
#
# 1.6430499780703218
# Processing parameter set 448.
#
# 1.709498271589269
# Processing parameter set 449.
#
# 1.6639651762749077
# Processing parameter set 450.
#
# 1.6888048617891074
# Processing parameter set 451.
#
# 1.6659705217979788
# Processing parameter set 452.
#
# 1.706258858819237
# Processing parameter set 453.
#
# 1.8267552121470434
# Processing parameter set 454.
#
# 1.6534169268053818
# Processing parameter set 455.
#
# 1.6921843786137054
# Processing parameter set 456.
#
# 1.62319748172041
# Processing parameter set 457.
#
# 1.6174965366595342
# Processing parameter set 458.
#
# 1.639214025266662
# Processing parameter set 459.
#
# 1.6458493387723552
# Processing parameter set 460.
#
# 1.6380483873124088
# Processing parameter set 461.
#
# 1.628852544755853
# Processing parameter set 462.
#
# 1.6292636734543584
# Processing parameter set 463.
#
# 1.6522145495725422
# Processing parameter set 464.
#
# 1.6217524542294377
# Processing parameter set 465.
#
# 1.654034899760864
# Processing parameter set 466.
#
# 1.630069256632842
# Processing parameter set 467.
#
# 1.6384467847972548
# Processing parameter set 468.
#
# 1.6486618489718803
# Processing parameter set 469.
#
# 1.6218321772622744
# Processing parameter set 470.
#
# 1.6467113455613878
# Processing parameter set 471.
#
# 1.6433298650984907
# Processing parameter set 472.
#
# 1.6448848802184395
# Processing parameter set 473.
#
# 1.668127668294035
# Processing parameter set 474.
#
# 1.630989943362832
# Processing parameter set 475.
#
# 1.6437062635665358
# Processing parameter set 476.
#
# 1.642941613454353
# Processing parameter set 477.
#
# 1.6407170616211986
# Processing parameter set 478.
#
# 1.7269418589020147
# Processing parameter set 479.
#
# 1.8822573340455873
# Processing parameter set 480.
#
# 1.6472962195681717
# Processing parameter set 481.
#
# 1.6485002994568472
# Processing parameter set 482.
#
# 1.63103259977548
# Processing parameter set 483.
#
# 1.6332201858874853
# Processing parameter set 484.
#
# 1.6402844681555624
# Processing parameter set 485.
#
# 1.6443477527401384
# Processing parameter set 486.
#
# 1.6503167585071878
# Processing parameter set 487.
#
# 1.7215635212112346
# Processing parameter set 488.
#
# 1.645633771457097
# Processing parameter set 489.
#
# 1.677317448844797
# Processing parameter set 490.
#
# 1.714205035386981
# Processing parameter set 491.
#
# 1.6622036299933816
# Processing parameter set 492.
#
# 1.6620693929036954
# Processing parameter set 493.
#
# 1.6943599938007101
# Processing parameter set 494.
#
# 1.6915509950020484
# Processing parameter set 495.
# 1.621607347378438
# Processing parameter set 496.
#
# 1.632962525086878
# Processing parameter set 497.
#
# 1.6454817015369154
# Processing parameter set 498.
#
# 1.6242687566388043
# Processing parameter set 499.
#
# 1.655684263746622
# Processing parameter set 500.
#
# 1.6406919571502958
# Processing parameter set 501.
#
# 1.6453577896588651
# Processing parameter set 502.
#
# 1.6352117801344666
# Processing parameter set 503.
#
# 1.6356915470837683
# Processing parameter set 504.
#
# 1.6317197579986722
# Processing parameter set 505.
#
# 1.6430499780703218
# Processing parameter set 506.
#
# 1.7062640387661876
# Processing parameter set 507.
#
# 1.6639651762749077
# Processing parameter set 508.
#
# 1.6888048617891074
# Processing parameter set 509.
#
# 1.6659705217979788
# Processing parameter set 510.
#
# 1.6810988042937793
# Processing parameter set 511.
#
# 1.8267552121470434
# Processing parameter set 512.
#
# 1.6534169268053818
# Processing parameter set 513.
#
# 1.6921843786137054
# Processing parameter set 514.
#
# 1.62319748172041
# Processing parameter set 515.
#
# 1.6174965366595342
# Processing parameter set 516.
#
# 1.639214025266662
# Processing parameter set 517.
#
# 1.6458493387723552
# Processing parameter set 518.
#
# 1.639341639359072
# Processing parameter set 519.
#
# 1.628852544755853
# Processing parameter set 520.
#
# 1.6292636734543584
# Processing parameter set 521.
#
# 1.6522145495725422
# Processing parameter set 522.
#
# 1.6217524542294377
# Processing parameter set 523.
#
# 1.654034899760864
# Processing parameter set 524.
#
# 1.630069256632842
# Processing parameter set 525.
#
# 1.6384467847972548
# Processing parameter set 526.
#
# 1.6486618489718803
# Processing parameter set 527.
#
# 1.6218321772622744
# Processing parameter set 528.
#
# 1.6326402380161753
# Processing parameter set 529.
#
# 1.6433298650984907
# Processing parameter set 530.
#
# 1.6448848802184395
# Processing parameter set 531.
#
# 1.668127668294035
# Processing parameter set 532.
#
# 1.630989943362832
# Processing parameter set 533.
#
# 1.6437062635665358
# Processing parameter set 534.
#
# 1.642941613454353
# Processing parameter set 535.
#
# 1.6297778836848806
# Processing parameter set 536.
#
# 1.7269418589020147
# Processing parameter set 537.
#
# 1.8822573340455873
# Processing parameter set 538.
#
# 1.6472962195681717
# Processing parameter set 539.
#
# 1.6485002994568472
# Processing parameter set 540.
#
# 1.63103259977548
# Processing parameter set 541.
#
# 1.6332201858874853
# Processing parameter set 542.
#
# 1.6402844681555624
# Processing parameter set 543.
#
# 1.6443477527401384
# Processing parameter set 544.
#
# 1.6503167585071878
# Processing parameter set 545.
#
# 1.7215635212112346
# Processing parameter set 546.
#
# 1.645633771457097
# Processing parameter set 547.
#
# 1.677317448844797
# Processing parameter set 548.
#
# 1.714205035386981
# Processing parameter set 549.
#
# 1.6622036299933816
# Processing parameter set 550.
#
# 1.6620693929036954
# Processing parameter set 551.
#
# 1.6943599938007101
# Processing parameter set 552.
#
# 1.6915509950020484
# Processing parameter set 553.
#
# 1.62473210304362
# Processing parameter set 554.
#
# 1.632962525086878
# Processing parameter set 555.
#
# 1.6454817015369154
# Processing parameter set 556.
#
# 1.6242687566388043
# Processing parameter set 557.
#
# 1.655684263746622
# Processing parameter set 558.
#
# 1.6406919571502958
# Processing parameter set 559.
#
# 1.6453577896588651
# Processing parameter set 560.
#
# 1.6352728138299892
# Processing parameter set 561.
#
# 1.6356565437987933
# Processing parameter set 562.
#
# 1.6317197579986722
# Processing parameter set 563.
#
# 1.6430499780703218
# Processing parameter set 564.
#
# 1.6717365372540485
# Processing parameter set 565.
#
# 1.6639651762749077
# Processing parameter set 566.
#
# 1.6888048617891074
# Processing parameter set 567.
#
# 1.6659705217979788
# Processing parameter set 568.
#
# 1.6810988042937793
# Processing parameter set 569.
#
# 1.8267552121470434
# Processing parameter set 570.
#
# 1.6534169268053818
# Processing parameter set 571.
#
# 1.6921843786137054
# Processing parameter set 572.
#
# 1.62319748172041
# Processing parameter set 573.
#
# 1.6174965366595342
# Processing parameter set 574.
#
# 1.63974855331584
# Processing parameter set 575.
#
# 1.6458493387723552
# Processing parameter set 576.
#
# 1.639341639359072
# Processing parameter set 577.
#
# 1.6278587001796023
# Processing parameter set 578.
#
# 1.6292636734543584
# Processing parameter set 579.
#
# 1.6522145495725422
# Processing parameter set 580.
#
# 1.6217524542294377
# Processing parameter set 581.
#
# 1.654034899760864
# Processing parameter set 582.
#
# 1.630069256632842
# Processing parameter set 583.
#
# 1.6430839466833975
# Processing parameter set 584.
#
# 1.6429468365047897
# Processing parameter set 585.
#
# 1.6218321772622744
# Processing parameter set 586.
#
# 1.6288705507497006
# Processing parameter set 587.
#
# 1.6433298650984907
# Processing parameter set 588.
#
# 1.6448848802184395
# Processing parameter set 589.
#
# 1.668127668294035
# Processing parameter set 590.
#
# 1.630989943362832
# Processing parameter set 591.
#
# 1.6437062635665358
# Processing parameter set 592.
#
# 1.6309623304287424
# Processing parameter set 593.
#
# 1.628445735733155
# Processing parameter set 594.
#
# 1.7269418589020147
# Processing parameter set 595.
#
# 1.872736375219245
# Processing parameter set 596.
#
# 1.6472962195681717
# Processing parameter set 597.
#
# 1.6485002994568472
# Processing parameter set 598.
#
# 1.63103259977548
# Processing parameter set 599.
#
# 1.6332201858874853
# Processing parameter set 600.
#
# 1.6402844681555624
# Processing parameter set 601.
#
# 1.642931283488202
# Processing parameter set 602.
#
# 1.6503167585071878
# Processing parameter set 603.
#
# 1.685449578086235
# Processing parameter set 604.
#
# 1.645633771457097
# Processing parameter set 605.
#
# 1.6764528736513402
# Processing parameter set 606.
#
# 1.714205035386981
# Processing parameter set 607.
#
# 1.6622036299933816
# Processing parameter set 608.
#
# 1.6620693929036954
# Processing parameter set 609.
#
# 1.6943599938007101
# Processing parameter set 610.
#
# 1.6915509950020484
# Processing parameter set 611.
#
# 1.62473210304362
# Processing parameter set 612.
#
# 1.632962525086878
# Processing parameter set 613.
#
# 1.6454817015369154
# Processing parameter set 614.
#
# 1.6242687566388043
# Processing parameter set 615.
#
# 1.655684263746622
# Processing parameter set 616.
#
# 1.6406919571502958
# Processing parameter set 617.
#
# 1.6453577896588651
# Processing parameter set 618.
#
# 1.6352728138299892
# Processing parameter set 619.
#
# 1.6356565437987933
# Processing parameter set 620.
#
# 1.6317197579986722
# Processing parameter set 621.
#
# 1.6430499780703218
# Processing parameter set 622.
#
# 1.6717365372540485
# Processing parameter set 623.
#
# 1.6639651762749077
# Processing parameter set 624.
#
# 1.6888048617891074
# Processing parameter set 625.
#
# 1.6659705217979788
# Processing parameter set 626.
#
# 1.6810988042937793
# Processing parameter set 627.
#
# 1.8267552121470434
# Processing parameter set 628.
#
# 1.6489662453036682
# Processing parameter set 629.
#
# 1.6921843786137054
# Processing parameter set 630.
#
# 1.62319748172041
# Processing parameter set 631.
#
# 1.6174965366595342
# Processing parameter set 632.
#
# 1.63974855331584
# Processing parameter set 633.
#
# 1.6458493387723552
# Processing parameter set 634.
#
# 1.639341639359072
# Processing parameter set 635.
#
# 1.6278587001796023
# Processing parameter set 636.
#
# 1.6292636734543584
# Processing parameter set 637.
#
# 1.6522145495725422
# Processing parameter set 638.
#
# 1.6217524542294377
# Processing parameter set 639.
#
# 1.654034899760864
# Processing parameter set 640.
#
# 1.630069256632842
# Processing parameter set 641.
#
# 1.6430839466833975
# Processing parameter set 642.
#
# 1.6429468365047897
# Processing parameter set 643.
#
# 1.6218321772622744
# Processing parameter set 644.
#
# 1.6288705507497006
# Processing parameter set 645.
#
# 1.6433298650984907
# Processing parameter set 646.
#
# 1.6448848802184395
# Processing parameter set 647.
#
# 1.668127668294035
# Processing parameter set 648.
#
# 1.630989943362832
# Processing parameter set 649.
#
# 1.6437062635665358
# Processing parameter set 650.
#
# 1.6309623304287424
# Processing parameter set 651.
#
# 1.628445735733155
# Processing parameter set 652.
#
# 1.71637065130492
# Processing parameter set 653.
#
# 1.872736375219245
# Processing parameter set 654.
#
# 1.6472962195681717
# Processing parameter set 655.
#
# 1.6485002994568472
# Processing parameter set 656.
#
# 1.63103259977548
# Processing parameter set 657.
#
# 1.6332201858874853
# Processing parameter set 658.
#
# 1.6402844681555624
# Processing parameter set 659.
#
# 1.6204671009637215
# Processing parameter set 660.
#
# 1.6503167585071878
# Processing parameter set 661.
#
# 1.685449578086235
# Processing parameter set 662.
#
# 1.645633771457097
# Processing parameter set 663.
#
# 1.676293642465986
# Processing parameter set 664.
#
# 1.7108378975965943
# Processing parameter set 665.
#
# 1.6622036299933816
# Processing parameter set 666.
#
# 1.6620693929036954
# Processing parameter set 667.
#
# 1.6943599938007101
# Processing parameter set 668.
#
# 1.6915509950020484
# Processing parameter set 669.
#
# 1.62473210304362
# Processing parameter set 670.
#
# 1.632962525086878
# Processing parameter set 671.
#
# 1.6454817015369154
# Processing parameter set 672.
#
# 1.6242687566388043
# Processing parameter set 673.
#
# 1.655684263746622
# Processing parameter set 674.
#
# 1.6406919571502958
# Processing parameter set 675.
#
# 1.6453577896588651
# Processing parameter set 676.
#
# 1.6280419288261325
# Processing parameter set 677.
#
# 1.6356565437987933
# Processing parameter set 678.
#
# 1.6317197579986722
# Processing parameter set 679.
#
# 1.6430499780703218
# Processing parameter set 680.
#
# 1.6717365372540485
# Processing parameter set 681.
#
# 1.6639651762749077
# Processing parameter set 682.
#
# 1.6888048617891074
# Processing parameter set 683.
#
# 1.6659705217979788
# Processing parameter set 684.
#
# 1.6810988042937793
# Processing parameter set 685.
#
# 1.8267552121470434
# Processing parameter set 686.
#
# 1.6489662453036682
# Processing parameter set 687.
#
# 1.6921843786137054
# Processing parameter set 688.
#
# 1.62319748172041
# Processing parameter set 689.
#
# 1.6174965366595342
# Processing parameter set 690.
#
# 1.63974855331584
# Processing parameter set 691.
#
# 1.6458493387723552
# Processing parameter set 692.
#
# 1.639341639359072
# Processing parameter set 693.
#
# 1.6278587001796023
# Processing parameter set 694.
#
# 1.6292636734543584
# Processing parameter set 695.
#
# 1.6553331893741896
# Processing parameter set 696.
#
# 1.6217524542294377
# Processing parameter set 697.
#
# 1.654034899760864
# Processing parameter set 698.
#
# 1.630069256632842
# Processing parameter set 699.
#
# 1.6430839466833975
# Processing parameter set 700.
#
# 1.6429468365047897
# Processing parameter set 701.
#
# 1.6218321772622744
# Processing parameter set 702.
#
# 1.6265185323016371
# Processing parameter set 703.
#
# 1.6371318677554163
# Processing parameter set 704.
#
# 1.6448848802184395
# Processing parameter set 705.
#
# 1.668127668294035
# Processing parameter set 706.
#
# 1.630989943362832
# Processing parameter set 707.
#
# 1.6437062635665358
# Processing parameter set 708.
#
# 1.6309623304287424
# Processing parameter set 709.
#
# 1.628445735733155
# Processing parameter set 710.
#
# 1.71637065130492
# Processing parameter set 711.
#
# 1.872736375219245
# Processing parameter set 712.
#
# 1.6472962195681717
# Processing parameter set 713.
#
# 1.6485002994568472
# Processing parameter set 714.
#
# 1.63103259977548
# Processing parameter set 715.
#
# 1.6332201858874853
# Processing parameter set 716.
#
# 1.6402844681555624
# Processing parameter set 717.
#
# 1.6204671009637215
# Processing parameter set 718.
#
# 1.6503167585071878
# Processing parameter set 719.
#
# 1.685449578086235
# Processing parameter set 720.
#
# 1.645633771457097
# Processing parameter set 721.
#
# 1.676293642465986
# Processing parameter set 722.
#
# 1.7108378975965943
# Processing parameter set 723.
#
# 1.6622036299933816
# Processing parameter set 724.
#
# 1.6620693929036954
# Processing parameter set 725.
#
# 1.6943599938007101
# Processing parameter set 726.
#
# 1.6915509950020484
# Processing parameter set 727.
#
# 1.62473210304362
# Processing parameter set 728.
#
# 1.632962525086878
# Processing parameter set 729.
#
# 1.6454817015369154
# Processing parameter set 730.
#
# 1.6242687566388043
# Processing parameter set 731.
#
# 1.655684263746622
# Processing parameter set 732.
#
# 1.6398535148197564
# Processing parameter set 733.
#
# 1.6453577896588651
# Processing parameter set 734.
#
# 1.6280419288261325
# Processing parameter set 735.
#
# 1.6356565437987933
# Processing parameter set 736.
#
# 1.6317197579986722
# Processing parameter set 737.
#
# 1.6430499780703218
# Processing parameter set 738.
#
# 1.6717365372540485
# Processing parameter set 739.
#
# 1.6639651762749077
# Processing parameter set 740.
#
# 1.6888048617891074
# Processing parameter set 741.
#
# 1.6659705217979788
# Processing parameter set 742.
#
# 1.6810988042937793
# Processing parameter set 743.
#
# 1.8267552121470434
# Processing parameter set 744.
#
# 1.6489662453036682
# Processing parameter set 745.
#
# 1.6921843786137054
# Processing parameter set 746.
#
# 1.62319748172041
# Processing parameter set 747.
#
# 1.6174965366595342
# Processing parameter set 748.
#
# 1.63974855331584
# Processing parameter set 749.
#
# 1.6458493387723552
# Processing parameter set 750.
#
# 1.639341639359072
# Processing parameter set 751.
#
# 1.6278587001796023
# Processing parameter set 752.
#
# 1.6292636734543584
# Processing parameter set 753.
#
# 1.6553331893741896
# Processing parameter set 754.
#
# 1.6217524542294377
# Processing parameter set 755.
#
# 1.654034899760864
# Processing parameter set 756.
#
# 1.630069256632842
# Processing parameter set 757.
#
# 1.6430839466833975
# Processing parameter set 758.
#
# 1.6429468365047897
# Processing parameter set 759.
#
# 1.6218321772622744
# Processing parameter set 760.
#
# 1.6265185323016371
# Processing parameter set 761.
#
# 1.6371318677554163
# Processing parameter set 762.
#
# 1.6448848802184395
# Processing parameter set 763.
#
# 1.6573337623843405
# Processing parameter set 764.
#
# 1.630989943362832
# Processing parameter set 765.
#
# 1.6432862050143011
# Processing parameter set 766.
#
# 1.6309623304287424
# Processing parameter set 767.
#
# 1.628445735733155
# Processing parameter set 768.
#
# 1.71637065130492
# Processing parameter set 769.
#
# 1.872736375219245
# Processing parameter set 770.
#
# 1.6472962195681717
# Processing parameter set 771.
#
# 1.6485002994568472
# Processing parameter set 772.
#
# 1.63103259977548
# Processing parameter set 773.
#
# 1.621189706473491
# Processing parameter set 774.
#
# 1.6402844681555624
# Processing parameter set 775.
#
# 1.6204671009637215
# Processing parameter set 776.
#
# 1.6503167585071878
# Processing parameter set 777.
#
# 1.685449578086235
# Processing parameter set 778.
#
# 1.645633771457097
# Processing parameter set 779.
#
# 1.676293642465986
# Processing parameter set 780.
#
# 1.706639997423586
# Processing parameter set 781.
#
# 1.6622036299933816
# Processing parameter set 782.
#
# 1.6545664880756537
# Processing parameter set 783.
#
# 1.6943599938007101
# Processing parameter set 784.
#
# 1.6915509950020484
# Processing parameter set 785.
#
# 1.62473210304362
# Processing parameter set 786.
#
# 1.632962525086878
# Processing parameter set 787.
#
# 1.64361141188219
# Processing parameter set 788.
#
# 1.6242687566388043
# Processing parameter set 789.
#
# 1.655684263746622
# Processing parameter set 790.
#
# 1.6398535148197564
# Processing parameter set 791.
#
# 1.6453577896588651
# Processing parameter set 792.
#
# 1.6280419288261325
# Processing parameter set 793.
#
# 1.6356565437987933
# Processing parameter set 794.
#
# 1.6317197579986722
# Processing parameter set 795.
#
# 1.6430499780703218
# Processing parameter set 796.
#
# 1.6717365372540485
# Processing parameter set 797.
#
# 1.6639651762749077
# Processing parameter set 798.
#
# 1.6888048617891074
# Processing parameter set 799.
#
# 1.6659705217979788
# Processing parameter set 800.
#
# 1.6810988042937793
# Processing parameter set 801.
#
# 1.8267552121470434
# Processing parameter set 802.
#
# 1.6489662453036682
# Processing parameter set 803.
#
# 1.6562144395638918
# Processing parameter set 804.
#
# 1.62319748172041
# Processing parameter set 805.
#
# 1.6174965366595342
# Processing parameter set 806.
#
# 1.63974855331584
# Processing parameter set 807.
#
# 1.6458493387723552
# Processing parameter set 808.
#
# 1.639341639359072
# Processing parameter set 809.
#
# 1.6278587001796023
# Processing parameter set 810.
#
# 1.6292636734543584
# Processing parameter set 811.
#
# 1.6553331893741896
# Processing parameter set 812.
#
# 1.6217524542294377
# Processing parameter set 813.
#
# 1.654034899760864
# Processing parameter set 814.
#
# 1.630069256632842
# Processing parameter set 815.
#
# 1.6430839466833975
# Processing parameter set 816.
#
# 1.6429468365047897
# Processing parameter set 817.
#
# 1.6218321772622744
# Processing parameter set 818.
#
# 1.6265185323016371
# Processing parameter set 819.
#
# 1.6371318677554163
# Processing parameter set 820.
#
# 1.6448848802184395
# Processing parameter set 821.
#
# 1.6490943299653122
# Processing parameter set 822.
#
# 1.630989943362832
# Processing parameter set 823.
#
# 1.6432862050143011
# Processing parameter set 824.
#
# 1.6309623304287424
# Processing parameter set 825.
#
# 1.628445735733155
# Processing parameter set 826.
# 1.71637065130492
# Processing parameter set 827.
#
# 1.872736375219245
# Processing parameter set 828.
#
# 1.6472962195681717
# Processing parameter set 829.
#
# 1.6485002994568472
# Processing parameter set 830.
#
# 1.63103259977548
# Processing parameter set 831.
#
# 1.621189706473491
# Processing parameter set 832.
#
# 1.6402844681555624
# Processing parameter set 833.
#
# 1.6204671009637215
# Processing parameter set 834.
#
# 1.6503167585071878
# Processing parameter set 835.
#
# 1.6857822782280614
# Processing parameter set 836.
#
# 1.645633771457097
# Processing parameter set 837.
#
# 1.676293642465986
# Processing parameter set 838.
#
# 1.706639997423586
# Processing parameter set 839.
#
# 1.6622036299933816
# Processing parameter set 840.
#
# 1.6545664880756537
# Processing parameter set 841.
#
# 1.6943599938007101
# Processing parameter set 842.
#
# 1.6915509950020484
# Processing parameter set 843.
#
# 1.62473210304362
# Processing parameter set 844.
#
# 1.632962525086878
# Processing parameter set 845.
#
# 1.64361141188219
# Processing parameter set 846.
#
# 1.6242687566388043
# Processing parameter set 847.
#
# 1.655684263746622
# Processing parameter set 848.
#
# 1.6398535148197564
# Processing parameter set 849.
#
# 1.6453577896588651
# Processing parameter set 850.
#
# 1.6280419288261325
# Processing parameter set 851.
#
# 1.6356565437987933
# Processing parameter set 852.
#
# 1.6317197579986722
# Processing parameter set 853.
#
# 1.6430499780703218
# Processing parameter set 854.
#
# 1.6717365372540485
# Processing parameter set 855.
#
# 1.6619285376382533
# Processing parameter set 856.
#
# 1.6888048617891074
# Processing parameter set 857.
#
# 1.6633107879103708
# Processing parameter set 858.
#
# 1.6810988042937793
# Processing parameter set 859.
#
# 1.8267552121470434
# Processing parameter set 860.
#
# 1.6489662453036682
# Processing parameter set 861.
#
# 1.6562144395638918
# Processing parameter set 862.
#
# 1.62319748172041
# Processing parameter set 863.
#
# 1.6174965366595342
# Processing parameter set 864.
#
# 1.63974855331584
# Processing parameter set 865.
#
# 1.6458493387723552
# Processing parameter set 866.
#
# 1.639341639359072
# Processing parameter set 867.
#
# 1.6278587001796023
# Processing parameter set 868.
#
# 1.6292636734543584
# Processing parameter set 869.
#
# 1.6553331893741896
# Processing parameter set 870.
#
# 1.6217524542294377
# Processing parameter set 871.
#
# 1.654034899760864
# Processing parameter set 872.
#
# 1.630069256632842
# Processing parameter set 873.
#
# 1.6430839466833975
# Processing parameter set 874.
#
# 1.6429468365047897
# Processing parameter set 875.
#
# 1.6218321772622744
# Processing parameter set 876.
#
# 1.6265185323016371
# Processing parameter set 877.
#
# 1.637461893382231
# Processing parameter set 878.
#
# 1.6402476973419844
# Processing parameter set 879.
#
# 1.6490943299653122
# Processing parameter set 880.
#
# 1.630989943362832
# Processing parameter set 881.
#
# 1.6432862050143011
# Processing parameter set 882.
#
# 1.6309623304287424
# Processing parameter set 883.
#
# 1.628445735733155
# Processing parameter set 884.
#
# 1.71637065130492
# Processing parameter set 885.
#
# 1.872736375219245
# Processing parameter set 886.
#
# 1.6472962195681717
# Processing parameter set 887.
#
# 1.6485002994568472
# Processing parameter set 888.
#
# 1.63103259977548
# Processing parameter set 889.
#
# 1.621189706473491
# Processing parameter set 890.
#
# 1.6402844681555624
# Processing parameter set 891.
#
# 1.6204671009637215
# Processing parameter set 892.
#
# 1.6503167585071878
# Processing parameter set 893.
#
# 1.6857822782280614
# Processing parameter set 894.
#
# 1.645633771457097
# Processing parameter set 895.
#
# 1.676293642465986
# Processing parameter set 896.
#
# 1.706639997423586
# Processing parameter set 897.
#
# 1.6527264961890487
# Processing parameter set 898.
#
# 1.6463903174613472
# Processing parameter set 899.
#
# 1.6870910624187716
# Processing parameter set 900.
#
# 1.6915509950020484
# Processing parameter set 901.
#
# 1.6220263416853227
# Processing parameter set 902.
#
# 1.632962525086878
# Processing parameter set 903.
#
# 1.6404088210266212
# Processing parameter set 904.
#
# 1.6242687566388043
# Processing parameter set 905.
#
# 1.633800245113191
# Processing parameter set 906.
#
# 1.6398535148197564
# Processing parameter set 907.
#
# 1.6453577896588651
# Processing parameter set 908.
#
# 1.6280419288261325
# Processing parameter set 909.
#
# 1.6356565437987933
# Processing parameter set 910.
#
# 1.6317197579986722
# Processing parameter set 911.
#
# 1.6430499780703218
# Processing parameter set 912.
#
# 1.6717365372540485
# Processing parameter set 913.
#
# 1.6619285376382533
# Processing parameter set 914.
#
# 1.6809961150172439
# Processing parameter set 915.
#
# 1.6633107879103708
# Processing parameter set 916.
#
# 1.6810988042937793
# Processing parameter set 917.
#
# 1.8267552121470434
# Processing parameter set 918.
#
# 1.6489662453036682
# Processing parameter set 919.
#
# 1.6548315644085336
# Processing parameter set 920.
#
# 1.62319748172041
# Processing parameter set 921.
#
# 1.6174965366595342
# Processing parameter set 922.
#
# 1.63974855331584
# Processing parameter set 923.
#
# 1.6458493387723552
# Processing parameter set 924.
#
# 1.639341639359072
# Processing parameter set 925.
#
# 1.6278587001796023
# Processing parameter set 926.
#
# 1.6292636734543584
# Processing parameter set 927.
#
# 1.6553331893741896
# Processing parameter set 928.
#
# 1.6217524542294377
# Processing parameter set 929.
#
# 1.654034899760864
# Processing parameter set 930.
#
# 1.630069256632842
# Processing parameter set 931.
#
# 1.6430839466833975
# Processing parameter set 932.
#
# 1.6429468365047897
# Processing parameter set 933.
#
# 1.6218321772622744
# Processing parameter set 934.
#
# 1.6265185323016371
# Processing parameter set 935.
#
# 1.637461893382231
# Processing parameter set 936.
#
# 1.6402476973419844
# Processing parameter set 937.
#
# 1.6490943299653122
# Processing parameter set 938.
#
# 1.630989943362832
# Processing parameter set 939.
#
# 1.6436888397352334
# Processing parameter set 940.
#
# 1.6309623304287424
# Processing parameter set 941.
#
# 1.628445735733155
# Processing parameter set 942.
#
# 1.71637065130492
# Processing parameter set 943.
#
# 1.872736375219245
# Processing parameter set 944.
#
# 1.6472962195681717
# Processing parameter set 945.
#
# 1.6485002994568472
# Processing parameter set 946.
#
# 1.63103259977548
# Processing parameter set 947.
#
# 1.621189706473491
# Processing parameter set 948.
#
# 1.6402844681555624
# Processing parameter set 949.
#
# 1.6204671009637215
# Processing parameter set 950.
#
# 1.6503167585071878
# Processing parameter set 951.
#
# 1.6857822782280614
# Processing parameter set 952.
#
# 1.645633771457097
# Processing parameter set 953.
#
# 1.676293642465986
# Processing parameter set 954.
#
# 1.706639997423586
# Processing parameter set 955.
#
# 1.6527264961890487
# Processing parameter set 956.
#
# 1.6463903174613472
# Processing parameter set 957.
#
# 1.6870910624187716
# Processing parameter set 958.
#
# 1.6915509950020484
# Processing parameter set 959.
#
# 1.6220263416853227
# Processing parameter set 960.
#
# 1.632962525086878
# Processing parameter set 961.
#
# 1.6404088210266212
# Processing parameter set 962.
#
# 1.6242687566388043
# Processing parameter set 963.
#
# 1.633800245113191
# Processing parameter set 964.
#
# 1.6398535148197564
# Processing parameter set 965.
#
# 1.6453577896588651
# Processing parameter set 966.
#
# 1.6280419288261325
# ...
# Processing parameter set 11951.
#
# 1.609950446559702
# Processing parameter set 11952.
#
# 1.616921392618614
# Processing parameter set 11953.
#
# 1.6120571962086603
# Processing parameter set 11954.
#
# 1.6195347739520363
# Processing parameter set 11955.
#
# 1.6165926437763343
# Processing parameter set 11956.
#
# 1.6206295715027823
# Processing parameter set 11957.
#
# 1.613066084870582
# Processing parameter set 11958.
# 1.6184343185758232
# Processing parameter set 11959.
#
# 1.60789215153834
# Processing parameter set 11960.
#
# 1.6082717741860129
# Processing parameter set 11961.
#
# 1.6135923699920836
# Processing parameter set 11962.
#
# 1.6366403738881588
# Processing parameter set 11963.
#
# 1.6176936661243704
# Processing parameter set 11964.
#
# 1.614067799435086
# Processing parameter set 11965.
#
# 1.6180724908389281
# Processing parameter set 11966.
#
# 1.6125748031267866
# Processing parameter set 11967.
#
# 1.6141932842348063
# Processing parameter set 11968.
#
# 1.6158226546212977
# Processing parameter set 11969.
#
# 1.6166061552863602
# Processing parameter set 11970.
#
# 1.6156565565049317
# Processing parameter set 11971.
#
# 1.6107125452067015
# Processing parameter set 11972.
#
# 1.6186967988687424
# Processing parameter set 11973.
#
# 1.6112570997772528
# Processing parameter set 11974.
#
# 1.6133466935004048
# Processing parameter set 11975.
#
# 1.6117486859437395
# Processing parameter set 11976.
#
# 1.6166112407329916
# Processing parameter set 11977.
#
# 1.6076925349737883
# Processing parameter set 11978.
#
# 1.6153184240081884
# Processing parameter set 11979.
#
# 1.6177163783047912
# Processing parameter set 11980.
#
# 1.6137473875516881
# Processing parameter set 11981.
#
# 1.615750806166113
# Processing parameter set 11982.
#
# 1.6169764022778386
# Processing parameter set 11983.
#
# 1.615519423202303
# Processing parameter set 11984.
#
# 1.6113645887098362
# Processing parameter set 11985.
#
# 1.6140807706534888
# Processing parameter set 11986.
#
# 1.6214245643780254
# Processing parameter set 11987.
#
# 1.6177909965788664
# Processing parameter set 11988.
#
# 1.6162935027106609
# Processing parameter set 11989.
#
# 1.6158542709854955
# Processing parameter set 11990.
#
# 1.6136159080037822
# Processing parameter set 11991.
#
# 1.6266158756020612
# Processing parameter set 11992.
#
# 1.617042492885415
# Processing parameter set 11993.
#
# 1.627649813038884
# Processing parameter set 11994.
#
# 1.610800533972408
# Processing parameter set 11995.
#
# 1.6076668399893659
# Processing parameter set 11996.
#
# 1.6119442566147417
# Processing parameter set 11997.
#
# 1.6171247028003692
# Processing parameter set 11998.
#
# 1.6135447571512127
# Processing parameter set 11999.
#
# 1.6133902403030171
# Processing parameter set 12000.
#
# 1.613995283516116
# Processing parameter set 12001.
#
# 1.6145963237646184
# Processing parameter set 12002.
#
# 1.6173437013740748
# Processing parameter set 12003.
#
# 1.6104867459949959
# Processing parameter set 12004.
#
# 1.6247294063605244
# Processing parameter set 12005.
#
# 1.6144351925529434
# Processing parameter set 12006.
#
# 1.609165351394505
# Processing parameter set 12007.
#
# 1.6123934442050532
# Processing parameter set 12008.
#
# 1.6177383093695137
# Processing parameter set 12009.
#
# 1.609950446559702
# Processing parameter set 12010.
#
# 1.616921392618614
# Processing parameter set 12011.
#
# 1.6120571962086603
# Processing parameter set 12012.
#
# 1.6195347739520363
# Processing parameter set 12013.
#
# 1.6165926437763343
# Processing parameter set 12014.
#
# 1.6206295715027823
# Processing parameter set 12015.
#
# 1.6130355997856762
# Processing parameter set 12016.
#
# 1.6184343185758232
# Processing parameter set 12017.
#
# 1.60789215153834
# Processing parameter set 12018.
#
# 1.6082717741860129
# Processing parameter set 12019.
#
# 1.6135923699920836
# Processing parameter set 12020.
#
# 1.6366403738881588
# Processing parameter set 12021.
#
# 1.6176936661243704
# Processing parameter set 12022.
#
# 1.614067799435086
# Processing parameter set 12023.
#
# 1.6180724908389281
# Processing parameter set 12024.
#
# 1.6125748031267866
# Processing parameter set 12025.
#
# 1.6141932842348063
# Processing parameter set 12026.
#
# 1.6158226546212977
# Processing parameter set 12027.
#
# 1.6167779913512195
# Processing parameter set 12028.
#
# 1.6156565565049317
# Processing parameter set 12029.
#
# 1.610921741897429
# Processing parameter set 12030.
#
# 1.6186967988687424
# Processing parameter set 12031.
#
# 1.6112570997772528
# Processing parameter set 12032.
#
# 1.6133466935004048
# Processing parameter set 12033.
#
# 1.6117486859437395
# Processing parameter set 12034.
#
# 1.6166112407329916
# Processing parameter set 12035.
#
# 1.6108369798790025
# Processing parameter set 12036.
#
# 1.6153184240081884
# Processing parameter set 12037.
#
# 1.6177163783047912
# Processing parameter set 12038.
#
# 1.6153142337747122
# Processing parameter set 12039.
#
# 1.6221450976981873
# Processing parameter set 12040.
#
# 1.6169764022778386
# Processing parameter set 12041.
#
# 1.615519423202303
# Processing parameter set 12042.
#
# 1.6113645887098362
# Processing parameter set 12043.
#
# 1.6140807706534888
# Processing parameter set 12044.
#
# 1.6214245643780254
# Processing parameter set 12045.
#
# 1.6163370130384598
# Processing parameter set 12046.
#
# 1.6162935027106609
# Processing parameter set 12047.
#
# 1.6179548366290062
# Processing parameter set 12048.
#
# 1.6119499197312719
# Processing parameter set 12049.
#
# 1.6266158756020612
# Processing parameter set 12050.
#
# 1.617042492885415
# Processing parameter set 12051.
#
# 1.627649813038884
# Processing parameter set 12052.
#
# 1.610800533972408
# Processing parameter set 12053.
#
# 1.6076668399893659
# Processing parameter set 12054.
#
# 1.6119442566147417
# Processing parameter set 12055.
#
# 1.6171247028003692
# Processing parameter set 12056.
#
# 1.6143047807617095
# Processing parameter set 12057.
#
# 1.6145814653251094
# Processing parameter set 12058.
#
# 1.613995283516116
# Processing parameter set 12059.
#
# 1.612685080350704
# Processing parameter set 12060.
#
# 1.6173437013740748
# Processing parameter set 12061.
#
# 1.609081544556676
# Processing parameter set 12062.
#
# 1.6247294063605244
# Processing parameter set 12063.
#
# 1.6137981924252807
# Processing parameter set 12064.
#
# 1.609165351394505
# Processing parameter set 12065.
#
# 1.6123934442050532
# Processing parameter set 12066.
#
# 1.6177383093695137
# Processing parameter set 12067.
#
# 1.609950446559702
# Processing parameter set 12068.
#
# 1.616921392618614
# Processing parameter set 12069.
#
# 1.6120571962086603
# Processing parameter set 12070.
#
# 1.6195347739520363
# Processing parameter set 12071.
#
# 1.6158494529583307
# Processing parameter set 12072.
#
# 1.6206295715027823
# Processing parameter set 12073.
#
# 1.6130355997856762
# Processing parameter set 12074.
#
# 1.6224877680807228
# Processing parameter set 12075.
#
# 1.60789215153834
# Processing parameter set 12076.
#
# 1.6082717741860129
# Processing parameter set 12077.
#
# 1.6135923699920836
# Processing parameter set 12078.
#
# 1.6366403738881588
# Processing parameter set 12079.
#
# 1.6166416693101888
# Processing parameter set 12080.
#
# 1.614067799435086
# Processing parameter set 12081.
#
# 1.6180724908389281
# Processing parameter set 12082.
#
# 1.6125748031267866
# Processing parameter set 12083.
#
# 1.6141932842348063
# Processing parameter set 12084.
#
# 1.6158226546212977
# Processing parameter set 12085.
#
# 1.6167779913512195
# Processing parameter set 12086.
#
# 1.6156565565049317
# Processing parameter set 12087.
#
# 1.610921741897429
# Processing parameter set 12088.
#
# 1.6186967988687424
# Processing parameter set 12089.
#
# 1.609008251073016
# Processing parameter set 12090.
#
# 1.6133466935004048
# Processing parameter set 12091.
#
# 1.6117486859437395
# Processing parameter set 12092.
#
# 1.6166112407329916
# Processing parameter set 12093.
#
# 1.6108369798790025
# Processing parameter set 12094.
#
# 1.6153184240081884
# Processing parameter set 12095.
#
# 1.6177163783047912
# Processing parameter set 12096.
#
# 1.6183801792088095
# Processing parameter set 12097.
#
# 1.6221450976981873
# Processing parameter set 12098.
#
# 1.6169764022778386
# Processing parameter set 12099.
#
# 1.615519423202303
# Processing parameter set 12100.
#
# 1.6113645887098362
# Processing parameter set 12101.
#
# 1.6140807706534888
# Processing parameter set 12102.
#
# 1.6218870099272986
# Processing parameter set 12103.
#
# 1.6163370130384598
# Processing parameter set 12104.
#
# 1.616829098583137
# Processing parameter set 12105.
#
# 1.6176071940327055
# Processing parameter set 12106.
#
# 1.6125779074498439
# Processing parameter set 12107.
#
# 1.6250350782478102
# Processing parameter set 12108.
#
# 1.6173000321428321
# Processing parameter set 12109.
#
# 1.6295321133854135
# Processing parameter set 12110.
#
# 1.610800533972408
# Processing parameter set 12111.
#
# 1.6076668399893659
# Processing parameter set 12112.
#
# 1.6119442566147417
# Processing parameter set 12113.
#
# 1.6171247028003692
# Processing parameter set 12114.
#
# 1.6143047807617095
# Processing parameter set 12115.
#
# 1.6157709624956957
# Processing parameter set 12116.
#
# 1.613955180417452
# Processing parameter set 12117.
#
# 1.612685080350704
# Processing parameter set 12118.
#
# 1.6173437013740748
# Processing parameter set 12119.
#
# 1.609081544556676
# Processing parameter set 12120.
#
# 1.6196871461111133
# Processing parameter set 12121.
#
# 1.6137981924252807
# Processing parameter set 12122.
#
# 1.609165351394505
# Processing parameter set 12123.
#
# 1.6123934442050532
# Processing parameter set 12124.
#
# 1.6177383093695137
# Processing parameter set 12125.
#
# 1.60779010698026
# Processing parameter set 12126.
#
# 1.616921392618614
# Processing parameter set 12127.
#
# 1.6120571962086603
# Processing parameter set 12128.
#
# 1.6195347739520363
# Processing parameter set 12129.
#
# 1.6171399664437762
# Processing parameter set 12130.
#
# 1.6206295715027823
# Processing parameter set 12131.
#
# 1.6130355997856762
# Processing parameter set 12132.
#
# 1.6224877680807228
# Processing parameter set 12133.
#
# 1.60789215153834
# Processing parameter set 12134.
#
# 1.6082717741860129
# Processing parameter set 12135.
#
# 1.6135923699920836
# Processing parameter set 12136.
#
# 1.6366403738881588
# Processing parameter set 12137.
#
# 1.6166416693101888
# Processing parameter set 12138.
#
# 1.614067799435086
# Processing parameter set 12139.
#
# 1.6180724908389281
# Processing parameter set 12140.
#
# 1.6125748031267866
# Processing parameter set 12141.
#
# 1.6141932842348063
# Processing parameter set 12142.
#
# 1.6142074864555287
# Processing parameter set 12143.
#
# 1.6167779913512195
# Processing parameter set 12144.
#
# 1.6156565565049317
# Processing parameter set 12145.
#
# 1.6113072317038448
# Processing parameter set 12146.
#
# 1.6186967988687424
# Processing parameter set 12147.
#
# 1.609008251073016
# Processing parameter set 12148.
#
# 1.6133466935004048
# Processing parameter set 12149.
#
# 1.6122552896824447
# Processing parameter set 12150.
#
# 1.6166112407329916
# Processing parameter set 12151.
#
# 1.6108369798790025
# Processing parameter set 12152.
#
# 1.6153184240081884
# Processing parameter set 12153.
#
# 1.6177163783047912
# Processing parameter set 12154.
#
# 1.6183801792088095
# Processing parameter set 12155.
#
# 1.6208699817327406
# Processing parameter set 12156.
#
# 1.6169764022778386
# Processing parameter set 12157.
#
# 1.615519423202303
# Processing parameter set 12158.
#
# 1.6113645887098362
# Processing parameter set 12159.
#
# 1.6140807706534888
# Processing parameter set 12160.
#
# 1.6218870099272986
# Processing parameter set 12161.
#
# 1.6163370130384598
# Processing parameter set 12162.
#
# 1.616829098583137
# Processing parameter set 12163.
#
# 1.6176071940327055
# Processing parameter set 12164.
#
# 1.6125779074498439
# Processing parameter set 12165.
#
# 1.6250350782478102
# Processing parameter set 12166.
#
# 1.6173000321428321
# Processing parameter set 12167.
#
# 1.6295321133854135
# Processing parameter set 12168.
#
# 1.610800533972408
# Processing parameter set 12169.
#
# 1.6076668399893659
# Processing parameter set 12170.
#
# 1.6119442566147417
# Processing parameter set 12171.
#
# 1.6164111653099682
# Processing parameter set 12172.
#
# 1.6187932878668312
# Processing parameter set 12173.
#
# 1.6153454905613724
# Processing parameter set 12174.
#
# 1.613955180417452
# Processing parameter set 12175.
#
# 1.612685080350704
# Processing parameter set 12176.
#
# 1.6173437013740748
# Processing parameter set 12177.
#
# 1.609081544556676
# Processing parameter set 12178.
#
# 1.6196871461111133
# Processing parameter set 12179.
#
# 1.6193106829907253
# Processing parameter set 12180.
#
# 1.6124228333315487
# Processing parameter set 12181.
#
# 1.6123934442050532
# Processing parameter set 12182.
#
# 1.6177383093695137
# Processing parameter set 12183.
#
# 1.6088843790800225
# Processing parameter set 12184.
#
# 1.616921392618614
# Processing parameter set 12185.
#
# 1.6120571962086603
# Processing parameter set 12186.
#
# 1.6195347739520363
# Processing parameter set 12187.
#
# 1.6164490043980404
# Processing parameter set 12188.
#
# 1.6206295715027823
# Processing parameter set 12189.
#
# 1.6130355997856762
# Processing parameter set 12190.
#
# 1.6224877680807228
# Processing parameter set 12191.
#
# 1.60789215153834
# Processing parameter set 12192.
#
# 1.6101820422925928
# Processing parameter set 12193.
#
# 1.6135923699920836
# Processing parameter set 12194.
#
# 1.6366403738881588
# Processing parameter set 12195.
#
# 1.6166416693101888
# Processing parameter set 12196.
#
# 1.614067799435086
# Processing parameter set 12197.
#
# 1.6180724908389281
# Processing parameter set 12198.
#
# 1.6125748031267866
# Processing parameter set 12199.
#
# 1.6141932842348063
# Processing parameter set 12200.
#
# 1.6142074864555287
# Processing parameter set 12201.
#
# 1.6167779913512195
# Processing parameter set 12202.
#
# 1.6156565565049317
# Processing parameter set 12203.
#
# 1.6113072317038448
# Processing parameter set 12204.
#
# 1.6186967988687424
# Processing parameter set 12205.
#
# 1.609033941310064
# Processing parameter set 12206.
#
# 1.6121297910642518
# Processing parameter set 12207.
#
# 1.6122552896824447
# Processing parameter set 12208.
#
# 1.6166112407329916
# Processing parameter set 12209.
#
# 1.6108369798790025
# Processing parameter set 12210.
#
# 1.615345238539789
# Processing parameter set 12211.
#
# 1.6128751410862578
# Processing parameter set 12212.
#
# 1.6183801792088095
# Processing parameter set 12213.
#
# 1.6208699817327406
# Processing parameter set 12214.
#
# 1.6169764022778386
# Processing parameter set 12215.
#
# 1.6089376232690402
# Processing parameter set 12216.
#
# 1.6136294815513696
# Processing parameter set 12217.
#
# 1.6140807706534888
# Processing parameter set 12218.
#
# 1.6218870099272986
# Processing parameter set 12219.
#
# 1.6163370130384598
# Processing parameter set 12220.
#
# 1.616829098583137
# Processing parameter set 12221.
#
# 1.6176071940327055
# Processing parameter set 12222.
#
# 1.6125779074498439
# Processing parameter set 12223.
#
# 1.6250350782478102
# Processing parameter set 12224.
#
# 1.6173000321428321
# Processing parameter set 12225.
#
# 1.6295321133854135
# Processing parameter set 12226.
#
# 1.610297771930871
# Processing parameter set 12227.
#
# 1.608518831586567
# Processing parameter set 12228.
#
# 1.6119442566147417
# Processing parameter set 12229.
#
# 1.6164111653099682
# Processing parameter set 12230.
#
# 1.6187932878668312
# Processing parameter set 12231.
#
# 1.6153454905613724
# Processing parameter set 12232.
#
# 1.613955180417452
# Processing parameter set 12233.
#
# 1.612685080350704
# Processing parameter set 12234.
#
# 1.6197085079289713
# Processing parameter set 12235.
#
# 1.6106039223031763
# Processing parameter set 12236.
#
# 1.6196871461111133
# Processing parameter set 12237.
#
# 1.60766307072296
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-4dadf9b2902f> in <module>
# ----> 1 fit.fnPullMolgroup(['protein'], sparse=sparse)
#
# ~/Dropbox/My Mac (PN115993.campus.nist.gov)/Documents/programming/molgroups/PlottingAndAnalysis/rs.py in fnPullMolgroup(self, liMolgroupNames, sparse)
#    2479         Saves results to file
#    2480         """
# -> 2481         diarea, dinsl, dinsld = self.fnPullMolgroupLoader(liMolgroupNames, sparse)
#    2482         diStat = self.fnPullMolgroupWorker(diarea, dinsl, dinsld)
#    2483
#
# ~/Dropbox/My Mac (PN115993.campus.nist.gov)/Documents/programming/molgroups/PlottingAndAnalysis/rs.py in fnPullMolgroupLoader(self, liMolgroupNames, sparse)
#    2506
#    2507         diarea = {
# -> 2508             'zaxis': self.diStatResults['Molgroups'][0][list(self.diStatResults['Molgroups'][0].keys())[0]]['zaxis']}
#    2509         dinsl = {
#    2510             'zaxis': self.diStatResults['Molgroups'][0][list(self.diStatResults['Molgroups'][0].keys())[0]]['zaxis']}
#
# IndexError: list index out of range

# %%
fit.diStatResults
