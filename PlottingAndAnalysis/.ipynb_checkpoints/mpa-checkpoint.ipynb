# %%
import rs
import os
# !pwd
# Out:
# /Users/frank/Dropbox/My Mac (PN115993.campus.nist.gov)/Documents/programming/molgroups/PlottingAndAnalysis

# %% [markdown]
# ## Define result directory and set up fit source
# The results directory is the save directory for the refl1d/bumps/garefl fit, which is typically one directory level up from the fit setup. If a garefl fit does not use MCMC, give the setup directory.
# The runfile is either the Python or C++ setup file. The refl1d Python runfile for a garefl fit is expected to be run.py.

# %%
# Bumps Test
setupdir = '/Users/frank/Desktop/DiffractionTest'
mcmcstor = setupdir + '/T1'
runfile = 'run-ff'
fitsource = 'bumps'

# Refl1D Test
# setupdir = '/Users/frank/Desktop/ssBLMtest'
# mcmcstor = setupdir + '/Output'
# runfile = 'ssblm_tiox_both'
# fitsource = 'refl1d'


# Garefl test
# setupdir = '/Users/frank/Desktop/garefltest'
# mcmcstor = setupdir + '/MCMC_64000_500'
# runfile = 'setup.cc'
# fitsource = 'garefl'

# Clean up previous results files
# TODO: Come up with a scheme on how to handle result files (keep or delete)
os.chdir(setupdir)
if os.path.isfile(mcmcstor + '/sErr.dat'):
    os.remove(mcmcstor + '/sErr.dat')
if os.path.isfile(mcmcstor + '/isErr.dat'):
    os.remove(mcmcstor + '/isErr.dat')
if os.path.isfile(mcmcstor + '/StatDataPython.dat'):
    os.remove(mcmcstor + '/StatDataPython.dat')

fit = rs.CMolStat(fitsource=fitsource, spath=setupdir, mcmcpath=mcmcstor, runfile=runfile)

# %% [markdown]
# ## Load MCMC information bumps / refl1d files

# %%
#fit.fnLoadStatData(sparse=0)
#fit.fnLoadParameters()
sparse = 0.002
fit.fnAnalyzeStatFile(fConfidence=-1, sparse=sparse)
# Out:
# In bilayer function!!
#
# In bilayer function!!
#
# Analysis of current MC simulation ...
# Number of iterations: 32
#           background_ch061  [|-|        ]  [    -1e-07,     1e-05]  [ 3.322e-07(0.002),  1.131e-06(0.002),  1.974e-06(0.002)] (- 7.991e-07, + 8.423e-07)
#            intensity_ch061  [     |  -| ]  [       0.9,      1.05]  [    0.9759(0.008),      1.027(0.000),      1.041(0.002)] (-   0.05124, +   0.01341)
#             siox_interface  [       | -|]  [         2,         9]  [     6.674(0.004),      7.962(0.005),      8.773(0.016)] (-     1.288, +    0.8111)
#                   siox_rho  [| -    |   ]  [       3.1,       5.1]  [     3.196(0.000),       3.44(0.007),      4.475(0.001)] (-    0.2438, +     1.036)
#             siox_thickness  [ |      - |]  [         5,        40]  [     9.904(0.005),      32.29(0.016),      38.54(0.014)] (-     22.39, +     6.253)
#                   tiox_rho  [   |-|     ]  [     1.163,     3.163]  [     1.775(0.000),      1.921(0.004),      2.137(0.000)] (-    0.1463, +    0.2154)
#                    d2o_rho  [      |+   ]  [       5.3,       6.5]  [     6.024(0.001),      6.127(0.001),      6.173(0.000)] (-    0.1033, +    0.0463)
#        substrate_roughness  [  |  -  |  ]  [         2,         9]  [     3.266(0.010),      5.523(0.017),      7.519(0.003)] (-     2.258, +     1.995)
# inner_acyl_chain_thickness  [|- |       ]  [         8,        16]  [     8.309(0.001),      9.022(0.004),      10.53(0.013)] (-    0.7129, +     1.513)
# outer_acyl_chain_thickness  [|-|        ]  [         8,        16]  [      8.27(0.000),      8.599(0.002),      9.348(0.002)] (-    0.3287, +    0.7488)
#      submembrane_thickness  [  |   -  | ]  [         0,        50]  [     8.447(0.001),       29.1(0.005),      44.78(0.010)] (-     20.65, +     15.69)
#          bilayer_roughness  [| - |      ]  [         2,         9]  [     2.242(0.001),      3.225(0.001),      4.585(0.003)] (-    0.9823, +      1.36)
#    volume_fraction_bilayer  [      |-|  ]  [         0,         1]  [    0.5528(0.002),     0.6732(0.015),     0.7741(0.001)] (-    0.1203, +     0.101)
#           background_ch060  [   | -|    ]  [    -1e-07,     1e-05]  [ 2.794e-06(0.004),  4.809e-06(0.005),   5.85e-06(0.002)] (- 2.015e-06, + 1.042e-06)
#                    h2o_rho  [   | - |   ]  [      -0.6,       0.6]  [   -0.2687(0.006),   -0.04433(0.002),      0.214(0.001)] (-    0.2243, +    0.2583)
#       total_tiox_thickness  [     |- |  ]  [        50,       150]  [     103.9(0.001),      111.7(0.004),      126.6(0.010)] (-     7.862, +     14.87)
# Maximum deviation from average over last 5 iterations: 0.0407
# Confidence level: 0.6827

# %%
fit.fnPullMolgroup(['lipid1'], sparse=sparse)
# Out:
# Failure to load StatDataPython.dat.
# Recreate statistical data from sErr.dat.
# Found sErr.dat
#
# Processing parameter set 0.
#
# In bilayer function!!
#
# 81.63669327724936
# In bilayer function!!
#
# 14.970860072380008
# Processing parameter set 1.
#
# In bilayer function!!
#
# 68.36570991889404
# In bilayer function!!
#
# 57.45511598015953
# Processing parameter set 2.
#
# In bilayer function!!
#
# 105.77789572034794
# In bilayer function!!
#
# 5.786600188214693
# Processing parameter set 3.
#
# In bilayer function!!
#
# 86.36329518545502
# In bilayer function!!
#
# 33.70313015802422
# Processing parameter set 4.
#
# In bilayer function!!
#
# 137.73361272267996
# In bilayer function!!
#
# 6.08229840945901
# Processing parameter set 5.
#
# In bilayer function!!
#
# 72.58765252272214
# In bilayer function!!
#
# 24.11334876704177
# Processing parameter set 6.
#
# In bilayer function!!
#
# 51.495769093360146
# In bilayer function!!
#
# 42.41966141443795
# Processing parameter set 7.
#
# In bilayer function!!
#
# 67.24059404622608
# In bilayer function!!
#
# 43.976382944310636
# Processing parameter set 8.
#
# In bilayer function!!
#
# 54.9705297145789
# In bilayer function!!
#
# 32.87160859705761
# Processing parameter set 9.
#
# In bilayer function!!
#
# 59.00198057990628
# In bilayer function!!
#
# 24.634402708015877
# Processing parameter set 10.
#
# In bilayer function!!
#
# 57.188465721285134
# In bilayer function!!
#
# 26.346981772379657
# Processing parameter set 11.
#
# In bilayer function!!
#
# 95.34109377854215
# In bilayer function!!
#
# 18.17386213575196
# Processing parameter set 12.
#
# In bilayer function!!
#
# 80.94899410310342
# In bilayer function!!
#
# 37.29880470014391
# Processing parameter set 13.
#
# In bilayer function!!
#
# 43.64705297426602
# In bilayer function!!
#
# 21.473156922976273
# Processing parameter set 14.
#
# In bilayer function!!
#
# 102.64778365747722
# In bilayer function!!
#
# 13.63396963467735
# Processing parameter set 15.
#
# In bilayer function!!
#
# 78.36014866850164
# In bilayer function!!
#
# 28.412775918572084
# Processing parameter set 16.
#
# In bilayer function!!
#
# 94.59485260963638
# In bilayer function!!
#
# 6.087013802992005
# Processing parameter set 17.
#
# In bilayer function!!
#
# 65.64334294662754
# In bilayer function!!
#
# 28.58087654534291
# Processing parameter set 18.
#
# In bilayer function!!
#
# 126.64628541417628
# In bilayer function!!
#
# 22.524798304606563
# Processing parameter set 19.
#
# In bilayer function!!
#
# 61.63814689963671
# In bilayer function!!
#
# 34.287982928845445
# Processing parameter set 20.
#
# In bilayer function!!
#
# 68.5680751085198
# In bilayer function!!
#
# 11.42581217856273
# Processing parameter set 21.
#
# In bilayer function!!
#
# 51.80443746868354
# In bilayer function!!
#
# 28.744312854604164
# Processing parameter set 22.
#
# In bilayer function!!
#
# 45.77401878459372
# In bilayer function!!
#
# 32.60751686623209
# Processing parameter set 23.
#
# In bilayer function!!
#
# 44.92595596770351
# In bilayer function!!
#
# 27.30204542927714
# Processing parameter set 24.
#
# In bilayer function!!
#
# 67.36838502694008
# In bilayer function!!
#
# 27.773088420816382
# Processing parameter set 25.
#
# In bilayer function!!
#
# 56.67793856728862
# In bilayer function!!
#
# 18.88295024331091
# Processing parameter set 26.
#
# In bilayer function!!
#
# 62.66881287484908
# In bilayer function!!
#
# 22.313555351696923
# Processing parameter set 27.
#
# In bilayer function!!
#
# 41.2365639205522
# In bilayer function!!
#
# 17.247449823122
# Processing parameter set 28.
#
# In bilayer function!!
#
# 42.95593633867966
# In bilayer function!!
#
# 39.40144716405798
# Processing parameter set 29.
#
# In bilayer function!!
#
# 48.583254552130505
# In bilayer function!!
#
# 27.06854119515558
# Processing parameter set 30.
#
# In bilayer function!!
#
# 41.29088161013204
# In bilayer function!!
#
# 16.242064043889037
# Processing parameter set 31.
#
# In bilayer function!!
#
# 43.07974879715531
# In bilayer function!!
#
# 19.143066637959567

# %%
fit.fnCreateBilayerPlotData()
# Out:
# Initializing ...
# Pulling all molgroups ...
#   substrate ...
# Loaded statistical data from StatDataPython.dat
#   siox ...
# Loaded statistical data from StatDataPython.dat
#   tether ...
# Loaded statistical data from StatDataPython.dat
# Molecular group bME does not exist.
# Molecular group tetherg does not exist.
# Molecular group tether does not exist.
#   innerhg ...
# Loaded statistical data from StatDataPython.dat
#   innerhc ...
# Loaded statistical data from StatDataPython.dat
#   outerhc ...
# Loaded statistical data from StatDataPython.dat
#   outerhg ...
# Loaded statistical data from StatDataPython.dat
#   protein ...
# Loaded statistical data from StatDataPython.dat
# Molecular group protein does not exist.
# Applying corrections ...
#
# Calculating statistics ...
#
# Saving data to bilayerplotdata.dat ...

# %%
fit.fnCalculateMolgroupProperty(fConfidence=-1)
# Out:
# Loaded statistical data from StatDataPython.dat
# Did not find any fractional envelopes ...
# WaterFracHeadgroup1  [    0.6801,       0.72,     0.7618] (-   0.03981, +   0.04189)
# WaterFracHeadgroup2  [    0.6656,     0.7043,     0.7532] (-   0.03871, +   0.04892)
# WaterFracHydrocarbon  [    0.2618,     0.3303,     0.4125] (-   0.06851, +   0.08221)
# WaterFracLipid1  [    0.2666,     0.3354,     0.4139] (-   0.06876, +   0.07855)
# WaterFracLipid2  [    0.2591,     0.3249,     0.4158] (-    0.0658, +   0.09093)
# WaterFracSubMembrane  [    0.9918,      0.996,     0.9975] (-  0.004201, +  0.001446)
# defect_hc_AVG  [    0.3806,     0.6047,     0.9604] (-    0.2241, +    0.3556)
# defect_hc_COM  [      68.9,      69.47,      70.32] (-    0.5751, +    0.8533)
# defect_hc_INT  [    0.5925,     0.9124,      1.463] (-      0.32, +    0.5508)
# defect_hg_AVG  [     0.121,     0.1571,     0.2143] (-   0.03605, +   0.05724)
# defect_hg_COM  [      68.9,      69.47,      70.32] (-    0.5751, +    0.8533)
# defect_hg_INT  [    0.1863,     0.2529,      0.336] (-   0.06661, +   0.08316)
# fAreaPerLipid2  [     88.39,      96.08,       99.9] (-     7.697, +     3.819)
# fTotalLipid1Length  [     9.303,       10.1,      11.79] (-    0.7982, +     1.694)
# fTotalLipid2Length  [     9.259,      9.627,      10.47] (-     0.368, +    0.8384)
# headgroup1_2_AVG  [         0,          0,          0] (-         0, +         0)
# headgroup1_2_COM  [     1e+05,      1e+05,      1e+05] (-         0, +         0)
# headgroup1_2_INT  [         0,          0,          0] (-         0, +         0)
# headgroup1_3_AVG  [         0,          0,          0] (-         0, +         0)
# headgroup1_3_COM  [     1e+05,      1e+05,      1e+05] (-         0, +         0)
# headgroup1_3_INT  [         0,          0,          0] (-         0, +         0)
# headgroup1_AVG  [     1.251,      1.494,      1.786] (-    0.2436, +    0.2916)
# headgroup1_COM  [     55.37,      55.37,      55.37] (- 7.105e-15, +         0)
# headgroup1_INT  [     1.997,       2.32,      2.734] (-    0.3238, +    0.4137)
# headgroup2_2_AVG  [         0,          0,          0] (-         0, +         0)
# headgroup2_2_COM  [     1e+05,      1e+05,      1e+05] (-         0, +         0)
# headgroup2_2_INT  [         0,          0,          0] (-         0, +         0)
# headgroup2_3_AVG  [         0,          0,          0] (-         0, +         0)
# headgroup2_3_COM  [     1e+05,      1e+05,      1e+05] (-         0, +         0)
# headgroup2_3_INT  [         0,          0,          0] (-         0, +         0)
# headgroup2_AVG  [     1.183,      1.441,      1.657] (-    0.2575, +    0.2161)
# headgroup2_COM  [     82.42,      83.57,      85.28] (-      1.15, +     1.707)
# headgroup2_INT  [     1.854,      2.345,      2.592] (-    0.4904, +    0.2471)
# lipid1_AVG  [     3.219,      3.846,      4.597] (-     0.627, +    0.7504)
# lipid1_COM  [     64.61,      65.03,      65.68] (-    0.4104, +    0.6562)
# lipid1_INT  [     5.139,      5.972,      7.037] (-    0.8333, +     1.065)
# lipid2_AVG  [     3.045,      3.708,      4.264] (-    0.6627, +    0.5562)
# lipid2_COM  [     72.96,      74.21,      75.61] (-     1.243, +     1.403)
# lipid2_INT  [     4.772,      6.034,       6.67] (-     1.262, +    0.6361)
# methyl1_AVG  [     0.385,       0.46,     0.5497] (-   0.07498, +   0.08974)
# methyl1_COM  [     68.31,      69.06,      70.66] (-    0.7556, +     1.603)
# methyl1_INT  [    0.6145,     0.7142,     0.8415] (-   0.09965, +    0.1273)
# methyl2_AVG  [    0.3641,     0.4434,     0.5099] (-   0.07925, +   0.06651)
# methyl2_COM  [     69.35,      70.09,      71.79] (-    0.7377, +     1.704)
# methyl2_INT  [    0.5707,     0.7216,     0.7977] (-    0.1509, +   0.07606)
# normarea_AVG  [     88.39,      96.08,       99.9] (-     7.697, +     3.819)
# normarea_COM  [     74.75,      74.75,      74.75] (-         0, + 1.421e-14)
# normarea_INT  [       150,        150,        150] (- 6.537e-13, + 6.821e-13)
# siox_AVG  [         0,          0,          0] (-         0, +         0)
# siox_COM  [     1e+05,      1e+05,      1e+05] (-         0, +         0)
# siox_INT  [         0,          0,          0] (-         0, +         0)
# substrate_AVG  [     11.93,      12.97,      13.49] (-      1.04, +    0.5147)
# substrate_COM  [     10.14,      10.63,      11.27] (-    0.4892, +    0.6404)
# substrate_INT  [     20.25,      20.25,      20.25] (-  0.002306, +  0.001212)
