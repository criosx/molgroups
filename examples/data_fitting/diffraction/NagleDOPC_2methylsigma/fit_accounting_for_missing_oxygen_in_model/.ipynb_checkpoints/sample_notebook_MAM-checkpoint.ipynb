# %% [markdown]
# # Imports

# %%
# !pwd
import sys
sys.path.append("..")
from bumps.names import Curve, fit, FitProblem
from bumps.dream.state import load_state
import matplotlib.pyplot as plt
import numpy as np
import scipy.fft as fft
import os

sys.path.append("../../../../../src/scatpy/")
import rs
import rsdi

sys.path.append("../../../../../src/molgroups/")
import molgroups as mol
import lipids
# Out:
# /Users/frank/Dropbox/My Mac (PN115993.campus.nist.gov)/Documents/programming/molgroups/examples/data_fitting/diffraction/NagleDOPC_2methylsigma/fit_accounting_for_missing_oxygen_in_model

# %% [markdown]
# # Variables

# %%
ed2sld = 2.814e-5
# bulk sld used during form factor calculation from experimental data
bulksld_ffc = 0.333 * ed2sld

maxarea = 100
stepsize = 0.1
#make sure dimension is odd
dimension = 1501
startz = 50

store = "T4"
setupdir = os.getcwd()
runfile = "run"
fitsource = "bumps"

if not os.path.isdir(store):
    os.mkdir(store)

run = True
burn = 1500
steps = 500

# %% [markdown]
# # Functions

# %%
def getSLD(aArea, aSL, normArea, bulksld):
    aSLD = np.zeros(dimension).tolist()
    
    # bulksld_ffc can be replaced by bulksld if it is assumed that during form factor calculation
    # the correct subtraction was applied
    
    for i in range(dimension):
        if aArea[i] != 0:
            aSLD[i] = aSL[i] / (aArea[i] * stepsize) * aArea[i] / normArea + bulksld_ffc * (1 - aArea[i] / normArea)
        else:
            aSLD[i] = bulksld_ffc
    return aSLD

# %%
def symmetrize(aSLD, bulksld):
    center = bilayer.fnGetCenter()
    center = int(center/stepsize+0.5)
    canvas_center = len(aSLD) // 2
    n = int(canvas_center - center)
    centered_bilayer = np.roll(aSLD, n)
    symmetrized_bilayer = np.add(centered_bilayer, centered_bilayer[::-1]) * 0.5
    symmetrized_bilayer -= bulksld
    return symmetrized_bilayer

# %%
def computeFormFactor(lq, aSLD, prefactor, dq, offset, stepsize, DCTtype=1):

    half_bilayer = aSLD[int(len(aSLD)/2) :]

    # TODO: Make sure that lq and x are roughly comparable
    # dimension should be odd
    dct_dimension = 5001
    
    # DCT is unnormalized, except for stepsize, which ensures that FO obeys the integral norm
    F = fft.dct(half_bilayer, n=dct_dimension, type=DCTtype) * stepsize
    F = np.abs(F)
    # normalization by integral of FF
    #sum = F.sum() * np.pi / (2 * dct_dimension * stepsize) * (2 * 1) * dq
    #if sum != 0:
    #    F /= sum
    x = np.array(
        [
            np.pi / (2 * dct_dimension * stepsize) * (2 * i) * dq
            for i in range(dct_dimension)
        ]
    )

    # interpolate (x, F) onto lq -> (lq, modelform)
    return np.interp(lq, x, F, period=None) * prefactor - offset

# %%
def setBilayer(
    l_lipid, va1, vm1, l_choline, v_choline, l_cg, v_cg, l_phosphate, v_phosphate, sigma, rel_pos, hg1_thickness, methyl_sigma, methyl_sigma2, nf_methyl2, bulksld):
    bilayer.methylene1_1.vol=va1-vm1
    bilayer.methylene2_1.vol=va1-vm1
    bilayer.methyl1_1.vol=vm1
    bilayer.methyl2_1.vol=vm1

    choline_SL = 1.407e-3
    phosphate_SL = 1.323e-3
    cg_SL = 1.885e-3 - (8*0.00002814) # one O is missing
    
    bilayer.headgroups1[0].choline.vol = bilayer.headgroups2[0].choline.vol = v_choline #108.6 # was 120
    bilayer.headgroups1[0].phosphate.vol = bilayer.headgroups2[0].phosphate.vol = v_phosphate #54
    bilayer.headgroups1[0].cg.vol = bilayer.headgroups2[0].cg.vol = v_cg # 156.2-15 # was 147

    bilayer.headgroups1[0].choline.l = bilayer.headgroups2[0].choline.l = l_choline
    bilayer.headgroups1[0].phosphate.l = bilayer.headgroups2[0].phosphate.l = l_phosphate
    bilayer.headgroups1[0].cg.l = bilayer.headgroups2[0].cg.l = l_cg

    bilayer.headgroups1[0].fnSet(hg1_thickness, rel_pos, cg_SL, choline_SL, phosphate_SL)
    bilayer.headgroups1[0].fnSetSigma(sigma)
    bilayer.headgroups2[0].fnSet(hg1_thickness, rel_pos, cg_SL, choline_SL, phosphate_SL)
    bilayer.headgroups2[0].fnSetSigma(sigma)

    bilayer.methyl_sigma[0] = methyl_sigma
    
    bilayer.headgroups1[1].choline.vol = bilayer.headgroups2[0].choline.vol = v_choline #108.6 # was 120
    bilayer.headgroups1[1].phosphate.vol = bilayer.headgroups2[0].phosphate.vol = v_phosphate #54
    bilayer.headgroups1[1].cg.vol = bilayer.headgroups2[0].cg.vol = v_cg # 156.2-15 # was 147

    bilayer.headgroups1[1].choline.l = bilayer.headgroups2[0].choline.l = l_choline
    bilayer.headgroups1[1].phosphate.l = bilayer.headgroups2[0].phosphate.l = l_phosphate
    bilayer.headgroups1[1].cg.l = bilayer.headgroups2[0].cg.l = l_cg

    bilayer.headgroups1[1].fnSet(hg1_thickness, rel_pos, cg_SL, choline_SL, phosphate_SL)
    bilayer.headgroups1[1].fnSetSigma(sigma)
    bilayer.headgroups2[1].fnSet(hg1_thickness, rel_pos, cg_SL, choline_SL, phosphate_SL)
    bilayer.headgroups2[1].fnSetSigma(sigma)

    bilayer.methyl_sigma[1] = methyl_sigma2
    
    bilayer.inner_lipid_nf = np.array([1-nf_methyl2, nf_methyl2])
    bilayer.outer_lipid_nf = np.array([1-nf_methyl2, nf_methyl2])

    bilayer.fnSet(sigma, bulksld, startz, l_lipid, l_lipid, vf_bilayer=1)

# %%
def modelformfactor(
    lq,
    l_lipid,
    va1,
    vm1,
    l_choline,
    v_choline,
    l_cg,
    v_cg,
    l_phosphate,
    v_phosphate,
    sigma,
#    prefactor,
#    dq,
#    offset,
    rel_pos,
    hg1_thickness,
    methyl_sigma,
    methyl_sigma2,
    nf_methyl2,
    bulksld
):
    setBilayer(
        l_lipid,
        va1,
        vm1,
        l_choline,
        v_choline,
        l_cg,
        v_cg,
        l_phosphate,
        v_phosphate,
        sigma,
        rel_pos,
        hg1_thickness,
        methyl_sigma,
        methyl_sigma2,
        nf_methyl2,
        bulksld
    )
    
    #set all unused parameters
    dq=1.0
    prefactor = 1.0
    offset=0.
    
    z = np.linspace(0, dimension * stepsize, dimension, endpoint=False)
    normArea, aArea, aSL = bilayer.fnWriteProfile(z)
    aSLD = getSLD(aArea, aSL, normArea, bulksld)
    aSLD = symmetrize(aSLD, bulksld)
    modelform = computeFormFactor(lq, aSLD/ed2sld, prefactor, dq, offset, stepsize)
    
    # save a bunch of parameters when restoring problem states
    problem.extra = bilayer
    problem.stepsize = stepsize
    problem.dimension = dimension
    problem.sld = aSLD
    problem.moldat = bilayer.fnWritePar2Dict({}, 'bilayer', z)
   
    return modelform

# %% [markdown]
# # Fit Setup

# %%
F2 = np.loadtxt("xff.dat")
F2 = F2[np.argsort(F2[:, 0])]
q_exp = F2[:, 0]
form_exp = F2[:, 1]
# constant error bar estimate of .05 Å
dform_exp = [0.01] * len(form_exp)

# %% [markdown]
# Set scattering lengths, volumes, lengths
# | abb | name |
# | :- | :- |
# |va1 |Volume acyl chains, lipid 1|
# |na1 |SL acyl chains, lipid 1|
# |vm1 |Volume methyl groups, lipid 1|
# |nm1 |SL methyl groups, lipid 1|
# |vh1 |Headgroup volume, lipid 1|
# |nh1 |SL headgroup, lipid 1|
# |lh1 |Length headgroup, lipid 1|
# |va2 |Volume acyl chains, lipid 2|
# |na2 |SL acyl chains, lipid 2|
# |vm2 |Volume methyl groups, lipid 2|
# |nm2 |SL methyl groups, lipid 2|
# |vh2 |Headgroup volume, lipid 2|
# |nh2 |SL headgroup, lipid 2|
# |lh2 |Length headgroup, lipid 2|
# |va3 |Volume acyl chains, lipid 3|
# |na3 |SL acyl chains, lipid 3|
# |vm3 |Volume methyl groups, lipid 3|
# |nm3 |SL methyl groups, lipid 3|
# |vh3 |Headgroup volume, lipid 3|
# |nh3 |SL headgroup, lipid 3|
# |lh3 |Length headgroup, lipid 3|
# |vc  |volume cholesterol|
# |nc  |SL cholesterol|

# %%
bilayer = mol.BLM(lipids=[lipids.DOPC, lipids.DOPC], lipid_nf=[0.5, 0.5], xray_wavelength=1.514)

# %%
l_lipid_initial = 11
va1_initial=985.6
vm1_initial=100.4
l_choline_initial = 6.34
v_choline_initial = 120
l_cg_initial = 4.21
v_cg_initial = 147
l_phosphate_initial = 3.86
v_phosphate_initial = 54
sigma_initial = 2.0
bulksld_initial = 9.4114e-06
prefactor_initial = 1
dq_initial = 1
offset_initial = 0
rel_pos_initial = 0.5
methyl_sigma_initial = 0.1
methyl_sigma2_initial = 0.2
nf_methyl2_initial = 0.5
lh1 = 9.65

# %%
M2 = Curve(
    modelformfactor,
    q_exp,
    form_exp,
    dform_exp,
    l_lipid=l_lipid_initial,
    va1=va1_initial,
    vm1=vm1_initial,
    l_choline=l_choline_initial,
    v_choline=v_choline_initial,
    l_cg=l_cg_initial,
    v_cg=v_cg_initial,
    l_phosphate=l_phosphate_initial,
    v_phosphate=v_phosphate_initial,
    sigma=sigma_initial,
#    prefactor=prefactor_initial,
#    dq=dq_initial,
#    offset=offset_initial,
    rel_pos=rel_pos_initial,
    hg1_thickness=lh1,
    methyl_sigma=methyl_sigma_initial,
    methyl_sigma2=methyl_sigma2_initial,
    nf_methyl2=nf_methyl2_initial,
    bulksld=bulksld_initial
)

# %%
M2.l_lipid.range(9, 13)
M2.va1.range(950, 1005)
M2.vm1.range(90, 110)
M2.l_choline.range(2, 7.5)
M2.v_choline.range(100., 140.)
M2.l_cg.range(1, 7)
M2.v_cg.range(130., 170.)
M2.l_phosphate.range(0.1, 7)
M2.v_phosphate.range(40., 80.)
M2.sigma.range(1.0, 4.0)
#M2.prefactor.range(0.5, 1.5)
#M2.dq.range(0.95, 1.1)
#M2.offset.range(-0.1, 0.1)
M2.hg1_thickness.range(7, 12)
M2.rel_pos.range(0, 1)
M2.methyl_sigma.range(0, 3)
M2.methyl_sigma2.range(5, 10)
M2.nf_methyl2.range(0.1, 0.5)
M2.bulksld.range(9.35e-6, 9.42e-6)
# Out:
# Parameter(bulksld)

# %% [markdown]
# # Run the fit

# %%
model = M2
problem = FitProblem(model)

# %%
from bumps.mapper import MPMapper

mapper = MPMapper.start_mapper(problem, None, cpus=0)  # cpus=0 for all CPUs
if run:
    result = fit(
        problem,
        method="dream",
        mapper = mapper,
        samples=10,
        burn=burn,
        steps=steps,
        thin=1,
        alpha=0,
        outliers="none",
        trim="none",
        verbose=True,
    )
    res_state = result.state
    res_state.save(store + "/" + runfile)  # save chains
    problem.fitness.save(store + "/" + runfile)  # save fit plot data

else:
    print(os.getcwd() + "/" + store + "/" + runfile)
    res_state = load_state(os.getcwd() + "/" + store + "/" + runfile)
    res_state.mark_outliers()
# Out:
# # steps: 500, # draws: 80000
# step 1 cost 360.533(18)
#                                  bulksld ........|. 9.4114e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness .....|....       9.65 in (7,12)
#                                     l_cg .....|....       4.21 in (1,7)
#                                l_choline .......|..       6.34 in (2,7.5)
#                                  l_lipid .....|....         11 in (9,13)
#                              l_phosphate .....|....    3.86001 in (0.1,7)
#                             methyl_sigma |.........  0.0999971 in (0,3)
#                            methyl_sigma2 |.........          5 in (5,10)
#                               nf_methyl2 .........|        0.5 in (0.1,0.5)
#                                  rel_pos .....|....   0.500001 in (0,1)
#                                    sigma ...|......          2 in (1,4)
#                                     v_cg ....|.....        147 in (130,170)
#                                v_choline .....|....        120 in (100,140)
#                              v_phosphate ...|......         54 in (40,80)
#                                      va1 ......|...      985.6 in (950,1005)
#                                      vm1 .....|....      100.4 in (90,110)
# step 5 cost 360.460(18)
# step 9 cost 360.328(18)
# step 12 cost 360.030(18)
# step 16 cost 359.596(18)
# step 19 cost 355.412(18)
# step 22 cost 352.160(18)
# step 25 cost 331.529(18)
# step 28 cost 303.291(18)
# step 31 cost 303.291(18)
# step 35 cost 154.363(18)
# step 38 cost 102.025(18)
# step 41 cost 54.978(18)
# step 44 cost 49.520(18)
# step 47 cost 35.533(18)
# step 50 cost 24.085(18)
# step 53 cost 20.830(18)
# step 56 cost 15.779(18)
# step 59 cost 14.994(18)
# step 62 cost 12.279(18)
# step 65 cost 12.279(18)
# step 68 cost 12.251(18)
# step 71 cost 10.895(18)
# step 74 cost 10.874(18)
# step 77 cost 10.874(18)
# step 80 cost 10.874(18)
# step 83 cost 10.874(18)
#                                  bulksld .|........ 9.3574e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness ..|.......    8.02981 in (7,12)
#                                     l_cg ........|.     6.0059 in (1,7)
#                                l_choline .......|..    6.32792 in (2,7.5)
#                                  l_lipid .........|     12.892 in (9,13)
#                              l_phosphate ......|...    4.90701 in (0.1,7)
#                             methyl_sigma |.........   0.269747 in (0,3)
#                            methyl_sigma2 |.........    5.04952 in (5,10)
#                               nf_methyl2 .........|   0.474008 in (0.1,0.5)
#                                  rel_pos ...|......   0.349597 in (0,1)
#                                    sigma ....|.....    2.33572 in (1,4)
#                                     v_cg ....|.....    149.998 in (130,170)
#                                v_choline ......|...    125.135 in (100,140)
#                              v_phosphate .|........    45.5415 in (40,80)
#                                      va1 .....|....    979.593 in (950,1005)
#                                      vm1 .....|....    100.812 in (90,110)
# step 86 cost 10.874(18)
# step 89 cost 10.031(18)
# step 92 cost 9.824(18)
# step 95 cost 6.077(18)
# step 98 cost 6.077(18)
# step 101 cost 6.077(18)
# step 104 cost 6.077(18)
# step 107 cost 6.077(18)
# step 110 cost 6.077(18)
# step 113 cost 6.077(18)
# step 116 cost 6.077(18)
# step 119 cost 6.077(18)
# step 122 cost 6.077(18)
# step 125 cost 6.077(18)
# step 128 cost 6.077(18)
# step 131 cost 6.077(18)
# step 134 cost 5.579(18)
# step 137 cost 5.579(18)
# step 140 cost 5.579(18)
# step 143 cost 5.579(18)
# step 146 cost 5.579(18)
# step 149 cost 5.579(18)
# step 152 cost 5.333(18)
# step 155 cost 5.333(18)
# step 158 cost 5.333(18)
# step 161 cost 5.333(18)
# step 164 cost 4.914(18)
#                                  bulksld ..|....... 9.36456e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness |.........    7.38989 in (7,12)
#                                     l_cg ....|.....     3.6947 in (1,7)
#                                l_choline ......|...    5.70106 in (2,7.5)
#                                  l_lipid .........|    12.7462 in (9,13)
#                              l_phosphate .....|....    4.02184 in (0.1,7)
#                             methyl_sigma .|........   0.560598 in (0,3)
#                            methyl_sigma2 |.........    5.10819 in (5,10)
#                               nf_methyl2 .........|   0.477494 in (0.1,0.5)
#                                  rel_pos ......|...   0.677335 in (0,1)
#                                    sigma ....|.....    2.37884 in (1,4)
#                                     v_cg ..|.......    138.052 in (130,170)
#                                v_choline ....|.....    119.416 in (100,140)
#                              v_phosphate ..|.......    50.7862 in (40,80)
#                                      va1 ......|...    987.329 in (950,1005)
#                                      vm1 .........|    109.058 in (90,110)
# step 167 cost 4.914(18)
# step 170 cost 4.914(18)
# step 173 cost 4.914(18)
# step 176 cost 4.914(18)
# step 179 cost 4.914(18)
# step 182 cost 4.914(18)
# step 185 cost 4.914(18)
# step 188 cost 4.914(18)
# step 191 cost 4.907(18)
# step 194 cost 4.907(18)
# step 197 cost 4.907(18)
# step 200 cost 4.907(18)
# step 203 cost 4.907(18)
# step 206 cost 4.907(18)
# step 209 cost 4.907(18)
# step 212 cost 4.907(18)
# step 215 cost 4.907(18)
# step 218 cost 4.907(18)
# step 220 cost 4.907(18)
# step 223 cost 4.907(18)
# step 226 cost 4.907(18)
# step 229 cost 4.907(18)
# step 231 cost 4.907(18)
# step 234 cost 4.907(18)
#                                  bulksld ..|....... 9.36457e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness |.........    7.38989 in (7,12)
#                                     l_cg ....|.....     3.6947 in (1,7)
#                                l_choline ......|...    5.70107 in (2,7.5)
#                                  l_lipid .........|    12.7462 in (9,13)
#                              l_phosphate .....|....    4.02184 in (0.1,7)
#                             methyl_sigma .|........   0.324622 in (0,3)
#                            methyl_sigma2 |.........    5.10819 in (5,10)
#                               nf_methyl2 .........|   0.477494 in (0.1,0.5)
#                                  rel_pos ......|...   0.677335 in (0,1)
#                                    sigma ....|.....    2.37884 in (1,4)
#                                     v_cg ..|.......    138.052 in (130,170)
#                                v_choline ....|.....    119.416 in (100,140)
#                              v_phosphate ..|.......    50.7862 in (40,80)
#                                      va1 ......|...    987.328 in (950,1005)
#                                      vm1 .........|    109.058 in (90,110)
# step 237 cost 4.907(18)
# step 240 cost 4.907(18)
# step 243 cost 4.907(18)
# step 246 cost 4.907(18)
# step 249 cost 4.788(18)
# step 252 cost 4.788(18)
# step 255 cost 4.788(18)
# step 258 cost 4.272(18)
# step 261 cost 4.272(18)
# step 264 cost 4.272(18)
# step 267 cost 4.272(18)
# step 270 cost 4.272(18)
# step 273 cost 4.268(18)
# step 276 cost 4.268(18)
# step 279 cost 4.268(18)
# step 281 cost 4.268(18)
# step 283 cost 4.268(18)
# step 286 cost 4.268(18)
# step 289 cost 4.139(18)
# step 292 cost 4.139(18)
# step 295 cost 4.139(18)
# step 298 cost 4.139(18)
# step 300 cost 4.139(18)
# step 303 cost 4.139(18)
#                                  bulksld ..|....... 9.36542e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness |.........    7.09987 in (7,12)
#                                     l_cg .|........    2.11225 in (1,7)
#                                l_choline ......|...    5.61541 in (2,7.5)
#                                  l_lipid .........|    12.9902 in (9,13)
#                              l_phosphate |.........   0.478674 in (0.1,7)
#                             methyl_sigma ..|.......   0.700832 in (0,3)
#                            methyl_sigma2 |.........    5.03135 in (5,10)
#                               nf_methyl2 ........|.   0.429444 in (0.1,0.5)
#                                  rel_pos .....|....   0.529502 in (0,1)
#                                    sigma ....|.....     2.4861 in (1,4)
#                                     v_cg .....|....    150.619 in (130,170)
#                                v_choline |.........    101.224 in (100,140)
#                              v_phosphate ....|.....     59.879 in (40,80)
#                                      va1 .....|....    980.416 in (950,1005)
#                                      vm1 ........|.    106.693 in (90,110)
# step 306 cost 4.139(18)
# step 309 cost 4.139(18)
# step 312 cost 4.139(18)
# step 315 cost 4.139(18)
# step 318 cost 4.139(18)
# step 321 cost 4.139(18)
# step 324 cost 4.139(18)
# step 327 cost 4.139(18)
# step 330 cost 4.139(18)
# step 333 cost 4.139(18)
# step 336 cost 4.139(18)
# step 339 cost 4.139(18)
# step 342 cost 3.983(18)
# step 345 cost 3.983(18)
# step 348 cost 3.983(18)
# step 351 cost 3.983(18)
# step 354 cost 3.983(18)
# step 357 cost 3.983(18)
# step 360 cost 3.970(18)
# step 363 cost 3.970(18)
# step 366 cost 3.970(18)
# step 369 cost 3.970(18)
# step 372 cost 3.970(18)
# step 375 cost 3.970(18)
# step 378 cost 3.970(18)
# step 381 cost 3.970(18)
#                                  bulksld ..|....... 9.36738e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness ......|...    10.0003 in (7,12)
#                                     l_cg ....|.....    3.57837 in (1,7)
#                                l_choline ......|...    5.80409 in (2,7.5)
#                                  l_lipid .......|..    11.9562 in (9,13)
#                              l_phosphate |.........   0.496022 in (0.1,7)
#                             methyl_sigma ....|.....    1.48682 in (0,3)
#                            methyl_sigma2 |.........    5.08624 in (5,10)
#                               nf_methyl2 .........|   0.475867 in (0.1,0.5)
#                                  rel_pos .....|....    0.52052 in (0,1)
#                                    sigma ..|.......    1.79789 in (1,4)
#                                     v_cg |.........     132.29 in (130,170)
#                                v_choline ..|.......     111.05 in (100,140)
#                              v_phosphate .....|....    63.7108 in (40,80)
#                                      va1 ........|.    994.193 in (950,1005)
#                                      vm1 .........|    109.801 in (90,110)
# step 384 cost 3.970(18)
# step 387 cost 3.970(18)
# step 390 cost 3.970(18)
# step 393 cost 3.970(18)
# step 396 cost 3.970(18)
# step 399 cost 3.970(18)
# step 402 cost 3.970(18)
# step 405 cost 3.970(18)
# step 408 cost 3.970(18)
# step 411 cost 3.970(18)
# step 414 cost 3.970(18)
# step 417 cost 3.970(18)
# step 420 cost 3.970(18)
# step 423 cost 3.970(18)
# step 426 cost 3.970(18)
# step 429 cost 3.970(18)
# step 432 cost 3.970(18)
# step 435 cost 3.960(18)
# step 438 cost 3.960(18)
# step 441 cost 3.960(18)
# step 444 cost 3.960(18)
# step 447 cost 3.960(18)
# step 450 cost 3.960(18)
# step 453 cost 3.960(18)
# step 456 cost 3.960(18)
# step 459 cost 3.960(18)
#                                  bulksld ..|....... 9.36738e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness ......|...    10.0003 in (7,12)
#                                     l_cg ....|.....    3.57837 in (1,7)
#                                l_choline ......|...     5.8041 in (2,7.5)
#                                  l_lipid .......|..    11.9562 in (9,13)
#                              l_phosphate |.........   0.496023 in (0.1,7)
#                             methyl_sigma ....|.....    1.48682 in (0,3)
#                            methyl_sigma2 |.........     5.0723 in (5,10)
#                               nf_methyl2 .........|   0.475868 in (0.1,0.5)
#                                  rel_pos .....|....    0.52052 in (0,1)
#                                    sigma ..|.......    1.79789 in (1,4)
#                                     v_cg |.........    132.291 in (130,170)
#                                v_choline ..|.......     111.05 in (100,140)
#                              v_phosphate .....|....    63.7108 in (40,80)
#                                      va1 ........|.    994.193 in (950,1005)
#                                      vm1 .........|    109.801 in (90,110)
# step 462 cost 3.960(18)
# step 465 cost 3.960(18)
# step 468 cost 3.960(18)
# step 471 cost 3.960(18)
# step 474 cost 3.960(18)
# step 477 cost 3.937(18)
# step 480 cost 3.937(18)
# step 483 cost 3.937(18)
# step 486 cost 3.937(18)
# step 489 cost 3.937(18)
# step 492 cost 3.937(18)
# step 495 cost 3.937(18)
# step 498 cost 3.937(18)
# step 501 cost 3.937(18)
# step 504 cost 3.937(18)
# step 507 cost 3.937(18)
# step 510 cost 3.937(18)
# step 513 cost 3.937(18)
# step 516 cost 3.937(18)
# step 519 cost 3.937(18)
# step 522 cost 3.937(18)
# step 525 cost 3.937(18)
# step 528 cost 3.937(18)
# step 531 cost 3.937(18)
# step 534 cost 3.937(18)
#                                  bulksld ..|....... 9.36739e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness ......|...    10.0003 in (7,12)
#                                     l_cg ....|.....    3.57837 in (1,7)
#                                l_choline ......|...    5.80411 in (2,7.5)
#                                  l_lipid .......|..    11.9562 in (9,13)
#                              l_phosphate |.........    0.73941 in (0.1,7)
#                             methyl_sigma ....|.....    1.48682 in (0,3)
#                            methyl_sigma2 |.........    5.07231 in (5,10)
#                               nf_methyl2 .........|   0.475868 in (0.1,0.5)
#                                  rel_pos .....|....   0.520519 in (0,1)
#                                    sigma ..|.......    1.79789 in (1,4)
#                                     v_cg |.........     132.29 in (130,170)
#                                v_choline ..|.......     111.05 in (100,140)
#                              v_phosphate .....|....    63.7107 in (40,80)
#                                      va1 ........|.    994.194 in (950,1005)
#                                      vm1 .........|    109.801 in (90,110)
# step 537 cost 3.937(18)
# step 540 cost 3.937(18)
# step 543 cost 3.937(18)
# step 546 cost 3.937(18)
# step 549 cost 3.937(18)
# step 552 cost 3.937(18)
# step 555 cost 3.937(18)
# step 558 cost 3.937(18)
# step 561 cost 3.937(18)
# step 563 cost 3.937(18)
# step 565 cost 3.937(18)
# step 568 cost 3.937(18)
# step 571 cost 3.937(18)
# step 573 cost 3.937(18)
# step 576 cost 3.937(18)
# step 577 cost 3.937(18)
# step 579 cost 3.937(18)
# step 581 cost 3.937(18)
# step 582 cost 3.937(18)
# step 584 cost 3.773(18)
# step 585 cost 3.773(18)
# step 587 cost 3.773(18)
# step 589 cost 3.773(18)
# step 591 cost 3.773(18)
#                                  bulksld .|........ 9.36077e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness ...|......    8.92321 in (7,12)
#                                     l_cg .|........    2.07462 in (1,7)
#                                l_choline .....|....    5.11312 in (2,7.5)
#                                  l_lipid ........|.    12.4982 in (9,13)
#                              l_phosphate ....|.....    3.07265 in (0.1,7)
#                             methyl_sigma ......|...    1.85593 in (0,3)
#                            methyl_sigma2 |.........    5.06754 in (5,10)
#                               nf_methyl2 ......|...   0.375314 in (0.1,0.5)
#                                  rel_pos .....|....   0.514973 in (0,1)
#                                    sigma ...|......    2.03353 in (1,4)
#                                     v_cg ..|.......    140.507 in (130,170)
#                                v_choline ......|...    125.805 in (100,140)
#                              v_phosphate .|........    45.1272 in (40,80)
#                                      va1 ......|...    985.617 in (950,1005)
#                                      vm1 .........|    109.299 in (90,110)
# step 593 cost 3.773(18)
# step 595 cost 3.773(18)
# step 597 cost 3.773(18)
# step 600 cost 3.773(18)
# step 603 cost 3.773(18)
# step 606 cost 3.773(18)
# step 609 cost 3.773(18)
# step 612 cost 3.773(18)
# step 615 cost 3.773(18)
# step 618 cost 3.773(18)
# step 621 cost 3.773(18)
# step 624 cost 3.773(18)
# step 627 cost 3.773(18)
# step 630 cost 3.773(18)
# step 633 cost 3.773(18)
# step 636 cost 3.773(18)
# step 639 cost 3.773(18)
# step 642 cost 3.773(18)
# step 645 cost 3.364(18)
# step 647 cost 3.364(18)
# step 650 cost 3.364(18)
# step 653 cost 3.364(18)
# step 656 cost 3.364(18)
# step 659 cost 3.364(18)
# step 662 cost 3.364(18)
#                                  bulksld |......... 9.35605e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness .......|..    10.7214 in (7,12)
#                                     l_cg .....|....    4.12101 in (1,7)
#                                l_choline .......|..     6.2003 in (2,7.5)
#                                  l_lipid ......|...    11.7548 in (9,13)
#                              l_phosphate ....|.....    2.94638 in (0.1,7)
#                             methyl_sigma .......|..    2.35383 in (0,3)
#                            methyl_sigma2 |.........    5.01792 in (5,10)
#                               nf_methyl2 ....|.....   0.261168 in (0.1,0.5)
#                                  rel_pos .....|....    0.50433 in (0,1)
#                                    sigma ..|.......    1.61129 in (1,4)
#                                     v_cg ..|.......     139.92 in (130,170)
#                                v_choline ....|.....    117.387 in (100,140)
#                              v_phosphate ...|......    53.7998 in (40,80)
#                                      va1 ......|...     986.41 in (950,1005)
#                                      vm1 ........|.    107.091 in (90,110)
# step 665 cost 3.364(18)
# step 668 cost 3.364(18)
# step 671 cost 3.364(18)
# step 674 cost 3.364(18)
# step 677 cost 3.364(18)
# step 680 cost 3.364(18)
# step 683 cost 3.364(18)
# step 686 cost 2.828(18)
# step 689 cost 2.828(18)
# step 692 cost 2.828(18)
# step 695 cost 2.828(18)
# step 698 cost 2.828(18)
# step 701 cost 2.828(18)
# step 704 cost 2.828(18)
# step 707 cost 2.828(18)
# step 710 cost 2.828(18)
# step 713 cost 2.828(18)
# step 716 cost 2.828(18)
# step 719 cost 2.828(18)
# step 722 cost 2.828(18)
# step 725 cost 2.828(18)
# step 728 cost 2.828(18)
# step 731 cost 2.828(18)
# step 734 cost 2.828(18)
# step 737 cost 2.828(18)
#                                  bulksld .|........ 9.36379e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness .......|..     10.546 in (7,12)
#                                     l_cg ..|.......    2.62145 in (1,7)
#                                l_choline ......|...    5.72596 in (2,7.5)
#                                  l_lipid .......|..    12.0181 in (9,13)
#                              l_phosphate .....|....     3.7841 in (0.1,7)
#                             methyl_sigma .......|..    2.21977 in (0,3)
#                            methyl_sigma2 |.........    5.11873 in (5,10)
#                               nf_methyl2 ......|...    0.36779 in (0.1,0.5)
#                                  rel_pos ....|.....   0.460881 in (0,1)
#                                    sigma ..|.......    1.68185 in (1,4)
#                                     v_cg ...|......    145.355 in (130,170)
#                                v_choline ......|...    124.861 in (100,140)
#                              v_phosphate |.........    41.2402 in (40,80)
#                                      va1 ......|...    984.953 in (950,1005)
#                                      vm1 .........|     109.88 in (90,110)
# step 740 cost 2.828(18)
# step 743 cost 2.828(18)
# step 746 cost 2.828(18)
# step 749 cost 2.828(18)
# step 752 cost 2.828(18)
# step 755 cost 2.828(18)
# step 758 cost 2.828(18)
# step 761 cost 2.828(18)
# step 763 cost 2.828(18)
# step 764 cost 2.828(18)
# step 765 cost 2.828(18)
# step 767 cost 2.828(18)
# step 769 cost 2.828(18)
# step 771 cost 2.828(18)
# step 773 cost 2.828(18)
# step 775 cost 2.828(18)
# step 778 cost 2.828(18)
# step 781 cost 2.828(18)
# step 784 cost 2.828(18)
# step 787 cost 2.828(18)
# step 790 cost 2.828(18)
# step 793 cost 2.828(18)
# step 796 cost 2.828(18)
# step 799 cost 2.828(18)
#                                  bulksld .|........ 9.36379e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness .......|..     10.546 in (7,12)
#                                     l_cg ..|.......    2.62145 in (1,7)
#                                l_choline ......|...    5.72596 in (2,7.5)
#                                  l_lipid .......|..    12.0181 in (9,13)
#                              l_phosphate .....|....     3.7841 in (0.1,7)
#                             methyl_sigma .......|..    2.21977 in (0,3)
#                            methyl_sigma2 |.........    5.11873 in (5,10)
#                               nf_methyl2 ......|...    0.36779 in (0.1,0.5)
#                                  rel_pos ....|.....   0.460881 in (0,1)
#                                    sigma ..|.......    1.68185 in (1,4)
#                                     v_cg ...|......    145.355 in (130,170)
#                                v_choline ......|...    124.861 in (100,140)
#                              v_phosphate |.........    41.2402 in (40,80)
#                                      va1 ......|...    984.953 in (950,1005)
#                                      vm1 .........|     109.88 in (90,110)
# step 802 cost 2.828(18)
# step 805 cost 2.828(18)
# step 808 cost 2.828(18)
# step 811 cost 2.828(18)
# step 814 cost 2.828(18)
# step 817 cost 2.828(18)
# step 820 cost 2.828(18)
# step 823 cost 2.828(18)
# step 826 cost 2.828(18)
# step 829 cost 2.828(18)
# step 832 cost 2.828(18)
# step 835 cost 2.828(18)
# step 838 cost 2.828(18)
# step 841 cost 2.828(18)
# step 844 cost 2.828(18)
# step 847 cost 2.828(18)
# step 850 cost 2.828(18)
# step 853 cost 2.828(18)
# step 856 cost 2.828(18)
# step 858 cost 2.828(18)
# step 861 cost 2.828(18)
# step 864 cost 2.828(18)
# step 867 cost 2.828(18)
# step 870 cost 2.828(18)
#                                  bulksld .|........ 9.36379e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness .......|..     10.546 in (7,12)
#                                     l_cg ..|.......    2.62145 in (1,7)
#                                l_choline ......|...    5.72596 in (2,7.5)
#                                  l_lipid .......|..    12.0181 in (9,13)
#                              l_phosphate .....|....     3.7841 in (0.1,7)
#                             methyl_sigma .......|..    2.21977 in (0,3)
#                            methyl_sigma2 |.........    5.11873 in (5,10)
#                               nf_methyl2 ......|...    0.36779 in (0.1,0.5)
#                                  rel_pos ....|.....   0.460881 in (0,1)
#                                    sigma ..|.......    1.68185 in (1,4)
#                                     v_cg ...|......    145.355 in (130,170)
#                                v_choline ......|...    124.861 in (100,140)
#                              v_phosphate |.........    41.2402 in (40,80)
#                                      va1 ......|...    984.953 in (950,1005)
#                                      vm1 .........|     109.88 in (90,110)
# step 873 cost 2.772(18)
# step 876 cost 2.772(18)
# step 879 cost 2.772(18)
# step 881 cost 2.772(18)
# step 883 cost 2.772(18)
# step 885 cost 2.772(18)
# step 887 cost 2.772(18)
# step 890 cost 2.772(18)
# step 893 cost 2.772(18)
# step 896 cost 2.772(18)
# step 899 cost 2.772(18)
# step 902 cost 2.772(18)
# step 905 cost 2.772(18)
# step 908 cost 2.772(18)
# step 911 cost 2.772(18)
# step 914 cost 2.772(18)
# step 917 cost 2.772(18)
# step 920 cost 2.772(18)
# step 923 cost 2.772(18)
# step 926 cost 2.772(18)
# step 929 cost 2.772(18)
# step 932 cost 2.591(18)
# step 935 cost 2.591(18)
# step 938 cost 2.591(18)
# step 941 cost 2.591(18)
#                                  bulksld .|........ 9.36377e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness .......|..     10.546 in (7,12)
#                                     l_cg ..|.......    2.62145 in (1,7)
#                                l_choline ......|...    5.72598 in (2,7.5)
#                                  l_lipid .......|..    12.0181 in (9,13)
#                              l_phosphate .....|....     3.7841 in (0.1,7)
#                             methyl_sigma .......|..    2.21657 in (0,3)
#                            methyl_sigma2 |.........    5.00096 in (5,10)
#                               nf_methyl2 ......|...    0.36779 in (0.1,0.5)
#                                  rel_pos ....|.....    0.46088 in (0,1)
#                                    sigma ..|.......    1.66022 in (1,4)
#                                     v_cg ...|......    145.356 in (130,170)
#                                v_choline ......|...    124.861 in (100,140)
#                              v_phosphate |.........    41.2402 in (40,80)
#                                      va1 ......|...    984.956 in (950,1005)
#                                      vm1 .........|     109.88 in (90,110)
# step 944 cost 2.591(18)
# step 947 cost 2.591(18)
# step 950 cost 2.591(18)
# step 953 cost 2.591(18)
# step 956 cost 2.591(18)
# step 959 cost 2.591(18)
# step 962 cost 2.591(18)
# step 965 cost 2.591(18)
# step 968 cost 2.591(18)
# step 971 cost 2.591(18)
# step 974 cost 2.591(18)
# step 977 cost 2.591(18)
# step 980 cost 2.591(18)
# step 983 cost 2.591(18)
# step 986 cost 2.591(18)
# step 989 cost 2.591(18)
# step 992 cost 2.591(18)
# step 995 cost 2.591(18)
# step 998 cost 2.591(18)
# step 1001 cost 2.591(18)
# step 1004 cost 2.591(18)
# step 1006 cost 2.591(18)
# step 1009 cost 2.575(18)
# step 1012 cost 2.575(18)
# step 1015 cost 2.575(18)
#                                  bulksld .|........ 9.36378e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness .......|..    10.5757 in (7,12)
#                                     l_cg ..|.......    2.62145 in (1,7)
#                                l_choline ......|...    5.72598 in (2,7.5)
#                                  l_lipid .......|..    12.0181 in (9,13)
#                              l_phosphate .....|....     3.7841 in (0.1,7)
#                             methyl_sigma .......|..    2.21657 in (0,3)
#                            methyl_sigma2 |.........    5.00096 in (5,10)
#                               nf_methyl2 ......|...   0.367789 in (0.1,0.5)
#                                  rel_pos ....|.....   0.460881 in (0,1)
#                                    sigma ..|.......    1.66022 in (1,4)
#                                     v_cg ...|......    145.356 in (130,170)
#                                v_choline ......|...    124.861 in (100,140)
#                              v_phosphate |.........    41.2402 in (40,80)
#                                      va1 ......|...    984.956 in (950,1005)
#                                      vm1 .........|     109.88 in (90,110)
# step 1018 cost 2.575(18)
# step 1021 cost 2.575(18)
# step 1024 cost 2.575(18)
# step 1027 cost 2.575(18)
# step 1030 cost 2.575(18)
# step 1033 cost 2.575(18)
# step 1036 cost 2.575(18)
# step 1039 cost 2.575(18)
# step 1042 cost 2.575(18)
# step 1045 cost 2.575(18)
# step 1048 cost 2.575(18)
# step 1051 cost 2.575(18)
# step 1054 cost 2.575(18)
# step 1057 cost 2.575(18)
# step 1060 cost 2.575(18)
# step 1063 cost 2.575(18)
# step 1066 cost 2.575(18)
# step 1069 cost 2.575(18)
# step 1072 cost 2.575(18)
# step 1075 cost 2.575(18)
# step 1078 cost 2.575(18)
# step 1081 cost 2.575(18)
# step 1084 cost 2.575(18)
#                                  bulksld .|........ 9.36378e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness .......|..    10.5757 in (7,12)
#                                     l_cg ..|.......    2.62145 in (1,7)
#                                l_choline ......|...    5.72598 in (2,7.5)
#                                  l_lipid .......|..    12.0181 in (9,13)
#                              l_phosphate .....|....     3.7841 in (0.1,7)
#                             methyl_sigma .......|..    2.21657 in (0,3)
#                            methyl_sigma2 |.........    5.00096 in (5,10)
#                               nf_methyl2 ......|...   0.367789 in (0.1,0.5)
#                                  rel_pos ....|.....   0.460881 in (0,1)
#                                    sigma ..|.......    1.66022 in (1,4)
#                                     v_cg ...|......    145.356 in (130,170)
#                                v_choline ......|...    124.861 in (100,140)
#                              v_phosphate |.........    41.2402 in (40,80)
#                                      va1 ......|...    984.956 in (950,1005)
#                                      vm1 .........|     109.88 in (90,110)
# step 1087 cost 2.575(18)
# step 1090 cost 2.575(18)
# step 1093 cost 2.575(18)
# step 1096 cost 2.575(18)
# step 1099 cost 2.575(18)
# step 1102 cost 2.575(18)
# step 1104 cost 2.575(18)
# step 1107 cost 2.575(18)
# step 1110 cost 2.575(18)
# step 1113 cost 2.575(18)
# step 1116 cost 2.575(18)
# step 1119 cost 2.575(18)
# step 1122 cost 2.575(18)
# step 1125 cost 2.575(18)
# step 1128 cost 2.575(18)
# step 1130 cost 2.575(18)
# step 1132 cost 2.575(18)
# step 1135 cost 2.575(18)
# step 1138 cost 2.575(18)
# step 1141 cost 2.575(18)
# step 1144 cost 2.575(18)
# step 1147 cost 2.575(18)
# step 1150 cost 2.501(18)
# step 1153 cost 2.501(18)
# step 1156 cost 2.501(18)
#                                  bulksld .|........ 9.36377e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness .......|..    10.5757 in (7,12)
#                                     l_cg ..|.......    2.62145 in (1,7)
#                                l_choline ......|...    5.72597 in (2,7.5)
#                                  l_lipid .......|..    12.0181 in (9,13)
#                              l_phosphate .....|....    3.78409 in (0.1,7)
#                             methyl_sigma .......|..    2.21656 in (0,3)
#                            methyl_sigma2 |.........    5.00096 in (5,10)
#                               nf_methyl2 ......|...    0.36779 in (0.1,0.5)
#                                  rel_pos ....|.....   0.460881 in (0,1)
#                                    sigma ..|.......    1.66022 in (1,4)
#                                     v_cg ...|......    145.356 in (130,170)
#                                v_choline ......|...    124.861 in (100,140)
#                              v_phosphate |.........    40.9532 in (40,80)
#                                      va1 ......|...    984.955 in (950,1005)
#                                      vm1 .........|     109.88 in (90,110)
# step 1159 cost 2.501(18)
# step 1162 cost 2.501(18)
# step 1165 cost 2.501(18)
# step 1168 cost 2.501(18)
# step 1171 cost 2.501(18)
# step 1174 cost 2.501(18)
# step 1177 cost 2.501(18)
# step 1180 cost 2.501(18)
# step 1183 cost 2.501(18)
# step 1186 cost 2.501(18)
# step 1188 cost 2.501(18)
# step 1190 cost 2.501(18)
# step 1193 cost 2.501(18)
# step 1196 cost 2.501(18)
# step 1198 cost 2.501(18)
# step 1199 cost 2.501(18)
# step 1200 cost 2.501(18)
# step 1202 cost 2.501(18)
# step 1203 cost 2.501(18)
# step 1205 cost 2.501(18)
# step 1207 cost 2.501(18)
# step 1209 cost 2.501(18)
#                                  bulksld .|........ 9.36377e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness .......|..    10.5757 in (7,12)
#                                     l_cg ..|.......    2.62145 in (1,7)
#                                l_choline ......|...    5.72597 in (2,7.5)
#                                  l_lipid .......|..    12.0181 in (9,13)
#                              l_phosphate .....|....    3.78409 in (0.1,7)
#                             methyl_sigma .......|..    2.21656 in (0,3)
#                            methyl_sigma2 |.........    5.00096 in (5,10)
#                               nf_methyl2 ......|...    0.36779 in (0.1,0.5)
#                                  rel_pos ....|.....   0.460881 in (0,1)
#                                    sigma ..|.......    1.66022 in (1,4)
#                                     v_cg ...|......    145.356 in (130,170)
#                                v_choline ......|...    124.861 in (100,140)
#                              v_phosphate |.........    40.9532 in (40,80)
#                                      va1 ......|...    984.955 in (950,1005)
#                                      vm1 .........|     109.88 in (90,110)
# step 1211 cost 2.501(18)
# step 1213 cost 2.501(18)
# step 1216 cost 2.501(18)
# step 1219 cost 2.501(18)
# step 1220 cost 2.501(18)
# step 1222 cost 2.501(18)
# step 1224 cost 2.501(18)
# step 1225 cost 2.501(18)
# step 1227 cost 2.501(18)
# step 1229 cost 2.501(18)
# step 1231 cost 2.501(18)
# step 1233 cost 2.501(18)
# step 1234 cost 2.501(18)
# step 1235 cost 2.501(18)
# step 1237 cost 2.501(18)
# step 1239 cost 2.501(18)
# step 1241 cost 2.501(18)
# step 1243 cost 2.501(18)
# step 1246 cost 2.501(18)
# step 1249 cost 2.501(18)
# step 1252 cost 2.501(18)
# step 1255 cost 2.501(18)
# step 1258 cost 2.501(18)
#                                  bulksld .|........ 9.36377e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness .......|..    10.5757 in (7,12)
#                                     l_cg ..|.......    2.62145 in (1,7)
#                                l_choline ......|...    5.72597 in (2,7.5)
#                                  l_lipid .......|..    12.0181 in (9,13)
#                              l_phosphate .....|....    3.78409 in (0.1,7)
#                             methyl_sigma .......|..    2.21656 in (0,3)
#                            methyl_sigma2 |.........    5.00096 in (5,10)
#                               nf_methyl2 ......|...    0.36779 in (0.1,0.5)
#                                  rel_pos ....|.....   0.460881 in (0,1)
#                                    sigma ..|.......    1.66022 in (1,4)
#                                     v_cg ...|......    145.356 in (130,170)
#                                v_choline ......|...    124.861 in (100,140)
#                              v_phosphate |.........    40.9532 in (40,80)
#                                      va1 ......|...    984.955 in (950,1005)
#                                      vm1 .........|     109.88 in (90,110)
# step 1261 cost 2.501(18)
# step 1264 cost 2.501(18)
# step 1267 cost 2.501(18)
# step 1270 cost 2.501(18)
# step 1273 cost 2.501(18)
# step 1276 cost 2.501(18)
# step 1279 cost 2.501(18)
# step 1282 cost 2.501(18)
# step 1285 cost 2.501(18)
# step 1288 cost 2.501(18)
# step 1291 cost 2.501(18)
# step 1294 cost 2.501(18)
# step 1297 cost 2.501(18)
# step 1300 cost 2.501(18)
# step 1302 cost 2.501(18)
# step 1305 cost 2.501(18)
# step 1307 cost 2.501(18)
# step 1308 cost 2.501(18)
# step 1309 cost 2.501(18)
# step 1312 cost 2.501(18)
# step 1314 cost 2.501(18)
# step 1316 cost 2.501(18)
#                                  bulksld .|........ 9.36377e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness .......|..    10.5757 in (7,12)
#                                     l_cg ..|.......    2.62145 in (1,7)
#                                l_choline ......|...    5.72597 in (2,7.5)
#                                  l_lipid .......|..    12.0181 in (9,13)
#                              l_phosphate .....|....    3.78409 in (0.1,7)
#                             methyl_sigma .......|..    2.21656 in (0,3)
#                            methyl_sigma2 |.........    5.00096 in (5,10)
#                               nf_methyl2 ......|...    0.36779 in (0.1,0.5)
#                                  rel_pos ....|.....   0.460881 in (0,1)
#                                    sigma ..|.......    1.66022 in (1,4)
#                                     v_cg ...|......    145.356 in (130,170)
#                                v_choline ......|...    124.861 in (100,140)
#                              v_phosphate |.........    40.9532 in (40,80)
#                                      va1 ......|...    984.955 in (950,1005)
#                                      vm1 .........|     109.88 in (90,110)
# step 1318 cost 2.501(18)
# step 1320 cost 2.501(18)
# step 1322 cost 2.501(18)
# step 1324 cost 2.501(18)
# step 1326 cost 2.501(18)
# step 1327 cost 2.501(18)
# step 1329 cost 2.501(18)
# step 1331 cost 2.501(18)
# step 1333 cost 2.501(18)
# step 1335 cost 2.501(18)
# step 1337 cost 2.501(18)
# step 1339 cost 2.501(18)
# step 1341 cost 2.501(18)
# step 1343 cost 2.501(18)
# step 1345 cost 2.501(18)
# step 1347 cost 2.501(18)
# step 1349 cost 2.501(18)
# step 1351 cost 2.501(18)
# step 1353 cost 2.501(18)
# step 1355 cost 2.501(18)
# step 1357 cost 2.501(18)
#                                  bulksld .|........ 9.36377e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness .......|..    10.5757 in (7,12)
#                                     l_cg ..|.......    2.62145 in (1,7)
#                                l_choline ......|...    5.72597 in (2,7.5)
#                                  l_lipid .......|..    12.0181 in (9,13)
#                              l_phosphate .....|....    3.78409 in (0.1,7)
#                             methyl_sigma .......|..    2.21656 in (0,3)
#                            methyl_sigma2 |.........    5.00096 in (5,10)
#                               nf_methyl2 ......|...    0.36779 in (0.1,0.5)
#                                  rel_pos ....|.....   0.460881 in (0,1)
#                                    sigma ..|.......    1.66022 in (1,4)
#                                     v_cg ...|......    145.356 in (130,170)
#                                v_choline ......|...    124.861 in (100,140)
#                              v_phosphate |.........    40.9532 in (40,80)
#                                      va1 ......|...    984.955 in (950,1005)
#                                      vm1 .........|     109.88 in (90,110)
# step 1359 cost 2.501(18)
# step 1361 cost 2.501(18)
# step 1363 cost 2.501(18)
# step 1365 cost 2.501(18)
# step 1367 cost 2.501(18)
# step 1370 cost 2.501(18)
# step 1372 cost 2.501(18)
# step 1375 cost 2.501(18)
# step 1378 cost 2.501(18)
# step 1381 cost 2.501(18)
# step 1384 cost 2.501(18)
# step 1387 cost 2.501(18)
# step 1389 cost 2.501(18)
# step 1392 cost 2.501(18)
# step 1395 cost 2.501(18)
# step 1398 cost 2.501(18)
# step 1401 cost 2.501(18)
# step 1404 cost 2.501(18)
# step 1407 cost 2.501(18)
# step 1409 cost 2.501(18)
# step 1412 cost 2.501(18)
# step 1415 cost 2.501(18)
# step 1418 cost 2.501(18)
# step 1421 cost 2.501(18)
#                                  bulksld .|........ 9.36377e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness .......|..    10.5757 in (7,12)
#                                     l_cg ..|.......    2.62145 in (1,7)
#                                l_choline ......|...    5.72597 in (2,7.5)
#                                  l_lipid .......|..    12.0181 in (9,13)
#                              l_phosphate .....|....    3.78409 in (0.1,7)
#                             methyl_sigma .......|..    2.21656 in (0,3)
#                            methyl_sigma2 |.........    5.00096 in (5,10)
#                               nf_methyl2 ......|...    0.36779 in (0.1,0.5)
#                                  rel_pos ....|.....   0.460881 in (0,1)
#                                    sigma ..|.......    1.66022 in (1,4)
#                                     v_cg ...|......    145.356 in (130,170)
#                                v_choline ......|...    124.861 in (100,140)
#                              v_phosphate |.........    40.9532 in (40,80)
#                                      va1 ......|...    984.955 in (950,1005)
#                                      vm1 .........|     109.88 in (90,110)
# step 1424 cost 2.501(18)
# step 1427 cost 2.501(18)
# step 1430 cost 2.501(18)
# step 1432 cost 2.501(18)
# step 1435 cost 2.501(18)
# step 1438 cost 2.501(18)
# step 1441 cost 2.501(18)
# step 1444 cost 2.501(18)
# step 1447 cost 2.501(18)
# step 1450 cost 2.501(18)
# step 1453 cost 2.501(18)
# step 1456 cost 2.501(18)
# step 1459 cost 2.501(18)
# step 1462 cost 2.501(18)
# step 1465 cost 2.501(18)
# step 1468 cost 2.501(18)
# step 1471 cost 2.501(18)
# step 1473 cost 2.501(18)
# step 1476 cost 2.501(18)
# step 1478 cost 2.501(18)
# step 1481 cost 2.501(18)
# step 1484 cost 2.501(18)
# step 1487 cost 2.501(18)
# step 1490 cost 2.501(18)
#                                  bulksld .|........ 9.36377e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness .......|..    10.5757 in (7,12)
#                                     l_cg ..|.......    2.62145 in (1,7)
#                                l_choline ......|...    5.72597 in (2,7.5)
#                                  l_lipid .......|..    12.0181 in (9,13)
#                              l_phosphate .....|....    3.78409 in (0.1,7)
#                             methyl_sigma .......|..    2.21656 in (0,3)
#                            methyl_sigma2 |.........    5.00096 in (5,10)
#                               nf_methyl2 ......|...    0.36779 in (0.1,0.5)
#                                  rel_pos ....|.....   0.460881 in (0,1)
#                                    sigma ..|.......    1.66022 in (1,4)
#                                     v_cg ...|......    145.356 in (130,170)
#                                v_choline ......|...    124.861 in (100,140)
#                              v_phosphate |.........    40.9532 in (40,80)
#                                      va1 ......|...    984.955 in (950,1005)
#                                      vm1 .........|     109.88 in (90,110)
# step 1493 cost 2.501(18)
# step 1496 cost 2.501(18)
# step 1499 cost 2.501(18)
# step 1502 cost 2.501(18)
# step 1505 cost 2.501(18)
# step 1508 cost 2.501(18)
# step 1511 cost 2.501(18)
# step 1513 cost 2.501(18)
# step 1514 cost 2.501(18)
# step 1516 cost 2.501(18)
# step 1518 cost 2.501(18)
# step 1520 cost 2.501(18)
# step 1522 cost 2.501(18)
# step 1524 cost 2.501(18)
# step 1526 cost 2.501(18)
# step 1528 cost 2.501(18)
# step 1530 cost 2.501(18)
# step 1531 cost 2.501(18)
# step 1533 cost 2.489(18)
# step 1535 cost 2.489(18)
# step 1537 cost 2.489(18)
# step 1539 cost 2.489(18)
# step 1541 cost 2.489(18)
#                                  bulksld .|........ 9.3636e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness ......|...    10.2048 in (7,12)
#                                     l_cg .|........    1.97191 in (1,7)
#                                l_choline .......|..    6.22551 in (2,7.5)
#                                  l_lipid .......|..    11.8603 in (9,13)
#                              l_phosphate ....|.....    2.91775 in (0.1,7)
#                             methyl_sigma .......|..     2.2498 in (0,3)
#                            methyl_sigma2 |.........    5.01558 in (5,10)
#                               nf_methyl2 .....|....   0.318973 in (0.1,0.5)
#                                  rel_pos ....|.....   0.474766 in (0,1)
#                                    sigma ..|.......    1.66196 in (1,4)
#                                     v_cg .....|....    150.846 in (130,170)
#                                v_choline |.........    102.912 in (100,140)
#                              v_phosphate ...|......    55.0251 in (40,80)
#                                      va1 ......|...    987.886 in (950,1005)
#                                      vm1 .........|      108.7 in (90,110)
# step 1543 cost 2.489(18)
# step 1544 cost 2.489(18)
# step 1546 cost 2.489(18)
# step 1548 cost 2.489(18)
# step 1550 cost 2.489(18)
# step 1552 cost 2.489(18)
# step 1554 cost 2.489(18)
# step 1556 cost 2.489(18)
# step 1558 cost 2.489(18)
# step 1560 cost 2.489(18)
# step 1563 cost 2.489(18)
# step 1566 cost 2.489(18)
# step 1569 cost 2.489(18)
# step 1572 cost 2.489(18)
# step 1575 cost 2.489(18)
# step 1577 cost 2.489(18)
# step 1580 cost 2.489(18)
# step 1583 cost 2.489(18)
# step 1586 cost 2.489(18)
# step 1588 cost 2.489(18)
# step 1589 cost 2.489(18)
# step 1591 cost 2.489(18)
# step 1593 cost 2.489(18)
#                                  bulksld .|........ 9.3636e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness ......|...    10.2048 in (7,12)
#                                     l_cg .|........    1.97191 in (1,7)
#                                l_choline .......|..    6.22551 in (2,7.5)
#                                  l_lipid .......|..    11.8603 in (9,13)
#                              l_phosphate ....|.....    2.91775 in (0.1,7)
#                             methyl_sigma .......|..     2.2498 in (0,3)
#                            methyl_sigma2 |.........    5.01558 in (5,10)
#                               nf_methyl2 .....|....   0.318973 in (0.1,0.5)
#                                  rel_pos ....|.....   0.474766 in (0,1)
#                                    sigma ..|.......    1.66196 in (1,4)
#                                     v_cg .....|....    150.846 in (130,170)
#                                v_choline |.........    102.912 in (100,140)
#                              v_phosphate ...|......    55.0251 in (40,80)
#                                      va1 ......|...    987.886 in (950,1005)
#                                      vm1 .........|      108.7 in (90,110)
# step 1595 cost 2.489(18)
# step 1597 cost 2.489(18)
# step 1599 cost 2.489(18)
# step 1601 cost 2.489(18)
# step 1603 cost 2.489(18)
# step 1605 cost 2.489(18)
# step 1607 cost 2.489(18)
# step 1609 cost 2.489(18)
# step 1611 cost 2.489(18)
# step 1613 cost 2.489(18)
# step 1615 cost 2.489(18)
# step 1617 cost 2.489(18)
# step 1620 cost 2.489(18)
# step 1623 cost 2.489(18)
# step 1625 cost 2.489(18)
# step 1628 cost 2.489(18)
# step 1631 cost 2.489(18)
# step 1634 cost 2.489(18)
# step 1637 cost 2.489(18)
# step 1640 cost 2.489(18)
# step 1643 cost 2.489(18)
# step 1646 cost 2.489(18)
# step 1649 cost 2.489(18)
#                                  bulksld .|........ 9.3636e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness ......|...    10.2048 in (7,12)
#                                     l_cg .|........    1.97191 in (1,7)
#                                l_choline .......|..    6.22551 in (2,7.5)
#                                  l_lipid .......|..    11.8603 in (9,13)
#                              l_phosphate ....|.....    2.91775 in (0.1,7)
#                             methyl_sigma .......|..     2.2498 in (0,3)
#                            methyl_sigma2 |.........    5.01558 in (5,10)
#                               nf_methyl2 .....|....   0.318973 in (0.1,0.5)
#                                  rel_pos ....|.....   0.474766 in (0,1)
#                                    sigma ..|.......    1.66196 in (1,4)
#                                     v_cg .....|....    150.846 in (130,170)
#                                v_choline |.........    102.912 in (100,140)
#                              v_phosphate ...|......    55.0251 in (40,80)
#                                      va1 ......|...    987.886 in (950,1005)
#                                      vm1 .........|      108.7 in (90,110)
# step 1652 cost 2.489(18)
# step 1655 cost 2.489(18)
# step 1658 cost 2.489(18)
# step 1661 cost 2.485(18)
# step 1664 cost 2.485(18)
# step 1667 cost 2.485(18)
# step 1670 cost 2.485(18)
# step 1673 cost 2.485(18)
# step 1676 cost 2.485(18)
# step 1679 cost 2.485(18)
# step 1682 cost 2.485(18)
# step 1685 cost 2.485(18)
# step 1688 cost 2.485(18)
# step 1691 cost 2.485(18)
# step 1694 cost 2.485(18)
# step 1697 cost 2.485(18)
# step 1700 cost 2.485(18)
# step 1703 cost 2.485(18)
# step 1706 cost 2.485(18)
# step 1709 cost 2.485(18)
# step 1712 cost 2.485(18)
# step 1715 cost 2.485(18)
# step 1718 cost 2.485(18)
# step 1721 cost 2.485(18)
#                                  bulksld .|........ 9.36376e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness .......|..    10.5757 in (7,12)
#                                     l_cg ..|.......    2.62145 in (1,7)
#                                l_choline ......|...    5.72597 in (2,7.5)
#                                  l_lipid .......|..    12.0181 in (9,13)
#                              l_phosphate .....|....    3.78409 in (0.1,7)
#                             methyl_sigma .......|..    2.21657 in (0,3)
#                            methyl_sigma2 |.........    5.00096 in (5,10)
#                               nf_methyl2 ......|...   0.367789 in (0.1,0.5)
#                                  rel_pos ....|.....   0.460881 in (0,1)
#                                    sigma ..|.......    1.66021 in (1,4)
#                                     v_cg ...|......    145.356 in (130,170)
#                                v_choline ......|...    124.861 in (100,140)
#                              v_phosphate |.........    40.8814 in (40,80)
#                                      va1 ......|...    984.957 in (950,1005)
#                                      vm1 .........|     109.88 in (90,110)
# step 1724 cost 2.485(18)
# step 1727 cost 2.485(18)
# step 1730 cost 2.485(18)
# step 1733 cost 2.485(18)
# step 1736 cost 2.485(18)
# step 1739 cost 2.485(18)
# step 1742 cost 2.415(18)
# step 1745 cost 2.415(18)
# step 1748 cost 2.415(18)
# step 1751 cost 2.415(18)
# step 1754 cost 2.415(18)
# step 1757 cost 2.415(18)
# step 1760 cost 2.415(18)
# step 1763 cost 2.415(18)
# step 1766 cost 2.415(18)
# step 1769 cost 2.415(18)
# step 1772 cost 2.415(18)
# step 1775 cost 2.415(18)
# step 1778 cost 2.415(18)
# step 1781 cost 2.415(18)
# step 1784 cost 2.415(18)
# step 1787 cost 2.415(18)
# step 1790 cost 2.415(18)
# step 1793 cost 2.415(18)
#                                  bulksld .|........ 9.36322e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness .......|..    10.6669 in (7,12)
#                                     l_cg .....|....    4.02783 in (1,7)
#                                l_choline ........|.     6.7382 in (2,7.5)
#                                  l_lipid .......|..    11.8011 in (9,13)
#                              l_phosphate ....|.....    3.31541 in (0.1,7)
#                             methyl_sigma .......|..    2.27337 in (0,3)
#                            methyl_sigma2 |.........    5.25475 in (5,10)
#                               nf_methyl2 ...|......    0.24729 in (0.1,0.5)
#                                  rel_pos .....|....    0.51391 in (0,1)
#                                    sigma ..|.......    1.65148 in (1,4)
#                                     v_cg .|........    137.611 in (130,170)
#                                v_choline ....|.....    118.239 in (100,140)
#                              v_phosphate ...|......    54.3041 in (40,80)
#                                      va1 ......|...    986.105 in (950,1005)
#                                      vm1 ........|.    106.984 in (90,110)
# step 1796 cost 2.415(18)
# step 1799 cost 2.415(18)
# step 1802 cost 2.415(18)
# step 1805 cost 2.415(18)
# step 1808 cost 2.415(18)
# step 1811 cost 2.415(18)
# step 1814 cost 2.415(18)
# step 1815 cost 2.415(18)
# step 1817 cost 2.415(18)
# step 1820 cost 2.415(18)
# step 1822 cost 2.408(18)
# step 1824 cost 2.390(18)
# step 1825 cost 2.390(18)
# step 1827 cost 2.390(18)
# step 1829 cost 2.390(18)
# step 1831 cost 2.390(18)
# step 1833 cost 2.390(18)
# step 1835 cost 2.390(18)
# step 1838 cost 2.390(18)
# step 1841 cost 2.390(18)
# step 1844 cost 2.390(18)
# step 1847 cost 2.390(18)
#                                  bulksld .|........ 9.36321e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness .......|..    10.6669 in (7,12)
#                                     l_cg .....|....    4.02783 in (1,7)
#                                l_choline ........|.    6.55166 in (2,7.5)
#                                  l_lipid .......|..    11.8011 in (9,13)
#                              l_phosphate ....|.....     3.3154 in (0.1,7)
#                             methyl_sigma .......|..    2.27337 in (0,3)
#                            methyl_sigma2 |.........    5.25475 in (5,10)
#                               nf_methyl2 ...|......    0.24729 in (0.1,0.5)
#                                  rel_pos .....|....   0.513911 in (0,1)
#                                    sigma ..|.......    1.65147 in (1,4)
#                                     v_cg .|........    137.611 in (130,170)
#                                v_choline ....|.....    118.239 in (100,140)
#                              v_phosphate ...|......     54.304 in (40,80)
#                                      va1 ......|...    986.105 in (950,1005)
#                                      vm1 ........|.    107.202 in (90,110)
# step 1849 cost 2.390(18)
# step 1852 cost 2.390(18)
# step 1855 cost 2.390(18)
# step 1858 cost 2.390(18)
# step 1861 cost 2.390(18)
# step 1864 cost 2.390(18)
# step 1867 cost 2.390(18)
# step 1870 cost 2.390(18)
# step 1873 cost 2.390(18)
# step 1876 cost 2.390(18)
# step 1879 cost 2.390(18)
# step 1882 cost 2.390(18)
# step 1885 cost 2.390(18)
# step 1888 cost 2.390(18)
# step 1891 cost 2.390(18)
# step 1894 cost 2.390(18)
# step 1897 cost 2.390(18)
# step 1900 cost 2.390(18)
# step 1903 cost 2.234(18)
# step 1905 cost 2.234(18)
# step 1908 cost 2.234(18)
# step 1909 cost 2.234(18)
# step 1911 cost 2.234(18)
#                                  bulksld ..|....... 9.36585e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness .......|..     10.552 in (7,12)
#                                     l_cg .|........    2.13793 in (1,7)
#                                l_choline ........|.    6.63426 in (2,7.5)
#                                  l_lipid .......|..    12.1687 in (9,13)
#                              l_phosphate .....|....    3.55434 in (0.1,7)
#                             methyl_sigma .......|..    2.20326 in (0,3)
#                            methyl_sigma2 |.........    5.00384 in (5,10)
#                               nf_methyl2 ......|...   0.350049 in (0.1,0.5)
#                                  rel_pos ....|.....   0.445867 in (0,1)
#                                    sigma ..|.......    1.73113 in (1,4)
#                                     v_cg ...|......    143.166 in (130,170)
#                                v_choline ......|...    124.498 in (100,140)
#                              v_phosphate |.........    42.3192 in (40,80)
#                                      va1 ......|...    985.872 in (950,1005)
#                                      vm1 .........|    109.186 in (90,110)
# step 1914 cost 2.234(18)
# step 1916 cost 2.234(18)
# step 1917 cost 2.234(18)
# step 1919 cost 2.234(18)
# step 1921 cost 2.234(18)
# step 1923 cost 2.234(18)
# step 1924 cost 2.234(18)
# step 1926 cost 2.234(18)
# step 1928 cost 2.234(18)
# step 1930 cost 2.234(18)
# step 1932 cost 2.234(18)
# step 1934 cost 2.234(18)
# step 1937 cost 2.234(18)
# step 1939 cost 2.234(18)
# step 1942 cost 2.234(18)
# step 1945 cost 2.234(18)
# step 1948 cost 2.234(18)
# step 1951 cost 2.234(18)
# step 1954 cost 2.234(18)
# step 1957 cost 2.234(18)
# step 1960 cost 2.234(18)
# step 1963 cost 2.234(18)
#                                  bulksld ..|....... 9.36585e-06 in (9.35e-06,9.42e-06)
#                            hg1_thickness .......|..     10.552 in (7,12)
#                                     l_cg .|........    2.13793 in (1,7)
#                                l_choline ........|.    6.63426 in (2,7.5)
#                                  l_lipid .......|..    12.1687 in (9,13)
#                              l_phosphate .....|....    3.55434 in (0.1,7)
#                             methyl_sigma .......|..    2.20326 in (0,3)
#                            methyl_sigma2 |.........    5.00384 in (5,10)
#                               nf_methyl2 ......|...   0.350049 in (0.1,0.5)
#                                  rel_pos ....|.....   0.445867 in (0,1)
#                                    sigma ..|.......    1.73113 in (1,4)
#                                     v_cg ...|......    143.166 in (130,170)
#                                v_choline ......|...    124.498 in (100,140)
#                              v_phosphate |.........    42.3192 in (40,80)
#                                      va1 ......|...    985.872 in (950,1005)
#                                      vm1 .........|    109.186 in (90,110)
# step 1966 cost 2.234(18)
# step 1969 cost 2.234(18)
# step 1972 cost 2.234(18)
# step 1975 cost 2.234(18)
# step 1978 cost 2.234(18)
# step 1981 cost 2.234(18)
# step 1984 cost 2.234(18)
# step 1987 cost 2.234(18)
# step 1990 cost 2.234(18)
# step 1993 cost 2.234(18)
# step 1996 cost 2.234(18)
# step 1999 cost 2.234(18)
# final chisq 2.234(18)
# === Uncertainty from curvature:     name value(unc.)     value(unc./chi)) ===
#                                  bulksld 9.36585(59)e-6  9.36585(39)e-6
#                            hg1_thickness 0.00(18)e6      0.00(12)e6
#                                     l_cg 0.00(100)e6     0.00(67)e6
#                                l_choline 0.0(20)e6       0.0(13)e6
#                                  l_lipid 0.00(15)e6      0.000(100)e6
#                              l_phosphate 0.00(38)e6      0.00(25)e6
#                             methyl_sigma 0.000(97)e6     0.000(65)e6
#                            methyl_sigma2 0.0(24)e6       0.0(16)e6
#                               nf_methyl2 0.000(31)e6     0.000(21)e6
#                                  rel_pos 0.000(42)e6     0.000(28)e6
#                                    sigma 0.0(24)e3       0.0(16)e3
#                                     v_cg 0.0(41)e6       0.0(27)e6
#                                v_choline 0.0(75)e6       0.0(50)e6
#                              v_phosphate 0.000(14)e9     0.0(96)e6
#                                      va1 0.0(39)e6       0.0(26)e6
#                                      vm1 0.0(81)e6       0.0(54)e6
# ===========================================================================

# %% [markdown]
# # Analyze Fit

# %%
p = res_state.best()[0]
problem.setp(p)
print(problem.chisq())

q, F, dq, Fy = np.loadtxt(store + "/" + runfile + ".dat", skiprows=1).T
fig, ax = plt.subplots()
ax.plot(q, Fy, zorder=2, label="model")
ax.errorbar(q, F, dq, zorder=1, label="simulation")
ax.legend(fontsize=8)
ax.set_xlim([q[0], q[-1]])
ax.set_ylabel("|F($q_z$)| (e/Å$^2$)", fontsize=10)
ax.minorticks_on()
ax.tick_params(which="both", direction="in", labelsize=10)
ax.tick_params(bottom=True, top=True, left=True, right=True, which="both")
ax.set_xlabel("$q_z$ (Å$^{-1}$)", fontsize=10)
ax.figure.set_size_inches(12.5, 7.5)
plt.savefig(store + "/model.png", facecolor="white")
plt.show()
# Out:
# 2.2341932612641084

# %%
from bumps.dream.stats import var_stats, save_vars

print("final chisq", problem.chisq_str())
draw = res_state.draw(portion=1)
all_vstats = var_stats(draw)
save_vars(all_vstats, store + "/" + runfile + ".json")
# Out:
# final chisq 2.234(18)

# %%
from bumps.dream import corrplot, varplot
from pylab import figure, savefig

err = sys.stderr
sys.stderr = open("/dev/stderr", "w")
figure(figsize=varplot.var_plot_size(len(all_vstats)))
nbins = max(min(draw.points.shape[0] // 10000, 400), 30)
varplot.plot_vars(draw, all_vstats, nbins=nbins)
if run:
    savefig(store + "/var", facecolor="white")
else:
    savefig(store + "/var_reloaded", facecolor="white")
sys.stderr = err
# Out:
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:240: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pylab.pcolormesh(x, y, z, vmin=vmin, vmax=vmax, cmap=cmap)
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:244: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   centers, height, maxlikelihood = array(bins).T
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:240: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pylab.pcolormesh(x, y, z, vmin=vmin, vmax=vmax, cmap=cmap)
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:244: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   centers, height, maxlikelihood = array(bins).T
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:240: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pylab.pcolormesh(x, y, z, vmin=vmin, vmax=vmax, cmap=cmap)
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:244: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   centers, height, maxlikelihood = array(bins).T
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:240: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pylab.pcolormesh(x, y, z, vmin=vmin, vmax=vmax, cmap=cmap)
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:244: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   centers, height, maxlikelihood = array(bins).T
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:240: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pylab.pcolormesh(x, y, z, vmin=vmin, vmax=vmax, cmap=cmap)
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:244: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   centers, height, maxlikelihood = array(bins).T
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:240: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pylab.pcolormesh(x, y, z, vmin=vmin, vmax=vmax, cmap=cmap)
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:244: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   centers, height, maxlikelihood = array(bins).T
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:240: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pylab.pcolormesh(x, y, z, vmin=vmin, vmax=vmax, cmap=cmap)
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:244: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   centers, height, maxlikelihood = array(bins).T
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:240: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pylab.pcolormesh(x, y, z, vmin=vmin, vmax=vmax, cmap=cmap)
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:244: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   centers, height, maxlikelihood = array(bins).T
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:240: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pylab.pcolormesh(x, y, z, vmin=vmin, vmax=vmax, cmap=cmap)
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:244: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   centers, height, maxlikelihood = array(bins).T
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:240: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pylab.pcolormesh(x, y, z, vmin=vmin, vmax=vmax, cmap=cmap)
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:244: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   centers, height, maxlikelihood = array(bins).T
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:240: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pylab.pcolormesh(x, y, z, vmin=vmin, vmax=vmax, cmap=cmap)
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:244: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   centers, height, maxlikelihood = array(bins).T
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:240: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pylab.pcolormesh(x, y, z, vmin=vmin, vmax=vmax, cmap=cmap)
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:244: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   centers, height, maxlikelihood = array(bins).T
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:240: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pylab.pcolormesh(x, y, z, vmin=vmin, vmax=vmax, cmap=cmap)
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:244: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   centers, height, maxlikelihood = array(bins).T
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:240: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pylab.pcolormesh(x, y, z, vmin=vmin, vmax=vmax, cmap=cmap)
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:244: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   centers, height, maxlikelihood = array(bins).T
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:240: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pylab.pcolormesh(x, y, z, vmin=vmin, vmax=vmax, cmap=cmap)
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:244: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   centers, height, maxlikelihood = array(bins).T
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:240: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   pylab.pcolormesh(x, y, z, vmin=vmin, vmax=vmax, cmap=cmap)
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/dream/varplot.py:244: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   centers, height, maxlikelihood = array(bins).T

# %%
if draw.num_vars <= 25:
    figure()
    c = corrplot.Corr2d(draw.points.T, bins=nbins, labels=draw.labels)
    c.plot()
if run:
    savefig(store + "/corr", facecolor="white")
else:
    savefig(store + "/corr_reloaded", facecolor="white")

# %%
p = res_state.best()[0]
problem.setp(p)
print(problem.chisq())
# Out:
# 2.2341932612641084

# %%
import os


if run:
    if os.path.isfile(store + "/sErr.dat"):
        os.remove(store + "/sErr.dat")
    if os.path.isfile(store + "/isErr.dat"):
        os.remove(store + "/isErr.dat")
    if os.path.isfile(store + "/StatDataPython.dat"):
        os.remove(store + "/StatDataPython.dat")

fit_analysis = rs.CMolStat(
    fitsource=fitsource,
    spath=setupdir,
    mcmcpath=store,
    runfile=runfile,
    state=res_state,
    problem=problem,
)

# %%
sparse = 0.005
fit_analysis.fnAnalyzeStatFile(fConfidence=-1, sparse=sparse)
# Out:
# Analysis of current MC simulation ...
# Number of iterations: 421
#       bulksld  [  +        ]  [  9.35e-06,  9.42e-06]  [ 9.364e-06(0.000),  9.365e-06(0.001),  9.367e-06(0.000)] (- 1.915e-09, + 1.842e-09)
# hg1_thickness  [ | -  |    ]  [         7,        12]  [     7.282(0.001),      8.453(0.000),      9.867(0.000)] (-     1.172, +     1.414)
#          l_cg  [    | - |  ]  [         1,         7]  [     3.602(0.001),      4.857(0.000),      5.965(0.000)] (-     1.254, +     1.108)
#     l_choline  [    | - |  ]  [         2,       7.5]  [     4.193(0.000),      5.206(0.003),      6.507(0.000)] (-     1.012, +     1.301)
#       l_lipid  [       |-| ]  [         9,        13]  [      11.9(0.000),      12.25(0.000),      12.73(0.000)] (-    0.3474, +    0.4817)
#   l_phosphate  [  | - |    ]  [       0.1,         7]  [     1.595(0.000),       2.78(0.001),      4.053(0.000)] (-     1.185, +     1.273)
#  methyl_sigma  [   |- |    ]  [         0,         3]  [    0.9755(0.000),      1.254(0.000),      1.764(0.000)] (-    0.2785, +      0.51)
# methyl_sigma2  #+          ]  [         5,        10]  [     5.011(0.000),      5.039(0.000),      5.203(0.000)] (-   0.02891, +    0.1633)
#    nf_methyl2  [     | -|  ]  [       0.1,       0.5]  [      0.29(0.000),     0.3836(0.000),     0.4351(0.000)] (-   0.09368, +   0.05149)
#       rel_pos  [     +|    ]  [         0,         1]  [    0.4843(0.000),     0.5335(0.000),     0.6465(0.000)] (-   0.04915, +    0.1131)
#         sigma  [   |-|     ]  [         1,         4]  [     2.038(0.000),      2.262(0.000),      2.388(0.000)] (-    0.2236, +    0.1263)
#          v_cg  [ | - |     ]  [       130,       170]  [     134.6(0.000),      140.2(0.000),      149.9(0.000)] (-     5.551, +     9.698)
#     v_choline  [  | -  |   ]  [       100,       140]  [     108.1(0.002),      117.6(0.003),      127.4(0.000)] (-     9.509, +     9.806)
#   v_phosphate  [ |- |      ]  [        40,        80]  [     43.41(0.000),      48.02(0.000),      57.52(0.002)] (-     4.604, +     9.504)
#           va1  [      |+   ]  [       950,      1005]  [     981.7(0.000),      986.1(0.000),      989.6(0.000)] (-     4.383, +     3.564)
#           vm1  [       | -|]  [        90,       110]  [     104.7(0.000),        108(0.000),      109.7(0.000)] (-     3.299, +     1.743)
# Maximum deviation from average over last 5 iterations: 0.0033
# Confidence level: 0.6827

# %%
fit_analysis.fnCreateBilayerPlotData()
# Out:
# Initializing ...
# Pulling all molgroups ...
#   substrate ...
# Failure to load StatDataPython.dat.
# Recreate statistical data from sErr.dat.
# Found sErr.dat
#
# Processing parameter set 0.
#
# 4.665667032246985
# Processing parameter set 1.
#
# 4.083449408522591
# Processing parameter set 2.
#
# 4.617905793073406
# Processing parameter set 3.
#
# 4.387895153008129
# Processing parameter set 4.
#
# 4.163070845187092
# Processing parameter set 5.
#
# 4.586610543301426
# Processing parameter set 6.
#
# 4.496441987576615
# Processing parameter set 7.
#
# 2.5469763717719136
# Processing parameter set 8.
#
# 4.343459524261967
# Processing parameter set 9.
#
# 4.678090386589171
# Processing parameter set 10.
#
# 3.8338337397222544
# Processing parameter set 11.
#
# 4.330115840773056
# Processing parameter set 12.
#
# 4.678090386589171
# Processing parameter set 13.
#
# 4.162611306592584
# Processing parameter set 14.
#
# 4.3947408343667105
# Processing parameter set 15.
#
# 4.496441987576615
# Processing parameter set 16.
#
# 3.3017926485193363
# Processing parameter set 17.
#
# 4.752734145412364
# Processing parameter set 18.
#
# 4.300101154106445
# Processing parameter set 19.
#
# 4.385701564757817
# Processing parameter set 20.
#
# 4.820622215812139
# Processing parameter set 21.
#
# 3.9775307694208393
# Processing parameter set 22.
#
# 3.0501136022266357
# Processing parameter set 23.
#
# 5.0790014542227215
# Processing parameter set 24.
#
# 4.039356075061525
# Processing parameter set 25.
#
# 3.9350429972657057
# Processing parameter set 26.
#
# 4.139901890816599
# Processing parameter set 27.
#
# 3.7095012739697486
# Processing parameter set 28.
#
# 3.2503938848312477
# Processing parameter set 29.
#
# 4.5271207682727175
# Processing parameter set 30.
#
# 4.615546936275984
# Processing parameter set 31.
#
# 4.475723446322789
# Processing parameter set 32.
#
# 4.119083614798071
# Processing parameter set 33.
#
# 2.9322275290278976
# Processing parameter set 34.
#
# 4.239075747886748
# Processing parameter set 35.
#
# 4.5271207682727175
# Processing parameter set 36.
#
# 4.1829454261797485
# Processing parameter set 37.
#
# 3.6306326151766677
# Processing parameter set 38.
#
# 4.51157284524417
# Processing parameter set 39.
#
# 4.089099255802357
# Processing parameter set 40.
#
# 4.098717520476389
# Processing parameter set 41.
#
# 3.6236647906691792
# Processing parameter set 42.
#
# 4.7026372088469754
# Processing parameter set 43.
#
# 4.215365268134148
# Processing parameter set 44.
#
# 4.163070845187092
# Processing parameter set 45.
#
# 4.42864188610135
# Processing parameter set 46.
#
# 4.630450248366774
# Processing parameter set 47.
#
# 3.995486252895054
# Processing parameter set 48.
#
# 4.51157284524417
# Processing parameter set 49.
#
# 3.2503938848312477
# Processing parameter set 50.
#
# 3.883550337721341
# Processing parameter set 51.
#
# 4.09997424260605
# Processing parameter set 52.
#
# 4.42864188610135
# Processing parameter set 53.
#
# 3.8361758084866286
# Processing parameter set 54.
#
# 4.019040820044532
# Processing parameter set 55.
#
# 4.162611306592584
# Processing parameter set 56.
#
# 4.019040820044532
# Processing parameter set 57.
#
# 3.380036524353645
# Processing parameter set 58.
#
# 3.8385877358222595
# Processing parameter set 59.
#
# 4.183991442152964
# Processing parameter set 60.
#
# 2.980483902856134
# Processing parameter set 61.
#
# 4.553555055860437
# Processing parameter set 62.
#
# 3.4095402433022866
# Processing parameter set 63.
#
# 4.62914250543317
# Processing parameter set 64.
#
# 5.032815422398924
# Processing parameter set 65.
#
# 3.692009697951161
# Processing parameter set 66.
#
# 4.139626226274116
# Processing parameter set 67.
#
# 2.6865575804476394
# Processing parameter set 68.
#
# 4.312591037845794
# Processing parameter set 69.
#
# 2.5006523671240894
# Processing parameter set 70.
#
# 4.314541307662098
# Processing parameter set 71.
#
# 2.6865575804476394
# Processing parameter set 72.
#
# 4.338686999182375
# Processing parameter set 73.
#
# 4.182951965451777
# Processing parameter set 74.
#
# 3.824599913797119
# Processing parameter set 75.
#
# 4.019998386284367
# Processing parameter set 76.
#
# 4.51157284524417
# Processing parameter set 77.
#
# 3.6577921945460945
# Processing parameter set 78.
#
# 4.097835322029151
# Processing parameter set 79.
#
# 4.181644454743049
# Processing parameter set 80.
#
# 4.115807906665388
# Processing parameter set 81.
#
# 4.832197338081799
# Processing parameter set 82.
#
# 4.591361641300449
# Processing parameter set 83.
#
# 4.729987461610524
# Processing parameter set 84.
#
# 4.033873870500643
# Processing parameter set 85.
#
# 3.436301439687915
# Processing parameter set 86.
#
# 5.0846102200899574
# Processing parameter set 87.
#
# 3.9775307694208393
# Processing parameter set 88.
#
# 4.0691090153639875
# Processing parameter set 89.
#
# 4.210055078996245
# Processing parameter set 90.
#
# 4.729987461610524
# Processing parameter set 91.
#
# 4.85302428945001
# Processing parameter set 92.
#
# 4.060277785633297
# Processing parameter set 93.
#
# 3.486444449755743
# Processing parameter set 94.
#
# 2.6865575804476394
# Processing parameter set 95.
#
# 4.374301961227197
# Processing parameter set 96.
#
# 3.9846042407060476
# Processing parameter set 97.
#
# 3.8024421812916067
# Processing parameter set 98.
#
# 5.268196764365582
# Processing parameter set 99.
#
# 3.9846042407060476
# Processing parameter set 100.
#
# 3.748923103282769
# Processing parameter set 101.
#
# 3.486444449755743
# Processing parameter set 102.
#
# 4.0066796273254806
# Processing parameter set 103.
#
# 4.42864188610135
# Processing parameter set 104.
#
# 4.019998386284367
# Processing parameter set 105.
#
# 2.6473360375971318
# Processing parameter set 106.
#
# 3.827577545836026
# Processing parameter set 107.
#
# 3.827577545836026
# Processing parameter set 108.
#
# 4.98991841490355
# Processing parameter set 109.
#
# 3.9846042407060476
# Processing parameter set 110.
#
# 5.0790014542227215
# Processing parameter set 111.
#
# 4.287109401077683
# Processing parameter set 112.
#
# 4.322272056663144
# Processing parameter set 113.
#
# 4.22458291646398
# Processing parameter set 114.
#
# 4.091087838818732
# Processing parameter set 115.
#
# 5.472114519405772
# Processing parameter set 116.
#
# 3.8385877358222595
# Processing parameter set 117.
#
# 4.360239497933424
# Processing parameter set 118.
#
# 4.7558117534438775
# Processing parameter set 119.
#
# 3.001882796852318
# Processing parameter set 120.
#
# 4.823410515906759
# Processing parameter set 121.
#
# 4.226696585175155
# Processing parameter set 122.
#
# 4.288574493146696
# Processing parameter set 123.
#
# 3.2826775151480083
# Processing parameter set 124.
#
# 3.827577545836026
# Processing parameter set 125.
#
# 4.601189544445168
# Processing parameter set 126.
#
# 3.96579992632948
# Processing parameter set 127.
#
# 5.224689131434489
# Processing parameter set 128.
#
# 3.4420998661132858
# Processing parameter set 129.
#
# 3.7508126453955843
# Processing parameter set 130.
#
# 4.367079571459697
# Processing parameter set 131.
#
# 3.9775307694208393
# Processing parameter set 132.
#
# 3.499220761683416
# Processing parameter set 133.
#
# 4.418997189001849
# Processing parameter set 134.
#
# 3.700864485667447
# Processing parameter set 135.
#
# 3.700864485667447
# Processing parameter set 136.
#
# 4.591361641300449
# Processing parameter set 137.
#
# 2.9201682960658824
# Processing parameter set 138.
#
# 4.7010326233279836
# Processing parameter set 139.
#
# 4.24973742611771
# Processing parameter set 140.
#
# 4.089952263906425
# Processing parameter set 141.
#
# 4.627354409231939
# Processing parameter set 142.
#
# 4.24973742611771
# Processing parameter set 143.
#
# 5.162864186563369
# Processing parameter set 144.
#
# 4.273146158725957
# Processing parameter set 145.
#
# 3.4095402433022866
# Processing parameter set 146.
#
# 3.9545234875228488
# Processing parameter set 147.
#
# 4.568258940016478
# Processing parameter set 148.
#
# 4.275927695401373
# Processing parameter set 149.
#
# 3.6425804370560986
# Processing parameter set 150.
#
# 4.151717540524909
# Processing parameter set 151.
#
# 3.4728540496227014
# Processing parameter set 152.
#
# 5.16306965951165
# Processing parameter set 153.
#
# 4.054001357975509
# Processing parameter set 154.
#
# 4.115090014222387
# Processing parameter set 155.
#
# 4.557517946676119
# Processing parameter set 156.
#
# 4.338686999182375
# Processing parameter set 157.
#
# 4.1654811314522355
# Processing parameter set 158.
#
# 3.4728540496227014
# Processing parameter set 159.
#
# 4.054001357975509
# Processing parameter set 160.
#
# 3.4420998661132858
# Processing parameter set 161.
#
# 4.630450248366774
# Processing parameter set 162.
#
# 4.474619158560053
# Processing parameter set 163.
#
# 3.6236647906691792
# Processing parameter set 164.
#
# 5.083366935001991
# Processing parameter set 165.
#
# 3.5396020490895603
# Processing parameter set 166.
#
# 3.2826775151480083
# Processing parameter set 167.
#
# 4.459551815426952
# Processing parameter set 168.
# 4.7482178535806145
# Processing parameter set 169.
#
# 4.3135883175570635
# Processing parameter set 170.
#
# 3.984681184650927
# Processing parameter set 171.
#
# 4.6204680141785035
# Processing parameter set 172.
#
# 4.009741540382527
# Processing parameter set 173.
#
# 4.407141303596442
# Processing parameter set 174.
#
# 4.146422681415192
# Processing parameter set 175.
#
# 4.039557025291421
# Processing parameter set 176.
#
# 3.5435819248685227
# Processing parameter set 177.
#
# 3.4420998661132858
# Processing parameter set 178.
#
# 4.58021799340302
# Processing parameter set 179.
#
# 4.532264603416683
# Processing parameter set 180.
#
# 3.9986939839452442
# Processing parameter set 181.
#
# 2.485170891224862
# Processing parameter set 182.
#
# 4.294807927653458
# Processing parameter set 183.
#
# 3.9799183174393833
# Processing parameter set 184.
#
# 4.054001357975509
# Processing parameter set 185.
#
# 4.374028201385677
# Processing parameter set 186.
#
# 3.620098849131066
# Processing parameter set 187.
#
# 4.30883616354885
# Processing parameter set 188.
#
# 4.579354212897709
# Processing parameter set 189.
#
# 3.8267501492340585
# Processing parameter set 190.
#
# 4.082424026848815
# Processing parameter set 191.
#
# 3.4728540496227014
# Processing parameter set 192.
#
# 3.976603660467932
# Processing parameter set 193.
#
# 4.130010494947587
# Processing parameter set 194.
#
# 3.9605102549106026
# Processing parameter set 195.
#
# 4.558187043933513
# Processing parameter set 196.
#
# 4.339008878537372
# Processing parameter set 197.
#
# 4.155927331607845
# Processing parameter set 198.
#
# 4.572106590732139
# Processing parameter set 199.
#
# 4.524247338933308
# Processing parameter set 200.
#
# 3.368940180296724
# Processing parameter set 201.
#
# 3.876646757849566
# Processing parameter set 202.
#
# 4.407141303596442
# Processing parameter set 203.
#
# 4.3666934676632625
# Processing parameter set 204.
#
# 4.604863192978246
# Processing parameter set 205.
#
# 4.083902467869343
# Processing parameter set 206.
#
# 5.362541916588376
# Processing parameter set 207.
#
# 3.368940180296724
# Processing parameter set 208.
#
# 4.273146158725957
# Processing parameter set 209.
#
# 3.1859607931874216
# Processing parameter set 210.
#
# 4.004061597426719
# Processing parameter set 211.
#
# 4.060124469017805
# Processing parameter set 212.
#
# 4.287723901102816
# Processing parameter set 213.
#
# 4.060124469017805
# Processing parameter set 214.
#
# 3.8450860116997228
# Processing parameter set 215.
#
# 4.348426226652674
# Processing parameter set 216.
#
# 3.824518223070164
# Processing parameter set 217.
#
# 4.009440950925849
# Processing parameter set 218.
#
# 2.902063204687212
# Processing parameter set 219.
#
# 3.4420998661132858
# Processing parameter set 220.
#
# 4.374028201385677
# Processing parameter set 221.
#
# 3.3187907582129403
# Processing parameter set 222.
#
# 4.600456687446006
# Processing parameter set 223.
#
# 4.21902811281498
# Processing parameter set 224.
#
# 4.183752695633456
# Processing parameter set 225.
#
# 4.904434338380445
# Processing parameter set 226.
#
# 2.901627621478438
# Processing parameter set 227.
#
# 3.7981509433362866
# Processing parameter set 228.
#
# 2.876104656574726
# Processing parameter set 229.
#
# 3.662703036162977
# Processing parameter set 230.
#
# 4.601189544445168
# Processing parameter set 231.
#
# 4.524247338933308
# Processing parameter set 232.
#
# 3.8758227600820763
# Processing parameter set 233.
#
# 4.152953213232481
# Processing parameter set 234.
#
# 4.836244743651157
# Processing parameter set 235.
#
# 4.558187043933513
# Processing parameter set 236.
#
# 4.097161217427495
# Processing parameter set 237.
#
# 3.8284576154807897
# Processing parameter set 238.
#
# 3.6191675739416467
# Processing parameter set 239.
#
# 4.27683110251809
# Processing parameter set 240.
#
# 3.768249049289951
# Processing parameter set 241.
#
# 4.097161217427495
# Processing parameter set 242.
#
# 4.135606199197098
# Processing parameter set 243.
#
# 3.4728540496227014
# Processing parameter set 244.
#
# 2.8762023078072607
# Processing parameter set 245.
#
# 3.662703036162977
# Processing parameter set 246.
#
# 4.0585273783542535
# Processing parameter set 247.
#
# 3.825029319548876
# Processing parameter set 248.
#
# 5.350799146215761
# Processing parameter set 249.
#
# 4.438902153454482
# Processing parameter set 250.
#
# 3.985446643205318
# Processing parameter set 251.
#
# 2.518686016654696
# Processing parameter set 252.
#
# 5.025673379176471
# Processing parameter set 253.
#
# 4.3195182333184965
# Processing parameter set 254.
#
# 5.226547798867858
# Processing parameter set 255.
#
# 4.454984204042771
# Processing parameter set 256.
#
# 2.8551369328559346
# Processing parameter set 257.
#
# 5.226547798867858
# Processing parameter set 258.
#
# 4.286076496878299
# Processing parameter set 259.
#
# 3.932250351918261
# Processing parameter set 260.
#
# 4.061506399234667
# Processing parameter set 261.
#
# 4.082424026848815
# Processing parameter set 262.
#
# 4.097161217427495
# Processing parameter set 263.
#
# 4.147851360267647
# Processing parameter set 264.
#
# 4.338201625987973
# Processing parameter set 265.
#
# 3.8199454297640885
# Processing parameter set 266.
#
# 3.3148245832240346
# Processing parameter set 267.
#
# 3.9269795781716432
# Processing parameter set 268.
#
# 4.474619158560053
# Processing parameter set 269.
#
# 3.813142713240261
# Processing parameter set 270.
#
# 4.316244723588814
# Processing parameter set 271.
#
# 3.4728540496227014
# Processing parameter set 272.
#
# 4.083902467869343
# Processing parameter set 273.
#
# 4.2362585994520465
# Processing parameter set 274.
#
# 4.601189544445168
# Processing parameter set 275.
#
# 4.475122652072642
# Processing parameter set 276.
#
# 3.7360045784253346
# Processing parameter set 277.
#
# 3.61372348576903
# Processing parameter set 278.
#
# 4.568258940016478
# Processing parameter set 279.
#
# 4.603312449582972
# Processing parameter set 280.
#
# 4.258927915950055
# Processing parameter set 281.
#
# 4.3666934676632625
# Processing parameter set 282.
#
# 3.869949137697615
# Processing parameter set 283.
#
# 4.128421852090882
# Processing parameter set 284.
#
# 4.512940386965796
# Processing parameter set 285.
#
# 3.2704530226516084
# Processing parameter set 286.
#
# 4.524247338933308
# Processing parameter set 287.
#
# 5.050762294981575
# Processing parameter set 288.
#
# 4.338201625987973
# Processing parameter set 289.
#
# 4.588191829996138
# Processing parameter set 290.
#
# 4.524247338933308
# Processing parameter set 291.
#
# 3.707131042827775
# Processing parameter set 292.
#
# 4.102514196372535
# Processing parameter set 293.
#
# 4.128421852090882
# Processing parameter set 294.
#
# 4.61264999655335
# Processing parameter set 295.
#
# 4.037457389939687
# Processing parameter set 296.
#
# 4.1047786549574345
# Processing parameter set 297.
#
# 4.588191829996138
# Processing parameter set 298.
#
# 4.475404970014735
# Processing parameter set 299.
#
# 3.618547813155778
# Processing parameter set 300.
#
# 4.037457389939687
# Processing parameter set 301.
#
# 3.653276373188262
# Processing parameter set 302.
#
# 4.077272971327698
# Processing parameter set 303.
#
# 4.585698916371642
# Processing parameter set 304.
#
# 3.7308799507863557
# Processing parameter set 305.
#
# 4.30143580332968
# Processing parameter set 306.
#
# 5.226547798867858
# Processing parameter set 307.
#
# 4.277195639381573
# Processing parameter set 308.
#
# 2.8762023078072607
# Processing parameter set 309.
#
# 4.512940386965796
# Processing parameter set 310.
#
# 3.86980565913324
# Processing parameter set 311.
#
# 3.956113616690824
# Processing parameter set 312.
#
# 3.931024996352794
# Processing parameter set 313.
#
# 4.082635383537792
# Processing parameter set 314.
#
# 4.338201625987973
# Processing parameter set 315.
#
# 3.2704530226516084
# Processing parameter set 316.
#
# 3.616461889479685
# Processing parameter set 317.
#
# 4.077272971327698
# Processing parameter set 318.
#
# 4.323676185835703
# Processing parameter set 319.
#
# 4.091159480554764
# Processing parameter set 320.
#
# 3.7308799507863557
# Processing parameter set 321.
#
# 3.815002887582137
# Processing parameter set 322.
#
# 4.082635383537792
# Processing parameter set 323.
#
# 4.114859525959117
# Processing parameter set 324.
#
# 4.0094863056123415
# Processing parameter set 325.
#
# 2.441464696150087
# Processing parameter set 326.
#
# 4.003923401597278
# Processing parameter set 327.
#
# 2.8098950961365343
# Processing parameter set 328.
#
# 5.11613710970097
# Processing parameter set 329.
#
# 4.6129616181143085
# Processing parameter set 330.
#
# 4.022679082988075
# Processing parameter set 331.
#
# 4.6462157563021576
# Processing parameter set 332.
#
# 3.828657944173912
# Processing parameter set 333.
#
# 4.476054755498305
# Processing parameter set 334.
#
# 4.277195639381573
# Processing parameter set 335.
# 4.345760206499161
# Processing parameter set 336.
#
# 4.116224309525407
# Processing parameter set 337.
#
# 3.4615526041276117
# Processing parameter set 338.
#
# 4.02160750432647
# Processing parameter set 339.
#
# 4.5838115137512965
# Processing parameter set 340.
#
# 3.869793334482929
# Processing parameter set 341.
#
# 3.953437777937076
# Processing parameter set 342.
#
# 3.3074355057393876
# Processing parameter set 343.
#
# 4.073452880174132
# Processing parameter set 344.
#
# 4.2507778708892765
# Processing parameter set 345.
#
# 4.283821902039885
# Processing parameter set 346.
#
# 4.895507862442903
# Processing parameter set 347.
#
# 3.90829253746703
# Processing parameter set 348.
#
# 3.895066436527968
# Processing parameter set 349.
#
# 3.953437777937076
# Processing parameter set 350.
#
# 4.276860924609233
# Processing parameter set 351.
#
# 4.016131016365051
# Processing parameter set 352.
#
# 3.931971469973488
# Processing parameter set 353.
#
# 3.7178228007362315
# Processing parameter set 354.
#
# 3.819216526911534
# Processing parameter set 355.
#
# 4.058709921447013
# Processing parameter set 356.
#
# 4.172015749666699
# Processing parameter set 357.
#
# 4.2716019453301035
# Processing parameter set 358.
#
# 4.12075140360844
# Processing parameter set 359.
#
# 4.245341914214477
# Processing parameter set 360.
#
# 4.180359404507477
# Processing parameter set 361.
#
# 3.079612850240882
# Processing parameter set 362.
#
# 3.8120790820322354
# Processing parameter set 363.
#
# 4.277375936345625
# Processing parameter set 364.
#
# 4.332159983502204
# Processing parameter set 365.
#
# 3.7360045784253346
# Processing parameter set 366.
#
# 4.474116209985072
# Processing parameter set 367.
#
# 4.190804685403072
# Processing parameter set 368.
#
# 3.828657944173912
# Processing parameter set 369.
#
# 4.4894035497431535
# Processing parameter set 370.
#
# 3.2704530226516084
# Processing parameter set 371.
#
# 3.9066076706184703
# Processing parameter set 372.
#
# 4.238561327797763
# Processing parameter set 373.
#
# 4.2716019453301035
# Processing parameter set 374.
#
# 4.079471844581425
# Processing parameter set 375.
#
# 4.302933482902816
# Processing parameter set 376.
#
# 3.86980565913324
# Processing parameter set 377.
#
# 4.505647446001102
# Processing parameter set 378.
#
# 3.5642420958044023
# Processing parameter set 379.
#
# 2.6871410517767274
# Processing parameter set 380.
#
# 2.993205099848987
# Processing parameter set 381.
#
# 4.807523657289827
# Processing parameter set 382.
#
# 3.8186829164130516
# Processing parameter set 383.
#
# 4.0361449996902525
# Processing parameter set 384.
#
# 3.2578080593205145
# Processing parameter set 385.
#
# 4.168552902550211
# Processing parameter set 386.
#
# 3.1934745633209354
# Processing parameter set 387.
#
# 4.822697732409173
# Processing parameter set 388.
#
# 4.105268596657679
# Processing parameter set 389.
#
# 4.080627645311076
# Processing parameter set 390.
#
# 4.069645795575687
# Processing parameter set 391.
#
# 4.1773080375688565
# Processing parameter set 392.
#
# 3.343241538106796
# Processing parameter set 393.
#
# 3.9014744850313967
# Processing parameter set 394.
#
# 4.323676185835703
# Processing parameter set 395.
#
# 4.035853109870176
# Processing parameter set 396.
#
# 3.903928941743496
# Processing parameter set 397.
#
# 2.388968550021522
# Processing parameter set 398.
#
# 4.6129616181143085
# Processing parameter set 399.
#
# 4.036085338885174
# Processing parameter set 400.
#
# 4.342519885486176
# Processing parameter set 401.
#
# 3.4715170304833545
# Processing parameter set 402.
#
# 4.011004556474753
# Processing parameter set 403.
#
# 3.651752711022212
# Processing parameter set 404.
#
# 4.514956282233603
# Processing parameter set 405.
#
# 4.04197082864505
# Processing parameter set 406.
#
# 4.984244803702706
# Processing parameter set 407.
#
# 3.7360045784253346
# Processing parameter set 408.
#
# 4.234371203790548
# Processing parameter set 409.
#
# 3.932564222849859
# Processing parameter set 410.
#
# 4.544471812880447
# Processing parameter set 411.
#
# 4.088730566984605
# Processing parameter set 412.
#
# 3.6153707682639498
# Processing parameter set 413.
#
# 5.104760484124443
# Processing parameter set 414.
#
# 4.069645795575687
# Processing parameter set 415.
#
# 4.064462748602939
# Processing parameter set 416.
#
# 4.082635383537792
# Processing parameter set 417.
#
# 4.055092560778412
# Processing parameter set 418.
#
# 4.2222327803563395
# Processing parameter set 419.
#
# 4.276889684265095
# Processing parameter set 420.
#
# 4.544471812880447
# Molecular group bilayer.substrate does not exist.
#   siox ...
# Loaded statistical data from StatDataPython.dat
# Molecular group bilayer.siox does not exist.
#   tether ...
# Loaded statistical data from StatDataPython.dat
# Molecular group bilayer.bME does not exist.
# Molecular group bilayer.tetherg does not exist.
# Molecular group bilayer.tether does not exist.
#   innerhg ...
# Loaded statistical data from StatDataPython.dat
# Loaded statistical data from StatDataPython.dat
# Loaded statistical data from StatDataPython.dat
# Loaded statistical data from StatDataPython.dat
#   innerhc ...
# Loaded statistical data from StatDataPython.dat
# Loaded statistical data from StatDataPython.dat
# Loaded statistical data from StatDataPython.dat
#   outerhc ...
# Loaded statistical data from StatDataPython.dat
# Loaded statistical data from StatDataPython.dat
# Loaded statistical data from StatDataPython.dat
#   outerhg ...
# Loaded statistical data from StatDataPython.dat
# Loaded statistical data from StatDataPython.dat
# Loaded statistical data from StatDataPython.dat
# Loaded statistical data from StatDataPython.dat
#   protein ...
# Loaded statistical data from StatDataPython.dat
# Molecular group protein does not exist.
# Applying corrections ...
#
# Calculating statistics ...
#
# Saving data to bilayerplotdata.dat ...

# %%
fit_analysis.fnCalculateMolgroupProperty(fConfidence=-1)
# Out:
# Loaded statistical data from StatDataPython.dat
# Did not find any fractional envelopes ...
# WaterFracHeadgroup1  [    0.4008,     0.4782,     0.5547] (-   0.07738, +   0.07655)
# WaterFracHeadgroup2  [    0.3857,     0.4641,     0.5431] (-   0.07837, +     0.079)
# WaterFracHydrocarbon  [   0.01453,    0.02419,     0.0293] (-  0.009653, +  0.005111)
# WaterFracLipid1  [    0.0146,    0.02672,    0.03261] (-   0.01212, +   0.00589)
# WaterFracLipid2  [   0.01342,    0.02125,    0.02607] (-  0.007828, +  0.004822)
# WaterFracSubMembrane  [    0.9902,     0.9933,     0.9956] (-   0.00306, +  0.002373)
# bilayer.defect_hc_AVG  [         0,          0,          0] (-         0, +         0)
# bilayer.defect_hc_COM  [     1e+05,      1e+05,      1e+05] (-         0, +         0)
# bilayer.defect_hc_INT  [         0,          0,          0] (-         0, +         0)
# bilayer.defect_hg_AVG  [         0,          0,          0] (-         0, +         0)
# bilayer.defect_hg_COM  [     1e+05,      1e+05,      1e+05] (-         0, +         0)
# bilayer.defect_hg_INT  [         0,          0,          0] (-         0, +         0)
# bilayer.headgroup1_1.cg_AVG  [    0.8969,     0.9338,     0.9985] (-   0.03698, +   0.06461)
# bilayer.headgroup1_1.cg_COM  [     54.92,      56.09,      57.58] (-     1.168, +     1.498)
# bilayer.headgroup1_1.cg_INT  [     1.873,      1.985,      2.096] (-     0.111, +    0.1112)
# bilayer.headgroup1_1.choline_AVG  [      0.72,     0.7833,     0.8486] (-   0.06335, +   0.06533)
# bilayer.headgroup1_1.choline_COM  [      52.1,       52.6,      53.25] (-    0.5061, +    0.6505)
# bilayer.headgroup1_1.choline_INT  [     1.504,      1.645,      1.837] (-    0.1408, +    0.1918)
# bilayer.headgroup1_1.phosphate_AVG  [    0.2892,     0.3199,     0.3832] (-   0.03068, +   0.06332)
# bilayer.headgroup1_1.phosphate_COM  [     53.08,      54.01,      54.91] (-    0.9309, +    0.9044)
# bilayer.headgroup1_1.phosphate_INT  [    0.6135,     0.6786,     0.8137] (-   0.06504, +    0.1352)
# bilayer.headgroup1_1_AVG  [     1.166,      1.262,      1.461] (-   0.09615, +    0.1983)
# bilayer.headgroup1_1_COM  [     53.63,      54.45,      55.43] (-    0.8193, +    0.9769)
# bilayer.headgroup1_1_INT  [     2.494,       2.68,      3.093] (-    0.1867, +    0.4126)
# bilayer.headgroup1_2.cg_AVG  [    0.8969,     0.9338,     0.9985] (-   0.03698, +   0.06461)
# bilayer.headgroup1_2.cg_COM  [     54.92,      56.09,      57.58] (-     1.168, +     1.498)
# bilayer.headgroup1_2.cg_INT  [     1.873,      1.985,      2.096] (-     0.111, +    0.1112)
# bilayer.headgroup1_2.choline_AVG  [      0.72,     0.7833,     0.8486] (-   0.06335, +   0.06533)
# bilayer.headgroup1_2.choline_COM  [      52.1,       52.6,      53.25] (-    0.5061, +    0.6505)
# bilayer.headgroup1_2.choline_INT  [     1.504,      1.645,      1.837] (-    0.1408, +    0.1918)
# bilayer.headgroup1_2.phosphate_AVG  [    0.2892,     0.3199,     0.3832] (-   0.03068, +   0.06332)
# bilayer.headgroup1_2.phosphate_COM  [     53.08,      54.01,      54.91] (-    0.9309, +    0.9044)
# bilayer.headgroup1_2.phosphate_INT  [    0.6135,     0.6786,     0.8137] (-   0.06504, +    0.1352)
# bilayer.headgroup1_2_AVG  [    0.5974,     0.7839,     0.9015] (-    0.1865, +    0.1175)
# bilayer.headgroup1_2_COM  [     53.63,      54.45,      55.43] (-    0.8193, +    0.9769)
# bilayer.headgroup1_2_INT  [     1.259,      1.628,      1.958] (-    0.3691, +    0.3306)
# bilayer.headgroup2_1.cg_AVG  [    0.8969,     0.9338,     0.9985] (-   0.03698, +   0.06461)
# bilayer.headgroup2_1.cg_COM  [     87.49,      88.29,      89.08] (-    0.7954, +    0.7922)
# bilayer.headgroup2_1.cg_INT  [     1.873,      1.985,      2.096] (-     0.111, +    0.1112)
# bilayer.headgroup2_1.choline_AVG  [      0.72,     0.7833,     0.8486] (-   0.06335, +   0.06533)
# bilayer.headgroup2_1.choline_COM  [     90.46,      91.91,      93.45] (-     1.452, +     1.544)
# bilayer.headgroup2_1.choline_INT  [     1.504,      1.645,      1.837] (-    0.1408, +    0.1918)
# bilayer.headgroup2_1.phosphate_AVG  [    0.2892,     0.3199,     0.3832] (-   0.03068, +   0.06332)
# bilayer.headgroup2_1.phosphate_COM  [      89.6,      90.32,      91.48] (-    0.7269, +     1.157)
# bilayer.headgroup2_1.phosphate_INT  [    0.6135,     0.6786,     0.8137] (-   0.06504, +    0.1352)
# bilayer.headgroup2_1_AVG  [     1.166,      1.262,      1.461] (-   0.09615, +    0.1983)
# bilayer.headgroup2_1_COM  [     88.96,      90.07,      91.09] (-     1.113, +     1.015)
# bilayer.headgroup2_1_INT  [     2.494,       2.68,      3.093] (-    0.1867, +    0.4126)
# bilayer.headgroup2_2.cg_AVG  [    0.9793,     0.9793,     0.9793] (-  2.22e-16, +  2.22e-16)
# bilayer.headgroup2_2.cg_COM  [     87.31,      88.07,      88.72] (-    0.7666, +    0.6463)
# bilayer.headgroup2_2.cg_INT  [     2.004,      2.062,      2.143] (-   0.05849, +   0.08109)
# bilayer.headgroup2_2.choline_AVG  [    0.7995,     0.7995,     0.7995] (- 3.331e-16, +  1.11e-16)
# bilayer.headgroup2_2.choline_COM  [     89.63,      91.08,      93.31] (-     1.453, +     2.229)
# bilayer.headgroup2_2.choline_INT  [     1.636,      1.684,       1.75] (-   0.04775, +   0.06619)
# bilayer.headgroup2_2.phosphate_AVG  [    0.3598,     0.3598,     0.3598] (- 5.551e-17, +         0)
# bilayer.headgroup2_2.phosphate_COM  [     89.51,      90.33,       91.5] (-     0.818, +     1.172)
# bilayer.headgroup2_2.phosphate_INT  [    0.7361,     0.7576,     0.7874] (-   0.02149, +   0.02979)
# bilayer.headgroup2_2_AVG  [    0.6201,     0.8205,     0.9306] (-    0.2004, +    0.1101)
# bilayer.headgroup2_2_COM  [     88.56,      89.57,      90.88] (-      1.01, +     1.308)
# bilayer.headgroup2_2_INT  [     1.307,        1.7,      2.022] (-    0.3934, +    0.3218)
# bilayer.methyl1_1_AVG  [    0.4106,     0.4446,     0.4965] (-   0.03405, +   0.05189)
# bilayer.methyl1_1_COM  [     70.71,      71.44,      72.55] (-    0.7294, +     1.115)
# bilayer.methyl1_1_INT  [    0.8817,     0.9348,      1.053] (-   0.05306, +    0.1182)
# bilayer.methyl1_2_AVG  [    0.1909,     0.2525,     0.2864] (-   0.06167, +   0.03389)
# bilayer.methyl1_2_COM  [     70.71,      71.44,      72.55] (-    0.7294, +     1.115)
# bilayer.methyl1_2_INT  [    0.4022,     0.5233,     0.6224] (-    0.1211, +   0.09905)
# bilayer.methyl2_1_AVG  [    0.4106,     0.4446,     0.4965] (-   0.03405, +   0.05189)
# bilayer.methyl2_1_COM  [      72.1,      72.82,      73.92] (-    0.7231, +     1.103)
# bilayer.methyl2_1_INT  [    0.8817,     0.9348,      1.053] (-   0.05306, +    0.1182)
# bilayer.methyl2_2_AVG  [    0.1909,     0.2525,     0.2864] (-   0.06167, +   0.03389)
# bilayer.methyl2_2_COM  [      72.1,      72.82,      73.92] (-    0.7231, +     1.103)
# bilayer.methyl2_2_INT  [    0.4022,     0.5233,     0.6224] (-    0.1211, +   0.09905)
# bilayer.methylene1_1_AVG  [     3.296,      3.612,       4.16] (-    0.3161, +    0.5471)
# bilayer.methylene1_1_COM  [     63.65,      64.61,      66.01] (-     0.967, +     1.394)
# bilayer.methylene1_1_INT  [     7.102,      7.567,       8.76] (-    0.4658, +     1.192)
# bilayer.methylene1_2_AVG  [     1.687,      2.232,      2.531] (-     0.545, +    0.2996)
# bilayer.methylene1_2_COM  [      64.6,      65.69,      66.98] (-     1.088, +     1.291)
# bilayer.methylene1_2_INT  [     3.555,      4.625,      5.501] (-      1.07, +    0.8754)
# bilayer.methylene2_1_AVG  [     3.296,      3.612,       4.16] (-    0.3161, +    0.5471)
# bilayer.methylene2_1_COM  [     78.92,      79.69,      80.46] (-    0.7669, +    0.7705)
# bilayer.methylene2_1_INT  [     7.102,      7.567,       8.76] (-    0.4658, +     1.192)
# bilayer.methylene2_2_AVG  [     1.687,      2.232,      2.531] (-     0.545, +    0.2996)
# bilayer.methylene2_2_COM  [     77.94,      78.73,      79.49] (-    0.7892, +    0.7595)
# bilayer.methylene2_2_INT  [     3.555,      4.625,      5.501] (-      1.07, +    0.8754)
# bilayer.normarea_AVG  [     68.58,      71.28,      73.36] (-     2.697, +      2.08)
# bilayer.normarea_COM  [        75,         75,         75] (- 1.421e-14, + 2.842e-14)
# bilayer.normarea_INT  [     150.1,      150.1,      150.1] (- 2.643e-12, + 4.661e-12)
# fAreaPerLipid2  [     68.59,      71.51,      73.83] (-     2.921, +     2.325)
# fTotalLipid1Length  [     13.25,      13.64,      14.17] (-    0.3867, +    0.5362)
# fTotalLipid2Length  [     13.25,      13.64,      14.17] (-    0.3867, +    0.5362)

# %%
# Carry over manually!
areaperlipid = 72.96
areaperlipid_sim = 72.4
bulknsld_fit=9.368e-06
prefactor_fit=1
offset_fit=0
v_cg_fit = 143.3
v_phosphate_fit = 49.58
v_choline_fit = 114.2
va1_fit = 986.6
vm1_fit = 99.19
dq_fit=1.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys

bilayer_plot_data = pd.read_csv(
    store + "/bilayerplotdata.dat", sep="\s", engine="python"
)

zax = bilayer_plot_data["zaxis"] - 0.5 * bilayer_plot_data["zaxis"][len(bilayer_plot_data["zaxis"])-1]+2.5

fig, ax = plt.subplots()
ax.plot(zax, bilayer_plot_data["water_corr_cvo"], label="water")
ax.plot(zax, bilayer_plot_data["innerhg_corr_cvo"] + bilayer_plot_data["outerhg_corr_cvo"], label="headgroups")
ax.plot(zax, bilayer_plot_data["inner_cg_corr_cvo"] + bilayer_plot_data["outer_cg_corr_cvo"],label="cg")
ax.plot(zax, bilayer_plot_data["inner_phosphate_corr_cvo"] + bilayer_plot_data["outer_phosphate_corr_cvo"], label="phosphate")
ax.plot(zax, bilayer_plot_data["inner_choline_corr_cvo"] + bilayer_plot_data["outer_choline_corr_cvo"], label="choline")
ax.plot(zax, bilayer_plot_data["innerhc_corr_cvo"]+bilayer_plot_data["outerhc_corr_cvo"], label="hydrocarbons")
ax.plot(zax, bilayer_plot_data["innerch2_corr_cvo"]+bilayer_plot_data["outerch2_corr_cvo"], label="CH2")
ax.plot(zax, bilayer_plot_data["innerch3_corr_cvo"]+bilayer_plot_data["outerch3_corr_cvo"], label="CH3")
ax.legend(loc="upper right")
plt.xlabel("Distance (Å)")
plt.ylabel("Component volume occupancy")
ax.minorticks_on()
ax.tick_params(which="both", direction="in", labelsize=10)
ax.tick_params(bottom=True, top=True, left=True, right=True, which="both")
plt.xlim(-35, 35)
plt.xticks(np.arange(-35, 36, 5.0))
plt.grid(True, which='Both')
fig.patch.set_facecolor('white')
ax.figure.set_size_inches(16, 10)
plt.savefig(store + "/cvo", facecolor="white")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys

bilayer_plot_data = pd.read_csv(
    store + "/bilayerplotdata.dat", sep="\s", engine="python"
)

zax = bilayer_plot_data["zaxis"] - 0.5 * bilayer_plot_data["zaxis"][len(bilayer_plot_data["zaxis"])-1]+2.5

fig, ax = plt.subplots()
ax.plot(zax, bilayer_plot_data["water_corr"], label="water")
ax.plot(zax, bilayer_plot_data["innerhg_corr"] + bilayer_plot_data["outerhg_corr"], label="headgroups")
ax.plot(zax, bilayer_plot_data["inner_cg_corr"] + bilayer_plot_data["outer_cg_corr"],label="cg")
ax.plot(zax, bilayer_plot_data["inner_phosphate_corr"] + bilayer_plot_data["outer_phosphate_corr"], label="phosphate")
ax.plot(zax, bilayer_plot_data["inner_choline_corr"] + bilayer_plot_data["outer_choline_corr"], label="choline")
ax.plot(zax, bilayer_plot_data["innerhc_corr"]+bilayer_plot_data["outerhc_corr"], label="hydrocarbons")
ax.plot(zax, bilayer_plot_data["innerch2_corr"]+bilayer_plot_data["outerch2_corr"], label="CH2")
ax.plot(zax, bilayer_plot_data["innerch3_corr"]+bilayer_plot_data["outerch3_corr"], label="CH3")
ax.legend(loc="upper right")
plt.xlabel("Distance (Å)")
plt.ylabel("Component volume occupancy")
ax.minorticks_on()
ax.tick_params(which="both", direction="in", labelsize=10)
ax.tick_params(bottom=True, top=True, left=True, right=True, which="both")
plt.xlim(-35, 35)
plt.xticks(np.arange(-35, 36, 5.0))
plt.grid(True, which='Both')
fig.patch.set_facecolor('white')
ax.figure.set_size_inches(16, 10)
plt.savefig(store + "/area", facecolor="white")
plt.show()

# %% [markdown]
# # Diagnostics

# %%
# Create an electron density profile from the sim data and, in a second step
# divide it by the electron densities per molecular group used in the fit
# this creates a volume-correct plot of the electron densities.


simdata = pd.read_csv('../dopc72.4bcut.sim', sep="\s+", comment='#')
#print(simdata)

columnlist = list(simdata)
for element in columnlist:
    if element[0] == 'o':
        simdata[element]=simdata[element].multiply(8.)
    if element[0] == 'h':
        simdata[element]=simdata[element].multiply(1.)
    if element[0] == 'd':
        simdata[element]=simdata[element].multiply(1.)
    if element[0] == 'n':
        simdata[element]=simdata[element].multiply(7.)
    if element[0] == 'p':
        simdata[element]=simdata[element].multiply(15.)
    if element[0] == 'c':
        simdata[element]=simdata[element].multiply(6.)


ph_str = "ph op1h op2h op3h op4h"
ph_col = ph_str.split()
cg_str = "c1c1 o1c1 c1h h1ah h1bh c1c2 o1c2 o2h c2h h2ah c3h h3ah h3bh" #o1h missing
cg_col = cg_str.split()
chol_str = "c6h h6ah h6bh h6ch c7h h7ah h7bh h7ch c8h h8ah h8bh h8ch c4h h4ah h4bh c5h h5ah h5bh nh"
chol_col = chol_str.split()
ch2_str = "c2c1 h2ac1 h2bc1 c3c1 h3ac1 h3bc1 c4c1 h4ac1 h4bc1 c5c1 h5ac1 h5bc1 c6c1 h6ac1 h6bc1 c7c1 h7ac1 h7bc1 c8c1 h8ac1 h8bc1 c11c1 h11ac1 h11bc1 c12c1 h12ac1 h12bc1 c13c1 h13ac1 h13bc1 c14c1 h14ac1 h14bc1 c15c1 h15ac1 h15bc1 c16c1 h16ac1 h16bc1 c17c1 h17ac1 h17bc1 c2c2 h2ac2 h2bc2 c3c2 h3ac2 h3bc2 c4c2 h4ac2 h4bc2 c5c2 h5ac2 h5bc2 c6c2 h6ac2 h6bc2 c7c2 h7ac2 h7bc2 c8c2 h8ac2 h8bc2 c11c2 h11ac2 h11bc2 c12c2 h12ac2 h12bc2 c13c2 h13ac2 h13bc2 c14c2 h14ac2 h14bc2 c15c2 h15ac2 h15bc2 c16c2 h16ac2 h16bc2 c17c2 h17ac2 h17bc2 c9c1 c10c1 h9ac1 h10ac1 c9c2 c10c2 h9ac2 h10ac2"
ch2_col = ch2_str.split()
ch3_str = "c18c1 h18ac1 h18bc1 h18cc1 c18c2 h18ac2 h18bc2 h18cc2"
ch3_col = ch3_str.split()
h2o_str = "ow d1w d2w"
h2o_col = h2o_str.split()

ph_sim=simdata[ph_col].sum(axis=1).to_numpy()
cg_sim=simdata[cg_col].sum(axis=1).to_numpy()
chol_sim=simdata[chol_col].sum(axis=1).to_numpy()
ch2_sim=simdata[ch2_col].sum(axis=1).to_numpy()
ch3_sim=simdata[ch3_col].sum(axis=1).to_numpy()
h2o_sim=simdata[h2o_col].sum(axis=1).to_numpy()
z_sim = simdata["Zbin"].to_numpy()

stepsize_sim = z_sim[1]-z_sim[0]
print("Simulation number density times electron number:")
print("choline: ",chol_sim.sum()*stepsize_sim*areaperlipid_sim/2)
print("phosphate: ",ph_sim.sum()*stepsize_sim*areaperlipid_sim/2)
print("cg: ",cg_sim.sum()*stepsize_sim*areaperlipid_sim/2)
print("hc: ",(ch2_sim+ch3_sim).sum()*stepsize_sim*areaperlipid_sim/2)
print("methyl: ",ch3_sim.sum()*stepsize_sim*areaperlipid_sim/2)
print("water: ",h2o_sim.sum()*stepsize_sim*areaperlipid_sim/2)

# edensity 
ed_total = (ph_sim+cg_sim+chol_sim+ch2_sim+ch3_sim+h2o_sim)
ed_mf = ph_sim+cg_sim+chol_sim+ch2_sim+ch3_sim

normfactor=1.0
ph_sim*=normfactor/(47/v_phosphate_fit)
cg_sim*=normfactor/((67-8)/(v_cg_fit))      #should be (67, 147), but one O is missing
chol_sim*=normfactor/(50/v_choline_fit)
ch2_sim*=normfactor/(252/(va1_fit-vm1_fit))
ch3_sim*=normfactor/(18/vm1_fit)

fig, ax = plt.subplots()
ax.plot(zax, bilayer_plot_data["water_corr_cvo"], label="water")
ax.plot(zax, bilayer_plot_data["innerhg_corr_cvo"] + bilayer_plot_data["outerhg_corr_cvo"], label="headgroups")

ax.plot(zax, bilayer_plot_data["inner_cg_corr_cvo"] + bilayer_plot_data["outer_cg_corr_cvo"],label="cg")
ax.plot(z_sim, cg_sim, linestyle='dotted', color='black')

ax.plot(zax, bilayer_plot_data["inner_phosphate_corr_cvo"] + bilayer_plot_data["outer_phosphate_corr_cvo"], label="phosphate")
ax.plot(z_sim, ph_sim, linestyle='dotted', color='black')

ax.plot(zax, bilayer_plot_data["inner_choline_corr_cvo"] + bilayer_plot_data["outer_choline_corr_cvo"], label="choline")
ax.plot(z_sim, chol_sim, linestyle='dotted', color='black')

ax.plot(zax, bilayer_plot_data["innerhc_corr_cvo"]+bilayer_plot_data["outerhc_corr_cvo"], label="hydrocarbons")

ax.plot(zax, bilayer_plot_data["innerch2_corr_cvo"]+bilayer_plot_data["outerch2_corr_cvo"], label="CH2")
ax.plot(z_sim, ch2_sim, linestyle='dotted', color='black')

ax.plot(zax, bilayer_plot_data["innerch3_corr_cvo"]+bilayer_plot_data["outerch3_corr_cvo"], label="CH3")
ax.plot(z_sim, ch3_sim, linestyle='dotted', color='black', label="sim")

ax.legend(loc="upper right")
plt.xlabel("Distance (Å)")
plt.ylabel("Component volume occupancy")
ax.minorticks_on()
#ax.tick_params(which="both", direction="in", labelsize=10)
ax.tick_params(bottom=True, top=True, left=True, right=True, which="both")
plt.xlim(-35, 35)
plt.xticks(np.arange(-35, 36, 5.0))
plt.grid(True, which='Both')
ax.figure.set_size_inches(16, 10)
plt.savefig(store + "/cvo_sldweighted", facecolor="white")
plt.show()

stepsize_z=zax[1]-zax[0]
print("Fit:")
print("choline: ",bilayer_plot_data["inner_choline_corr_cvo"].sum()*stepsize_z*areaperlipid)
print("phosphate: ",bilayer_plot_data["inner_phosphate_corr_cvo"].sum()*stepsize_z*areaperlipid)
print("cg: ",bilayer_plot_data["inner_cg_corr_cvo"].sum()*stepsize_z*areaperlipid)
print("hc: ",bilayer_plot_data["innerhc_corr_cvo"].sum()*stepsize_z*areaperlipid)
print("methyl: ",bilayer_plot_data["innerch3_corr_cvo"].sum()*stepsize_z*areaperlipid)
print("Simulation, volume weighted electron densities:")
print("choline: ",chol_sim.sum()*stepsize_sim*areaperlipid_sim/2)
print("phosphate: ",ph_sim.sum()*stepsize_sim*areaperlipid_sim/2)
print("cg: ",cg_sim.sum()*stepsize_sim*areaperlipid_sim/2)
print("hc: ",(ch2_sim+ch3_sim).sum()*stepsize_sim*areaperlipid_sim/2)
print("methyl: ",ch3_sim.sum()*stepsize_sim*areaperlipid_sim/2)
# Out:
# Simulation number density times electron number:
# choline:  49.98850759999983
# phosphate:  46.98311119999985
# cg:  58.9887687999998
# hc:  269.94463079999906
# methyl:  17.99429599999994
# water:  309.490234799999
# Fit:
# choline:  116.85010395106607
# phosphate:  48.48606582118065
# cg:  140.11420706019942
# hc:  985.6616253926916
# methyl:  104.55499144165263
# Simulation, volume weighted electron densities:
# choline:  114.17375135839961
# phosphate:  49.56218411268068
# cg:  143.27272150915203
# hc:  986.3936733659808
# methyl:  99.15856779111077

# %%
# Create an volume density plot using VDW radii

simdata = pd.read_csv('../dopc72.4bcut.sim', sep="\s+", comment='#')
#print(simdata)

columnlist = list(simdata)
#for element in columnlist:
#    if element[0] == 'o':
#        simdata[element]=simdata[element].multiply(0.5*4./3.*np.pi*(1.6)**3)
#    if element[0] == 'h':
#        simdata[element]=simdata[element].multiply(0.5*4./3.*np.pi*(1.2)**3)
#    if element[0] == 'n':
#        simdata[element]=simdata[element].multiply(0.5*4./3.*np.pi*(1.7)**3)
#    if element[0] == 'p':
#        simdata[element]=simdata[element].multiply(0.5*4./3.*np.pi*(1.8)**3)
#    if element[0] == 'c':
#        simdata[element]=simdata[element].multiply(0.5*4./3.*np.pi*(1.9)**3)


ph_str = "ph op1h op2h op3h op4h"
ph_col = ph_str.split()
cg_str = "c1c1 o1c1 c1h h1ah h1bh c1c2 o1c2 o2h c2h h2ah c3h h3ah h3bh" #o1h missing
cg_col = cg_str.split()
chol_str = "c6h h6ah h6bh h6ch c7h h7ah h7bh h7ch c8h h8ah h8bh h8ch c4h h4ah h4bh c5h h5ah h5bh nh"
chol_col = chol_str.split()
ch2_str = "c2c1 h2ac1 h2bc1 c3c1 h3ac1 h3bc1 c4c1 h4ac1 h4bc1 c5c1 h5ac1 h5bc1 c6c1 h6ac1 h6bc1 c7c1 h7ac1 h7bc1 c8c1 h8ac1 h8bc1 c11c1 h11ac1 h11bc1 c12c1 h12ac1 h12bc1 c13c1 h13ac1 h13bc1 c14c1 h14ac1 h14bc1 c15c1 h15ac1 h15bc1 c16c1 h16ac1 h16bc1 c17c1 h17ac1 h17bc1 c2c2 h2ac2 h2bc2 c3c2 h3ac2 h3bc2 c4c2 h4ac2 h4bc2 c5c2 h5ac2 h5bc2 c6c2 h6ac2 h6bc2 c7c2 h7ac2 h7bc2 c8c2 h8ac2 h8bc2 c11c2 h11ac2 h11bc2 c12c2 h12ac2 h12bc2 c13c2 h13ac2 h13bc2 c14c2 h14ac2 h14bc2 c15c2 h15ac2 h15bc2 c16c2 h16ac2 h16bc2 c17c2 h17ac2 h17bc2 c9c1 c10c1 h9ac1 h10ac1 c9c2 c10c2 h9ac2 h10ac2"
ch2_col = ch2_str.split()
ch3_str = "c18c1 h18ac1 h18bc1 h18cc1 c18c2 h18ac2 h18bc2 h18cc2"
ch3_col = ch3_str.split()

ph_sim=simdata[ph_col].sum(axis=1).to_numpy()
cg_sim=simdata[cg_col].sum(axis=1).to_numpy()
chol_sim=simdata[chol_col].sum(axis=1).to_numpy()
ch2_sim=simdata[ch2_col].sum(axis=1).to_numpy()
ch3_sim=simdata[ch3_col].sum(axis=1).to_numpy()
z_sim = simdata["Zbin"].to_numpy()

stepsize_sim = z_sim[1]-z_sim[0]
print("Number of electrons (half bilayer):")
print("choline: ",chol_sim.sum()*stepsize_sim*areaperlipid_sim/2)
print("phosphate: ",ph_sim.sum()*stepsize_sim*areaperlipid_sim/2)
print("cg: ",cg_sim.sum()*stepsize_sim*areaperlipid_sim/2)
print("hc: ",(ch2_sim+ch3_sim).sum()*stepsize_sim*areaperlipid_sim/2)
print("methyl: ",ch3_sim.sum()*stepsize_sim*areaperlipid_sim/2)

normfactor=1.0
ph_sim*=normfactor/4*(v_phosphate_fit)
cg_sim*=normfactor/(14-1)*(v_cg_fit)   #should be (14,147), but one O is missing      
chol_sim*=normfactor/19*(v_choline_fit)
ch2_sim*=normfactor/92*(va1_fit-vm1_fit)
ch3_sim*=normfactor/8*vm1_fit

fig, ax = plt.subplots()
ax.plot(zax, bilayer_plot_data["water_corr_cvo"], label="water")
ax.plot(zax, bilayer_plot_data["innerhg_corr_cvo"] + bilayer_plot_data["outerhg_corr_cvo"], label="headgroups")

ax.plot(zax, bilayer_plot_data["inner_cg_corr_cvo"] + bilayer_plot_data["outer_cg_corr_cvo"],label="cg")
ax.plot(z_sim, cg_sim, linestyle='dotted', color='black')

ax.plot(zax, bilayer_plot_data["inner_phosphate_corr_cvo"] + bilayer_plot_data["outer_phosphate_corr_cvo"], label="phosphate")
ax.plot(z_sim, ph_sim, linestyle='dotted', color='black')

ax.plot(zax, bilayer_plot_data["inner_choline_corr_cvo"] + bilayer_plot_data["outer_choline_corr_cvo"], label="choline")
ax.plot(z_sim, chol_sim, linestyle='dotted', color='black')

ax.plot(zax, bilayer_plot_data["innerhc_corr_cvo"]+bilayer_plot_data["outerhc_corr_cvo"], label="hydrocarbons")

ax.plot(zax, bilayer_plot_data["innerch2_corr_cvo"]+bilayer_plot_data["outerch2_corr_cvo"], label="CH2")
ax.plot(z_sim, ch2_sim, linestyle='dotted', color='black')

ax.plot(zax, bilayer_plot_data["innerch3_corr_cvo"]+bilayer_plot_data["outerch3_corr_cvo"], label="CH3")
ax.plot(z_sim, ch3_sim, linestyle='dotted', color='black', label='sim')

ax.legend(loc="upper right")
plt.xlabel("Distance (Å)")
plt.ylabel("Component volume occupancy")
ax.minorticks_on()
#ax.tick_params(which="both", direction="in", labelsize=10)
ax.tick_params(bottom=True, top=True, left=True, right=True, which="both")
plt.xlim(-35, 35)
plt.xticks(np.arange(-35, 36, 5.0))
plt.grid(True, which='Both')
ax.figure.set_size_inches(16, 10)
plt.savefig(store + "/cvo_atomdensityweighted", facecolor="white")
plt.show()

print("Fit:")
print("choline: ",bilayer_plot_data["inner_choline_corr_cvo"].sum()*stepsize_z*areaperlipid)
print("phosphate: ",bilayer_plot_data["inner_phosphate_corr_cvo"].sum()*stepsize_z*areaperlipid)
print("cg: ",bilayer_plot_data["inner_cg_corr_cvo"].sum()*stepsize_z*areaperlipid)
print("hc: ",bilayer_plot_data["innerhc_corr_cvo"].sum()*stepsize_z*areaperlipid)
print("methyl: ",bilayer_plot_data["innerch3_corr_cvo"].sum()*stepsize_z*areaperlipid)
print("Simulation, volume weighted electron densities:")
print("choline: ",chol_sim.sum()*stepsize_sim*areaperlipid_sim/2)
print("phosphate: ",ph_sim.sum()*stepsize_sim*areaperlipid_sim/2)
print("cg: ",cg_sim.sum()*stepsize_sim*areaperlipid_sim/2)
print("hc: ",(ch2_sim+ch3_sim).sum()*stepsize_sim*areaperlipid_sim/2)
print("methyl: ",ch3_sim.sum()*stepsize_sim*areaperlipid_sim/2)
# Out:
# Number of electrons (half bilayer):
# choline:  18.99623959999993
# phosphate:  4.998278799999984
# cg:  12.997320399999955
# hc:  99.97947679999966
# methyl:  7.998389999999973
# Fit:
# choline:  116.85010395106607
# phosphate:  48.48606582118065
# cg:  140.11420706019942
# hc:  985.6616253926916
# methyl:  104.55499144165263
# Simulation, volume weighted electron densities:
# choline:  114.17739801684168
# phosphate:  61.95366572599977
# cg:  143.27046256307645
# hc:  986.3976058080183
# methyl:  99.17003801249965

# %%
#feller = np.loadtxt("FellerDOPCSimedp.dat")


a = fit_analysis.diStatResults["nSLDProfiles"]
b = []
for i in range(len(a)):
    it = a[i][0][0]
    it = [(it[n] + bulknsld_fit) / 2.814e-5 for n in range(len(it))]
    b += [it]

b = np.array(b).T
c = []
for i in range(len(b)):
    cc = fit_analysis.fnCalcConfidenceLimits(b[i])
    c += [cc]
c = np.array(c).T
z = [stepsize * (i - np.argmin(c[2])) for i in range(dimension)]

plt.figure(figsize=(16, 10))
plt.fill_between(z, c[3], y2=c[1], color="grey")
plt.xlabel("Distance from Bilayer Center (Å)")
plt.ylabel("ρ $(e/Å^3)$")
plt.plot(z, c[2], color="black", label="model")
#plt.plot(feller[:, 0], feller[:, 1], color="red", label="feller")
plt.plot(z_sim, ed_total, color="red", label="72.4 simulation")
plt.minorticks_on()
plt.tick_params(which="both", direction="in", labelsize=10)
plt.tick_params(bottom=True, top=True, left=True, right=True, which="both")
plt.legend(loc="lower right")
plt.xlim(-35, 35)
plt.xticks(np.arange(-35, 36, 5.0))
plt.grid(True, which='Both')
plt.savefig(store + "/electron_density", facecolor="white")
plt.show()

# %% [markdown]
# ## Solvent-subtracted electron density profile

# %%
fit_ed_minus_fluid = c[2]-bulknsld_fit/ed2sld
sdp_ed_minus_fluid = ed_total-9.4269e-6/ed2sld

sum_fit = fit_ed_minus_fluid.sum()
sum_sdp = sdp_ed_minus_fluid.sum()
half_fit_ed_minus_fluid = fit_ed_minus_fluid[int(len(fit_ed_minus_fluid)/2) :]
half_sdp_ed_minus_fluid = sdp_ed_minus_fluid[int(len(sdp_ed_minus_fluid)/2) :]
half_sum_fit = half_fit_ed_minus_fluid.sum()
half_sum_sdp = half_sdp_ed_minus_fluid.sum()

print("Stepsizes:")
print("fit: ", stepsize_z, z[1] - z[0])
print("SDP: ", stepsize_sim, z_sim[1] - z_sim[0])

print("Integral (half): ")
print("fit: ", half_sum_fit * stepsize_z)
print("SDP: ", half_sum_sdp * stepsize_sim)
#print("SDP_mf", half_sum_spd_mf * stepsize_sim)

print("FO from DCT-definition (half profile):")
print("fit: ", np.abs((2 * half_sum_fit - half_fit_ed_minus_fluid[0])* stepsize_z))
print("SDP: ", np.abs((2 * half_sum_sdp) * stepsize_sim))

print("F0 estimate (half profile):")
print("fit: ", np.abs(half_sum_fit * stepsize_z)*2)
print("SDP: ", np.abs(half_sum_sdp * stepsize_sim)*2)

plt.figure(figsize=(16, 10))
plt.xlabel("Distance from Bilayer Center (Å)")
plt.ylabel("ρ $(e/Å^3)$")
plt.plot(z, fit_ed_minus_fluid, color="black", label="model")
#plt.plot(z[int(len(z)/2):], half_fit_ed_minus_fluid+0.02, color="black", label="1/2 model + 0.02")
#plt.plot(feller[:, 0], feller[:, 1], color="red", label="feller")
plt.plot(z_sim, sdp_ed_minus_fluid, color="red", label="72.4 simulation")
#plt.plot(z_sim, ed_mf, label="72.4 simulation mf")
#plt.plot(z_sim[int(len(z_sim)/2):], half_sdp_ed_minus_fluid+0.02, color="red", label="1/2 72.4 simulation + 0.02")
plt.minorticks_on()
plt.tick_params(which="both", direction="in", labelsize=10)
plt.tick_params(bottom=True, top=True, left=True, right=True, which="both")
plt.legend(loc="lower right")
plt.xlim(-35, 35)
plt.xticks(np.arange(-35, 36, 5.0))
plt.grid(True, which='Both')
plt.savefig(store + "/electron_density_fluid_subtracted", facecolor="white")
plt.show()
# Out:
# Stepsizes:
# fit:  0.09999999999999432 0.09999999999999432
# SDP:  0.1999999999999993 0.1999999999999993
# Integral (half):
# fit:  -0.036366826250126515
# SDP:  -0.10139399999999837
# FO from DCT-definition (half profile):
# fit:  0.06430209685230355
# SDP:  0.20278799999999675
# F0 estimate (half profile):
# fit:  0.07273365250025303
# SDP:  0.20278799999999675

# %%
Afterfit_FF = computeFormFactor(q, fit_ed_minus_fluid, prefactor_fit, dq_fit, 0, z[1] - z[0])
SDP_FF = computeFormFactor(q, sdp_ed_minus_fluid, 1, dq_fit, 0, z_sim[1] - z_sim[0], DCTtype=2)

# %%
p = res_state.best()[0]
problem.setp(p)
print(problem.chisq())

q, F, dq, Fy = np.loadtxt(store + "/" + runfile + ".dat", skiprows=1).T
fig, ax = plt.subplots()
ax.errorbar(q, F, dq, zorder=1, label="simulation (fit target)")
ax.plot(q, Fy, zorder=2, label="median model fit as stored in optimizer")
ax.plot(q, Afterfit_FF, zorder=3, label="FF backcalculated from model fit EDP")
ax.plot(q, SDP_FF, zorder=4, label="FF backcalculated from SDP data")

ax.legend(fontsize=8)
ax.set_xlim([q[0], q[-1]])
ax.set_ylabel("|F($q_z$)| (e/Å$^2$)", fontsize=10)
ax.minorticks_on()
ax.tick_params(which="both", direction="in", labelsize=10)
ax.tick_params(bottom=True, top=True, left=True, right=True, which="both")
ax.set_xlabel("$q_z$ (Å$^{-1}$)", fontsize=10)
ax.figure.set_size_inches(12.5, 7.5)
plt.savefig(store + "/model_comparison.png", facecolor="white")
plt.show()
# Out:
# 2.2341932612641084

# %%
fig, ax = plt.subplots()
ax.errorbar(q, F, dq, zorder=1, label="simulation (fit target)")
ax.plot(q, Fy, zorder=2, label="median model fit as stored in optimizer")
ax.plot(q, Afterfit_FF, zorder=3, label="FF backcalculated from model fit EDP")
ax.plot(q, SDP_FF, zorder=4, label="FF backcalculated from SDP data")

ax.legend(fontsize=8)
ax.set_xlim([q[0], q[-1]])
ax.set_ylabel("|F($q_z$)| (e/Å$^2$)", fontsize=10)
ax.minorticks_on()
ax.tick_params(which="both", direction="in", labelsize=10)
ax.tick_params(bottom=True, top=True, left=True, right=True, which="both")
ax.set_xlabel("$q_z$ (Å$^{-1}$)", fontsize=10)
ax.figure.set_size_inches(12.5, 7.5)
plt.xlim(0.0, 0.1)
plt.ylim(-0.01, 0.5)
plt.savefig(store + "/model_comparison_zoom.png", facecolor="white")
plt.show()
