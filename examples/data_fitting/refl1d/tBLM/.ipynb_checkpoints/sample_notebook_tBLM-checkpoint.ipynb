# %% [markdown]
# # Imports

# %%
import sys
import os
from molgroups import components as cmp
from molgroups import mol
from molgroups import lipids
import numpy as np

from bumps.cli import load_model, load_best
import matplotlib.pyplot as plt
import rs

# %% [markdown]
# # Variables

# %% [markdown]
# Variables to set the storage folder for the fit, the base name of the runfile, and the global optimizer. Further the
# number of burn and production stepst for the MCMC are set. The run flag determines whether the refl1d MCMC is run, or
# just a data analysis on a previous fit is performed.
#
# Steps (and burn) are intentionally small in this example to reduce file sizes.

# %%
setupdir = os.getcwd()
store = "fit"
runfile = "tblm"
fitsource = "refl1d"

if not os.path.isdir(store):
    os.mkdir(store)

run = True
burn = 4000
steps = 50

# %% [markdown]
# # Example Fit

# %% [markdown]
# The content of the following cell is written out to the runfile of the fit 'tblm.py'.

# %%
# %%writefile tblm.py
## === Import section ===

import sys
# append path to your molgroups, or just link molgroups to your same directory
sys.path.append('')
import numpy as np
import molgroups as mol
import components as cmp
import lipids
from refl1d.names import load4, Parameter, SLD, Slab, Stack, Experiment, FitProblem
from refl1d.flayer import FunctionalProfile

## === Film structure definition section ===

### Bilayer profile definition function

def bilayer(z, sigma, bulknsld, global_rough, rho_substrate,nf_tether, mult_tether, l_tether, l_lipid1, l_lipid2, vf_bilayer):
    """ Generic tethered bilayer """

    # Scale all SLDs from Refl1D units (1e-6 Ang^-2) to molgroups units (Ang^-2)
    bulknsld = bulknsld * 1e-6
    rho_substrate = rho_substrate * 1e-6

    blm.fnSet(sigma=sigma, bulknsld=bulknsld, global_rough=global_rough, rho_substrate=rho_substrate,
              nf_tether=nf_tether, mult_tether=mult_tether, l_tether=l_tether, l_lipid1=l_lipid1, l_lipid2=l_lipid2,
              vf_bilayer=vf_bilayer)

    # Calculate scattering properties of volume occupied by bilayer
    normarea, area, nsl = blm.fnWriteProfile(z)

    # Fill in the remaining volume with buffer of appropriate nSLD
    nsld = nsl / (normarea * np.gradient(z)) + (1.0 - area / normarea) * bulknsld

    # export objects for post analysis, needs to be from this function
    problem.bilayers = [blm]
    problem.dimension = dimension
    problem.stepsize = stepsize
    problem.moldat = blm.fnWriteGroup2Dict({}, 'bilayer', np.arange(dimension) * stepsize)

    # Return nSLD profile in Refl1D units
    return nsld * 1e6

# Define bilayer parameters
vf_bilayer = Parameter(name='volume fraction bilayer', value=0.9).range(0.0, 1.0)
l_lipid1 = Parameter(name='inner acyl chain thickness', value=10.0).range(8, 30)
l_lipid2 = Parameter(name='outer acyl chain thickness', value=10.0).range(8, 16)
sigma = Parameter(name='bilayer roughness', value=5).range(2, 9)
global_rough = Parameter(name ='substrate roughness', value=5).range(2, 9)
d_oxide = Parameter(name='silicon oxide layer thickness', value=10).range(5, 30)
d_Cr =  Parameter(name='chromium layer thickness', value=40).range(10, 150)
d_gold =  Parameter(name='gold layer thickness', value=100).range(150, 250) #thickness of gold
rough_cr_au =  Parameter(name='gold chromium roughness', value=10).range(2, 24.0) # roughness of Cr/Au interface
nf_tether =  Parameter(name='number fraction tether', value=0.7).range(0.2, 1.0) # number fraction of tether molecules in inner leaflet
mult_tether =  Parameter(name='bME to tether ratio', value=2).range(0.1, 4) #ratio of bME to tether molecules at surface
l_tether =  Parameter(name='tether length', value=10).range(3, 18) #distance from substrate to inner headgroup/acyl chain interface

### Define bilayer object
blm = mol.tBLM(tether=lipids.HC18SAc, filler=cmp.bmeSAc, lipids=[lipids.POPC], lipid_nf=[1.0])        # required to subtract the bilayer length in layer_tiox definition; only really necessary if using "global blm" in bilayer function

### Define molgroups space.
dimension=300       # Number of steps

# Length of steps. Also sets calculation resolution, and determines speed of calculation
stepsize=0.5

## === Stack ===
##
## First, we create a 'material' for each bulk layer, which has an real and imaginary
## scattering length density, stored in a Refl1d object called 'SLD'
d2o = SLD(name='d2o', rho=6.3000, irho=0.0000)
h2o = SLD(name='h2o', rho=-0.56, irho=0.0000)
siox = SLD(name='siox', rho=4.1000, irho=0.0000)
silicon = SLD(name='silicon', rho=2.0690, irho=0.0000)
cr = SLD(name='chromium', rho=2.7, irho=0.0)
gold = SLD(name='gold', rho=4.4, irho=0.0) #iro is the absorption of neutrons, should be 0

## Then bulk layers are created, each with its own 'material'.  If you want to force
## two layers to always match SLD you can use the same material in multiple layers.
## The roughnesses of each layer are set to zero to begin with:

layer_d2o = Slab(material=d2o, thickness=0.0000, interface=5.0000)
layer_h2o = Slab(material=h2o, thickness=0.0000, interface=5.0000)
layer_siox = Slab(material=siox, thickness=d_oxide, interface=global_rough)
layer_silicon = Slab(material=silicon, thickness=0.0000, interface=global_rough)
layer_cr = Slab(material=cr, thickness=d_Cr, interface=rough_cr_au)
layer_gold = Slab(material=gold, thickness=d_gold - (blm.substrate.z + 0.5 * blm.substrate.l), interface=0.0000)

## Use the bilayer definition function to generate the bilayer SLD profile, passing in the relevant parameters.
## Note that substrate and bulk SLDs are linked to their respective materials.
mollayer = FunctionalProfile(dimension*stepsize, 0, profile=bilayer, sigma=sigma, bulknsld=d2o.rho,
                             global_rough=global_rough, rho_substrate=gold.rho, nf_tether = nf_tether,
                             mult_tether = mult_tether, l_tether = l_tether, l_lipid1=l_lipid1, l_lipid2=l_lipid2,
                             vf_bilayer=vf_bilayer)

mollayerh = FunctionalProfile(dimension*stepsize, 0, profile=bilayer, sigma=sigma, bulknsld=h2o.rho,
                              global_rough=global_rough, rho_substrate=gold.rho, nf_tether = nf_tether,
                              mult_tether = mult_tether, l_tether = l_tether, l_lipid1=l_lipid1, l_lipid2=l_lipid2,
                              vf_bilayer=vf_bilayer)

## Stack the layers into individual samples, using common layer objects for layers that are unchanged between samples
## As a convention, always build the sample from the substrate up. If the neutron beam is incident from the substrate side,
## set back_reflectivity = True in the probe definition later.

sample = layer_silicon | layer_siox | layer_cr | layer_gold | mollayer | layer_d2o
sampleh = layer_silicon | layer_siox | layer_cr | layer_gold | mollayerh | layer_h2o

## Set sample parameter ranges and constraints between layer properties, if these are not set using parameters previously

# nSLD parameters
d2o.rho.range(5.3000, 6.5000)
h2o.rho.range(-0.6, 0.6)
siox.rho.range(3.1000, 5.1000)
cr.rho.range(2.7000, 4.0000)
gold.rho.range(4.2000, 4.8000)

## === Data files ===
probe = load4('os046_4column.refl', back_reflectivity=True)
probeh = load4('os047_4column.refl', back_reflectivity=True)

# Background parameter
# probe.background.value = 0.0000
probe.background.range(-1e-7, 1e-5)
probeh.background.range(-1e-7, 1e-5)
probe.intensity.range(0.9, 1.05)
probeh.intensity = probe.intensity
probe.theta_offset.range(-0.015, 0.015)
probeh.theta_offset = probe.theta_offset
probe.sample_broadening.range(-0.005, 0.02)
probeh.sample_broadening = probe.sample_broadening

# Define critical edge oversampling for samples that require it (typically D2O only)
probe.critical_edge(substrate=silicon, surface=d2o)

## === Problem definition ===
## a model object consists of a sample and a probe,

## step = True corresponds to a calculation of the reflectivity from an actual profile
## with microslabbed interfaces.  When step = False, the Nevot-Croce
## approximation is used to account for roughness.  This approximation speeds up
## the calculation tremendously, and is reasonably accuarate as long as the
## roughness is much less than the layer thickness
step = False

model = Experiment(sample=sample, probe=probe, dz=stepsize, step_interfaces = step)
modelh = Experiment(sample=sampleh, probe=probeh, dz=stepsize, step_interfaces = step)
problem = FitProblem([model, modelh])
# Out:
# Overwriting tblm.py

# %% [markdown]
# # Running the fit

# %% [markdown]
# The following runs the fit using rs.py. It can also be run manually from the command line using, for example:
# > refl1d_cli.py tblm.py --fit=dream --init=lhs --parallel --store=fit --burn=16000 --steps=500

# %%
if run:
    if os.path.isfile(store + "/sErr.dat"):
        os.remove(store + "/sErr.dat")
    if os.path.isfile(store + "/isErr.dat"):
        os.remove(store + "/isErr.dat")
    if os.path.isfile(store + "/StatDataPython.dat"):
        os.remove(store + "/StatDataPython.dat")

fit_object = rs.CMolStat(
    fitsource=fitsource,
    spath=setupdir,
    mcmcpath=store,
    runfile=runfile,
    state=None,
    problem=None
)

if run:
    fit_object.Interactor.fnRunMCMC(burn, steps, batch=False)
# Out:
# Start value clipped to range for parameter gold layer thickness
# # /Users/frank/opt/anaconda3/envs/Python37/bin/refl1d_cli.py /Users/frank/Dropbox/My Mac (PN115993.campus.nist.gov)/Documents/programming/molgroups/examples/data_fitting/refl1d/tBLM/tblm.py --fit=dream --parallel --init=lhs --store=fit --burn=4000 --steps=50 --overwrite --seed=364908
# -- Model 0 os046_4column
# .probe
#   .back_absorption = back_absorption os046_4column = 1
#   .background = background os046_4column = 0 in [-1e-07,1e-05]
#   .intensity = intensity os046_4column = 1 in [0.9,1.05]
#   .sample_broadening = sample_broadening os046_4column = 0 in [-0.005,0.02]
#   .theta_offset = theta_offset os046_4column = 0 in [-0.015,0.015]
# .sample
#   .layers
#     [0]
#       .interface = substrate roughness = 5 in [2,9]
#       .material
#         .irho = silicon irho = 0
#         .rho = silicon rho = 2.069
#       .thickness = silicon thickness = 0
#     [1]
#       .interface = substrate roughness = 5 in [2,9]
#       .material
#         .irho = siox irho = 0
#         .rho = siox rho = 4.1 in [3.1,5.1]
#       .thickness = silicon oxide layer thickness = 10 in [5,30]
#     [2]
#       .interface = gold chromium roughness = 10 in [2,24]
#       .material
#         .irho = chromium irho = 0
#         .rho = chromium rho = 2.7 in [2.7,4]
#       .thickness = chromium layer thickness = 40 in [10,150]
#     [3]
#       .interface = gold interface = 0
#       .material
#         .irho = gold irho = 0
#         .rho = gold rho = 4.4 in [4.2,4.8]
#       .thickness = (gold layer thickness - 20.0) = 130
#     [4]
#       .bulknsld = d2o rho = 6.3 in [5.3,6.5]
#       .global_rough = substrate roughness = 5 in [2,9]
#       .interface = bilayer interface = 0
#       .l_lipid1 = inner acyl chain thickness = 10 in [8,30]
#       .l_lipid2 = outer acyl chain thickness = 10 in [8,16]
#       .l_tether = tether length = 10 in [3,18]
#       .mult_tether = bME to tether ratio = 2 in [0.1,4]
#       .nf_tether = number fraction tether = 0.7 in [0.2,1]
#       .rho_substrate = gold rho = 4.4 in [4.2,4.8]
#       .sigma = bilayer roughness = 5 in [2,9]
#       .thickness = bilayer thickness = 150
#       .vf_bilayer = volume fraction bilayer = 0.9 in [0,1]
#     [5]
#       .interface = d2o interface = 5
#       .material
#         .irho = d2o irho = 0
#         .rho = d2o rho = 6.3 in [5.3,6.5]
#       .thickness = d2o thickness = 0
#   .thickness = stack thickness = 330
#
# [chisq=NaN, nllf=inf]
# -- Model 1 os047_4column
# .probe
#   .back_absorption = back_absorption os047_4column = 1
#   .background = background os047_4column = 0 in [-1e-07,1e-05]
#   .intensity = intensity os046_4column = 1 in [0.9,1.05]
#   .sample_broadening = sample_broadening os046_4column = 0 in [-0.005,0.02]
#   .theta_offset = theta_offset os046_4column = 0 in [-0.015,0.015]
# .sample
#   .layers
#     [0]
#       .interface = substrate roughness = 5 in [2,9]
#       .material
#         .irho = silicon irho = 0
#         .rho = silicon rho = 2.069
#       .thickness = silicon thickness = 0
#     [1]
#       .interface = substrate roughness = 5 in [2,9]
#       .material
#         .irho = siox irho = 0
#         .rho = siox rho = 4.1 in [3.1,5.1]
#       .thickness = silicon oxide layer thickness = 10 in [5,30]
#     [2]
#       .interface = gold chromium roughness = 10 in [2,24]
#       .material
#         .irho = chromium irho = 0
#         .rho = chromium rho = 2.7 in [2.7,4]
#       .thickness = chromium layer thickness = 40 in [10,150]
#     [3]
#       .interface = gold interface = 0
#       .material
#         .irho = gold irho = 0
#         .rho = gold rho = 4.4 in [4.2,4.8]
#       .thickness = (gold layer thickness - 20.0) = 130
#     [4]
#       .bulknsld = h2o rho = -0.56 in [-0.6,0.6]
#       .global_rough = substrate roughness = 5 in [2,9]
#       .interface = bilayer interface = 0
#       .l_lipid1 = inner acyl chain thickness = 10 in [8,30]
#       .l_lipid2 = outer acyl chain thickness = 10 in [8,16]
#       .l_tether = tether length = 10 in [3,18]
#       .mult_tether = bME to tether ratio = 2 in [0.1,4]
#       .nf_tether = number fraction tether = 0.7 in [0.2,1]
#       .rho_substrate = gold rho = 4.4 in [4.2,4.8]
#       .sigma = bilayer roughness = 5 in [2,9]
#       .thickness = bilayer thickness = 150
#       .vf_bilayer = volume fraction bilayer = 0.9 in [0,1]
#     [5]
#       .interface = h2o interface = 5
#       .material
#         .irho = h2o irho = 0
#         .rho = h2o rho = -0.56 in [-0.6,0.6]
#       .thickness = h2o thickness = 0
#   .thickness = stack thickness = 330
#
# [chisq=46.67(17), nllf=3009.97]
# [overall chisq=NaN, nllf=inf]
# # steps: 50, # draws: 11000
# step 1 cost 64.70(10)
#                 background os046_4column |......... 5.13841e-07 in (-1e-07,1e-05)
#                  intensity os046_4column ......|...    1.00493 in (0.9,1.05)
#          sample_broadening os046_4column ......|...  0.0110052 in (-0.005,0.02)
#               theta_offset os046_4column ..|....... -0.00792583 in (-0.015,0.015)
#                      substrate roughness ........|.    7.68757 in (2,9)
#                                 siox rho ..|.......    3.62991 in (3.1,5.1)
#            silicon oxide layer thickness |.........    5.91769 in (5,30)
#                  gold chromium roughness |.........    2.47797 in (2,24)
#                             chromium rho ........|.    3.78546 in (2.7,4)
#                 chromium layer thickness .|........     24.848 in (10,150)
#                                 gold rho .|........    4.26199 in (4.2,4.8)
#                                  d2o rho ....|.....    5.86789 in (5.3,6.5)
#               inner acyl chain thickness ....|.....    16.9216 in (8,30)
#               outer acyl chain thickness |.........    8.32313 in (8,16)
#                            tether length .......|..    14.9136 in (3,18)
#                      bME to tether ratio ....|.....    2.03549 in (0.1,4)
#                   number fraction tether ......|...   0.728442 in (0.2,1)
#                        bilayer roughness .......|..    7.09157 in (2,9)
#                  volume fraction bilayer .......|..   0.775195 in (0,1)
#                 background os047_4column .........| 9.94166e-06 in (-1e-07,1e-05)
#                                  h2o rho ......|...   0.138088 in (-0.6,0.6)
#                     gold layer thickness .....|....     203.63 in (150,250)
# step 3 cost 64.43(10)
# step 5 cost 21.56(10)
# step 7 cost 21.56(10)
# step 9 cost 19.13(10)
# step 11 cost 19.13(10)
# step 13 cost 19.13(10)
# step 15 cost 19.13(10)
# step 17 cost 19.13(10)
# step 19 cost 19.13(10)
# step 20 cost 19.13(10)
# step 21 cost 19.13(10)
# step 23 cost 19.13(10)
# step 25 cost 19.13(10)
# step 27 cost 19.13(10)
# step 28 cost 19.13(10)
# step 29 cost 19.13(10)
# step 30 cost 19.13(10)
# step 31 cost 19.13(10)
# step 32 cost 19.13(10)
#                 background os046_4column |......... 2.35855e-07 in (-1e-07,1e-05)
#                  intensity os046_4column .......|..    1.01257 in (0.9,1.05)
#          sample_broadening os046_4column ....|.....  0.0064513 in (-0.005,0.02)
#               theta_offset os046_4column .........|  0.0149255 in (-0.015,0.015)
#                      substrate roughness ......|...    6.76886 in (2,9)
#                                 siox rho ....|.....     4.0679 in (3.1,5.1)
#            silicon oxide layer thickness .|........    9.46785 in (5,30)
#                  gold chromium roughness .........|    21.9932 in (2,24)
#                             chromium rho ...|......    3.12355 in (2.7,4)
#                 chromium layer thickness .|........     32.725 in (10,150)
#                                 gold rho ........|.    4.69286 in (4.2,4.8)
#                                  d2o rho .........|     6.4974 in (5.3,6.5)
#               inner acyl chain thickness .|........    10.9068 in (8,30)
#               outer acyl chain thickness .....|....    12.2449 in (8,16)
#                            tether length .......|..    13.5806 in (3,18)
#                      bME to tether ratio .......|..    2.87479 in (0.1,4)
#                   number fraction tether ......|...   0.701435 in (0.2,1)
#                        bilayer roughness .....|....    5.60163 in (2,9)
#                  volume fraction bilayer .........|   0.963728 in (0,1)
#                 background os047_4column ....|..... 4.60655e-06 in (-1e-07,1e-05)
#                                  h2o rho ...|......  -0.137671 in (-0.6,0.6)
#                     gold layer thickness .|........    162.847 in (150,250)
# step 33 cost 19.13(10)
# step 34 cost 19.13(10)
# step 35 cost 19.13(10)
# step 36 cost 17.01(10)
# step 37 cost 17.01(10)
# step 38 cost 10.98(10)
# step 39 cost 10.98(10)
# step 40 cost 10.98(10)
# step 41 cost 10.98(10)
# step 42 cost 10.98(10)
# step 43 cost 10.98(10)
# step 44 cost 10.98(10)
# step 45 cost 10.98(10)
# step 46 cost 10.98(10)
# step 47 cost 10.98(10)
# step 48 cost 10.98(10)
# step 49 cost 10.98(10)
# step 50 cost 10.26(10)
#                 background os046_4column .|........ 1.12234e-06 in (-1e-07,1e-05)
#                  intensity os046_4column ....|.....   0.962668 in (0.9,1.05)
#          sample_broadening os046_4column ......|...  0.0115928 in (-0.005,0.02)
#               theta_offset os046_4column ....|..... -0.00260801 in (-0.015,0.015)
#                      substrate roughness |.........    2.47221 in (2,9)
#                                 siox rho .|........    3.42346 in (3.1,5.1)
#            silicon oxide layer thickness .........|    29.9646 in (5,30)
#                  gold chromium roughness .|........    6.26264 in (2,24)
#                             chromium rho ........|.    3.76283 in (2.7,4)
#                 chromium layer thickness ..|.......    40.0533 in (10,150)
#                                 gold rho ...|......    4.42518 in (4.2,4.8)
#                                  d2o rho .....|....    5.98376 in (5.3,6.5)
#               inner acyl chain thickness ..|.......    13.6222 in (8,30)
#               outer acyl chain thickness |.........    8.05268 in (8,16)
#                            tether length .....|....    11.1278 in (3,18)
#                      bME to tether ratio |.........   0.309725 in (0.1,4)
#                   number fraction tether .......|..   0.803178 in (0.2,1)
#                        bilayer roughness ...|......    4.71176 in (2,9)
#                  volume fraction bilayer .........|   0.988541 in (0,1)
#                 background os047_4column ....|..... 4.58533e-06 in (-1e-07,1e-05)
#                                  h2o rho |.........  -0.580881 in (-0.6,0.6)
#                     gold layer thickness |.........     154.96 in (150,250)
# step 51 cost 10.26(10)
# step 52 cost 10.26(10)
# step 53 cost 10.26(10)
# step 54 cost 10.26(10)
# step 55 cost 10.26(10)
# step 56 cost 10.26(10)
# step 57 cost 8.58(10)
# step 58 cost 8.58(10)
# step 59 cost 8.58(10)
# step 60 cost 8.58(10)
# step 61 cost 8.58(10)
# step 62 cost 8.58(10)
# step 63 cost 8.58(10)
# step 64 cost 8.58(10)
# step 65 cost 8.58(10)
# step 66 cost 8.58(10)
# step 67 cost 8.58(10)
# step 68 cost 8.58(10)
#                 background os046_4column .|........ 1.12234e-06 in (-1e-07,1e-05)
#                  intensity os046_4column ....|.....   0.962669 in (0.9,1.05)
#          sample_broadening os046_4column ......|...  0.0116897 in (-0.005,0.02)
#               theta_offset os046_4column ....|..... -0.00260801 in (-0.015,0.015)
#                      substrate roughness |.........    2.47221 in (2,9)
#                                 siox rho .|........    3.42346 in (3.1,5.1)
#            silicon oxide layer thickness .........|    27.5037 in (5,30)
#                  gold chromium roughness .|........    6.26264 in (2,24)
#                             chromium rho .........|    3.90926 in (2.7,4)
#                 chromium layer thickness ..|.......    40.0533 in (10,150)
#                                 gold rho ...|......    4.42518 in (4.2,4.8)
#                                  d2o rho .....|....    5.98378 in (5.3,6.5)
#               inner acyl chain thickness ..|.......    13.6222 in (8,30)
#               outer acyl chain thickness |.........    8.05268 in (8,16)
#                            tether length .....|....    11.1278 in (3,18)
#                      bME to tether ratio |.........   0.113734 in (0.1,4)
#                   number fraction tether .......|..   0.803179 in (0.2,1)
#                        bilayer roughness ...|......    4.71176 in (2,9)
#                  volume fraction bilayer .........|   0.988542 in (0,1)
#                 background os047_4column ......|... 6.55842e-06 in (-1e-07,1e-05)
#                                  h2o rho |.........  -0.580881 in (-0.6,0.6)
#                     gold layer thickness |.........     154.96 in (150,250)
# step 69 cost 8.58(10)
# step 70 cost 8.58(10)
# step 71 cost 8.58(10)
# step 72 cost 8.58(10)
# step 73 cost 8.58(10)
# step 74 cost 8.58(10)
# step 75 cost 8.58(10)
# step 76 cost 8.58(10)
# step 77 cost 8.39(10)
# step 78 cost 8.39(10)
# step 79 cost 8.39(10)
# step 80 cost 7.81(10)
# step 81 cost 7.81(10)
# step 82 cost 7.81(10)
# step 83 cost 7.81(10)
# step 84 cost 7.81(10)
# step 85 cost 7.81(10)
# step 86 cost 7.81(10)
#                 background os046_4column |......... 3.48195e-08 in (-1e-07,1e-05)
#                  intensity os046_4column ....|.....   0.962669 in (0.9,1.05)
#          sample_broadening os046_4column ..|....... 0.00249821 in (-0.005,0.02)
#               theta_offset os046_4column ....|..... -0.00260801 in (-0.015,0.015)
#                      substrate roughness |.........    2.47222 in (2,9)
#                                 siox rho .|........    3.42345 in (3.1,5.1)
#            silicon oxide layer thickness .........|    27.5037 in (5,30)
#                  gold chromium roughness .|........    6.26264 in (2,24)
#                             chromium rho .........|    3.90926 in (2.7,4)
#                 chromium layer thickness ..|.......    40.0533 in (10,150)
#                                 gold rho ...|......    4.42517 in (4.2,4.8)
#                                  d2o rho .....|....    5.98376 in (5.3,6.5)
#               inner acyl chain thickness ..|.......    13.6222 in (8,30)
#               outer acyl chain thickness |.........    8.05269 in (8,16)
#                            tether length .....|....    11.1278 in (3,18)
#                      bME to tether ratio |.........   0.113734 in (0.1,4)
#                   number fraction tether .......|..   0.803177 in (0.2,1)
#                        bilayer roughness ...|......    4.71176 in (2,9)
#                  volume fraction bilayer .........|   0.988541 in (0,1)
#                 background os047_4column ......|... 6.55842e-06 in (-1e-07,1e-05)
#                                  h2o rho |.........  -0.580881 in (-0.6,0.6)
#                     gold layer thickness |.........    154.959 in (150,250)
# step 87 cost 7.81(10)
# step 88 cost 7.81(10)
# step 89 cost 7.81(10)
# step 90 cost 7.81(10)
# step 91 cost 7.08(10)
# step 92 cost 7.08(10)
# step 93 cost 7.08(10)
# step 94 cost 7.08(10)
# step 95 cost 7.08(10)
# step 96 cost 7.08(10)
# step 97 cost 7.08(10)
# step 98 cost 7.08(10)
# step 99 cost 7.08(10)
# step 100 cost 7.08(10)
#                 background os046_4column |......... 6.37621e-07 in (-1e-07,1e-05)
#                  intensity os046_4column ..|.......   0.930952 in (0.9,1.05)
#          sample_broadening os046_4column |......... -0.00327332 in (-0.005,0.02)
#               theta_offset os046_4column .......|.. 0.00708821 in (-0.015,0.015)
#                      substrate roughness .|........    3.15214 in (2,9)
#                                 siox rho .......|..    4.56346 in (3.1,5.1)
#            silicon oxide layer thickness .|........    9.10735 in (5,30)
#                  gold chromium roughness ........|.    19.6103 in (2,24)
#                             chromium rho ..|.......    3.04237 in (2.7,4)
#                 chromium layer thickness .|........    26.5688 in (10,150)
#                                 gold rho ........|.    4.68554 in (4.2,4.8)
#                                  d2o rho ........|.    6.31661 in (5.3,6.5)
#               inner acyl chain thickness .|........     10.254 in (8,30)
#               outer acyl chain thickness ....|.....    11.2735 in (8,16)
#                            tether length ...|......    7.91971 in (3,18)
#                      bME to tether ratio ...|......    1.47217 in (0.1,4)
#                   number fraction tether ....|.....   0.589679 in (0.2,1)
#                        bilayer roughness .|........     3.1097 in (2,9)
#                  volume fraction bilayer .........|   0.990152 in (0,1)
#                 background os047_4column |.........  1.307e-07 in (-1e-07,1e-05)
#                                  h2o rho ..|.......  -0.346523 in (-0.6,0.6)
#                     gold layer thickness ...|......    180.542 in (150,250)
# step 101 cost 7.08(10)
# step 102 cost 7.08(10)
# step 103 cost 7.08(10)
# step 104 cost 7.08(10)
# step 105 cost 5.60(10)
# step 106 cost 5.60(10)
# step 107 cost 5.60(10)
# step 108 cost 5.60(10)
# step 109 cost 5.60(10)
# step 110 cost 5.60(10)
# step 111 cost 5.60(10)
# step 112 cost 5.60(10)
# step 113 cost 5.60(10)
# step 114 cost 5.60(10)
# step 115 cost 5.60(10)
# step 116 cost 5.60(10)
# step 117 cost 5.60(10)
#                 background os046_4column |......... 3.48196e-08 in (-1e-07,1e-05)
#                  intensity os046_4column ........|.    1.03461 in (0.9,1.05)
#          sample_broadening os046_4column ..|....... 0.00249821 in (-0.005,0.02)
#               theta_offset os046_4column ....|..... -0.00260801 in (-0.015,0.015)
#                      substrate roughness ...|......    4.48461 in (2,9)
#                                 siox rho |.........    3.21012 in (3.1,5.1)
#            silicon oxide layer thickness ........|.    27.2991 in (5,30)
#                  gold chromium roughness .|........    6.26264 in (2,24)
#                             chromium rho .........|    3.95628 in (2.7,4)
#                 chromium layer thickness ..|.......    40.0532 in (10,150)
#                                 gold rho ...|......    4.39442 in (4.2,4.8)
#                                  d2o rho .....|....    5.98375 in (5.3,6.5)
#               inner acyl chain thickness ..|.......    13.6222 in (8,30)
#               outer acyl chain thickness |.........    8.05269 in (8,16)
#                            tether length .....|....    11.1278 in (3,18)
#                      bME to tether ratio |.........   0.434223 in (0.1,4)
#                   number fraction tether ........|.   0.884939 in (0.2,1)
#                        bilayer roughness ...|......    4.71177 in (2,9)
#                  volume fraction bilayer .........|    0.98854 in (0,1)
#                 background os047_4column ......|... 6.27799e-06 in (-1e-07,1e-05)
#                                  h2o rho |.........  -0.580881 in (-0.6,0.6)
#                     gold layer thickness |.........    154.959 in (150,250)
# step 118 cost 5.60(10)
# step 119 cost 5.60(10)
# step 120 cost 5.60(10)
# step 121 cost 5.60(10)
# step 122 cost 5.60(10)
# step 123 cost 5.60(10)
# step 124 cost 5.60(10)
# step 125 cost 5.60(10)
# step 126 cost 5.60(10)
# step 127 cost 5.60(10)
# step 128 cost 5.60(10)
# step 129 cost 5.60(10)
# step 130 cost 5.60(10)
# step 131 cost 5.60(10)
# step 132 cost 5.60(10)
# step 133 cost 5.60(10)
# step 134 cost 5.60(10)
# step 135 cost 5.60(10)
#                 background os046_4column |......... 3.48196e-08 in (-1e-07,1e-05)
#                  intensity os046_4column ........|.    1.03461 in (0.9,1.05)
#          sample_broadening os046_4column ..|....... 0.00249821 in (-0.005,0.02)
#               theta_offset os046_4column ....|..... -0.00260801 in (-0.015,0.015)
#                      substrate roughness ...|......    4.48461 in (2,9)
#                                 siox rho |.........    3.21012 in (3.1,5.1)
#            silicon oxide layer thickness ........|.    27.2991 in (5,30)
#                  gold chromium roughness .|........    6.26264 in (2,24)
#                             chromium rho .........|    3.95628 in (2.7,4)
#                 chromium layer thickness ..|.......    40.0532 in (10,150)
#                                 gold rho ...|......    4.39442 in (4.2,4.8)
#                                  d2o rho .....|....    5.98375 in (5.3,6.5)
#               inner acyl chain thickness ..|.......    13.6222 in (8,30)
#               outer acyl chain thickness |.........    8.05269 in (8,16)
#                            tether length .....|....    11.1278 in (3,18)
#                      bME to tether ratio |.........   0.434223 in (0.1,4)
#                   number fraction tether ........|.   0.884939 in (0.2,1)
#                        bilayer roughness ...|......    4.71177 in (2,9)
#                  volume fraction bilayer .........|    0.98854 in (0,1)
#                 background os047_4column ......|... 6.27799e-06 in (-1e-07,1e-05)
#                                  h2o rho |.........  -0.580881 in (-0.6,0.6)
#                     gold layer thickness |.........    154.959 in (150,250)
# step 136 cost 5.60(10)
# step 137 cost 5.60(10)
# step 138 cost 5.60(10)
# step 139 cost 5.60(10)
# step 140 cost 5.60(10)
# step 141 cost 5.60(10)
# step 142 cost 5.56(10)
# step 143 cost 5.56(10)
# step 144 cost 5.56(10)
# step 145 cost 5.56(10)
# step 146 cost 5.56(10)
# step 147 cost 4.61(10)
# step 148 cost 4.61(10)
# step 149 cost 4.61(10)
# step 150 cost 4.61(10)
# step 151 cost 4.61(10)
# step 152 cost 4.61(10)
# step 153 cost 4.61(10)
#                 background os046_4column |......... 6.96304e-07 in (-1e-07,1e-05)
#                  intensity os046_4column ..|.......   0.933014 in (0.9,1.05)
#          sample_broadening os046_4column |......... -0.00298198 in (-0.005,0.02)
#               theta_offset os046_4column .......|.. 0.00663911 in (-0.015,0.015)
#                      substrate roughness .|........    3.07014 in (2,9)
#                                 siox rho .....|....     4.1698 in (3.1,5.1)
#            silicon oxide layer thickness .|........    9.14655 in (5,30)
#                  gold chromium roughness .......|..     18.005 in (2,24)
#                             chromium rho ..|.......    3.05023 in (2.7,4)
#                 chromium layer thickness .|........    27.1964 in (10,150)
#                                 gold rho ........|.    4.68368 in (4.2,4.8)
#                                  d2o rho ........|.    6.30433 in (5.3,6.5)
#               inner acyl chain thickness .|........    10.4979 in (8,30)
#               outer acyl chain thickness ....|.....    11.3604 in (8,16)
#                            tether length ...|......    7.92845 in (3,18)
#                      bME to tether ratio ...|......    1.48012 in (0.1,4)
#                   number fraction tether ....|.....   0.589501 in (0.2,1)
#                        bilayer roughness .|........    3.17841 in (2,9)
#                  volume fraction bilayer .........|   0.981128 in (0,1)
#                 background os047_4column ..|....... 2.21837e-06 in (-1e-07,1e-05)
#                                  h2o rho ..|.......  -0.328115 in (-0.6,0.6)
#                     gold layer thickness ..|.......    179.938 in (150,250)
# step 154 cost 4.61(10)
# step 155 cost 4.61(10)
# step 156 cost 4.61(10)
# step 157 cost 4.61(10)
# step 158 cost 4.61(10)
# step 159 cost 4.61(10)
# step 160 cost 4.61(10)
# step 161 cost 4.61(10)
# step 162 cost 4.61(10)
# step 163 cost 4.61(10)
# step 164 cost 4.61(10)
# step 165 cost 4.61(10)
# step 166 cost 4.61(10)
# step 167 cost 4.61(10)
# step 168 cost 4.61(10)
# step 169 cost 4.61(10)
# step 170 cost 4.61(10)
#                 background os046_4column .|........ 1.38855e-06 in (-1e-07,1e-05)
#                  intensity os046_4column ........|.    1.02625 in (0.9,1.05)
#          sample_broadening os046_4column |......... -0.00432746 in (-0.005,0.02)
#               theta_offset os046_4column .........|  0.0121298 in (-0.015,0.015)
#                      substrate roughness ...|......    4.44713 in (2,9)
#                                 siox rho ..|.......    3.68432 in (3.1,5.1)
#            silicon oxide layer thickness |.........     6.9002 in (5,30)
#                  gold chromium roughness ........|.     20.445 in (2,24)
#                             chromium rho ...|......    3.17685 in (2.7,4)
#                 chromium layer thickness .|........     31.091 in (10,150)
#                                 gold rho .....|....    4.55134 in (4.2,4.8)
#                                  d2o rho .........|     6.4018 in (5.3,6.5)
#               inner acyl chain thickness .|........     10.905 in (8,30)
#               outer acyl chain thickness .......|..     14.025 in (8,16)
#                            tether length |.........    3.28472 in (3,18)
#                      bME to tether ratio |.........   0.148771 in (0.1,4)
#                   number fraction tether ...|......   0.458591 in (0.2,1)
#                        bilayer roughness .|........    3.20077 in (2,9)
#                  volume fraction bilayer ........|.    0.85505 in (0,1)
#                 background os047_4column .....|.... 5.78547e-06 in (-1e-07,1e-05)
#                                  h2o rho |.........  -0.554382 in (-0.6,0.6)
#                     gold layer thickness ..|.......    178.707 in (150,250)
# step 171 cost 4.61(10)
# step 172 cost 4.61(10)
# step 173 cost 4.61(10)
# step 174 cost 4.61(10)
# step 175 cost 4.61(10)
# step 176 cost 4.61(10)
# step 177 cost 4.61(10)
# step 178 cost 4.61(10)
# step 179 cost 4.61(10)
# step 180 cost 4.61(10)
# step 181 cost 4.61(10)
# step 182 cost 4.61(10)
# step 183 cost 4.61(10)
# step 184 cost 4.61(10)
# step 185 cost 4.61(10)
# step 186 cost 4.61(10)
# step 187 cost 4.61(10)
# step 188 cost 4.41(10)
#                 background os046_4column ..|....... 2.0905e-06 in (-1e-07,1e-05)
#                  intensity os046_4column .....|....   0.986077 in (0.9,1.05)
#          sample_broadening os046_4column |......... -0.00360207 in (-0.005,0.02)
#               theta_offset os046_4column .........|  0.0123675 in (-0.015,0.015)
#                      substrate roughness ...|......    4.54687 in (2,9)
#                                 siox rho ..|.......    3.52061 in (3.1,5.1)
#            silicon oxide layer thickness .|........    8.76669 in (5,30)
#                  gold chromium roughness .......|..    18.8774 in (2,24)
#                             chromium rho .....|....    3.35365 in (2.7,4)
#                 chromium layer thickness .|........    32.5295 in (10,150)
#                                 gold rho .........|    4.74479 in (4.2,4.8)
#                                  d2o rho .........|    6.41694 in (5.3,6.5)
#               inner acyl chain thickness |.........    8.30187 in (8,30)
#               outer acyl chain thickness .........|    15.5823 in (8,16)
#                            tether length ..|.......    6.31628 in (3,18)
#                      bME to tether ratio .......|..     3.0363 in (0.1,4)
#                   number fraction tether |.........   0.263231 in (0.2,1)
#                        bilayer roughness |.........    2.59128 in (2,9)
#                  volume fraction bilayer .........|    0.90124 in (0,1)
#                 background os047_4column .....|.... 5.17759e-06 in (-1e-07,1e-05)
#                                  h2o rho ....|.....   -0.10107 in (-0.6,0.6)
#                     gold layer thickness ..|.......    178.899 in (150,250)
# step 189 cost 4.41(10)
# step 190 cost 4.41(10)
# step 191 cost 4.41(10)
# step 192 cost 4.41(10)
# step 193 cost 4.41(10)
# step 194 cost 4.41(10)
# step 196 cost 4.41(10)
# step 198 cost 4.41(10)
# step 199 cost 4.41(10)
# step 200 cost 4.41(10)
# step 202 cost 4.41(10)
# step 204 cost 4.41(10)
# step 206 cost 4.41(10)
# step 207 cost 4.41(10)
# step 208 cost 4.41(10)
# step 209 cost 4.41(10)
# step 210 cost 4.41(10)
# step 211 cost 4.41(10)
# step 212 cost 4.41(10)
# step 213 cost 4.41(10)
# step 214 cost 4.41(10)
#                 background os046_4column ..|....... 2.0905e-06 in (-1e-07,1e-05)
#                  intensity os046_4column .....|....   0.986077 in (0.9,1.05)
#          sample_broadening os046_4column |......... -0.00360207 in (-0.005,0.02)
#               theta_offset os046_4column .........|  0.0123675 in (-0.015,0.015)
#                      substrate roughness ...|......    4.54687 in (2,9)
#                                 siox rho ..|.......    3.52061 in (3.1,5.1)
#            silicon oxide layer thickness .|........    8.76669 in (5,30)
#                  gold chromium roughness .......|..    18.8774 in (2,24)
#                             chromium rho .....|....    3.35365 in (2.7,4)
#                 chromium layer thickness .|........    32.5295 in (10,150)
#                                 gold rho .........|    4.74479 in (4.2,4.8)
#                                  d2o rho .........|    6.41694 in (5.3,6.5)
#               inner acyl chain thickness |.........    8.30187 in (8,30)
#               outer acyl chain thickness .........|    15.5823 in (8,16)
#                            tether length ..|.......    6.31628 in (3,18)
#                      bME to tether ratio .......|..     3.0363 in (0.1,4)
#                   number fraction tether |.........   0.263231 in (0.2,1)
#                        bilayer roughness |.........    2.59128 in (2,9)
#                  volume fraction bilayer .........|    0.90124 in (0,1)
#                 background os047_4column .....|.... 5.17759e-06 in (-1e-07,1e-05)
#                                  h2o rho ....|.....   -0.10107 in (-0.6,0.6)
#                     gold layer thickness ..|.......    178.899 in (150,250)
# step 216 cost 4.41(10)
# step 218 cost 4.41(10)
# step 219 cost 3.97(10)
# step 220 cost 3.97(10)
# step 221 cost 3.97(10)
# step 223 cost 3.97(10)
# step 225 cost 3.97(10)
# step 226 cost 3.97(10)
# step 227 cost 3.97(10)
# step 228 cost 3.97(10)
# step 229 cost 3.97(10)
# step 230 cost 3.97(10)
# step 231 cost 3.97(10)
# step 232 cost 3.97(10)
# step 234 cost 3.97(10)
# step 236 cost 3.97(10)
# step 238 cost 3.97(10)
# step 240 cost 3.97(10)
# step 242 cost 3.97(10)
# step 244 cost 3.86(10)
#                 background os046_4column |......... 1.67936e-07 in (-1e-07,1e-05)
#                  intensity os046_4column ...|......   0.948515 in (0.9,1.05)
#          sample_broadening os046_4column ...|...... 0.00498235 in (-0.005,0.02)
#               theta_offset os046_4column ........|.  0.0104386 in (-0.015,0.015)
#                      substrate roughness .|........    2.78571 in (2,9)
#                                 siox rho ......|...    4.38388 in (3.1,5.1)
#            silicon oxide layer thickness .|........    7.60761 in (5,30)
#                  gold chromium roughness ........|.     20.186 in (2,24)
#                             chromium rho .|........    2.95496 in (2.7,4)
#                 chromium layer thickness |.........    20.1862 in (10,150)
#                                 gold rho .......|..    4.67898 in (4.2,4.8)
#                                  d2o rho ........|.    6.33171 in (5.3,6.5)
#               inner acyl chain thickness |.........    8.90254 in (8,30)
#               outer acyl chain thickness ......|...    12.8395 in (8,16)
#                            tether length ....|.....    10.0943 in (3,18)
#                      bME to tether ratio .....|....    2.13087 in (0.1,4)
#                   number fraction tether ......|...   0.684015 in (0.2,1)
#                        bilayer roughness ...|......    4.33588 in (2,9)
#                  volume fraction bilayer .........|   0.999323 in (0,1)
#                 background os047_4column |......... 5.71346e-07 in (-1e-07,1e-05)
#                                  h2o rho .|........  -0.479417 in (-0.6,0.6)
#                     gold layer thickness ...|......    186.251 in (150,250)
# step 246 cost 3.86(10)
# step 248 cost 3.86(10)
# step 250 cost 3.86(10)
# step 252 cost 3.57(10)
# step 253 cost 3.57(10)
# step 255 cost 3.44(10)
# step 257 cost 3.44(10)
# step 258 cost 3.44(10)
# step 260 cost 3.44(10)
# step 262 cost 3.43(10)
# step 263 cost 3.43(10)
# step 265 cost 2.51(10)
# step 267 cost 2.51(10)
# step 268 cost 2.51(10)
# step 269 cost 2.51(10)
# step 271 cost 2.46(10)
# step 272 cost 2.46(10)
# step 273 cost 2.46(10)
# step 274 cost 2.46(10)
# step 275 cost 2.46(10)
#                 background os046_4column |......... 1.52816e-07 in (-1e-07,1e-05)
#                  intensity os046_4column .......|..    1.01039 in (0.9,1.05)
#          sample_broadening os046_4column ...|...... 0.00467718 in (-0.005,0.02)
#               theta_offset os046_4column ......|... 0.00482711 in (-0.015,0.015)
#                      substrate roughness .....|....    5.57194 in (2,9)
#                                 siox rho |.........     3.2564 in (3.1,5.1)
#            silicon oxide layer thickness ..|.......     11.401 in (5,30)
#                  gold chromium roughness ..|.......     8.5252 in (2,24)
#                             chromium rho ......|...    3.49738 in (2.7,4)
#                 chromium layer thickness .|........    35.8107 in (10,150)
#                                 gold rho .....|....    4.51479 in (4.2,4.8)
#                                  d2o rho .......|..     6.1914 in (5.3,6.5)
#               inner acyl chain thickness |.........    8.74429 in (8,30)
#               outer acyl chain thickness .......|..    14.0812 in (8,16)
#                            tether length ...|......     7.5736 in (3,18)
#                      bME to tether ratio ........|.    3.32548 in (0.1,4)
#                   number fraction tether |.........   0.238728 in (0.2,1)
#                        bilayer roughness ..|.......    3.52965 in (2,9)
#                  volume fraction bilayer .........|   0.995187 in (0,1)
#                 background os047_4column ......|... 6.41597e-06 in (-1e-07,1e-05)
#                                  h2o rho .|........   -0.44448 in (-0.6,0.6)
#                     gold layer thickness ..|.......    171.525 in (150,250)
# step 276 cost 2.46(10)
# step 277 cost 2.46(10)
# step 278 cost 2.46(10)
# step 279 cost 2.46(10)
# step 280 cost 2.46(10)
# step 281 cost 2.46(10)
# step 282 cost 2.46(10)
# step 283 cost 2.46(10)
# step 284 cost 2.46(10)
# step 285 cost 2.46(10)
# step 286 cost 2.46(10)
# step 287 cost 2.46(10)
# step 288 cost 2.46(10)
# step 289 cost 2.46(10)
# step 290 cost 2.46(10)
# step 291 cost 2.46(10)
# step 292 cost 2.46(10)
#                 background os046_4column |......... 1.52816e-07 in (-1e-07,1e-05)
#                  intensity os046_4column .......|..    1.01039 in (0.9,1.05)
#          sample_broadening os046_4column ...|...... 0.00467718 in (-0.005,0.02)
#               theta_offset os046_4column ......|... 0.00482711 in (-0.015,0.015)
#                      substrate roughness .....|....    5.57194 in (2,9)
#                                 siox rho |.........     3.2564 in (3.1,5.1)
#            silicon oxide layer thickness ..|.......     11.401 in (5,30)
#                  gold chromium roughness ..|.......     8.5252 in (2,24)
#                             chromium rho ......|...    3.49738 in (2.7,4)
#                 chromium layer thickness .|........    35.8107 in (10,150)
#                                 gold rho .....|....    4.51479 in (4.2,4.8)
#                                  d2o rho .......|..     6.1914 in (5.3,6.5)
#               inner acyl chain thickness |.........    8.74429 in (8,30)
#               outer acyl chain thickness .......|..    14.0812 in (8,16)
#                            tether length ...|......     7.5736 in (3,18)
#                      bME to tether ratio ........|.    3.32548 in (0.1,4)
#                   number fraction tether |.........   0.238728 in (0.2,1)
#                        bilayer roughness ..|.......    3.52965 in (2,9)
#                  volume fraction bilayer .........|   0.995187 in (0,1)
#                 background os047_4column ......|... 6.41597e-06 in (-1e-07,1e-05)
#                                  h2o rho .|........   -0.44448 in (-0.6,0.6)
#                     gold layer thickness ..|.......    171.525 in (150,250)
# step 293 cost 2.46(10)
# step 294 cost 2.46(10)
# step 295 cost 2.46(10)
# step 296 cost 2.46(10)
# step 297 cost 2.46(10)
# step 298 cost 2.46(10)
# step 299 cost 2.30(10)
# step 300 cost 2.30(10)
# step 301 cost 2.30(10)
# step 302 cost 2.30(10)
# step 303 cost 2.30(10)
# step 304 cost 2.30(10)
# step 305 cost 2.30(10)
# step 306 cost 2.30(10)
# step 307 cost 2.30(10)
#                 background os046_4column |......... 3.82995e-07 in (-1e-07,1e-05)
#                  intensity os046_4column ......|...     1.0049 in (0.9,1.05)
#          sample_broadening os046_4column ...|...... 0.00376322 in (-0.005,0.02)
#               theta_offset os046_4column ......|... 0.00593485 in (-0.015,0.015)
#                      substrate roughness .....|....     5.8618 in (2,9)
#                                 siox rho .|........    3.30791 in (3.1,5.1)
#            silicon oxide layer thickness ..|.......    11.7532 in (5,30)
#                  gold chromium roughness ..|.......    8.33699 in (2,24)
#                             chromium rho ......|...    3.52145 in (2.7,4)
#                 chromium layer thickness .|........    36.3861 in (10,150)
#                                 gold rho .....|....    4.54679 in (4.2,4.8)
#                                  d2o rho .......|..    6.22384 in (5.3,6.5)
#               inner acyl chain thickness |.........    8.75016 in (8,30)
#               outer acyl chain thickness .......|..    14.2227 in (8,16)
#                            tether length ..|.......    7.10818 in (3,18)
#                      bME to tether ratio .......|..    3.04511 in (0.1,4)
#                   number fraction tether .|........   0.315695 in (0.2,1)
#                        bilayer roughness ..|.......    3.43341 in (2,9)
#                  volume fraction bilayer .........|    0.98951 in (0,1)
#                 background os047_4column ......|... 6.24808e-06 in (-1e-07,1e-05)
#                                  h2o rho .|........   -0.39879 in (-0.6,0.6)
#                     gold layer thickness ..|.......    170.257 in (150,250)
# step 308 cost 2.30(10)
# step 309 cost 2.30(10)
# step 310 cost 2.30(10)
# step 311 cost 2.30(10)
# step 312 cost 2.30(10)
# step 313 cost 2.30(10)
# step 314 cost 2.30(10)
# step 315 cost 2.30(10)
# step 316 cost 2.30(10)
# step 317 cost 2.30(10)
# step 318 cost 2.30(10)
# step 319 cost 2.30(10)
# step 320 cost 2.30(10)
# step 321 cost 2.30(10)
# step 322 cost 2.30(10)
#                 background os046_4column |......... 3.82995e-07 in (-1e-07,1e-05)
#                  intensity os046_4column ......|...     1.0049 in (0.9,1.05)
#          sample_broadening os046_4column ...|...... 0.00376322 in (-0.005,0.02)
#               theta_offset os046_4column ......|... 0.00593485 in (-0.015,0.015)
#                      substrate roughness .....|....     5.8618 in (2,9)
#                                 siox rho .|........    3.30791 in (3.1,5.1)
#            silicon oxide layer thickness ..|.......    11.7532 in (5,30)
#                  gold chromium roughness ..|.......    8.33699 in (2,24)
#                             chromium rho ......|...    3.52145 in (2.7,4)
#                 chromium layer thickness .|........    36.3861 in (10,150)
#                                 gold rho .....|....    4.54679 in (4.2,4.8)
#                                  d2o rho .......|..    6.22384 in (5.3,6.5)
#               inner acyl chain thickness |.........    8.75016 in (8,30)
#               outer acyl chain thickness .......|..    14.2227 in (8,16)
#                            tether length ..|.......    7.10818 in (3,18)
#                      bME to tether ratio .......|..    3.04511 in (0.1,4)
#                   number fraction tether .|........   0.315695 in (0.2,1)
#                        bilayer roughness ..|.......    3.43341 in (2,9)
#                  volume fraction bilayer .........|    0.98951 in (0,1)
#                 background os047_4column ......|... 6.24808e-06 in (-1e-07,1e-05)
#                                  h2o rho .|........   -0.39879 in (-0.6,0.6)
#                     gold layer thickness ..|.......    170.257 in (150,250)
# step 323 cost 2.30(10)
# step 324 cost 2.30(10)
# step 325 cost 2.30(10)
# step 326 cost 2.30(10)
# step 327 cost 2.30(10)
# step 328 cost 2.30(10)
# step 329 cost 2.30(10)
# step 330 cost 2.30(10)
# step 331 cost 2.30(10)
# step 332 cost 2.30(10)
# step 333 cost 2.30(10)
# step 334 cost 2.30(10)
# step 335 cost 2.30(10)
# step 336 cost 2.30(10)
# step 337 cost 2.30(10)
# step 338 cost 2.30(10)
# step 339 cost 2.30(10)
#                 background os046_4column |......... 3.82995e-07 in (-1e-07,1e-05)
#                  intensity os046_4column ......|...     1.0049 in (0.9,1.05)
#          sample_broadening os046_4column ...|...... 0.00376322 in (-0.005,0.02)
#               theta_offset os046_4column ......|... 0.00593485 in (-0.015,0.015)
#                      substrate roughness .....|....     5.8618 in (2,9)
#                                 siox rho .|........    3.30791 in (3.1,5.1)
#            silicon oxide layer thickness ..|.......    11.7532 in (5,30)
#                  gold chromium roughness ..|.......    8.33699 in (2,24)
#                             chromium rho ......|...    3.52145 in (2.7,4)
#                 chromium layer thickness .|........    36.3861 in (10,150)
#                                 gold rho .....|....    4.54679 in (4.2,4.8)
#                                  d2o rho .......|..    6.22384 in (5.3,6.5)
#               inner acyl chain thickness |.........    8.75016 in (8,30)
#               outer acyl chain thickness .......|..    14.2227 in (8,16)
#                            tether length ..|.......    7.10818 in (3,18)
#                      bME to tether ratio .......|..    3.04511 in (0.1,4)
#                   number fraction tether .|........   0.315695 in (0.2,1)
#                        bilayer roughness ..|.......    3.43341 in (2,9)
#                  volume fraction bilayer .........|    0.98951 in (0,1)
#                 background os047_4column ......|... 6.24808e-06 in (-1e-07,1e-05)
#                                  h2o rho .|........   -0.39879 in (-0.6,0.6)
#                     gold layer thickness ..|.......    170.257 in (150,250)
# step 340 cost 2.30(10)
# step 341 cost 2.30(10)
# step 342 cost 2.30(10)
# step 343 cost 2.30(10)
# step 344 cost 2.30(10)
# step 345 cost 2.30(10)
# step 346 cost 2.30(10)
# step 347 cost 2.30(10)
# step 348 cost 2.30(10)
# step 349 cost 2.30(10)
# step 350 cost 2.30(10)
# step 351 cost 2.30(10)
# step 352 cost 2.30(10)
# step 353 cost 2.30(10)
# step 354 cost 2.30(10)
# step 355 cost 2.30(10)
# step 356 cost 2.30(10)
#                 background os046_4column |......... 3.82995e-07 in (-1e-07,1e-05)
#                  intensity os046_4column ......|...     1.0049 in (0.9,1.05)
#          sample_broadening os046_4column ...|...... 0.00376322 in (-0.005,0.02)
#               theta_offset os046_4column ......|... 0.00593485 in (-0.015,0.015)
#                      substrate roughness .....|....     5.8618 in (2,9)
#                                 siox rho .|........    3.30791 in (3.1,5.1)
#            silicon oxide layer thickness ..|.......    11.7532 in (5,30)
#                  gold chromium roughness ..|.......    8.33699 in (2,24)
#                             chromium rho ......|...    3.52145 in (2.7,4)
#                 chromium layer thickness .|........    36.3861 in (10,150)
#                                 gold rho .....|....    4.54679 in (4.2,4.8)
#                                  d2o rho .......|..    6.22384 in (5.3,6.5)
#               inner acyl chain thickness |.........    8.75016 in (8,30)
#               outer acyl chain thickness .......|..    14.2227 in (8,16)
#                            tether length ..|.......    7.10818 in (3,18)
#                      bME to tether ratio .......|..    3.04511 in (0.1,4)
#                   number fraction tether .|........   0.315695 in (0.2,1)
#                        bilayer roughness ..|.......    3.43341 in (2,9)
#                  volume fraction bilayer .........|    0.98951 in (0,1)
#                 background os047_4column ......|... 6.24808e-06 in (-1e-07,1e-05)
#                                  h2o rho .|........   -0.39879 in (-0.6,0.6)
#                     gold layer thickness ..|.......    170.257 in (150,250)
# step 357 cost 2.30(10)
# step 358 cost 2.30(10)
# step 359 cost 2.30(10)
# step 360 cost 2.30(10)
# step 361 cost 2.30(10)
# step 362 cost 2.30(10)
# step 363 cost 2.30(10)
# step 364 cost 2.30(10)
# step 365 cost 2.30(10)
# step 366 cost 2.30(10)
# step 367 cost 2.30(10)
# step 368 cost 2.30(10)
# step 369 cost 2.30(10)
# step 370 cost 2.30(10)
# step 371 cost 2.30(10)
# step 372 cost 2.30(10)
# step 373 cost 2.30(10)
# step 374 cost 2.30(10)
#                 background os046_4column |......... 3.82995e-07 in (-1e-07,1e-05)
#                  intensity os046_4column ......|...     1.0049 in (0.9,1.05)
#          sample_broadening os046_4column ...|...... 0.00376322 in (-0.005,0.02)
#               theta_offset os046_4column ......|... 0.00593485 in (-0.015,0.015)
#                      substrate roughness .....|....     5.8618 in (2,9)
#                                 siox rho .|........    3.30791 in (3.1,5.1)
#            silicon oxide layer thickness ..|.......    11.7532 in (5,30)
#                  gold chromium roughness ..|.......    8.33699 in (2,24)
#                             chromium rho ......|...    3.52145 in (2.7,4)
#                 chromium layer thickness .|........    36.3861 in (10,150)
#                                 gold rho .....|....    4.54679 in (4.2,4.8)
#                                  d2o rho .......|..    6.22384 in (5.3,6.5)
#               inner acyl chain thickness |.........    8.75016 in (8,30)
#               outer acyl chain thickness .......|..    14.2227 in (8,16)
#                            tether length ..|.......    7.10818 in (3,18)
#                      bME to tether ratio .......|..    3.04511 in (0.1,4)
#                   number fraction tether .|........   0.315695 in (0.2,1)
#                        bilayer roughness ..|.......    3.43341 in (2,9)
#                  volume fraction bilayer .........|    0.98951 in (0,1)
#                 background os047_4column ......|... 6.24808e-06 in (-1e-07,1e-05)
#                                  h2o rho .|........   -0.39879 in (-0.6,0.6)
#                     gold layer thickness ..|.......    170.257 in (150,250)
# step 375 cost 2.30(10)
# step 376 cost 2.30(10)
# step 377 cost 2.30(10)
# step 378 cost 2.30(10)
# step 379 cost 2.30(10)
# step 380 cost 2.30(10)
# step 381 cost 2.30(10)
# step 382 cost 2.30(10)
# step 383 cost 2.30(10)
# step 384 cost 2.30(10)
# step 385 cost 2.30(10)
# step 386 cost 2.30(10)
# step 387 cost 2.30(10)
# step 388 cost 2.30(10)
# step 389 cost 2.30(10)
# step 390 cost 2.30(10)
# step 391 cost 2.30(10)
# step 392 cost 2.30(10)
# step 393 cost 2.30(10)
#                 background os046_4column |......... 3.82995e-07 in (-1e-07,1e-05)
#                  intensity os046_4column ......|...     1.0049 in (0.9,1.05)
#          sample_broadening os046_4column ...|...... 0.00376322 in (-0.005,0.02)
#               theta_offset os046_4column ......|... 0.00593485 in (-0.015,0.015)
#                      substrate roughness .....|....     5.8618 in (2,9)
#                                 siox rho .|........    3.30791 in (3.1,5.1)
#            silicon oxide layer thickness ..|.......    11.7532 in (5,30)
#                  gold chromium roughness ..|.......    8.33699 in (2,24)
#                             chromium rho ......|...    3.52145 in (2.7,4)
#                 chromium layer thickness .|........    36.3861 in (10,150)
#                                 gold rho .....|....    4.54679 in (4.2,4.8)
#                                  d2o rho .......|..    6.22384 in (5.3,6.5)
#               inner acyl chain thickness |.........    8.75016 in (8,30)
#               outer acyl chain thickness .......|..    14.2227 in (8,16)
#                            tether length ..|.......    7.10818 in (3,18)
#                      bME to tether ratio .......|..    3.04511 in (0.1,4)
#                   number fraction tether .|........   0.315695 in (0.2,1)
#                        bilayer roughness ..|.......    3.43341 in (2,9)
#                  volume fraction bilayer .........|    0.98951 in (0,1)
#                 background os047_4column ......|... 6.24808e-06 in (-1e-07,1e-05)
#                                  h2o rho .|........   -0.39879 in (-0.6,0.6)
#                     gold layer thickness ..|.......    170.257 in (150,250)
# step 394 cost 2.30(10)
# step 395 cost 2.30(10)
# step 396 cost 2.24(10)
# step 397 cost 2.24(10)
# step 398 cost 2.24(10)
# step 399 cost 2.24(10)
# step 400 cost 2.24(10)
# step 401 cost 2.24(10)
# step 402 cost 2.24(10)
# step 403 cost 2.24(10)
# step 404 cost 2.24(10)
# step 405 cost 2.24(10)
# step 406 cost 2.24(10)
# step 407 cost 2.24(10)
# step 408 cost 2.24(10)
# step 409 cost 2.24(10)
# step 410 cost 2.24(10)
# step 411 cost 2.24(10)
#                 background os046_4column |......... 3.82995e-07 in (-1e-07,1e-05)
# ...
#                        bilayer roughness ..|.......     3.7688 in (2,9)
#                  volume fraction bilayer .........|   0.997903 in (0,1)
#                 background os047_4column ...|...... 3.5747e-06 in (-1e-07,1e-05)
#                                  h2o rho .|........  -0.433539 in (-0.6,0.6)
#                     gold layer thickness ...|......      183.4 in (150,250)
# step 3938 cost 1.16(10)
# step 3939 cost 1.16(10)
# step 3940 cost 1.16(10)
# step 3941 cost 1.16(10)
# step 3942 cost 1.16(10)
# step 3943 cost 1.16(10)
# step 3944 cost 1.16(10)
# step 3945 cost 1.16(10)
# step 3946 cost 1.16(10)
# step 3947 cost 1.16(10)
# step 3948 cost 1.16(10)
# step 3949 cost 1.16(10)
# step 3950 cost 1.16(10)
# step 3951 cost 1.16(10)
# step 3952 cost 1.16(10)
# step 3953 cost 1.16(10)
# step 3954 cost 1.16(10)
# step 3955 cost 1.16(10)
# step 3956 cost 1.16(10)
#                 background os046_4column |......... 9.56942e-08 in (-1e-07,1e-05)
#                  intensity os046_4column ......|...   0.997128 in (0.9,1.05)
#          sample_broadening os046_4column ..|....... 0.00011237 in (-0.005,0.02)
#               theta_offset os046_4column ....|..... -0.00288203 in (-0.015,0.015)
#                      substrate roughness ..|.......    3.40703 in (2,9)
#                                 siox rho ..|.......    3.61062 in (3.1,5.1)
#            silicon oxide layer thickness ...|......    13.3828 in (5,30)
#                  gold chromium roughness .......|..    17.6236 in (2,24)
#                             chromium rho ..|.......    2.98042 in (2.7,4)
#                 chromium layer thickness |.........    21.7618 in (10,150)
#                                 gold rho ...|......    4.41505 in (4.2,4.8)
#                                  d2o rho .....|....    6.01738 in (5.3,6.5)
#               inner acyl chain thickness .|........    11.0016 in (8,30)
#               outer acyl chain thickness ......|...    12.8848 in (8,16)
#                            tether length |.........    3.55871 in (3,18)
#                      bME to tether ratio |.........   0.224128 in (0.1,4)
#                   number fraction tether ...|......   0.485562 in (0.2,1)
#                        bilayer roughness ..|.......     3.7688 in (2,9)
#                  volume fraction bilayer .........|   0.997903 in (0,1)
#                 background os047_4column ...|...... 3.5747e-06 in (-1e-07,1e-05)
#                                  h2o rho .|........  -0.433539 in (-0.6,0.6)
#                     gold layer thickness ...|......      183.4 in (150,250)
# step 3957 cost 1.16(10)
# step 3958 cost 1.16(10)
# step 3959 cost 1.16(10)
# step 3960 cost 1.16(10)
# step 3961 cost 1.16(10)
# step 3962 cost 1.16(10)
# step 3963 cost 1.16(10)
# step 3964 cost 1.16(10)
# step 3965 cost 1.16(10)
# step 3966 cost 1.16(10)
# step 3967 cost 1.16(10)
# step 3968 cost 1.16(10)
# step 3969 cost 1.16(10)
# step 3970 cost 1.16(10)
# step 3971 cost 1.16(10)
# step 3972 cost 1.16(10)
# step 3973 cost 1.16(10)
# step 3974 cost 1.16(10)
# step 3975 cost 1.16(10)
#                 background os046_4column |......... 9.56942e-08 in (-1e-07,1e-05)
#                  intensity os046_4column ......|...   0.997128 in (0.9,1.05)
#          sample_broadening os046_4column ..|....... 0.00011237 in (-0.005,0.02)
#               theta_offset os046_4column ....|..... -0.00288203 in (-0.015,0.015)
#                      substrate roughness ..|.......    3.40703 in (2,9)
#                                 siox rho ..|.......    3.61062 in (3.1,5.1)
#            silicon oxide layer thickness ...|......    13.3828 in (5,30)
#                  gold chromium roughness .......|..    17.6236 in (2,24)
#                             chromium rho ..|.......    2.98042 in (2.7,4)
#                 chromium layer thickness |.........    21.7618 in (10,150)
#                                 gold rho ...|......    4.41505 in (4.2,4.8)
#                                  d2o rho .....|....    6.01738 in (5.3,6.5)
#               inner acyl chain thickness .|........    11.0016 in (8,30)
#               outer acyl chain thickness ......|...    12.8848 in (8,16)
#                            tether length |.........    3.55871 in (3,18)
#                      bME to tether ratio |.........   0.224128 in (0.1,4)
#                   number fraction tether ...|......   0.485562 in (0.2,1)
#                        bilayer roughness ..|.......     3.7688 in (2,9)
#                  volume fraction bilayer .........|   0.997903 in (0,1)
#                 background os047_4column ...|...... 3.5747e-06 in (-1e-07,1e-05)
#                                  h2o rho .|........  -0.433539 in (-0.6,0.6)
#                     gold layer thickness ...|......      183.4 in (150,250)
# step 3976 cost 1.16(10)
# step 3977 cost 1.16(10)
# step 3978 cost 1.16(10)
# step 3979 cost 1.16(10)
# step 3980 cost 1.16(10)
# step 3981 cost 1.16(10)
# step 3982 cost 1.16(10)
# step 3983 cost 1.16(10)
# step 3984 cost 1.16(10)
# step 3985 cost 1.16(10)
# step 3986 cost 1.16(10)
# step 3987 cost 1.16(10)
# step 3988 cost 1.16(10)
# step 3989 cost 1.16(10)
# step 3990 cost 1.16(10)
# step 3991 cost 1.16(10)
# step 3992 cost 1.16(10)
# step 3993 cost 1.16(10)
# step 3994 cost 1.16(10)
#                 background os046_4column |......... 1.79598e-07 in (-1e-07,1e-05)
#                  intensity os046_4column .....|....   0.984615 in (0.9,1.05)
#          sample_broadening os046_4column .|........ -0.000227376 in (-0.005,0.02)
#               theta_offset os046_4column ....|..... -0.000989085 in (-0.015,0.015)
#                      substrate roughness .|........    3.12749 in (2,9)
#                                 siox rho .|........    3.38294 in (3.1,5.1)
#            silicon oxide layer thickness ....|.....    16.2834 in (5,30)
#                  gold chromium roughness ....|.....    12.5109 in (2,24)
#                             chromium rho .....|....     3.4017 in (2.7,4)
#                 chromium layer thickness .|........    29.3862 in (10,150)
#                                 gold rho ....|.....       4.45 in (4.2,4.8)
#                                  d2o rho ......|...    6.06973 in (5.3,6.5)
#               inner acyl chain thickness .|........    11.3277 in (8,30)
#               outer acyl chain thickness .....|....    12.1749 in (8,16)
#                            tether length .|........    5.09801 in (3,18)
#                      bME to tether ratio .|........   0.593752 in (0.1,4)
#                   number fraction tether ....|.....   0.573764 in (0.2,1)
#                        bilayer roughness |.........    2.61677 in (2,9)
#                  volume fraction bilayer .........|   0.965452 in (0,1)
#                 background os047_4column ...|...... 3.69264e-06 in (-1e-07,1e-05)
#                                  h2o rho .|........  -0.460725 in (-0.6,0.6)
#                     gold layer thickness ..|.......    174.692 in (150,250)
# step 3995 cost 1.16(10)
# step 3996 cost 1.16(10)
# step 3997 cost 1.16(10)
# step 3998 cost 1.16(10)
# step 3999 cost 1.16(10)
# step 4000 cost 1.16(10)
# step 4001 cost 1.16(10)
# step 4002 cost 1.16(10)
# step 4003 cost 1.16(10)
# step 4004 cost 1.16(10)
# step 4005 cost 1.16(10)
# step 4006 cost 1.16(10)
# step 4007 cost 1.16(10)
# step 4008 cost 1.16(10)
# step 4009 cost 1.16(10)
# step 4010 cost 1.16(10)
# step 4011 cost 1.16(10)
# step 4012 cost 1.16(10)
# step 4013 cost 1.16(10)
#                 background os046_4column |......... 1.79598e-07 in (-1e-07,1e-05)
#                  intensity os046_4column .....|....   0.984615 in (0.9,1.05)
#          sample_broadening os046_4column .|........ -0.000227376 in (-0.005,0.02)
#               theta_offset os046_4column ....|..... -0.000989085 in (-0.015,0.015)
#                      substrate roughness .|........    3.12749 in (2,9)
#                                 siox rho .|........    3.38294 in (3.1,5.1)
#            silicon oxide layer thickness ....|.....    16.2834 in (5,30)
#                  gold chromium roughness ....|.....    12.5109 in (2,24)
#                             chromium rho .....|....     3.4017 in (2.7,4)
#                 chromium layer thickness .|........    29.3862 in (10,150)
#                                 gold rho ....|.....       4.45 in (4.2,4.8)
#                                  d2o rho ......|...    6.06973 in (5.3,6.5)
#               inner acyl chain thickness .|........    11.3277 in (8,30)
#               outer acyl chain thickness .....|....    12.1749 in (8,16)
#                            tether length .|........    5.09801 in (3,18)
#                      bME to tether ratio .|........   0.593752 in (0.1,4)
#                   number fraction tether ....|.....   0.573764 in (0.2,1)
#                        bilayer roughness |.........    2.61677 in (2,9)
#                  volume fraction bilayer .........|   0.965452 in (0,1)
#                 background os047_4column ...|...... 3.69264e-06 in (-1e-07,1e-05)
#                                  h2o rho .|........  -0.460725 in (-0.6,0.6)
#                     gold layer thickness ..|.......    174.692 in (150,250)
# step 4014 cost 1.16(10)
# step 4015 cost 1.16(10)
# step 4016 cost 1.16(10)
# step 4017 cost 1.16(10)
# step 4018 cost 1.16(10)
# step 4019 cost 1.16(10)
# step 4020 cost 1.16(10)
# step 4021 cost 1.16(10)
# step 4022 cost 1.16(10)
# step 4023 cost 1.16(10)
# step 4024 cost 1.16(10)
# step 4025 cost 1.16(10)
# step 4026 cost 1.16(10)
# step 4027 cost 1.16(10)
# step 4028 cost 1.16(10)
# step 4029 cost 1.16(10)
# step 4030 cost 1.16(10)
# step 4031 cost 1.16(10)
# step 4032 cost 1.16(10)
# step 4033 cost 1.16(10)
#                 background os046_4column |......... 1.79598e-07 in (-1e-07,1e-05)
#                  intensity os046_4column .....|....   0.984615 in (0.9,1.05)
#          sample_broadening os046_4column .|........ -0.000227376 in (-0.005,0.02)
#               theta_offset os046_4column ....|..... -0.000989085 in (-0.015,0.015)
#                      substrate roughness .|........    3.12749 in (2,9)
#                                 siox rho .|........    3.38294 in (3.1,5.1)
#            silicon oxide layer thickness ....|.....    16.2834 in (5,30)
#                  gold chromium roughness ....|.....    12.5109 in (2,24)
#                             chromium rho .....|....     3.4017 in (2.7,4)
#                 chromium layer thickness .|........    29.3862 in (10,150)
#                                 gold rho ....|.....       4.45 in (4.2,4.8)
#                                  d2o rho ......|...    6.06973 in (5.3,6.5)
#               inner acyl chain thickness .|........    11.3277 in (8,30)
#               outer acyl chain thickness .....|....    12.1749 in (8,16)
#                            tether length .|........    5.09801 in (3,18)
#                      bME to tether ratio .|........   0.593752 in (0.1,4)
#                   number fraction tether ....|.....   0.573764 in (0.2,1)
#                        bilayer roughness |.........    2.61677 in (2,9)
#                  volume fraction bilayer .........|   0.965452 in (0,1)
#                 background os047_4column ...|...... 3.69264e-06 in (-1e-07,1e-05)
#                                  h2o rho .|........  -0.460725 in (-0.6,0.6)
#                     gold layer thickness ..|.......    174.692 in (150,250)
# step 4034 cost 1.16(10)
# step 4035 cost 1.16(10)
# step 4036 cost 1.16(10)
# step 4037 cost 1.16(10)
# step 4038 cost 1.16(10)
# step 4039 cost 1.16(10)
# step 4040 cost 1.16(10)
# step 4041 cost 1.16(10)
# step 4042 cost 1.16(10)
# step 4043 cost 1.16(10)
# step 4044 cost 1.16(10)
# step 4045 cost 1.16(10)
# step 4046 cost 1.16(10)
# step 4047 cost 1.16(10)
# step 4048 cost 1.16(10)
# step 4049 cost 1.16(10)
# step 4050 cost 1.16(10)
# step 4051 cost 1.16(10)
# Did not converge!
# -- Model 0 os046_4column
# .probe
#   .back_absorption = back_absorption os046_4column = 1
#   .background = background os046_4column = 1.79598e-07 in [-1e-07,1e-05]
#   .intensity = intensity os046_4column = 0.984615 in [0.9,1.05]
#   .sample_broadening = sample_broadening os046_4column = -0.000227376 in [-0.005,0.02]
#   .theta_offset = theta_offset os046_4column = -0.000989085 in [-0.015,0.015]
# .sample
#   .layers
#     [0]
#       .interface = substrate roughness = 3.12749 in [2,9]
#       .material
#         .irho = silicon irho = 0
#         .rho = silicon rho = 2.069
#       .thickness = silicon thickness = 0
#     [1]
#       .interface = substrate roughness = 3.12749 in [2,9]
#       .material
#         .irho = siox irho = 0
#         .rho = siox rho = 3.38294 in [3.1,5.1]
#       .thickness = silicon oxide layer thickness = 16.2834 in [5,30]
#     [2]
#       .interface = gold chromium roughness = 12.5109 in [2,24]
#       .material
#         .irho = chromium irho = 0
#         .rho = chromium rho = 3.4017 in [2.7,4]
#       .thickness = chromium layer thickness = 29.3862 in [10,150]
#     [3]
#       .interface = gold interface = 0
#       .material
#         .irho = gold irho = 0
#         .rho = gold rho = 4.45 in [4.2,4.8]
#       .thickness = (gold layer thickness - 20.0) = 154.692
#     [4]
#       .bulknsld = d2o rho = 6.06973 in [5.3,6.5]
#       .global_rough = substrate roughness = 3.12749 in [2,9]
#       .interface = bilayer interface = 0
#       .l_lipid1 = inner acyl chain thickness = 11.3277 in [8,30]
#       .l_lipid2 = outer acyl chain thickness = 12.1749 in [8,16]
#       .l_tether = tether length = 5.09801 in [3,18]
#       .mult_tether = bME to tether ratio = 0.593752 in [0.1,4]
#       .nf_tether = number fraction tether = 0.573764 in [0.2,1]
#       .rho_substrate = gold rho = 4.45 in [4.2,4.8]
#       .sigma = bilayer roughness = 2.61677 in [2,9]
#       .thickness = bilayer thickness = 150
#       .vf_bilayer = volume fraction bilayer = 0.965452 in [0,1]
#     [5]
#       .interface = d2o interface = 5
#       .material
#         .irho = d2o irho = 0
#         .rho = d2o rho = 6.06973 in [5.3,6.5]
#       .thickness = d2o thickness = 0
#   .thickness = stack thickness = 350.362
#
# [chisq=1.56(18), nllf=99.8546]
# -- Model 1 os047_4column
# .probe
#   .back_absorption = back_absorption os047_4column = 1
#   .background = background os047_4column = 3.69264e-06 in [-1e-07,1e-05]
#   .intensity = intensity os046_4column = 0.984615 in [0.9,1.05]
#   .sample_broadening = sample_broadening os046_4column = -0.000227376 in [-0.005,0.02]
#   .theta_offset = theta_offset os046_4column = -0.000989085 in [-0.015,0.015]
# .sample
#   .layers
#     [0]
#       .interface = substrate roughness = 3.12749 in [2,9]
#       .material
#         .irho = silicon irho = 0
#         .rho = silicon rho = 2.069
#       .thickness = silicon thickness = 0
#     [1]
#       .interface = substrate roughness = 3.12749 in [2,9]
#       .material
#         .irho = siox irho = 0
#         .rho = siox rho = 3.38294 in [3.1,5.1]
#       .thickness = silicon oxide layer thickness = 16.2834 in [5,30]
#     [2]
#       .interface = gold chromium roughness = 12.5109 in [2,24]
#       .material
#         .irho = chromium irho = 0
#         .rho = chromium rho = 3.4017 in [2.7,4]
#       .thickness = chromium layer thickness = 29.3862 in [10,150]
#     [3]
#       .interface = gold interface = 0
#       .material
#         .irho = gold irho = 0
#         .rho = gold rho = 4.45 in [4.2,4.8]
#       .thickness = (gold layer thickness - 20.0) = 154.692
#     [4]
#       .bulknsld = h2o rho = -0.460725 in [-0.6,0.6]
#       .global_rough = substrate roughness = 3.12749 in [2,9]
#       .interface = bilayer interface = 0
#       .l_lipid1 = inner acyl chain thickness = 11.3277 in [8,30]
#       .l_lipid2 = outer acyl chain thickness = 12.1749 in [8,16]
#       .l_tether = tether length = 5.09801 in [3,18]
#       .mult_tether = bME to tether ratio = 0.593752 in [0.1,4]
#       .nf_tether = number fraction tether = 0.573764 in [0.2,1]
#       .rho_substrate = gold rho = 4.45 in [4.2,4.8]
#       .sigma = bilayer roughness = 2.61677 in [2,9]
#       .thickness = bilayer thickness = 150
#       .vf_bilayer = volume fraction bilayer = 0.965452 in [0,1]
#     [5]
#       .interface = h2o interface = 5
#       .material
#         .irho = h2o irho = 0
#         .rho = h2o rho = -0.460725 in [-0.6,0.6]
#       .thickness = h2o thickness = 0
#   .thickness = stack thickness = 350.362
#
# [chisq=1.05(17), nllf=67.4871]
# [overall chisq=1.42(10), nllf=167.342]
#
# Figure(640x480)
# Figure(640x480)
# Figure(1735x1140)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)

# %% [markdown]
# # Analysis

# %% [markdown]
# Statistical analysis of fit results.
#
# Median values, 68% confidence limits (-1, 94%: -2, etc.), and fit intervals for all fit parameters.

# %%
sparse = 0.05
fit_object.fnAnalyzeStatFile(fConfidence=-1, sparse=sparse)
# Out:
# No StatDataPython.dat.
# Recreate statistical data from sErr.dat.
# Analysis of current MC simulation ...
# Number of iterations: 637
#        background_os046_4column  #+          ]  [    -1e-07,     1e-05]  [-6.951e-08(0.000), -1.965e-08(0.000),  9.449e-08(0.000)] (- 4.986e-08, + 1.141e-07)
#         intensity_os046_4column  [      +|   ]  [       0.9,      1.05]  [    0.9847(0.000),      0.995(0.000),      1.006(0.000)] (-   0.01028, +    0.0111)
# sample_broadening_os046_4column  [ |-|       ]  [    -0.005,      0.02]  [ -0.001682(0.000),  0.0004911(0.000),   0.002792(0.000)] (-  0.002173, +  0.002301)
#      theta_offset_os046_4column  [    | - |  ]  [    -0.015,     0.015]  [ -0.003896(0.000),   0.001883(0.001),   0.009078(0.000)] (-  0.005779, +  0.007195)
#             substrate_roughness  [   |-|     ]  [         2,         9]  [     3.962(0.000),      4.802(0.001),      5.636(0.000)] (-    0.8402, +    0.8339)
#                        siox_rho  [ |- |      ]  [       3.1,       5.1]  [     3.374(0.000),      3.516(0.001),       3.86(0.000)] (-    0.1417, +    0.3443)
#   silicon_oxide_layer_thickness  [  | -   |  ]  [         5,        30]  [     9.645(0.011),      15.45(0.002),       25.5(0.000)] (-     5.809, +     10.04)
#         gold_chromium_roughness  [    |- |   ]  [         2,        24]  [     10.63(0.000),      14.02(0.000),       17.6(0.001)] (-     3.392, +     3.575)
#                    chromium_rho  [   | -|    ]  [       2.7,         4]  [     3.111(0.001),      3.334(0.007),      3.529(0.000)] (-    0.2223, +    0.1949)
#        chromium_layer_thickness  [ +|        ]  [        10,       150]  [     19.11(0.000),      25.82(0.000),      34.27(0.000)] (-     6.718, +     8.449)
#                        gold_rho  [    |- |   ]  [       4.2,       4.8]  [     4.418(0.000),      4.517(0.000),      4.611(0.001)] (-    0.0995, +     0.094)
#                         d2o_rho  [      |-|  ]  [       5.3,       6.5]  [     5.997(0.000),      6.143(0.000),      6.304(0.000)] (-    0.1457, +    0.1611)
#      inner_acyl_chain_thickness  [ +|        ]  [         8,        30]  [      9.12(0.000),      10.42(0.000),      11.97(0.000)] (-     1.302, +     1.545)
#      outer_acyl_chain_thickness  [     | -|  ]  [         8,        16]  [     11.72(0.001),      13.26(0.000),      14.47(0.000)] (-     1.546, +     1.209)
#                   tether_length  [ |-|       ]  [         3,        18]  [      3.75(0.000),      5.413(0.000),      6.956(0.001)] (-     1.663, +     1.543)
#             bME_to_tether_ratio  [ |-  |     ]  [       0.1,         4]  [    0.3307(0.000),     0.7744(0.000),      1.875(0.000)] (-    0.4437, +     1.101)
#          number_fraction_tether  [ | - |     ]  [       0.2,         1]  [     0.256(0.000),     0.4023(0.000),     0.5973(0.000)] (-    0.1464, +     0.195)
#               bilayer_roughness  [  |-|      ]  [         2,         9]  [     3.663(0.000),      4.449(0.000),      5.093(0.000)] (-    0.7857, +    0.6439)
#         volume_fraction_bilayer  [          +#  [         0,         1]  [    0.9505(0.000),     0.9774(0.000),     0.9936(0.000)] (-   0.02683, +   0.01619)
#        background_os047_4column  [    +      ]  [    -1e-07,     1e-05]  [ 3.681e-06(0.000),  4.069e-06(0.000),  4.371e-06(0.000)] (- 3.881e-07, + 3.019e-07)
#                         h2o_rho  [ |-|       ]  [      -0.6,       0.6]  [    -0.487(0.000),    -0.3874(0.000),    -0.2589(0.000)] (-   0.09955, +    0.1286)
#            gold_layer_thickness  [  +|       ]  [       150,       250]  [     171.4(0.000),      174.9(0.000),      179.8(0.000)] (-     3.518, +     4.886)
# Maximum deviation from average over last 5 iterations: 0.0060
# Confidence level: 0.6827

# %% [markdown]
# Create bilayer statistics from above parameter statistics. Results are saved to bilayerplotdata.dat.

# %%
fit_object.fnCreateBilayerPlotData()
# Out:
# Initializing ...
# Pulling all molgroups ...
#   substrate ...
#   siox ...
# Molecular group bilayer.siox does not exist.
#   tether ...
# Molecular group bilayer.tetherg does not exist.
# Molecular group bilayer.tether does not exist.
#   innerhg ...
#   innerhc ...
#   outerhc ...
#   outerhg ...
#   protein ...
# Molecular group protein does not exist.
# Applying corrections ...
#
# Calculating statistics ...
#
# Saving data to bilayerplotdata.dat ...

# %% [markdown]
# Plot selected data from bilayerplotdata.dat
#
# > _cvo is component volume occupancy data [0 ,1] opposed to area profiles [0, area per lipid outer leaflet].
#
# > _corr is corrected data taking into account bilayer material replacement by protein (not applicable here, but does not
# > hurt)
#
# > cg, phos, and chol subgroups of the PC headgroup are currently only extracted for the first lipid component, to help
# with certain applications. They are not scaled down according to the scaling factor of the parent headgroup and
# represent the area of one subgroup.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys

bilayer_plot_data = pd.read_csv(store + "/bilayerplotdata.dat", sep="\s", engine="python")

zax = bilayer_plot_data["zaxis"]

fig, ax = plt.subplots()
ax.plot(zax, bilayer_plot_data["water_corr_cvo"], label="water")
ax.plot(zax, bilayer_plot_data["substrate_corr_cvo"], label="substrate")
ax.plot(zax, bilayer_plot_data["tether_corr_cvo"], label="tether")
ax.plot(zax, bilayer_plot_data["innerhg_corr_cvo"] + bilayer_plot_data["outerhg_corr_cvo"], label="headgroups")
#ax.plot(zax, bilayer_plot_data["inner_cg_corr_cvo"] + bilayer_plot_data["outer_cg_corr_cvo"],label="cg")
#ax.plot(zax, bilayer_plot_data["inner_phosphate_corr_cvo"] + bilayer_plot_data["outer_phosphate_corr_cvo"], label="phosphate")
#ax.plot(zax, bilayer_plot_data["inner_choline_corr_cvo"] + bilayer_plot_data["outer_choline_corr_cvo"], label="choline")
ax.plot(zax, bilayer_plot_data["innerhc_corr_cvo"]+bilayer_plot_data["outerhc_corr_cvo"], label="hydrocarbons")
ax.plot(zax, bilayer_plot_data["innerch2_corr_cvo"]+bilayer_plot_data["outerch2_corr_cvo"], label="CH2")
ax.plot(zax, bilayer_plot_data["innerch3_corr_cvo"]+bilayer_plot_data["outerch3_corr_cvo"], label="CH3")
ax.legend(loc="upper right")
plt.xlabel("Distance (Å)")
plt.ylabel("Component volume occupancy")
ax.minorticks_on()
ax.tick_params(which="both", direction="in", labelsize=10)
ax.tick_params(bottom=True, top=True, left=True, right=True, which="both")
plt.xlim(0, 100)
#plt.xticks(np.arange(-35, 36, 5.0))
plt.grid(True, which='Both')
fig.patch.set_facecolor('white')
ax.figure.set_size_inches(16, 10)
plt.savefig(store + "/cvo", facecolor="white")
plt.show()

# %% [markdown]
# Compute statistical properties of interest with 68% confidence limits, such as the area per lipid of the outer lipid
# leaflet.

# %%
fit_object.fnCalculateMolgroupProperty(fConfidence=-1)
# Out:
# Did not find any fractional envelopes ...
# WaterFracHeadgroup1  [    0.5184,     0.6332,     0.7588] (-    0.1149, +    0.1256)
# WaterFracHeadgroup2  [    0.4165,     0.4473,     0.4915] (-    0.0308, +   0.04414)
# WaterFracHydrocarbon  [    0.1792,     0.2341,     0.3405] (-   0.05491, +    0.1063)
# WaterFracLipid1  [    0.2744,     0.3953,     0.5498] (-    0.1209, +    0.1545)
# WaterFracLipid2  [   0.09373,     0.1232,     0.1622] (-   0.02948, +   0.03902)
# WaterFracSubMembrane  [    0.9479,     0.9618,     0.9755] (-   0.01385, +   0.01378)
# bilayer.bME_AVG  [    0.1197,     0.3117,     0.5637] (-     0.192, +     0.252)
# bilayer.bME_COM  [      17.8,      20.62,      22.78] (-     2.826, +     2.158)
# bilayer.bME_INT  [    0.3284,     0.7981,      1.418] (-    0.4697, +    0.6204)
# bilayer.defect_hc_AVG  [   0.01373,    0.04597,    0.09974] (-   0.03224, +   0.05378)
# bilayer.defect_hc_COM  [     39.22,      40.15,      41.06] (-    0.9258, +    0.9087)
# bilayer.defect_hc_INT  [    0.0323,     0.1192,     0.2543] (-   0.08687, +    0.1352)
# bilayer.defect_hg_AVG  [   0.00567,    0.01868,    0.03941] (-   0.01301, +   0.02074)
# bilayer.defect_hg_COM  [     44.01,      44.93,      45.84] (-    0.9258, +    0.9086)
# bilayer.defect_hg_INT  [   0.01334,    0.04833,     0.1006] (-   0.03499, +   0.05231)
# bilayer.headgroup1_1.carbonyl_glycerol_AVG  [      0.98,       0.98,       0.98] (-  2.33e-06, + 6.863e-08)
# bilayer.headgroup1_1.carbonyl_glycerol_COM  [     23.84,      24.66,      25.56] (-    0.8262, +    0.8935)
# bilayer.headgroup1_1.carbonyl_glycerol_INT  [     2.231,      2.525,      2.755] (-    0.2942, +    0.2303)
# bilayer.headgroup1_1.choline_AVG  [       0.8,        0.8,        0.8] (- 3.101e-06, + 7.456e-08)
# bilayer.headgroup1_1.choline_COM  [     24.64,      24.93,      25.25] (-    0.2907, +    0.3145)
# bilayer.headgroup1_1.choline_INT  [     1.821,      2.061,      2.249] (-    0.2402, +     0.188)
# bilayer.headgroup1_1.phosphate_AVG  [      0.36,       0.36,       0.36] (- 8.097e-07, + 1.992e-08)
# bilayer.headgroup1_1.phosphate_COM  [     24.02,      24.31,      24.78] (-    0.2908, +    0.4699)
# bilayer.headgroup1_1.phosphate_INT  [    0.8194,     0.9275,      1.012] (-    0.1081, +   0.08459)
# bilayer.headgroup1_1_AVG  [    0.6276,     0.9044,      1.302] (-    0.2768, +    0.3977)
# bilayer.headgroup1_1_COM  [     24.17,       24.7,      25.31] (-     0.536, +    0.6058)
# bilayer.headgroup1_1_INT  [     1.617,      2.298,      3.198] (-    0.6811, +    0.8996)
# bilayer.headgroup2_1.carbonyl_glycerol_AVG  [      0.98,       0.98,       0.98] (-  2.22e-16, +         0)
# bilayer.headgroup2_1.carbonyl_glycerol_COM  [     54.49,      55.58,      56.76] (-     1.092, +     1.175)
# bilayer.headgroup2_1.carbonyl_glycerol_INT  [     2.231,      2.525,      2.755] (-    0.2942, +    0.2302)
# bilayer.headgroup2_1.choline_AVG  [       0.8,        0.8,        0.8] (-         0, +         0)
# bilayer.headgroup2_1.choline_COM  [     59.41,       60.5,      61.68] (-     1.092, +     1.175)
# bilayer.headgroup2_1.choline_INT  [     1.821,      2.061,      2.249] (-    0.2402, +     0.188)
# bilayer.headgroup2_1.phosphate_AVG  [      0.36,       0.36,       0.36] (- 5.551e-17, + 5.551e-17)
# bilayer.headgroup2_1.phosphate_COM  [     57.94,      59.03,       60.2] (-     1.092, +     1.175)
# bilayer.headgroup2_1.phosphate_INT  [    0.8194,     0.9275,      1.012] (-    0.1081, +   0.08458)
# bilayer.headgroup2_1_AVG  [     2.034,      2.092,      2.126] (-   0.05742, +   0.03464)
# bilayer.headgroup2_1_COM  [     56.91,         58,      59.18] (-     1.092, +     1.175)
# bilayer.headgroup2_1_INT  [     4.717,      5.379,      5.811] (-    0.6623, +    0.4313)
# bilayer.methyl1_1_AVG  [    0.1932,     0.2784,     0.4008] (-   0.08526, +    0.1224)
# bilayer.methyl1_1_COM  [     35.81,      37.83,      40.45] (-     2.025, +      2.62)
# bilayer.methyl1_1_INT  [    0.4977,     0.7074,     0.9842] (-    0.2096, +    0.2769)
# bilayer.methyl2_1_AVG  [    0.6261,     0.6438,     0.6544] (-   0.01767, +   0.01066)
# bilayer.methyl2_1_COM  [     37.25,      39.29,      41.88] (-      2.04, +     2.592)
# bilayer.methyl2_1_INT  [     1.452,      1.656,      1.788] (-    0.2038, +    0.1328)
# bilayer.methylene1_1_AVG  [      1.51,      2.176,      3.132] (-    0.6664, +    0.9563)
# bilayer.methylene1_1_COM  [     30.83,      32.13,      33.76] (-     1.301, +     1.632)
# bilayer.methylene1_1_INT  [      3.89,      5.529,      7.693] (-     1.639, +     2.164)
# bilayer.methylene2_1_AVG  [     4.893,      5.032,      5.115] (-    0.1381, +   0.08332)
# bilayer.methylene2_1_COM  [     45.18,      46.71,      48.44] (-     1.528, +     1.731)
# bilayer.methylene2_1_INT  [     11.35,      12.94,      13.98] (-     1.593, +     1.038)
# bilayer.normarea_AVG  [     53.35,      58.22,       65.9] (-     4.865, +      7.68)
# bilayer.normarea_COM  [     74.75,      74.75,      74.75] (- 1.421e-14, + 1.421e-14)
# bilayer.normarea_INT  [       150,        150,        150] (- 5.684e-13, + 6.253e-13)
# bilayer.substrate_AVG  [     7.203,       7.86,      8.896] (-    0.6568, +     1.037)
# bilayer.substrate_COM  [     10.26,      10.44,      10.66] (-    0.1818, +    0.2149)
# bilayer.substrate_INT  [     20.25,      20.25,      20.25] (- 8.904e-05, + 7.678e-06)
# bilayer.tether_bme_AVG  [    0.3791,     0.5252,      0.774] (-     0.146, +    0.2488)
# bilayer.tether_bme_COM  [      17.8,      20.62,      22.78] (-     2.826, +     2.158)
# bilayer.tether_bme_INT  [     1.018,      1.382,      1.839] (-    0.3632, +    0.4575)
# bilayer.tether_free_AVG  [         0,          0,          0] (-         0, +         0)
# bilayer.tether_free_COM  [     1e+05,      1e+05,      1e+05] (-         0, +         0)
# bilayer.tether_free_INT  [         0,          0,          0] (-         0, +         0)
# bilayer.tether_hg_AVG  [     0.366,     0.6571,      1.173] (-    0.2911, +    0.5154)
# bilayer.tether_hg_COM  [     24.02,      24.58,      25.18] (-    0.5586, +    0.6039)
# bilayer.tether_hg_INT  [    0.9569,      1.737,      2.879] (-    0.7805, +     1.141)
# bilayer.tether_methyl_AVG  [    0.1303,     0.1818,     0.3069] (-   0.05149, +    0.1251)
# bilayer.tether_methyl_COM  [     35.81,      37.83,      40.45] (-     2.025, +      2.62)
# bilayer.tether_methyl_INT  [    0.3409,     0.4729,     0.7216] (-     0.132, +    0.2487)
# bilayer.tether_methylene_AVG  [     1.152,      1.607,      2.713] (-    0.4551, +     1.106)
# bilayer.tether_methylene_COM  [     30.83,      32.13,      33.76] (-     1.301, +     1.632)
# bilayer.tether_methylene_INT  [     3.013,       4.18,      6.377] (-     1.166, +     2.198)
# fAreaPerLipid2  [     52.05,      56.64,      63.98] (-     4.598, +     7.333)
# fTotalLipid1Length  [     10.22,       11.7,       13.4] (-     1.478, +       1.7)
# fTotalLipid2Length  [     13.22,      14.96,      16.33] (-     1.743, +     1.364)

# %% [markdown]
# A simple way to show output files from the fit. Publication-ready graphs can be created from the data in the storage
# directory or using fit_object:

# %%
from IPython.display import Image, display
import glob
for file in glob.glob(store+"/*.png"):
    display(Image(filename=file))

# %% [markdown]
# # Publication-ready graphs
#
# ...

# %% [markdown]
# # Useful Routines

# %% [markdown]
# Create a HC18 / POPC tethered lipid membrane object and manually change model parameters. Show the molecular
# distributions.

# %%
blm = mol.tBLM(tether=lipids.HC18SAc, filler=cmp.bmeSAc, lipids=[lipids.POPC], lipid_nf=[1.0])
blm.l_tether = 20.
#blm.fnSetSigma(0.001)
#blm.global_rough=0.001
#blm.tether_methyl_sigma=0.001
#blm.methyl_sigma = blm.methyl_sigma/2.0*0.001
blm.fnAdjustParameters()

# %%
def plot_components(z, blm):
    dd, aArea, anSL = blm.fnWriteProfile(z)
    aArea = np.array(aArea)
    anSL = np.array(anSL)
    sel = aArea>0
    anSLD = anSL[sel] / (aArea[sel] * stepsize)

    fig, ax = plt.subplots(3, 1, figsize=(20,24))
    fig.patch.set_facecolor('white')
    ax[0].plot(z[sel], aArea[sel])
    ax[1].plot(z[sel], anSLD)
    ax[2].plot(z[sel], anSL[sel])
    ax[0].set_ylabel('Area')
    ax[1].set_ylabel('nSLD')
    ax[2].set_ylabel('nSL')
    ax[0].set_xlabel('z')
    ax[1].set_xlabel('z')
    ax[2].set_xlabel('z')

    # plot individual components
    for key, val in blm.__dict__.items():       # cycle over all attributes of blm
        if isinstance(val, mol.nSLDObj):        # if instance of nSLDObj, plot its profile
            ddp, aArea, anSL = val.fnWriteProfile(z)
            aArea = np.array(aArea)
            anSL = np.array(anSL)
            sel = aArea>0
            anSLD = anSL[sel] / (aArea[sel] * stepsize)
            ax[0].plot(z[sel], aArea[sel], '-', label=val.name)
            ax[1].plot(z[sel], anSLD, '-', label=val.name)
            ax[2].plot(z[sel], anSL[sel], '-', label=val.name)

    ax[0].legend(loc=0)
    ax[1].legend(loc=0)
    ax[2].legend(loc=0)

dimension = 1500
stepsize =0.1
z = np.arange(dimension) * stepsize
plot_components(z, blm)

# %% [markdown]
# Load the best-fit tBLM profile and show it.

# %%
model = load_model(runfile+'.py')
load_best(model, store+'/'+runfile+'.par')
model.chisq_str()
# Out:
# '2.65(10)'

# %%
z = np.arange(model.dimension) * model.stepsize
stepsize = model.stepsize
blm = model.bilayers[0]

plot_components(z, model.bilayers[0])

# %%
from bumps.dream.state import load_state
state = load_state(store+'/tBLM')
state.mark_outliers() # ignore outlier chains
#state.show()  # Plot statistics

# %%
dw = state.draw(thin=5)

# calculate the actual mult_tether and l_tether distributions
mts = list()
lts = list()

for i, d in enumerate(dw.points):
    #if np.mod(i, 100)==0:
    #    print(i, flush=True)
    model.setp(d)
    model.chisq_str()
    mts.append(model.bilayers[0].mult_tether)
    lts.append(model.bilayers[0].l_tether)

plt.figure()
plt.hist(mts, bins=20)
plt.title('mts')

plt.figure()
plt.hist(lts, bins=20)
plt.title('lts')

print('mts', np.mean(mts), np.std(mts), np.median(mts))
print('lts', np.mean(lts), np.std(lts), np.median(lts))
# Out:
# mts 0.8106461934535957 0.5869041762326473 0.6603126415066737
# lts 6.99236765438544 1.0070951070003218 6.917622753402412

# %%
from bumps.dream.stats import credible_interval

print(credible_interval(np.array(mts), [0, 0.68, 0.95]))
print(credible_interval(np.array(lts), [0, 0.68, 0.95]))
# Out:
# [[0.66031264 0.66031264]
#  [0.27230704 1.36677032]
#  [0.12917349 2.35561949]]
# [[6.91762275 6.91762275]
#  [5.96638804 8.07605148]
#  [5.02358133 8.88306211]]
