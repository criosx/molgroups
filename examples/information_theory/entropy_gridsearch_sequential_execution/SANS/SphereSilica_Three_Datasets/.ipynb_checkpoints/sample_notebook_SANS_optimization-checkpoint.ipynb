# %% [markdown]
# # Imports

# %%
import os
import shutil
import copy
import matplotlib.pyplot as plt

from molgroups.support import molstat
from molgroups.infotheory import entropy

print(os.getcwd())

# always use the same testdata
shutil.copyfile('./bu/sim0.dat', os.getcwd()+'/sim0.dat')
shutil.copyfile('./bu/sim1.dat', os.getcwd()+'/sim1.dat')
shutil.copyfile('./bu/sim2.dat', os.getcwd()+'/sim2.dat')
# Out:
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\examples\information_theory\entropy_gridsearch_sequential_execution\SANS\SphereSilica_Two_Datasets
# 'C:\\Users\\Frank Heinrich\\PycharmProjects\\molgroups\\examples\\information_theory\\entropy_gridsearch_sequential_execution\\SANS\\SphereSilica_Two_Datasets/sim2.dat'

# %% [markdown]
# # Create Short Example Fit

# %% [markdown]
# - The model needs to define fittable parameters with unique names, as shown below. For example, model0.scale and model1.scale would not be unique, since both parameters would be internally named 'scale' by bumps. In such a case, define parameters using the Parameter method and assign them to the models afterwards.

# %%
# %%writefile sanssilica.py
import numpy

from bumps.names import *
from sasmodels.core import load_model
from sasmodels.bumps_model import Model, Experiment
from sasmodels.data import load_data, plot_data

# IMPORT THE DATA USED
data0 = load_data('sim0.dat')
data1 = load_data('sim1.dat')
data2 = load_data('sim2.dat')

#setattr(data, 'qmin', 0.01)
#setattr(data, 'qmax', 10.0)

# DEFINE THE MODEL
kernel = load_model('sphere')

pars0 = dict(scale=0.002, background=0.15, sld=3.0, sld_solvent=2.4, radius=60.0)
pars1 = dict(scale=0.002, background=0.15, sld=3.0, sld_solvent=3.4, radius=60.0)
pars2 = dict(scale=0.002, background=0.15, sld=3.0, sld_solvent=4.4, radius=60.0)

model0 = Model(kernel, **pars0)
model1 = Model(kernel, **pars1)
model2 = Model(kernel, **pars2)

# PARAMETER RANGES (ONLY THOSE PARAMETERS ARE FITTED)

background0 = Parameter(name='background0', value=0.4).range(0.01, 0.8)
background1 = Parameter(name='background1', value=0.4).range(0.01, 0.8)
background2 = Parameter(name='background2', value=0.4).range(0.01, 0.8)
sld_solvent0 = Parameter(name='sld_solvent0', value=2.0).range(-0.56, 6.4)
sld_solvent1 = Parameter(name='sld_solvent1', value=2.0).range(-0.56, 6.4)
sld_solvent2 = Parameter(name='sld_solvent2', value=2.0).range(-0.56, 6.4)

model0.scale.range(0.0001, 0.05)
model0.background = background0
model0.sld.range(1, 4)
model0.sld_solvent = sld_solvent0
model0.radius.range(50., 200.)

model1.scale = model0.scale
model1.background = background1
model1.sld = model0.sld
model1.sld_solvent = sld_solvent1
model1.radius = model0.radius

model2.scale = model0.scale
model2.background = background2
model2.sld = model0.sld
model2.sld_solvent = sld_solvent2
model2.radius = model0.radius


M0 = Experiment(data=data0, model=model0)
M1 = Experiment(data=data1, model=model1)
M2 = Experiment(data=data2, model=model2)

problem = MultiFitProblem([M0, M1, M2])
# Out:
# Overwriting sanssilica.py

# %% [markdown]
# # Variables

# %%
#Example is from https://github.com/SasView/sasmodels/tree/master/example

store = "T"
setupdir = os.getcwd()
runfile = "sanssilica"
fitsource = "SASView"

# remove store directory if it already exists, since we do not want to reload here
if os.path.isdir(os.path.join(setupdir, store)):
    shutil.rmtree(os.path.join(setupdir, store))

burn=100
steps=100

# %% [markdown]
# # Setup Example Fit

# %%
fitobj = molstat.CMolStat(
    fitsource=fitsource,
    spath=setupdir,
    mcmcpath=store,
    runfile=runfile,
    state=None,
    problem=None,
)
# Out:
# No file: C:\Users\Frank Heinrich\PycharmProjects\molgroups\examples\information_theory\entropy_gridsearch_sequential_execution\SANS\SphereSilica_Two_Datasets\T\sanssilica.py
# No state to reload.

# %%
fitobj.Interactor.fnRunMCMC(burn, steps, batch=False)
# Out:
# # steps: 100, # draws: 9000
# step 1 cost 5630.752(13)
#                              background0 ...|......   0.254862 in (0.01,0.8)
#                                   radius ....|.....    116.093 in (50,200)
#                                    scale |......... 0.000639159 in (0.0001,0.05)
#                                      sld .......|..    3.20778 in (1,4)
#                             sld_solvent0 .....|....     3.5187 in (-0.56,6.4)
#                              background1 ...|......   0.289459 in (0.01,0.8)
#                             sld_solvent1 ...|......    2.12755 in (-0.56,6.4)
#                              background2 ........|.   0.704961 in (0.01,0.8)
#                             sld_solvent2 |......... -0.0890165 in (-0.56,6.4)
# step 17 cost 746.241(13)
# step 33 cost 515.042(13)
# step 49 cost 466.665(13)
# step 65 cost 176.579(13)
# step 81 cost 138.438(13)
# step 97 cost 99.163(13)
# step 113 cost 86.788(13)
# step 128 cost 77.902(13)
# step 144 cost 27.934(13)
# step 160 cost 27.934(13)
# step 176 cost 27.934(13)
# step 191 cost 27.934(13)
# -- Model 0 sim0.dat
# .background = background0 = 0.160176 in [0.01,0.8]
# .radius = 87.4939 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.0150372 in [0.0001,0.05]
# .sld = 1.4796 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent0 = 1.16329 in [-0.56,6.4]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=32.257(23), nllf=4048.26]
# -- Model 1 sim1.dat
# .background = background1 = 0.297315 in [0.01,0.8]
# .radius = 87.4939 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.0150372 in [0.0001,0.05]
# .sld = 1.4796 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent1 = 1.51886 in [-0.56,6.4]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=20.628(23), nllf=2588.87]
# -- Model 2 sim2.dat
# .background = background2 = 0.513388 in [0.01,0.8]
# .radius = 87.4939 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.0150372 in [0.0001,0.05]
# .sld = 1.4796 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent2 = 0.843757 in [-0.56,6.4]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=17.470(19), nllf=2672.85]
# [overall chisq=23.304(13), nllf=9309.98]
# -- Model 0 sim0.dat
# .background = background0 = 0.160176 in [0.01,0.8]
# .radius = 87.4939 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.0150372 in [0.0001,0.05]
# .sld = 1.4796 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent0 = 1.16329 in [-0.56,6.4]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=32.257(23), nllf=4048.26]
# -- Model 1 sim1.dat
# .background = background1 = 0.297315 in [0.01,0.8]
# .radius = 87.4939 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.0150372 in [0.0001,0.05]
# .sld = 1.4796 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent1 = 1.51886 in [-0.56,6.4]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=20.628(23), nllf=2588.87]
# -- Model 2 sim2.dat
# .background = background2 = 0.513388 in [0.01,0.8]
# .radius = 87.4939 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.0150372 in [0.0001,0.05]
# .sld = 1.4796 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent2 = 0.843757 in [-0.56,6.4]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=17.470(19), nllf=2672.85]
# [overall chisq=23.304(13), nllf=9309.98]
#               Parameter       mean  median    best [   68% interval] [   95% interval]
#  1          background0  0.159(19)  0.1573  0.1602 [  0.146   0.172] [  0.124   0.199]
#  2               radius     89(31)    81.0    87.5 [     60     121] [     52     163]
#  3                scale 5.8(94)e-3  0.0020  0.0150 [  0.001   0.012] [  0.000   0.040]
#  4                  sld   2.46(90)   2.466   1.480 [   1.48    3.56] [   1.03    3.93]
#  5         sld_solvent0    2.4(15)   2.172   1.163 [   0.85    4.00] [  -0.18    5.61]
#  6          background1  0.295(24)   0.296   0.297 [   0.28    0.31] [   0.25    0.35]
#  7         sld_solvent1    2.5(12)   2.393   1.519 [   1.33    3.78] [   0.48    5.12]
#  8          background2  0.514(34)   0.510   0.513 [   0.49    0.54] [   0.45    0.61]
#  9         sld_solvent2    2.8(20)   2.870   0.844 [   0.67    5.31] [  -0.41    6.30]
#
# Statistics and plots based on 9768 samples (100.0% of total samples drawn)

# %%
# %%writefile simpar.dat
# background0 0.158961
# background1 0.295525
# background2 0.509283
# sld_solvent0 1.884
# sld_solvent1 3.362
# sld_solvent2 0.875
# scale 0.0013
# sld  3.098
# radius  90.563
# Out:
# Overwriting simpar.dat

# %%
# buffer is not subtracted but treated as a fitting parameter
sb = 0.0

configuration_dataset1 = [{'lambda': 6.0,
                            "sample_detector_distance": 100,
                            'source_sample_distance': 387.6,
                            'source_aperture_radius':5.08*0.5,
                            'sample_aperture_radius':1.27*0.5,
                            "beamstop_diameter": 10.16,
                            "neutron_flux": 9e5,
                            'time': 1200,
                            'beam_center_x': 25,
                            "dlambda_lambda":0.136,
                            "differential_cross_section_buffer": sb,
                            "cuvette_thickness": 0.1},
                          {'lambda': 6.0,
                           "sample_detector_distance": 400,
                           'source_sample_distance': 850.05,
                           'source_aperture_radius':5.08*0.5,
                           'sample_aperture_radius':1.27*0.5,
                           "beamstop_diameter": 10.16,
                           "neutron_flux": 2e5,
                           'time': 2400,
                           "dlambda_lambda":0.136,
                           "differential_cross_section_buffer": sb,
                           "cuvette_thickness": 0.1},
                         {'lambda': 6.0,
                          "sample_detector_distance": 1300,
                          'source_sample_distance': 1467,
                          'source_aperture_radius':5.08*0.5,
                          'sample_aperture_radius':1.27*0.5,
                          "dlambda_lambda":0.136,
                          "beamstop_diameter": 7.62,
                          "neutron_flux": 8e4,
                          'time': 3600,
                          "differential_cross_section_buffer": sb,
                          "cuvette_thickness": 0.1}]

configuration = [configuration_dataset1, copy.deepcopy(configuration_dataset1), copy.deepcopy(configuration_dataset1)]
fitobj.fnSimulateData(basefilename='sim.dat', liConfigurations=configuration, qmin=0.001, qmax=0.8, t_total=None)
# Out:
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = liData[i][1].append(newframe, ignore_index=True)
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = newframe.append(liData[i][1], ignore_index=True)
# background0 0.158961
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 1.884
# background1 0.295525
# sld_solvent1 3.362
# background2 0.509283
# sld_solvent2 0.875
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# background0 0.158961
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 1.884
# background1 0.295525
# sld_solvent1 3.362
# background2 0.509283
# sld_solvent2 0.875
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq

# %% [markdown]
# Compare original and simulated data.

# %%
import pandas

fig, ax = plt.subplots()

original0 = pandas.read_csv('bu/sim0.dat', sep=' ', skip_blank_lines=True,comment='#')
simdata0 = pandas.read_csv('sim0.dat', sep=' ', skip_blank_lines=True,comment='#')
original1 = pandas.read_csv('bu/sim1.dat', sep=' ', skip_blank_lines=True,comment='#')
simdata1 = pandas.read_csv('sim1.dat', sep=' ', skip_blank_lines=True,comment='#')
original2 = pandas.read_csv('bu/sim2.dat', sep=' ', skip_blank_lines=True,comment='#')
simdata2 = pandas.read_csv('sim2.dat', sep=' ', skip_blank_lines=True,comment='#')

ax.errorbar(simdata0['Q'], simdata0['I'], simdata0['dI'], label="sim0")
ax.errorbar(simdata1['Q'], simdata1['I'], simdata1['dI'], label="sim1")
ax.errorbar(simdata2['Q'], simdata2['I'], simdata2['dI'], label="sim2")
ax.errorbar(original0['Q'], original0['I'], original0['dI'], label="original0")
ax.errorbar(original1['Q'], original1['I'], original1['dI'], label="original1")
ax.errorbar(original2['Q'], original2['I'], original2['dI'], label="original2")

ax.legend(fontsize=8)
ax.set_ylabel("I", fontsize=10)
ax.set_yscale('log')
ax.set_xscale('log')
ax.minorticks_on()
ax.tick_params(which="both", direction="in", labelsize=10)
ax.tick_params(bottom=True, top=True, left=True, right=True, which="both")
ax.set_xlabel("$q$ (Å$^{-1}$)", fontsize=10)
ax.figure.set_size_inches(12.5, 7.5)
#ax.set_ylim(1e-2, 1e8)
plt.savefig(store + "/model_comparison.png", facecolor="white")
plt.show()

# %%
fig, ax = plt.subplots()

#i = 0
#while os.path.isfile('testdata.DAT'):
original = pandas.read_csv('bu/sim1.dat', sep=' ', skip_blank_lines=True,comment='#')
simdata = pandas.read_csv('sim1.dat', sep=' ', skip_blank_lines=True,comment='#')

ax.plot(simdata['Q'], (simdata['dI']/simdata['I']), label="sim")
ax.plot(original['Q'], (original['dI']/original['I']), label="original")

ax.legend(fontsize=8)
ax.set_ylabel("dI/I", fontsize=10)
ax.set_yscale('log')
ax.set_xscale('log')
ax.minorticks_on()
ax.tick_params(which="both", direction="in", labelsize=10)
ax.tick_params(bottom=True, top=True, left=True, right=True, which="both")
ax.set_xlabel("$q$ (Å$^{-1}$)", fontsize=10)
ax.figure.set_size_inches(12.5, 7.5)
#ax.set_ylim(0, 0.25)
plt.savefig(store + "/model_comparison.png", facecolor="white")
plt.show()

# %%
fig, ax = plt.subplots()

#i = 0
#while os.path.isfile('testdata.DAT'):
original = pandas.read_csv('bu/sim0.dat', sep=' ', skip_blank_lines=True,comment='#')
simdata = pandas.read_csv('sim0.dat', sep=' ', skip_blank_lines=True,comment='#')
ax.plot(simdata['Q'], (simdata['dQ']/simdata['Q']), label="sim")
ax.plot(original['Q'], (original['dQ']/original['Q']), label="original")

ax.legend(fontsize=8)
ax.set_ylabel("dQ/Q", fontsize=10)
ax.set_yscale('linear')
ax.set_xscale('log')
ax.minorticks_on()
ax.tick_params(which="both", direction="in", labelsize=10)
ax.tick_params(bottom=True, top=True, left=True, right=True, which="both")
ax.set_xlabel("$q$ (Å$^{-1}$)", fontsize=10)
ax.figure.set_size_inches(12.5, 7.5)
#ax.set_ylim(0, 0.01)
plt.savefig(store + "/model_comparison.png", facecolor="white")
plt.show()

# %% [markdown]
# # Experimental Optimization

# %% [markdown]
# * Entropypar.dat contains a list of all fit parameters with a designation, whether they are marginal (d) or nuisance (i) parameters. This is followed by the parameter name, the initial parameter value, and the fit boundaries.
# * Configuration parameters are given by a preceeding n x y, where x is the data set it applies to and y the configuration number. Specifying x,y = '*' makes this parameter apply to all configurations.
# * Any numbers x y following a fit parameter indicates that this paramter is used for this particular dataset/configuration to determine the background (incoherent crosssection). This typically applies to SLDs. The 'mode' argument for entropy.Entropy() then determines whether this is to be interpreted as an aqueous solvent or other. Sometimes, instead of subtracting an incoherent crosssection from the data, a background parameter is retained in the model. If any of the parameters is asigned an x = bi, this background will be se to the incoherent (isotropic) crosssection of the ith data set, instead of applying this value to the configuration. Fit boundaries for such backgrounds must be large enough to encompass all possible outcomes. They will not be updated dynamically.
# * If three more numbers are given, this designates that an information content search over this parameter is performed (start, stop, step).
# * A preceding f (fi or fd) at the beginning of the line indicates that the fit boundaries for such a search parameter are fixed (for example for volume fractions between 0 and 1), otherwise the fit boundary moves according to the varied parameter and the initally given fit boundaries.
# * Any theta offset currently needs to have an initial value of zero. Otherwise, refl1d will shift the q-values during data simulation with unexpected outcomes.
# * If an instrumental parameter is specified for one data set, the instrumental parameter needs to be specified for all other datasets, as well.
# * Data filenames are currently limited to sim.dat for a single file fit, or simx.dat, x = 0 ... n, for fits with multiple data sets

# %%
text = [
        'i b0 * background0 0.509283 0.0 2.0',
        'i b1 * background1 0.295525 0.0 2.0',
        'i b2 * background2 0.158961 0.0 2.0',
        'i 0 * sld_solvent0 2.0 1.98 2.02 -0.5 4.5 1.0',
        'i 1 * sld_solvent1 2.0 1.98 2.02 -0.5 4.5 1.0',
        'i 2 * sld_solvent2 2.0 1.98 2.02 -0.5 4.5 1.0',
        'i _ _ scale 0.0013 0.0001 0.005',
        'd _ _ sld  3.098 1.0 4.0',
        'i _ _ radius  90.563 50 200',
        'n * * lambda 6.00',
        'n * * differential_cross_section_buffer 0.0',
        'n * 0 sample_detector_distance 100',
        'n * 1 sample_detector_distance 400',
        'n * 2 sample_detector_distance 1300',
        'n * 0 source_sample_distance 387.6',
        'n * 1 source_sample_distance 850.05',
        'n * 2 source_sample_distance 1467',
        'n * 0 neutron_flux 9e5',
        'n * 1 neutron_flux 2e5',
        'n * 2 neutron_flux 8e4',
        'n * * source_aperture_radius 2.54',
        'n * * sample_aperture_radius 0.635',
        'n * * dlambda_lambda 0.136',
        'n * 0 beamstop_diameter 10.16',
        'n * 1 beamstop_diameter 10.16',
        'n * 2 beamstop_diameter 7.62',
        'n * 0 time 1200',
        'n * 1 time 2400',
        'n * 2 time 3600',
        'n * 0 beam_center_x 25.',
        'n * * cuvette_thickness 0.1'
        ]

f=open('entropypar.dat', 'w')
f.writelines(line + '\n' for line in text)
f.close()

# %%
# general fit setup
setupdir = setupdir
runfile = runfile
store = 'T'
fitsource = fitsource

# isotropic scattering background
# user-defined linear relationship between a SLD of the bulk solvent and the differential macroscopic scattering crosssection of the buffer
cross_section_background = {'slope':-0.1626, 'y_intercept': 0.7980}
mode = 'SANS_linear'

# particular entropy setup
burn = 5000
steps = 500
convergence = 2.0
miniter = 3
bClusterMode = False
bFetchMode = False
time = 2
bcalcsymmetric = True
upper_info_plotlevel = None
plotlimits_filename = ""
calcsingle = False

# setup batchscript for SLURM (if used)
script = ['#!/bin/bash\n',
          '#SBATCH --job-name=entro {mcmc_iteration}\n',
          '#SBATCH -A mc4s9np\n', '#SBATCH -p RM\n',
          '#SBATCH -t 0' + str(time) + ':00:00\n',
          '#SBATCH -N 4\n', '#SBATCH --ntasks-per-node 28\n',
          '\n',
          'set +x\n',
          'cd $SLURM_SUBMIT_DIR\n',
          '\n',
          'module load python/2.7.11_gcc\n',
          'export PYTHONPATH=/home/hoogerhe/bin/lib/python2.7/site-packages:/home/hoogerhe/src/bumps\n',
          '\n',
          'mpirun -np 112 python /home/hoogerhe/src/refl1d/bin/refl1d_cli.py {mcmc_dirname}/run.py --fit=dream --mpi --init=lhs --batch --pop=28 --time='
          + str(float(time) - 0.1) + ' --thin=20 --store={mcmc_dirname}/save --burn=' + str(burn)
          + ' --steps=' + str(steps) + '\n'
          ]
# script.append('cd '+dirname+'\n')

# %%
entr = entropy.Entropy(
    fitsource=fitsource,
    spath=setupdir,
    mcmcpath=store,
    runfile=runfile,
    mcmcburn=burn,
    mcmcsteps=steps,
    convergence=convergence,
    miniter=miniter,
    mode=mode,
    background_rule = cross_section_background,
    bClusterMode=bClusterMode,
    bFetchMode=bFetchMode,
    calc_symmetric=bcalcsymmetric,
    upper_info_plotlevel=upper_info_plotlevel,
    plotlimits_filename=plotlimits_filename,
    slurmscript=script,
    configuration = configuration
)

# %% [markdown]
# The optimization might be supplemented with qmin, qmax, and qrangefromfile attributes that are applied to all datasets. These are independent of qrange limitations imparted by individual SANS configurations. When the q-range is taken from file, the first dataset (0) will be used. In most cases, provide the default values given below.

# %%
qmin = 0.001
qmax = 0.8
qrangefromfile = False
t_total = None
entr.run_optimization(qmin=qmin, qmax=qmax, qrangefromfile=qrangefromfile, t_total=t_total)
# Out:
# No problem to reload.
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = liData[i][1].append(newframe, ignore_index=True)
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = newframe.append(liData[i][1], ignore_index=True)
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 -0.5
# background2 0.4728
# sld_solvent2 -0.5
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 -0.5
# background2 0.4728
# sld_solvent2 -0.5
# # steps: 500, # draws: 45000
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# -- Model 0 sim0.dat
# .background = background0 = 0.473069 in [0.01,0.8]
# .radius = 90.3838 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00134393 in [0.0001,0.05]
# .sld = 3.04252 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent0 = -0.509988 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.119(63), nllf=52.6111]
# -- Model 1 sim1.dat
# .background = background1 = 0.472351 in [0.01,0.8]
# .radius = 90.3838 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00134393 in [0.0001,0.05]
# .sld = 3.04252 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent1 = -0.504735 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.763(63), nllf=35.8582]
# -- Model 2 sim2.dat
# .background = background2 = 0.473367 in [0.01,0.8]
# .radius = 90.3838 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00134393 in [0.0001,0.05]
# .sld = 3.04252 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent2 = -0.498282 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.087(63), nllf=51.1028]
# [overall chisq=1.023(38), nllf=139.572]
# No problem to reload.
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = liData[i][1].append(newframe, ignore_index=True)
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = newframe.append(liData[i][1], ignore_index=True)
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 -0.5
# background2 0.4728
# sld_solvent2 0.5
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 -0.5
# background2 0.4728
# sld_solvent2 0.5
# # steps: 500, # draws: 45000
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# -- Model 0 sim0.dat
# .background = background0 = 0.472688 in [0.01,0.8]
# .radius = 90.8511 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00129395 in [0.0001,0.05]
# .sld = 3.08473 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent0 = -0.519169 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.137(63), nllf=53.4532]
# -- Model 1 sim1.dat
# .background = background1 = 0.472953 in [0.01,0.8]
# .radius = 90.8511 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00129395 in [0.0001,0.05]
# .sld = 3.08473 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent1 = -0.516672 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.165(63), nllf=54.7723]
# -- Model 2 sim2.dat
# .background = background2 = 0.472887 in [0.01,0.8]
# .radius = 90.8511 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00129395 in [0.0001,0.05]
# .sld = 3.08473 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent2 = 0.491964 in [0.48,0.52]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.039(63), nllf=48.8368]
# [overall chisq=1.151(38), nllf=157.062]
# No problem to reload.
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = liData[i][1].append(newframe, ignore_index=True)
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = newframe.append(liData[i][1], ignore_index=True)
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 -0.5
# background2 0.4728
# sld_solvent2 1.5
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 -0.5
# background2 0.4728
# sld_solvent2 1.5
# # steps: 500, # draws: 45000
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# -- Model 0 sim0.dat
# .background = background0 = 0.472625 in [0.01,0.8]
# .radius = 90.9054 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00130021 in [0.0001,0.05]
# .sld = 3.07494 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent0 = -0.515026 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.847(63), nllf=39.8128]
# -- Model 1 sim1.dat
# .background = background1 = 0.472926 in [0.01,0.8]
# .radius = 90.9054 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00130021 in [0.0001,0.05]
# .sld = 3.07494 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent1 = -0.508512 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.826(63), nllf=38.8036]
# -- Model 2 sim2.dat
# .background = background2 = 0.473527 in [0.01,0.8]
# .radius = 90.9054 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00130021 in [0.0001,0.05]
# .sld = 3.07494 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent2 = 1.49073 in [1.48,1.52]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.165(63), nllf=54.1907]
# [overall chisq=0.977(38), nllf=132.807]
# No problem to reload.
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = liData[i][1].append(newframe, ignore_index=True)
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = newframe.append(liData[i][1], ignore_index=True)
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 -0.5
# background2 0.4728
# sld_solvent2 2.5
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 -0.5
# background2 0.4728
# sld_solvent2 2.5
# # steps: 500, # draws: 45000
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# -- Model 0 sim0.dat
# .background = background0 = 0.47349 in [0.01,0.8]
# .radius = 90.6469 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00258938 in [0.0001,0.05]
# .sld = 2.04021 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent0 = -0.504959 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.029(63), nllf=48.362]
# -- Model 1 sim1.dat
# .background = background1 = 0.472863 in [0.01,0.8]
# .radius = 90.6469 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00258938 in [0.0001,0.05]
# .sld = 2.04021 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent1 = -0.513354 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.888(63), nllf=41.7134]
# -- Model 2 sim2.dat
# .background = background2 = 0.47265 in [0.01,0.8]
# .radius = 90.6469 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00258938 in [0.0001,0.05]
# .sld = 2.04021 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent2 = 2.5006 in [2.48,2.52]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.125(63), nllf=52.8538]
# [overall chisq=1.047(38), nllf=142.929]
# No problem to reload.
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = liData[i][1].append(newframe, ignore_index=True)
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = newframe.append(liData[i][1], ignore_index=True)
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 -0.5
# background2 0.4728
# sld_solvent2 3.5
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 -0.5
# background2 0.4728
# sld_solvent2 3.5
# # steps: 500, # draws: 45000
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# -- Model 0 sim0.dat
# .background = background0 = 0.473366 in [0.01,0.8]
# .radius = 90.6152 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00133752 in [0.0001,0.05]
# .sld = 3.07595 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent0 = -0.484259 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.048(63), nllf=49.26]
# -- Model 1 sim1.dat
# .background = background1 = 0.473051 in [0.01,0.8]
# .radius = 90.6152 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00133752 in [0.0001,0.05]
# .sld = 3.07595 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent1 = -0.4832 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.741(63), nllf=34.8314]
# -- Model 2 sim2.dat
# .background = background2 = 0.472896 in [0.01,0.8]
# .radius = 90.6152 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00133752 in [0.0001,0.05]
# .sld = 3.07595 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent2 = 3.50934 in [3.48,3.52]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.796(63), nllf=37.4074]
# [overall chisq=0.890(38), nllf=121.499]
# No problem to reload.
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = liData[i][1].append(newframe, ignore_index=True)
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = newframe.append(liData[i][1], ignore_index=True)
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 -0.5
# background2 0.4728
# sld_solvent2 4.5
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 -0.5
# background2 0.4728
# sld_solvent2 4.5
# # steps: 500, # draws: 45000
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# -- Model 0 sim0.dat
# .background = background0 = 0.47242 in [0.01,0.8]
# .radius = 90.5484 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00131037 in [0.0001,0.05]
# .sld = 3.09206 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent0 = -0.484146 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.964(63), nllf=45.2957]
# -- Model 1 sim1.dat
# .background = background1 = 0.472219 in [0.01,0.8]
# .radius = 90.5484 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00131037 in [0.0001,0.05]
# .sld = 3.09206 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent1 = -0.491777 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.889(63), nllf=41.7719]
# -- Model 2 sim2.dat
# .background = background2 = 0.472568 in [0.01,0.8]
# .radius = 90.5484 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00131037 in [0.0001,0.05]
# .sld = 3.09206 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent2 = 4.49411 in [4.48,4.52]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.813(63), nllf=38.2039]
# [overall chisq=0.918(38), nllf=125.272]
# No problem to reload.
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = liData[i][1].append(newframe, ignore_index=True)
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = newframe.append(liData[i][1], ignore_index=True)
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 0.5
# background2 0.4728
# sld_solvent2 -0.5
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 0.5
# background2 0.4728
# sld_solvent2 -0.5
# # steps: 500, # draws: 45000
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# -- Model 0 sim0.dat
# .background = background0 = 0.472615 in [0.01,0.8]
# .radius = 90.6409 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00135618 in [0.0001,0.05]
# .sld = 3.01637 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent0 = -0.500701 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.151(63), nllf=54.1202]
# -- Model 1 sim1.dat
# .background = background1 = 0.472176 in [0.01,0.8]
# .radius = 90.6409 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00135618 in [0.0001,0.05]
# .sld = 3.01637 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent1 = 0.489735 in [0.48,0.52]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.822(63), nllf=38.6403]
# -- Model 2 sim2.dat
# .background = background2 = 0.473211 in [0.01,0.8]
# .radius = 90.6409 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00135618 in [0.0001,0.05]
# .sld = 3.01637 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent2 = -0.509929 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.118(63), nllf=52.5408]
# [overall chisq=1.064(38), nllf=145.301]
# No problem to reload.
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = liData[i][1].append(newframe, ignore_index=True)
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = newframe.append(liData[i][1], ignore_index=True)
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 0.5
# background2 0.4728
# sld_solvent2 0.5
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 0.5
# background2 0.4728
# sld_solvent2 0.5
# # steps: 500, # draws: 45000
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# -- Model 0 sim0.dat
# .background = background0 = 0.472828 in [0.01,0.8]
# .radius = 90.5672 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00127555 in [0.0001,0.05]
# .sld = 3.11738 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent0 = -0.505781 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.952(63), nllf=44.7543]
# -- Model 1 sim1.dat
# .background = background1 = 0.473063 in [0.01,0.8]
# .radius = 90.5672 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00127555 in [0.0001,0.05]
# .sld = 3.11738 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent1 = 0.494322 in [0.48,0.52]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.118(63), nllf=52.5655]
# -- Model 2 sim2.dat
# .background = background2 = 0.472734 in [0.01,0.8]
# .radius = 90.5672 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00127555 in [0.0001,0.05]
# .sld = 3.11738 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent2 = 0.484403 in [0.48,0.52]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.111(63), nllf=52.2355]
# [overall chisq=1.096(38), nllf=149.555]
# No problem to reload.
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = liData[i][1].append(newframe, ignore_index=True)
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = newframe.append(liData[i][1], ignore_index=True)
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 0.5
# background2 0.4728
# sld_solvent2 1.5
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 0.5
# background2 0.4728
# sld_solvent2 1.5
# # steps: 500, # draws: 45000
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# -- Model 0 sim0.dat
# .background = background0 = 0.472912 in [0.01,0.8]
# .radius = 90.5005 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00125584 in [0.0001,0.05]
# .sld = 3.14355 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent0 = -0.5149 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.117(63), nllf=52.5044]
# -- Model 1 sim1.dat
# .background = background1 = 0.472868 in [0.01,0.8]
# .radius = 90.5005 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00125584 in [0.0001,0.05]
# .sld = 3.14355 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent1 = 0.495401 in [0.48,0.52]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.925(63), nllf=43.4669]
# -- Model 2 sim2.dat
# .background = background2 = 0.472283 in [0.01,0.8]
# .radius = 90.5005 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00125584 in [0.0001,0.05]
# .sld = 3.14355 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent2 = 1.51237 in [1.48,1.52]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.762(63), nllf=35.8181]
# [overall chisq=0.965(38), nllf=131.79]
# No problem to reload.
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = liData[i][1].append(newframe, ignore_index=True)
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = newframe.append(liData[i][1], ignore_index=True)
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 0.5
# background2 0.4728
# sld_solvent2 2.5
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 0.5
# background2 0.4728
# sld_solvent2 2.5
# # steps: 500, # draws: 45000
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# -- Model 0 sim0.dat
# .background = background0 = 0.473401 in [0.01,0.8]
# .radius = 90.6429 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.0012783 in [0.0001,0.05]
# .sld = 3.1083 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent0 = -0.518354 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.981(63), nllf=46.1155]
# -- Model 1 sim1.dat
# .background = background1 = 0.473031 in [0.01,0.8]
# .radius = 90.6429 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.0012783 in [0.0001,0.05]
# .sld = 3.1083 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent1 = 0.484484 in [0.48,0.52]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.083(63), nllf=50.8946]
# -- Model 2 sim2.dat
# .background = background2 = 0.472707 in [0.01,0.8]
# .radius = 90.6429 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.0012783 in [0.0001,0.05]
# .sld = 3.1083 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent2 = 2.501 in [2.48,2.52]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.368(63), nllf=64.2844]
# [overall chisq=1.182(38), nllf=161.295]
# No problem to reload.
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = liData[i][1].append(newframe, ignore_index=True)
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = newframe.append(liData[i][1], ignore_index=True)
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 0.5
# background2 0.4728
# sld_solvent2 3.5
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 0.5
# background2 0.4728
# sld_solvent2 3.5
# # steps: 500, # draws: 45000
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# -- Model 0 sim0.dat
# .background = background0 = 0.473216 in [0.01,0.8]
# .radius = 90.6657 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00125639 in [0.0001,0.05]
# .sld = 3.12815 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent0 = -0.51056 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.930(63), nllf=43.694]
# -- Model 1 sim1.dat
# .background = background1 = 0.473153 in [0.01,0.8]
# .radius = 90.6657 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00125639 in [0.0001,0.05]
# .sld = 3.12815 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent1 = 0.497045 in [0.48,0.52]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.881(63), nllf=41.4036]
# -- Model 2 sim2.dat
# .background = background2 = 0.473127 in [0.01,0.8]
# .radius = 90.6657 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00125639 in [0.0001,0.05]
# .sld = 3.12815 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent2 = 3.51112 in [3.48,3.52]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.158(63), nllf=54.4301]
# [overall chisq=1.022(38), nllf=139.528]
# No problem to reload.
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = liData[i][1].append(newframe, ignore_index=True)
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = newframe.append(liData[i][1], ignore_index=True)
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 0.5
# background2 0.4728
# sld_solvent2 4.5
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 0.5
# background2 0.4728
# sld_solvent2 4.5
# # steps: 500, # draws: 45000
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# -- Model 0 sim0.dat
# .background = background0 = 0.47247 in [0.01,0.8]
# .radius = 90.414 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00130211 in [0.0001,0.05]
# .sld = 3.09727 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent0 = -0.498664 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.018(63), nllf=47.8493]
# -- Model 1 sim1.dat
# .background = background1 = 0.472212 in [0.01,0.8]
# .radius = 90.414 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00130211 in [0.0001,0.05]
# .sld = 3.09727 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent1 = 0.484262 in [0.48,0.52]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.813(63), nllf=38.2039]
# -- Model 2 sim2.dat
# .background = background2 = 0.473164 in [0.01,0.8]
# .radius = 90.414 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00130211 in [0.0001,0.05]
# .sld = 3.09727 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent2 = 4.51387 in [4.48,4.52]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.130(63), nllf=53.1025]
# [overall chisq=1.019(38), nllf=139.156]
# No problem to reload.
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = liData[i][1].append(newframe, ignore_index=True)
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = newframe.append(liData[i][1], ignore_index=True)
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 1.5
# background2 0.4728
# sld_solvent2 -0.5
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 1.5
# background2 0.4728
# sld_solvent2 -0.5
# # steps: 500, # draws: 45000
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# -- Model 0 sim0.dat
# .background = background0 = 0.472315 in [0.01,0.8]
# .radius = 90.4965 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00134864 in [0.0001,0.05]
# .sld = 3.03683 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent0 = -0.499241 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.697(63), nllf=32.7596]
# -- Model 1 sim1.dat
# .background = background1 = 0.47246 in [0.01,0.8]
# .radius = 90.4965 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00134864 in [0.0001,0.05]
# .sld = 3.03683 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent1 = 1.4838 in [1.48,1.52]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.369(63), nllf=64.3475]
# -- Model 2 sim2.dat
# .background = background2 = 0.472532 in [0.01,0.8]
# .radius = 90.4965 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00134864 in [0.0001,0.05]
# .sld = 3.03683 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent2 = -0.484513 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.126(63), nllf=52.9033]
# [overall chisq=1.099(38), nllf=150.01]
# No problem to reload.
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = liData[i][1].append(newframe, ignore_index=True)
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = newframe.append(liData[i][1], ignore_index=True)
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 1.5
# background2 0.4728
# sld_solvent2 0.5
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 1.5
# background2 0.4728
# sld_solvent2 0.5
# # steps: 500, # draws: 45000
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# -- Model 0 sim0.dat
# .background = background0 = 0.473499 in [0.01,0.8]
# .radius = 90.5101 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.0013015 in [0.0001,0.05]
# .sld = 3.11185 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent0 = -0.485827 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.306(63), nllf=61.3631]
# -- Model 1 sim1.dat
# .background = background1 = 0.473277 in [0.01,0.8]
# .radius = 90.5101 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.0013015 in [0.0001,0.05]
# .sld = 3.11185 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent1 = 1.5106 in [1.48,1.52]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.875(63), nllf=40.6909]
# -- Model 2 sim2.dat
# .background = background2 = 0.473081 in [0.01,0.8]
# .radius = 90.5101 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.0013015 in [0.0001,0.05]
# .sld = 3.11185 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent2 = 0.507207 in [0.48,0.52]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.937(63), nllf=44.0207]
# [overall chisq=1.074(38), nllf=146.075]
# No problem to reload.
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = liData[i][1].append(newframe, ignore_index=True)
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = newframe.append(liData[i][1], ignore_index=True)
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 1.5
# background2 0.4728
# sld_solvent2 1.5
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 1.5
# background2 0.4728
# sld_solvent2 1.5
# # steps: 500, # draws: 45000
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# -- Model 0 sim0.dat
# .background = background0 = 0.473142 in [0.01,0.8]
# .radius = 90.5958 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00123945 in [0.0001,0.05]
# .sld = 3.15881 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent0 = -0.515086 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.801(63), nllf=37.663]
# -- Model 1 sim1.dat
# .background = background1 = 0.472378 in [0.01,0.8]
# .radius = 90.5958 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00123945 in [0.0001,0.05]
# .sld = 3.15881 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent1 = 1.51076 in [1.48,1.52]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.882(63), nllf=41.4711]
# -- Model 2 sim2.dat
# .background = background2 = 0.473122 in [0.01,0.8]
# .radius = 90.5958 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00123945 in [0.0001,0.05]
# .sld = 3.15881 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent2 = 1.51921 in [1.48,1.52]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.953(63), nllf=44.775]
# [overall chisq=0.908(38), nllf=123.909]
# No problem to reload.
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = liData[i][1].append(newframe, ignore_index=True)
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = newframe.append(liData[i][1], ignore_index=True)
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 1.5
# background2 0.4728
# sld_solvent2 2.5
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 1.5
# background2 0.4728
# sld_solvent2 2.5
# # steps: 500, # draws: 45000
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# -- Model 0 sim0.dat
# .background = background0 = 0.473431 in [0.01,0.8]
# .radius = 90.5072 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00132235 in [0.0001,0.05]
# .sld = 3.07089 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent0 = -0.498705 in [-0.52,-0.48]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.183(63), nllf=55.5913]
# -- Model 1 sim1.dat
# .background = background1 = 0.47269 in [0.01,0.8]
# .radius = 90.5072 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00132235 in [0.0001,0.05]
# .sld = 3.07089 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent1 = 1.49189 in [1.48,1.52]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=0.755(63), nllf=35.4786]
# -- Model 2 sim2.dat
# .background = background2 = 0.472979 in [0.01,0.8]
# .radius = 90.5072 in [50,200]
# .radius_pd = 0
# .radius_pd_n = 35
# .radius_pd_nsigma = 3
# .scale = 0.00132235 in [0.0001,0.05]
# .sld = 3.07089 in [1,4]
# .sld_M0 = 0
# .sld_mphi = 0
# .sld_mtheta = 0
# .sld_solvent = sld_solvent2 = 2.49034 in [2.48,2.52]
# .sld_solvent_M0 = 0
# .sld_solvent_mphi = 0
# .sld_solvent_mtheta = 0
# .up_angle = 0
# .up_frac_f = 0
# .up_frac_i = 0
# .up_phi = 0
#
# [chisq=1.080(63), nllf=50.2143]
# [overall chisq=1.039(38), nllf=141.284]
# No problem to reload.
# C:\Users\Frank Heinrich\anaconda3\envs\Python38\lib\site-packages\sasmodels\bumps_model.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   return (self.theory() - self.Iq) / self.dIq
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:43: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = liData[i][1].append(newframe, ignore_index=True)
# C:\Users\Frank Heinrich\PycharmProjects\molgroups\molgroups\support\api_base.py:55: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   liData[i][1] = newframe.append(liData[i][1], ignore_index=True)
# background0 0.4728
# radius 90.563
# scale 0.0013
# sld 3.098
# sld_solvent0 -0.5
# background1 0.4728
# sld_solvent1 1.5
# ...
#    2841     sfig.draw(renderer)
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\axes\_base.py:3055, in _AxesBase.draw(self, renderer)
#    3052     for spine in self.spines.values():
#    3053         artists.remove(spine)
# -> 3055 self._update_title_position(renderer)
#    3057 if not self.axison:
#    3058     for _axis in self._get_axis_list():
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\axes\_base.py:2991, in _AxesBase._update_title_position(self, renderer)
#    2988 for ax in axs:
#    2989     if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    2990             or ax.xaxis.get_label_position() == 'top'):
# -> 2991         bb = ax.xaxis.get_tightbbox(renderer)
#    2992     else:
#    2993         if 'outline' in ax.spines:
#    2994             # Special case for colorbars:
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\axis.py:1105, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1101     return
#    1103 ticks_to_draw = self._update_ticks()
# -> 1105 self._update_label_position(renderer)
#    1107 # go back to just this axis's tick labels
#    1108 ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(
#    1109             ticks_to_draw, renderer)
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\axis.py:2089, in XAxis._update_label_position(self, renderer)
#    2087 try:
#    2088     spine = self.axes.spines['bottom']
# -> 2089     spinebbox = spine.get_window_extent()
#    2090 except KeyError:
#    2091     # use axes if spine doesn't exist
#    2092     spinebbox = self.axes.bbox
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\spines.py:153, in Spine.get_window_extent(self, renderer)
#     151 # make sure the location is updated so that transforms etc are correct:
#     152 self._adjust_location()
# --> 153 bb = super().get_window_extent(renderer=renderer)
#     154 if self.axis is None:
#     155     return bb
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\patches.py:629, in Patch.get_window_extent(self, renderer)
#     628 def get_window_extent(self, renderer=None):
# --> 629     return self.get_path().get_extents(self.get_transform())
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\path.py:614, in Path.get_extents(self, transform, **kwargs)
#     612 from .transforms import Bbox
#     613 if transform is not None:
# --> 614     self = transform.transform_path(self)
#     615 if self.codes is None:
#     616     xys = self.vertices
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\transforms.py:1608, in Transform.transform_path(self, path)
#    1601 def transform_path(self, path):
#    1602     """
#    1603     Apply the transform to `.Path` *path*, returning a new `.Path`.
#    1604
#    1605     In some cases, this transform may insert curves into the path
#    1606     that began as line segments.
#    1607     """
# -> 1608     return self.transform_path_affine(self.transform_path_non_affine(path))
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\transforms.py:1618, in Transform.transform_path_affine(self, path)
#    1610 def transform_path_affine(self, path):
#    1611     """
#    1612     Apply the affine part of this transform to `.Path` *path*, returning a
#    1613     new `.Path`.
#    (...)
#    1616     ``transform_path_affine(transform_path_non_affine(values))``.
#    1617     """
# -> 1618     return self.get_affine().transform_path_affine(path)
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\transforms.py:2264, in BlendedGenericTransform.get_affine(self)
#    2262     self._affine = self._x.get_affine()
#    2263 else:
# -> 2264     x_mtx = self._x.get_affine().get_matrix()
#    2265     y_mtx = self._y.get_affine().get_matrix()
#    2266     # We already know the transforms are separable, so we can skip
#    2267     # setting b and c to zero.
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\transforms.py:2446, in CompositeGenericTransform.get_affine(self)
#    2444     return self._b.get_affine()
#    2445 else:
# -> 2446     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2447                            self._a.get_affine().get_matrix()))
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\transforms.py:2446, in CompositeGenericTransform.get_affine(self)
#    2444     return self._b.get_affine()
#    2445 else:
# -> 2446     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2447                            self._a.get_affine().get_matrix()))
#
# File <__array_function__ internals>:5, in dot(*args, **kwargs)
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x000002E91AE32A60> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib_inline\backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~\anaconda3\envs\Python38\lib\site-packages\IPython\core\display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~\anaconda3\envs\Python38\lib\site-packages\IPython\core\formatters.py:178, in DisplayFormatter.format(self, obj, include, exclude)
#     176 md = None
#     177 try:
# --> 178     data = formatter(obj)
#     179 except:
#     180     # FIXME: log the exception
#     181     raise
#
# File ~\anaconda3\envs\Python38\lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~\anaconda3\envs\Python38\lib\site-packages\IPython\core\formatters.py:222, in catch_format_error(method, self, *args, **kwargs)
#     220 """show traceback on failed format call"""
#     221 try:
# --> 222     r = method(self, *args, **kwargs)
#     223 except NotImplementedError:
#     224     # don't warn on NotImplementedErrors
#     225     return self._check_return(None, args[0])
#
# File ~\anaconda3\envs\Python38\lib\site-packages\IPython\core\formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File ~\anaconda3\envs\Python38\lib\site-packages\IPython\core\pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\_api\deprecation.py:415, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     405     deprecation_addendum = (
#     406         f"If any parameter follows {name!r}, they should be passed as "
#     407         f"keyword, not positionally.")
#     408     warn_deprecated(
#     409         since,
#     410         name=repr(name),
#    (...)
#     413                  else deprecation_addendum,
#     414         **kwargs)
# --> 415 return func(*inner_args, **inner_kwargs)
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\backends\backend_agg.py:540, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     490 @_check_savefig_extra_args
#     491 @_api.delete_parameter("3.5", "args")
#     492 def print_png(self, filename_or_obj, *args,
#     493               metadata=None, pil_kwargs=None):
#     494     """
#     495     Write the figure to a PNG file.
#     496
#    (...)
#     538         *metadata*, including the default 'Software' key.
#     539     """
# --> 540     FigureCanvasAgg.draw(self)
#     541     mpl.image.imsave(
#     542         filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     543         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\backends\backend_agg.py:436, in FigureCanvasAgg.draw(self)
#     432 # Acquire a lock on the shared font cache.
#     433 with RendererAgg.lock, \
#     434      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435       else nullcontext()):
# --> 436     self.figure.draw(self.renderer)
#     437     # A GUI class may be need to update a window using this draw, so
#     438     # don't forget to call the superclass.
#     439     super().draw()
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\artist.py:73, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      71 @wraps(draw)
#      72 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73     result = draw(artist, renderer, *args, **kwargs)
#      74     if renderer._rasterizing:
#      75         renderer.stop_rasterizing()
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\figure.py:2837, in Figure.draw(self, renderer)
#    2834         # ValueError can occur when resizing a window.
#    2836 self.patch.draw(renderer)
# -> 2837 mimage._draw_list_compositing_images(
#    2838     renderer, self, artists, self.suppressComposite)
#    2840 for sfig in self.subfigs:
#    2841     sfig.draw(renderer)
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\axes\_base.py:3091, in _AxesBase.draw(self, renderer)
#    3088         a.draw(renderer)
#    3089     renderer.stop_rasterizing()
# -> 3091 mimage._draw_list_compositing_images(
#    3092     renderer, self, artists, self.figure.suppressComposite)
#    3094 renderer.close_group('axes')
#    3095 self.stale = False
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\collections.py:2200, in QuadMesh.draw(self, renderer)
#    2196     renderer.draw_gouraud_triangles(
#    2197         gc, triangles, colors, transform.frozen())
#    2198 else:
#    2199     renderer.draw_quad_mesh(
# -> 2200         gc, transform.frozen(),
#    2201         coordinates.shape[1] - 1, coordinates.shape[0] - 1,
#    2202         coordinates, offsets, transOffset,
#    2203         # Backends expect flattened rgba arrays (n*m, 4) for fc and ec
#    2204         self.get_facecolor().reshape((-1, 4)),
#    2205         self._antialiased, self.get_edgecolors().reshape((-1, 4)))
#    2206 gc.restore()
#    2207 renderer.close_group(self.__class__.__name__)
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\transforms.py:2375, in CompositeGenericTransform.frozen(self)
#    2371 def frozen(self):
#    2372     # docstring inherited
#    2373     self._invalid = 0
#    2374     frozen = composite_transform_factory(
# -> 2375         self._a.frozen(), self._b.frozen())
#    2376     if not isinstance(frozen, CompositeGenericTransform):
#    2377         return frozen.frozen()
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\transforms.py:2377, in CompositeGenericTransform.frozen(self)
#    2374 frozen = composite_transform_factory(
#    2375     self._a.frozen(), self._b.frozen())
#    2376 if not isinstance(frozen, CompositeGenericTransform):
# -> 2377     return frozen.frozen()
#    2378 return frozen
#
# File ~\anaconda3\envs\Python38\lib\site-packages\matplotlib\transforms.py:1848, in Affine2DBase.frozen(self)
#    1846 def frozen(self):
#    1847     # docstring inherited
# -> 1848     return Affine2D(self.get_matrix().copy())
#
# KeyboardInterrupt:

# %%
entr.plot_results()
