# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt
import os
import shutil

from molgroups.support import molstat

print(os.getcwd())
# Out:
# /Users/frank/Dropbox/My Mac (PN115993.campus.nist.gov)/Documents/programming/molgroups/examples/information_theory/simulate_data/garefl

# %% [markdown]
# # Create Short Example Fit

# %%
#!refl1d run.py --fit=dream --store=T --init=lhs --parallel --burn=4 --steps=4 --overwrite

store = "T"
setupdir = os.getcwd()
runfile = "run"
fitsource = "garefl"

if os.path.isdir(os.path.join(setupdir, store)):
    shutil.rmtree(os.path.join(setupdir, store))

fitobj = molstat.CMolStat(
    fitsource=fitsource,
    spath=setupdir,
    mcmcpath=store,
    runfile=runfile,
    state=None,
    problem=None,
)

fitobj.Interactor.fnRunMCMC(burn=50, steps=50)
# Out:
# No file: /Users/frank/Dropbox/My Mac (PN115993.campus.nist.gov)/Documents/programming/molgroups/examples/information_theory/simulate_data/garefl/T/run.py
# No state to reload.
# g++  -g -O2 -Wall  -fPIC -DUSE_DOUBLE -DReal=double -DHAVE_CONFIG_H -I/Users/frank/danse/refl1d/garefl/boxmin -I/Users/frank/danse/refl1d/garefl/model1d -I/Users/frank/danse/refl1d/garefl/src -c setup.cc -o setup.o
# In file included from setup.cc:9:
# ./molgroups.cc:79:25: warning: variable 'dUpperLimit' set but not used [-Wunused-but-set-variable]
#     double dLowerLimit, dUpperLimit, d, dmirror, dAreaInc, dnSLDInc;
#                         ^
# ./molgroups.cc:3085:12: warning: variable 'V_tg' set but not used [-Wunused-but-set-variable]
#     double V_tg;
#            ^
# ./molgroups.cc:3088:17: warning: variable 'V_EO' set but not used [-Wunused-but-set-variable]
#     double l_EO,V_EO;
#                 ^
# ./molgroups.cc:3091:18: warning: variable 'V_bME' set but not used [-Wunused-but-set-variable]
#     double l_bME,V_bME;
#                  ^
# ./molgroups.cc:3091:12: warning: variable 'l_bME' set but not used [-Wunused-but-set-variable]
#     double l_bME,V_bME;
#            ^
# ./molgroups.cc:3531:17: warning: variable 'V_EO' set but not used [-Wunused-but-set-variable]
#     double l_EO,V_EO;
#                 ^
# ./molgroups.cc:3528:12: warning: variable 'V_tg' set but not used [-Wunused-but-set-variable]
#     double V_tg;
#            ^
# ./molgroups.cc:3534:18: warning: variable 'V_bME' set but not used [-Wunused-but-set-variable]
#     double l_bME,V_bME;
#                  ^
# ./molgroups.cc:3534:12: warning: variable 'l_bME' set but not used [-Wunused-but-set-variable]
#     double l_bME,V_bME;
#            ^
# ./molgroups.cc:3887:12: warning: variable 'V_tg' set but not used [-Wunused-but-set-variable]
#     double V_tg;
#            ^
# ./molgroups.cc:3893:12: warning: variable 'l_bME' set but not used [-Wunused-but-set-variable]
#     double l_bME,V_bME;
#            ^
# ./molgroups.cc:3893:18: warning: variable 'V_bME' set but not used [-Wunused-but-set-variable]
#     double l_bME,V_bME;
#                  ^
# ./molgroups.cc:3890:17: warning: variable 'V_EO' set but not used [-Wunused-but-set-variable]
#     double l_EO,V_EO;
#                 ^
# setup.cc:176:9: warning: unused variable 'iPeaked' [-Wunused-variable]
#     int iPeaked,iMaxPeak, i, k, i2, wait;
#         ^
# setup.cc:176:17: warning: unused variable 'iMaxPeak' [-Wunused-variable]
#     int iPeaked,iMaxPeak, i, k, i2, wait;
#                 ^
# setup.cc:176:33: warning: unused variable 'i2' [-Wunused-variable]
#     int iPeaked,iMaxPeak, i, k, i2, wait;
#                                 ^
# setup.cc:176:37: warning: unused variable 'wait' [-Wunused-variable]
#     int iPeaked,iMaxPeak, i, k, i2, wait;
#                                     ^
# setup.cc:177:14: warning: unused variable 'pars' [-Wunused-variable]
#     fitpars *pars = &fit[0].pars;
#              ^
# 18 warnings generated.
# cd /Users/frank/danse/refl1d/garefl/boxmin && /Applications/Xcode.app/Contents/Developer/usr/bin/make
# make[1]: Nothing to be done for `all'.
# cd /Users/frank/danse/refl1d/garefl/model1d && /Applications/Xcode.app/Contents/Developer/usr/bin/make
# make[1]: Nothing to be done for `all'.
# cd /Users/frank/danse/refl1d/garefl/src && /Applications/Xcode.app/Contents/Developer/usr/bin/make
# make[1]: Nothing to be done for `all'.
# g++    -fPIC -o fit setup.o /Users/frank/danse/refl1d/garefl/src/ga_simul.o /Users/frank/danse/refl1d/garefl/src/ga.o -L/Users/frank/danse/refl1d/garefl/model1d -lrefl -L/Users/frank/danse/refl1d/garefl/boxmin -lboxmin  -lm
# g++ -shared -o model.so setup.o /Users/frank/danse/refl1d/garefl/src/refl1d.o -L/Users/frank/danse/refl1d/garefl/model1d -lrefl  -lm
# g++  -g -O2 -Wall  -fPIC -DUSE_DOUBLE -DReal=double -DHAVE_CONFIG_H -I/Users/frank/danse/refl1d/garefl/boxmin -I/Users/frank/danse/refl1d/garefl/model1d -I/Users/frank/danse/refl1d/garefl/src -c setup.cc -o setup.o
# In file included from setup.cc:9:
# ./molgroups.cc:79:25: warning: variable 'dUpperLimit' set but not used [-Wunused-but-set-variable]
#     double dLowerLimit, dUpperLimit, d, dmirror, dAreaInc, dnSLDInc;
#                         ^
# ./molgroups.cc:3085:12: warning: variable 'V_tg' set but not used [-Wunused-but-set-variable]
#     double V_tg;
#            ^
# ./molgroups.cc:3088:17: warning: variable 'V_EO' set but not used [-Wunused-but-set-variable]
#     double l_EO,V_EO;
#                 ^
# ./molgroups.cc:3091:18: warning: variable 'V_bME' set but not used [-Wunused-but-set-variable]
#     double l_bME,V_bME;
#                  ^
# ./molgroups.cc:3091:12: warning: variable 'l_bME' set but not used [-Wunused-but-set-variable]
#     double l_bME,V_bME;
#            ^
# ./molgroups.cc:3531:17: warning: variable 'V_EO' set but not used [-Wunused-but-set-variable]
#     double l_EO,V_EO;
#                 ^
# ./molgroups.cc:3528:12: warning: variable 'V_tg' set but not used [-Wunused-but-set-variable]
#     double V_tg;
#            ^
# ./molgroups.cc:3534:18: warning: variable 'V_bME' set but not used [-Wunused-but-set-variable]
#     double l_bME,V_bME;
#                  ^
# ./molgroups.cc:3534:12: warning: variable 'l_bME' set but not used [-Wunused-but-set-variable]
#     double l_bME,V_bME;
#            ^
# ./molgroups.cc:3887:12: warning: variable 'V_tg' set but not used [-Wunused-but-set-variable]
#     double V_tg;
#            ^
# ./molgroups.cc:3893:12: warning: variable 'l_bME' set but not used [-Wunused-but-set-variable]
#     double l_bME,V_bME;
#            ^
# ./molgroups.cc:3893:18: warning: variable 'V_bME' set but not used [-Wunused-but-set-variable]
#     double l_bME,V_bME;
#                  ^
# ./molgroups.cc:3890:17: warning: variable 'V_EO' set but not used [-Wunused-but-set-variable]
#     double l_EO,V_EO;
#                 ^
# setup.cc:176:9: warning: unused variable 'iPeaked' [-Wunused-variable]
#     int iPeaked,iMaxPeak, i, k, i2, wait;
#         ^
# setup.cc:176:17: warning: unused variable 'iMaxPeak' [-Wunused-variable]
#     int iPeaked,iMaxPeak, i, k, i2, wait;
#                 ^
# setup.cc:176:33: warning: unused variable 'i2' [-Wunused-variable]
#     int iPeaked,iMaxPeak, i, k, i2, wait;
#                                 ^
# setup.cc:176:37: warning: unused variable 'wait' [-Wunused-variable]
#     int iPeaked,iMaxPeak, i, k, i2, wait;
#                                     ^
# setup.cc:177:14: warning: unused variable 'pars' [-Wunused-variable]
#     fitpars *pars = &fit[0].pars;
#              ^
# 18 warnings generated.
# cd /Users/frank/danse/refl1d/garefl/boxmin && /Applications/Xcode.app/Contents/Developer/usr/bin/make
# make[1]: Nothing to be done for `all'.
# cd /Users/frank/danse/refl1d/garefl/model1d && /Applications/Xcode.app/Contents/Developer/usr/bin/make
# make[1]: Nothing to be done for `all'.
# cd /Users/frank/danse/refl1d/garefl/src && /Applications/Xcode.app/Contents/Developer/usr/bin/make
# make[1]: Nothing to be done for `all'.
# g++    -fPIC -o fit setup.o /Users/frank/danse/refl1d/garefl/src/ga_simul.o /Users/frank/danse/refl1d/garefl/src/ga.o -L/Users/frank/danse/refl1d/garefl/model1d -lrefl -L/Users/frank/danse/refl1d/garefl/boxmin -lboxmin  -lm
# g++ -shared -o model.so setup.o /Users/frank/danse/refl1d/garefl/src/refl1d.o -L/Users/frank/danse/refl1d/garefl/model1d -lrefl  -lm
# # steps: 50, # draws: 25500
# step 1 cost 6.07(14)
#                                  d_oxide ......|...    27.1386 in (5,40)
#                                     d_Cr |.........    12.0045 in (10,60)
#                                   d_gold ...|......    140.085 in (120,180)
#                                 l_tether |.........    6.15699 in (6,18)
#                                 l_lipid1 ....|.....    14.3227 in (8,22)
#                                 l_lipid2 ..|.......    10.4945 in (7,20)
#                        dl_lipid_gcrinse1 .......|..    0.12527 in (-3,1)
#                                nf_tether ........|.   0.914454 in (0.4,1)
#                              mult_tether |.........   0.110863 in (0.1,4)
#                               vf_bilayer .........|   0.999771 in (0.8,1)
#                      vf_bilayer_gcrinse1 .........|   0.999113 in (0.6,1)
#                          fraction_rinse2 .........|    0.96389 in (0.5,1)
#                                   dp_on0 |.........   -5.08019 in (-7,15)
#                                   dp_on1 ..|.......   -3.04115 in (-7,7)
#                                   dp_on2 ....|.....  -0.795635 in (-7,7)
#                                   dp_on3 .|........   -4.21816 in (-7,7)
#                                   dp_on4 .|........   -5.39244 in (-7,7)
#                                   dp_on5 ......|...    2.07166 in (-7,7)
#                                   dp_on6 ..|.......   -3.65269 in (-7,7)
#                                   dp_on7 ........|.    5.20461 in (-7,7)
#                                   dp_on8 .......|..    3.05368 in (-7,7)
#                                   vf_on1 |......... -0.000388032 in (-0.001,0.1)
#                                   vf_on2 |.........  0.0243012 in (-0.001,0.4)
#                                   vf_on3 |.........  0.0392614 in (-0.001,0.5)
#                                   vf_on4 |......... 0.00276528 in (-0.001,0.4)
#                                   vf_on5 .|........  0.0771454 in (-0.001,0.4)
#                                   vf_on6 .|........   0.057724 in (-0.001,0.4)
#                                   vf_on7 |.........   0.013405 in (-0.001,0.4)
#                                frac2_on0 .........|   0.994131 in (0,1)
#                                frac2_on1 .|........   0.131596 in (0,1)
#                                frac2_on2 .|........   0.198737 in (0,1)
#                                frac2_on3 ....|.....    0.46263 in (0,1)
#                                frac2_on4 ..|.......    0.20962 in (0,1)
#                                frac2_on5 .|........   0.119255 in (0,1)
#                                frac2_on6 |.........  0.0251001 in (0,1)
#                                frac2_on7 |.........  0.0991725 in (0,1)
#                                 rho_SiOx ..|.......    3.33859 in (3.2,3.8)
#                                   rho_Cr .......|..     3.8062 in (2.7,4.25)
#                                   rho_Au ...|......    4.43664 in (4.2,4.8)
#                               rho_solv_0 .........|    6.28762 in (5.8,6.34)
#                               rho_solv_1 |.........  -0.534264 in (-0.56,-0.1)
#                               rho_solv_2 |.........  -0.557353 in (-0.56,-0.1)
#                               rho_solv_3 ........|.       6.28 in (5.8,6.34)
#                             global_rough .|........    3.83535 in (1,25)
#                              rough_cr_au .........|    9.15352 in (1,10)
#                                    sigma ........|.    4.46337 in (2,5)
#                             thetaoffset0 ....|..... -0.00133542 in (-0.01,0.01)
#                             background_0 ...|......   -7.61277 in (-9,-5)
#                             background_1 ........|.   -5.66373 in (-9,-5)
#                             background_2 ........|.   -5.64104 in (-9,-5)
#                             background_3 ...|......   -7.59052 in (-9,-5)
# step 2 cost 6.07(14)
# step 3 cost 6.07(14)
# step 4 cost 6.07(14)
# step 5 cost 6.07(14)
# step 6 cost 6.07(14)
# step 7 cost 6.07(14)
# step 8 cost 6.07(14)
# step 9 cost 6.07(14)
# step 10 cost 6.07(14)
# step 11 cost 6.07(14)
# step 12 cost 6.07(14)
# step 13 cost 6.07(14)
# step 14 cost 6.07(14)
#                                  d_oxide ......|...    27.1386 in (5,40)
#                                     d_Cr |.........    12.0045 in (10,60)
#                                   d_gold ...|......    140.085 in (120,180)
#                                 l_tether |.........    6.15699 in (6,18)
#                                 l_lipid1 ....|.....    14.3227 in (8,22)
#                                 l_lipid2 ..|.......    10.4945 in (7,20)
#                        dl_lipid_gcrinse1 .......|..    0.12527 in (-3,1)
#                                nf_tether ........|.   0.914454 in (0.4,1)
#                              mult_tether |.........   0.110863 in (0.1,4)
#                               vf_bilayer .........|   0.999771 in (0.8,1)
#                      vf_bilayer_gcrinse1 .........|   0.999113 in (0.6,1)
#                          fraction_rinse2 .........|    0.96389 in (0.5,1)
#                                   dp_on0 |.........   -5.08019 in (-7,15)
#                                   dp_on1 ..|.......   -3.04115 in (-7,7)
#                                   dp_on2 ....|.....  -0.795635 in (-7,7)
#                                   dp_on3 .|........   -4.21816 in (-7,7)
#                                   dp_on4 .|........   -5.39244 in (-7,7)
#                                   dp_on5 ......|...    2.07166 in (-7,7)
#                                   dp_on6 ..|.......   -3.65269 in (-7,7)
#                                   dp_on7 ........|.    5.20461 in (-7,7)
#                                   dp_on8 .......|..    3.05368 in (-7,7)
#                                   vf_on1 |......... -0.000388032 in (-0.001,0.1)
#                                   vf_on2 |.........  0.0243012 in (-0.001,0.4)
#                                   vf_on3 |.........  0.0392614 in (-0.001,0.5)
#                                   vf_on4 |......... 0.00276528 in (-0.001,0.4)
#                                   vf_on5 .|........  0.0771454 in (-0.001,0.4)
#                                   vf_on6 .|........   0.057724 in (-0.001,0.4)
#                                   vf_on7 |.........   0.013405 in (-0.001,0.4)
#                                frac2_on0 .........|   0.994131 in (0,1)
#                                frac2_on1 .|........   0.131596 in (0,1)
#                                frac2_on2 .|........   0.198737 in (0,1)
#                                frac2_on3 ....|.....    0.46263 in (0,1)
#                                frac2_on4 ..|.......    0.20962 in (0,1)
#                                frac2_on5 .|........   0.119255 in (0,1)
#                                frac2_on6 |.........  0.0251001 in (0,1)
#                                frac2_on7 |.........  0.0991725 in (0,1)
#                                 rho_SiOx ..|.......    3.33859 in (3.2,3.8)
#                                   rho_Cr .......|..     3.8062 in (2.7,4.25)
#                                   rho_Au ...|......    4.43664 in (4.2,4.8)
#                               rho_solv_0 .........|    6.28762 in (5.8,6.34)
#                               rho_solv_1 |.........  -0.534264 in (-0.56,-0.1)
#                               rho_solv_2 |.........  -0.557353 in (-0.56,-0.1)
#                               rho_solv_3 ........|.       6.28 in (5.8,6.34)
#                             global_rough .|........    3.83535 in (1,25)
#                              rough_cr_au .........|    9.15352 in (1,10)
#                                    sigma ........|.    4.46337 in (2,5)
#                             thetaoffset0 ....|..... -0.00133542 in (-0.01,0.01)
#                             background_0 ...|......   -7.61277 in (-9,-5)
#                             background_1 ........|.   -5.66373 in (-9,-5)
#                             background_2 ........|.   -5.64104 in (-9,-5)
#                             background_3 ...|......   -7.59052 in (-9,-5)
# step 15 cost 6.07(14)
# step 16 cost 6.07(14)
# step 17 cost 6.07(14)
# step 18 cost 6.07(14)
# step 19 cost 6.07(14)
# step 20 cost 6.07(14)
# step 21 cost 6.07(14)
# step 22 cost 6.07(14)
# step 23 cost 6.07(14)
# step 24 cost 6.07(14)
# step 25 cost 6.07(14)
# step 26 cost 6.07(14)
#                                  d_oxide ......|...    27.1386 in (5,40)
#                                     d_Cr |.........    12.0045 in (10,60)
#                                   d_gold ...|......    140.085 in (120,180)
#                                 l_tether |.........    6.15699 in (6,18)
#                                 l_lipid1 ....|.....    14.3227 in (8,22)
#                                 l_lipid2 ..|.......    10.4945 in (7,20)
#                        dl_lipid_gcrinse1 .......|..    0.12527 in (-3,1)
#                                nf_tether ........|.   0.914454 in (0.4,1)
#                              mult_tether |.........   0.110863 in (0.1,4)
#                               vf_bilayer .........|   0.999771 in (0.8,1)
#                      vf_bilayer_gcrinse1 .........|   0.999113 in (0.6,1)
#                          fraction_rinse2 .........|    0.96389 in (0.5,1)
#                                   dp_on0 |.........   -5.08019 in (-7,15)
#                                   dp_on1 ..|.......   -3.04115 in (-7,7)
#                                   dp_on2 ....|.....  -0.795635 in (-7,7)
#                                   dp_on3 .|........   -4.21816 in (-7,7)
#                                   dp_on4 .|........   -5.39244 in (-7,7)
#                                   dp_on5 ......|...    2.07166 in (-7,7)
#                                   dp_on6 ..|.......   -3.65269 in (-7,7)
#                                   dp_on7 ........|.    5.20461 in (-7,7)
#                                   dp_on8 .......|..    3.05368 in (-7,7)
#                                   vf_on1 |......... -0.000388032 in (-0.001,0.1)
#                                   vf_on2 |.........  0.0243012 in (-0.001,0.4)
#                                   vf_on3 |.........  0.0392614 in (-0.001,0.5)
#                                   vf_on4 |......... 0.00276528 in (-0.001,0.4)
#                                   vf_on5 .|........  0.0771454 in (-0.001,0.4)
#                                   vf_on6 .|........   0.057724 in (-0.001,0.4)
#                                   vf_on7 |.........   0.013405 in (-0.001,0.4)
#                                frac2_on0 .........|   0.994131 in (0,1)
#                                frac2_on1 .|........   0.131596 in (0,1)
#                                frac2_on2 .|........   0.198737 in (0,1)
#                                frac2_on3 ....|.....    0.46263 in (0,1)
#                                frac2_on4 ..|.......    0.20962 in (0,1)
#                                frac2_on5 .|........   0.119255 in (0,1)
#                                frac2_on6 |.........  0.0251001 in (0,1)
#                                frac2_on7 |.........  0.0991725 in (0,1)
#                                 rho_SiOx ..|.......    3.33859 in (3.2,3.8)
#                                   rho_Cr .......|..     3.8062 in (2.7,4.25)
#                                   rho_Au ...|......    4.43664 in (4.2,4.8)
#                               rho_solv_0 .........|    6.28762 in (5.8,6.34)
#                               rho_solv_1 |.........  -0.534264 in (-0.56,-0.1)
#                               rho_solv_2 |.........  -0.557353 in (-0.56,-0.1)
#                               rho_solv_3 ........|.       6.28 in (5.8,6.34)
#                             global_rough .|........    3.83535 in (1,25)
#                              rough_cr_au .........|    9.15352 in (1,10)
#                                    sigma ........|.    4.46337 in (2,5)
#                             thetaoffset0 ....|..... -0.00133542 in (-0.01,0.01)
#                             background_0 ...|......   -7.61277 in (-9,-5)
#                             background_1 ........|.   -5.66373 in (-9,-5)
#                             background_2 ........|.   -5.64104 in (-9,-5)
#                             background_3 ...|......   -7.59052 in (-9,-5)
# step 27 cost 6.07(14)
# step 28 cost 6.07(14)
# step 29 cost 6.07(14)
# step 30 cost 6.07(14)
# step 31 cost 6.07(14)
# step 32 cost 6.07(14)
# step 33 cost 6.07(14)
# step 34 cost 6.07(14)
# step 35 cost 6.07(14)
# step 36 cost 6.07(14)
# step 37 cost 6.07(14)
# step 38 cost 6.07(14)
# step 39 cost 6.07(14)
#                                  d_oxide ......|...    27.1386 in (5,40)
#                                     d_Cr |.........    12.0045 in (10,60)
#                                   d_gold ...|......    140.085 in (120,180)
#                                 l_tether |.........    6.15699 in (6,18)
#                                 l_lipid1 ....|.....    14.3227 in (8,22)
#                                 l_lipid2 ..|.......    10.4945 in (7,20)
#                        dl_lipid_gcrinse1 .......|..    0.12527 in (-3,1)
#                                nf_tether ........|.   0.914454 in (0.4,1)
#                              mult_tether |.........   0.110863 in (0.1,4)
#                               vf_bilayer .........|   0.999771 in (0.8,1)
#                      vf_bilayer_gcrinse1 .........|   0.999113 in (0.6,1)
#                          fraction_rinse2 .........|    0.96389 in (0.5,1)
#                                   dp_on0 |.........   -5.08019 in (-7,15)
#                                   dp_on1 ..|.......   -3.04115 in (-7,7)
#                                   dp_on2 ....|.....  -0.795635 in (-7,7)
#                                   dp_on3 .|........   -4.21816 in (-7,7)
#                                   dp_on4 .|........   -5.39244 in (-7,7)
#                                   dp_on5 ......|...    2.07166 in (-7,7)
#                                   dp_on6 ..|.......   -3.65269 in (-7,7)
#                                   dp_on7 ........|.    5.20461 in (-7,7)
#                                   dp_on8 .......|..    3.05368 in (-7,7)
#                                   vf_on1 |......... -0.000388032 in (-0.001,0.1)
#                                   vf_on2 |.........  0.0243012 in (-0.001,0.4)
#                                   vf_on3 |.........  0.0392614 in (-0.001,0.5)
#                                   vf_on4 |......... 0.00276528 in (-0.001,0.4)
#                                   vf_on5 .|........  0.0771454 in (-0.001,0.4)
#                                   vf_on6 .|........   0.057724 in (-0.001,0.4)
#                                   vf_on7 |.........   0.013405 in (-0.001,0.4)
#                                frac2_on0 .........|   0.994131 in (0,1)
#                                frac2_on1 .|........   0.131596 in (0,1)
#                                frac2_on2 .|........   0.198737 in (0,1)
#                                frac2_on3 ....|.....    0.46263 in (0,1)
#                                frac2_on4 ..|.......    0.20962 in (0,1)
#                                frac2_on5 .|........   0.119255 in (0,1)
#                                frac2_on6 |.........  0.0251001 in (0,1)
#                                frac2_on7 |.........  0.0991725 in (0,1)
#                                 rho_SiOx ..|.......    3.33859 in (3.2,3.8)
#                                   rho_Cr .......|..     3.8062 in (2.7,4.25)
#                                   rho_Au ...|......    4.43664 in (4.2,4.8)
#                               rho_solv_0 .........|    6.28762 in (5.8,6.34)
#                               rho_solv_1 |.........  -0.534264 in (-0.56,-0.1)
#                               rho_solv_2 |.........  -0.557353 in (-0.56,-0.1)
#                               rho_solv_3 ........|.       6.28 in (5.8,6.34)
#                             global_rough .|........    3.83535 in (1,25)
#                              rough_cr_au .........|    9.15352 in (1,10)
#                                    sigma ........|.    4.46337 in (2,5)
#                             thetaoffset0 ....|..... -0.00133542 in (-0.01,0.01)
#                             background_0 ...|......   -7.61277 in (-9,-5)
#                             background_1 ........|.   -5.66373 in (-9,-5)
#                             background_2 ........|.   -5.64104 in (-9,-5)
#                             background_3 ...|......   -7.59052 in (-9,-5)
# step 40 cost 6.07(14)
# step 41 cost 6.07(14)
# step 42 cost 6.07(14)
# step 43 cost 6.07(14)
# step 44 cost 6.07(14)
# step 45 cost 6.07(14)
# step 46 cost 6.07(14)
# step 47 cost 6.07(14)
# step 48 cost 6.07(14)
# step 49 cost 6.07(14)
# step 50 cost 6.07(14)
# step 51 cost 6.07(14)
#                                  d_oxide ......|...    27.1386 in (5,40)
#                                     d_Cr |.........    12.0045 in (10,60)
#                                   d_gold ...|......    140.085 in (120,180)
#                                 l_tether |.........    6.15699 in (6,18)
#                                 l_lipid1 ....|.....    14.3227 in (8,22)
#                                 l_lipid2 ..|.......    10.4945 in (7,20)
#                        dl_lipid_gcrinse1 .......|..    0.12527 in (-3,1)
#                                nf_tether ........|.   0.914454 in (0.4,1)
#                              mult_tether |.........   0.110863 in (0.1,4)
#                               vf_bilayer .........|   0.999771 in (0.8,1)
#                      vf_bilayer_gcrinse1 .........|   0.999113 in (0.6,1)
#                          fraction_rinse2 .........|    0.96389 in (0.5,1)
#                                   dp_on0 |.........   -5.08019 in (-7,15)
#                                   dp_on1 ..|.......   -3.04115 in (-7,7)
#                                   dp_on2 ....|.....  -0.795635 in (-7,7)
#                                   dp_on3 .|........   -4.21816 in (-7,7)
#                                   dp_on4 .|........   -5.39244 in (-7,7)
#                                   dp_on5 ......|...    2.07166 in (-7,7)
#                                   dp_on6 ..|.......   -3.65269 in (-7,7)
#                                   dp_on7 ........|.    5.20461 in (-7,7)
#                                   dp_on8 .......|..    3.05368 in (-7,7)
#                                   vf_on1 |......... -0.000388032 in (-0.001,0.1)
#                                   vf_on2 |.........  0.0243012 in (-0.001,0.4)
#                                   vf_on3 |.........  0.0392614 in (-0.001,0.5)
#                                   vf_on4 |......... 0.00276528 in (-0.001,0.4)
#                                   vf_on5 .|........  0.0771454 in (-0.001,0.4)
#                                   vf_on6 .|........   0.057724 in (-0.001,0.4)
#                                   vf_on7 |.........   0.013405 in (-0.001,0.4)
#                                frac2_on0 .........|   0.994131 in (0,1)
#                                frac2_on1 .|........   0.131596 in (0,1)
#                                frac2_on2 .|........   0.198737 in (0,1)
#                                frac2_on3 ....|.....    0.46263 in (0,1)
#                                frac2_on4 ..|.......    0.20962 in (0,1)
#                                frac2_on5 .|........   0.119255 in (0,1)
#                                frac2_on6 |.........  0.0251001 in (0,1)
#                                frac2_on7 |.........  0.0991725 in (0,1)
#                                 rho_SiOx ..|.......    3.33859 in (3.2,3.8)
#                                   rho_Cr .......|..     3.8062 in (2.7,4.25)
#                                   rho_Au ...|......    4.43664 in (4.2,4.8)
#                               rho_solv_0 .........|    6.28762 in (5.8,6.34)
#                               rho_solv_1 |.........  -0.534264 in (-0.56,-0.1)
#                               rho_solv_2 |.........  -0.557353 in (-0.56,-0.1)
#                               rho_solv_3 ........|.       6.28 in (5.8,6.34)
#                             global_rough .|........    3.83535 in (1,25)
#                              rough_cr_au .........|    9.15352 in (1,10)
#                                    sigma ........|.    4.46337 in (2,5)
#                             thetaoffset0 ....|..... -0.00133542 in (-0.01,0.01)
#                             background_0 ...|......   -7.61277 in (-9,-5)
#                             background_1 ........|.   -5.66373 in (-9,-5)
#                             background_2 ........|.   -5.64104 in (-9,-5)
#                             background_3 ...|......   -7.59052 in (-9,-5)
# step 52 cost 6.07(14)
# step 53 cost 6.07(14)
# step 54 cost 6.07(14)
# step 55 cost 6.07(14)
# step 56 cost 6.07(14)
# step 57 cost 6.07(14)
# step 58 cost 6.07(14)
# step 59 cost 6.07(14)
# step 60 cost 6.07(14)
# step 61 cost 6.07(14)
# -- Model 0 kr031.refl
# [0] = d_oxide = 27.1386 in [5,40]
# [1] = d_Cr = 12.0045 in [10,60]
# [2] = d_gold = 140.085 in [120,180]
# [3] = l_tether = 6.15699 in [6,18]
# [4] = l_lipid1 = 14.3227 in [8,22]
# [5] = l_lipid2 = 10.4945 in [7,20]
# [6] = dl_lipid_gcrinse1 = 0.12527 in [-3,1]
# [7] = nf_tether = 0.914454 in [0.4,1]
# [8] = mult_tether = 0.110863 in [0.1,4]
# [9] = vf_bilayer = 0.999771 in [0.8,1]
# [10] = vf_bilayer_gcrinse1 = 0.999113 in [0.6,1]
# [11] = fraction_rinse2 = 0.96389 in [0.5,1]
# [12] = dp_on0 = -5.08019 in [-7,15]
# [13] = dp_on1 = -3.04115 in [-7,7]
# [14] = dp_on2 = -0.795635 in [-7,7]
# [15] = dp_on3 = -4.21816 in [-7,7]
# [16] = dp_on4 = -5.39244 in [-7,7]
# [17] = dp_on5 = 2.07166 in [-7,7]
# [18] = dp_on6 = -3.65269 in [-7,7]
# [19] = dp_on7 = 5.20461 in [-7,7]
# [20] = dp_on8 = 3.05368 in [-7,7]
# [21] = vf_on1 = -0.000388032 in [-0.001,0.1]
# [22] = vf_on2 = 0.0243012 in [-0.001,0.4]
# [23] = vf_on3 = 0.0392614 in [-0.001,0.5]
# [24] = vf_on4 = 0.00276528 in [-0.001,0.4]
# [25] = vf_on5 = 0.0771454 in [-0.001,0.4]
# [26] = vf_on6 = 0.057724 in [-0.001,0.4]
# [27] = vf_on7 = 0.013405 in [-0.001,0.4]
# [28] = frac2_on0 = 0.994131 in [0,1]
# [29] = frac2_on1 = 0.131596 in [0,1]
# [30] = frac2_on2 = 0.198737 in [0,1]
# [31] = frac2_on3 = 0.46263 in [0,1]
# [32] = frac2_on4 = 0.20962 in [0,1]
# [33] = frac2_on5 = 0.119255 in [0,1]
# [34] = frac2_on6 = 0.0251001 in [0,1]
# [35] = frac2_on7 = 0.0991725 in [0,1]
# [36] = rho_SiOx = 3.33859 in [3.2,3.8]
# [37] = rho_Cr = 3.8062 in [2.7,4.25]
# [38] = rho_Au = 4.43664 in [4.2,4.8]
# [39] = rho_solv_0 = 6.28762 in [5.8,6.34]
# [40] = rho_solv_1 = -0.534264 in [-0.56,-0.1]
# [41] = rho_solv_2 = -0.557353 in [-0.56,-0.1]
# [42] = rho_solv_3 = 6.28 in [5.8,6.34]
# [43] = global_rough = 3.83535 in [1,25]
# [44] = rough_cr_au = 9.15352 in [1,10]
# [45] = sigma = 4.46337 in [2,5]
# [46] = thetaoffset0 = -0.00133542 in [-0.01,0.01]
# [47] = background_0 = -7.61277 in [-9,-5]
# [48] = background_1 = -5.66373 in [-9,-5]
# [49] = background_2 = -5.64104 in [-9,-5]
# [50] = background_3 = -7.59052 in [-9,-5]
#
# [chisq=4.98(49), nllf=279.076]
# -- Model 1 kr032.refl
# None
# [chisq=5.4152(89), nllf=303.254]
# -- Model 2 kr035.refl
# None
# [chisq=4.5909(89), nllf=257.093]
# -- Model 3 kr036.refl
# None
# [chisq=6.5405(89), nllf=366.268]
# [overall chisq=6.07(14), nllf=1205.69]
#               Parameter       mean  median    best [   68% interval] [   95% interval]
#  1              d_oxide     23(10)   22.98   27.14 [   10.7    34.9] [    5.9    39.2]
#  2                 d_Cr     35(15)   35.64   12.00 [   18.0    52.6] [   11.3    58.7]
#  3               d_gold    150(18)  150.24  140.09 [  129.0   170.9] [  121.5   178.6]
#  4             l_tether   12.0(35)   11.88    6.16 [    7.8    16.2] [    6.3    17.8]
#  5             l_lipid1   15.1(41)   15.08   14.32 [   10.2    19.9] [    8.3    21.7]
#  6             l_lipid2   13.4(38)   13.41   10.49 [    8.9    17.9] [    7.3    19.7]
#  7    dl_lipid_gcrinse1   -1.0(12)  -1.020   0.125 [  -2.36    0.37] [  -2.90    0.91]
#  8            nf_tether   0.70(17)   0.702   0.914 [   0.49    0.91] [   0.41    0.99]
#  9          mult_tether    2.0(11)   2.039   0.111 [   0.72    3.37] [   0.20    3.91]
# 10           vf_bilayer  0.900(58)   0.899   1.000 [   0.83    0.97] [   0.81    1.00]
# 11  vf_bilayer_gcrinse1   0.80(12)   0.802   0.999 [   0.66    0.94] [   0.61    0.99]
# 12      fraction_rinse2   0.75(15)   0.753   0.964 [   0.58    0.92] [   0.51    0.99]
# 13               dp_on0    4.1(64)    4.20   -5.08 [   -3.5    11.6] [   -6.4    14.5]
# 14               dp_on1    0.1(41)    0.08   -3.04 [   -4.8     5.0] [   -6.6     6.7]
# 15               dp_on2   -0.1(41)   -0.09   -0.80 [   -4.9     4.9] [   -6.7     6.6]
# 16               dp_on3    0.0(41)    0.05   -4.22 [   -4.8     5.0] [   -6.7     6.6]
# 17               dp_on4    0.0(41)    0.05   -5.39 [   -4.9     4.9] [   -6.7     6.7]
# 18               dp_on5   -0.1(41)   -0.20    2.07 [   -4.9     4.8] [   -6.7     6.7]
# 19               dp_on6   -0.0(41)   -0.02   -3.65 [   -4.9     4.8] [   -6.7     6.7]
# 20               dp_on7    0.0(41)   -0.05    5.20 [   -4.8     4.9] [   -6.7     6.7]
# 21               dp_on8   -0.1(41)   -0.13    3.05 [   -4.9     4.8] [   -6.7     6.7]
# 22               vf_on1  49(30)e-3  0.0491 -0.0004 [  0.014   0.084] [  0.001   0.098]
# 23               vf_on2   0.20(12)   0.198   0.024 [   0.06    0.34] [   0.01    0.39]
# 24               vf_on3   0.25(15)   0.255   0.039 [   0.08    0.43] [   0.01    0.49]
# 25               vf_on4   0.20(12)   0.197   0.003 [   0.06    0.34] [   0.01    0.39]
# 26               vf_on5   0.20(12)   0.200   0.077 [   0.06    0.34] [   0.01    0.39]
# 27               vf_on6   0.20(12)   0.198   0.058 [   0.06    0.34] [   0.01    0.39]
# 28               vf_on7   0.20(12)   0.197   0.013 [   0.06    0.34] [   0.01    0.39]
# 29            frac2_on0   0.50(29)   0.497   0.994 [   0.14    0.85] [   0.02    0.97]
# 30            frac2_on1   0.50(29)   0.499   0.132 [   0.16    0.84] [   0.03    0.98]
# 31            frac2_on2   0.50(29)   0.494   0.199 [   0.16    0.85] [   0.03    0.98]
# 32            frac2_on3   0.50(29)   0.498   0.463 [   0.16    0.84] [   0.02    0.98]
# 33            frac2_on4   0.50(29)   0.506   0.210 [   0.16    0.84] [   0.02    0.97]
# 34            frac2_on5   0.50(29)   0.502   0.119 [   0.16    0.85] [   0.02    0.98]
# 35            frac2_on6   0.50(29)   0.494   0.025 [   0.15    0.85] [   0.03    0.98]
# 36            frac2_on7   0.50(29)   0.494   0.099 [   0.16    0.83] [   0.02    0.97]
# 37             rho_SiOx   3.50(18)   3.502   3.339 [   3.29    3.71] [   3.21    3.79]
# 38               rho_Cr   3.48(45)   3.478   3.806 [   2.94    4.01] [   2.74    4.21]
# 39               rho_Au   4.50(18)   4.502   4.437 [   4.29    4.71] [   4.21    4.79]
# 40           rho_solv_0   6.07(16)   6.079   6.288 [   5.89    6.26] [   5.81    6.33]
# 41           rho_solv_1  -0.33(13)  -0.330  -0.534 [  -0.49   -0.17] [  -0.55   -0.11]
# 42           rho_solv_2  -0.33(13)  -0.325  -0.557 [  -0.49   -0.17] [  -0.55   -0.11]
# 43           rho_solv_3   6.07(16)   6.075   6.280 [   5.89    6.26] [   5.81    6.33]
# 44         global_rough   13.0(70)   13.03    3.84 [    4.7    21.4] [    1.6    24.4]
# 45          rough_cr_au    5.5(26)   5.484   9.154 [   2.41    8.61] [   1.22    9.78]
# 46                sigma   3.51(88)   3.509   4.463 [   2.46    4.57] [   2.07    4.93]
# 47         thetaoffset0 0.0(58)e-3 -0.0000 -0.0013 [ -0.007   0.007] [ -0.010   0.010]
# 48         background_0   -7.0(12)  -6.987  -7.613 [  -8.38   -5.63] [  -8.91   -5.09]
# 49         background_1   -7.0(12)  -7.021  -5.664 [  -8.42   -5.61] [  -8.91   -5.09]
# 50         background_2   -7.0(12)  -7.011  -5.641 [  -8.38   -5.62] [  -8.90   -5.10]
# 51         background_3   -7.0(12)  -7.032  -7.591 [  -8.40   -5.62] [  -8.90   -5.09]
#
# Statistics and plots based on 31110 samples (100.0% of total samples drawn)
# /Users/frank/opt/anaconda3/envs/Python37/lib/python3.7/site-packages/bumps/wsolve.py:243: RuntimeWarning: divide by zero encountered in true_divide
#   A, y = A/dy, y/dy

# %% [markdown]
# # Simulation Parameter Setup
#
# Requires all parameters of the model

# %%
# %%writefile simpar.dat
# d_oxide 27.1385608994351
# d_Cr 12.0045081882702
# d_gold 140.085054050314
# l_tether 6.15699252838842
# l_lipid1 14.3227020845953
# l_lipid2 10.4945223924891
# dl_lipid_gcrinse1 0.125269558010402
# nf_tether 0.914453587700949
# mult_tether 1.15817117378898
# vf_bilayer 0.999771193924136
# vf_bilayer_gcrinse1 0.999112772552033
# fraction_rinse2 0.963889796755209
# dp_on0 -5.08018692755215
# dp_on1 -3.0411460131031
# dp_on2 -0.795635069335647
# dp_on3 -4.21815619677066
# dp_on4 -5.39244018573827
# dp_on5 2.07165524339043
# dp_on6 -3.65269205349576
# dp_on7 5.20460893426816
# dp_on8 3.05367888205943
# vf_on1 -0.000388032438721351
# vf_on2 0.0243012193412938
# vf_on3 0.0392613731348821
# vf_on4 0.00276528066509467
# vf_on5 0.0771453818074722
# vf_on6 0.057724000404784
# vf_on7 0.0134049690450054
# frac2_on0 0.994131099540302
# frac2_on1 0.131595733681778
# frac2_on2 0.198736670207635
# frac2_on3 0.462629684267791
# frac2_on4 0.209619582294796
# frac2_on5 0.119254915599886
# frac2_on6 0.0251001206065209
# frac2_on7 0.0991724640806507
# rho_SiOx 3.33858816434842
# rho_Cr 3.80619808359983
# rho_Au 4.43663614249802
# rho_solv_0 6.28762463860248
# rho_solv_1 -0.53426429275032
# rho_solv_2 -0.557353147004738
# rho_solv_3 6.27999900375132
# global_rough 3.83535194725321
# rough_cr_au 9.15351977082056
# sigma 4.46336922363305
# thetaoffset0 -0.00133541877727692
# background_0 -7.6127717506753
# background_1 -5.66373077514838
# background_2 -5.64104256585764
# background_3 -7.59051691573969
# Out:
# Overwriting simpar.dat

# %%
fitobj.fnSimulateData()
# Out:
# d_oxide 27.1385608994351
# d_Cr 12.0045081882702
# d_gold 140.085054050314
# l_tether 6.15699252838842
# l_lipid1 14.3227020845953
# l_lipid2 10.4945223924891
# dl_lipid_gcrinse1 0.125269558010402
# nf_tether 0.914453587700949
# mult_tether 1.15817117378898
# vf_bilayer 0.999771193924136
# vf_bilayer_gcrinse1 0.999112772552033
# fraction_rinse2 0.963889796755209
# dp_on0 -5.08018692755215
# dp_on1 -3.0411460131031
# dp_on2 -0.795635069335647
# dp_on3 -4.21815619677066
# dp_on4 -5.39244018573827
# dp_on5 2.07165524339043
# dp_on6 -3.65269205349576
# dp_on7 5.20460893426816
# dp_on8 3.05367888205943
# vf_on1 -0.0003880324387213
# vf_on2 0.0243012193412938
# vf_on3 0.0392613731348821
# vf_on4 0.0027652806650946
# vf_on5 0.0771453818074722
# vf_on6 0.057724000404784
# vf_on7 0.0134049690450054
# frac2_on0 0.994131099540302
# frac2_on1 0.131595733681778
# frac2_on2 0.198736670207635
# frac2_on3 0.462629684267791
# frac2_on4 0.209619582294796
# frac2_on5 0.119254915599886
# frac2_on6 0.0251001206065209
# frac2_on7 0.0991724640806507
# rho_SiOx 3.33858816434842 => changed to 3.3385881643484197e-06
# rho_Cr 3.80619808359983 => changed to 3.8061980835998298e-06
# rho_Au 4.43663614249802 => changed to 4.43663614249802e-06
# rho_solv_0 6.28762463860248 => changed to 6.28762463860248e-06
# rho_solv_1 -0.53426429275032 => changed to -5.3426429275032e-07
# rho_solv_2 -0.557353147004738 => changed to -5.57353147004738e-07
# rho_solv_3 6.27999900375132 => changed to 6.27999900375132e-06
# global_rough 3.83535194725321
# rough_cr_au 9.15351977082056
# sigma 4.46336922363305
# thetaoffset0 -0.0013354187772769
# background_0 -7.6127717506753
# background_1 -5.66373077514838
# background_2 -5.64104256585764
# background_3 -7.59051691573969
# g++  -g -O2 -Wall  -fPIC -DUSE_DOUBLE -DReal=double -DHAVE_CONFIG_H -I/Users/frank/danse/refl1d/garefl/boxmin -I/Users/frank/danse/refl1d/garefl/model1d -I/Users/frank/danse/refl1d/garefl/src -c setup.cc -o setup.o
# In file included from setup.cc:9:
# ./molgroups.cc:79:25: warning: variable 'dUpperLimit' set but not used [-Wunused-but-set-variable]
#     double dLowerLimit, dUpperLimit, d, dmirror, dAreaInc, dnSLDInc;
#                         ^
# ./molgroups.cc:3088:17: warning: variable 'V_EO' set but not used [-Wunused-but-set-variable]
#     double l_EO,V_EO;
#                 ^
# ./molgroups.cc:3091:18: warning: variable 'V_bME' set but not used [-Wunused-but-set-variable]
#     double l_bME,V_bME;
#                  ^
# ./molgroups.cc:3091:12: warning: variable 'l_bME' set but not used [-Wunused-but-set-variable]
#     double l_bME,V_bME;
#            ^
# ./molgroups.cc:3085:12: warning: variable 'V_tg' set but not used [-Wunused-but-set-variable]
#     double V_tg;
#            ^
# ./molgroups.cc:3528:12: warning: variable 'V_tg' set but not used [-Wunused-but-set-variable]
#     double V_tg;
#            ^
# ./molgroups.cc:3534:18: warning: variable 'V_bME' set but not used [-Wunused-but-set-variable]
#     double l_bME,V_bME;
#                  ^
# ./molgroups.cc:3534:12: warning: variable 'l_bME' set but not used [-Wunused-but-set-variable]
#     double l_bME,V_bME;
#            ^
# ./molgroups.cc:3531:17: warning: variable 'V_EO' set but not used [-Wunused-but-set-variable]
#     double l_EO,V_EO;
#                 ^
# ./molgroups.cc:3890:17: warning: variable 'V_EO' set but not used [-Wunused-but-set-variable]
#     double l_EO,V_EO;
#                 ^
# ./molgroups.cc:3887:12: warning: variable 'V_tg' set but not used [-Wunused-but-set-variable]
#     double V_tg;
#            ^
# ./molgroups.cc:3893:12: warning: variable 'l_bME' set but not used [-Wunused-but-set-variable]
#     double l_bME,V_bME;
#            ^
# ./molgroups.cc:3893:18: warning: variable 'V_bME' set but not used [-Wunused-but-set-variable]
#     double l_bME,V_bME;
#                  ^
# setup.cc:227:9: warning: unused variable 'iPeaked' [-Wunused-variable]
#     int iPeaked,iMaxPeak, i, k, i2, wait;
#         ^
# setup.cc:227:17: warning: unused variable 'iMaxPeak' [-Wunused-variable]
#     int iPeaked,iMaxPeak, i, k, i2, wait;
#                 ^
# setup.cc:227:33: warning: unused variable 'i2' [-Wunused-variable]
#     int iPeaked,iMaxPeak, i, k, i2, wait;
#                                 ^
# setup.cc:227:37: warning: unused variable 'wait' [-Wunused-variable]
#     int iPeaked,iMaxPeak, i, k, i2, wait;
#                                     ^
# setup.cc:228:14: warning: unused variable 'pars' [-Wunused-variable]
#     fitpars *pars = &fit[0].pars;
#              ^
# 18 warnings generated.
# cd /Users/frank/danse/refl1d/garefl/boxmin && /Applications/Xcode.app/Contents/Developer/usr/bin/make
# make[1]: Nothing to be done for `all'.
# cd /Users/frank/danse/refl1d/garefl/model1d && /Applications/Xcode.app/Contents/Developer/usr/bin/make
# make[1]: Nothing to be done for `all'.
# cd /Users/frank/danse/refl1d/garefl/src && /Applications/Xcode.app/Contents/Developer/usr/bin/make
# make[1]: Nothing to be done for `all'.
# g++    -fPIC -o fit setup.o /Users/frank/danse/refl1d/garefl/src/ga_simul.o /Users/frank/danse/refl1d/garefl/src/ga.o -L/Users/frank/danse/refl1d/garefl/model1d -lrefl -L/Users/frank/danse/refl1d/garefl/boxmin -lboxmin  -lm
# g++ -shared -o model.so setup.o /Users/frank/danse/refl1d/garefl/src/refl1d.o -L/Users/frank/danse/refl1d/garefl/model1d -lrefl  -lm
# chisq_0 = 4.98349
# chisq_1 = 5.41525
# chisq_2 = 4.59094
# chisq_3 = 6.5405
# chisq = 6.07401

# %%
import pandas

fig, ax = plt.subplots()

i = 0
while os.path.isfile('sim' + str(i) + '.dat'):
    simdata = pandas.read_csv('sim' + str(i) + '.dat', sep=' ', skip_blank_lines=True,comment='#', names=['Q', 'R', 'dR'])
    ax.errorbar(simdata['Q'], simdata['R'], simdata['dR'], label="sim " + str(i))
    i += 1

ax.legend(fontsize=8)
ax.set_ylabel("R", fontsize=10)
ax.set_yscale('log')
ax.minorticks_on()
ax.tick_params(which="both", direction="in", labelsize=10)
ax.tick_params(bottom=True, top=True, left=True, right=True, which="both")
ax.set_xlabel("$q_z$ (Å$^{-1}$)", fontsize=10)
ax.figure.set_size_inches(12.5, 7.5)
plt.savefig(store + "/model_comparison.png", facecolor="white")
plt.show()
